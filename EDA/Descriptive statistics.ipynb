# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[:, 10:35]
# Out:
#                                                   caption  is_ad  Post ID  \
# 0       Preseason game 2 outfit.Vintage hat (which I t...    NaN   184752
# 1       Took Heidi to meet Santa today at @petsmart. S...    NaN   184764
# 2       4/18/18- Game 2 Rockets vs Wolves. Light up ha...    NaN   184776
# 3       4/18/18- Game 2 vs T-Wolves pics. Section 107 ...  False   184777
# 4       Season opener outfit. The left is kind of what...    NaN   184780
# ...                                                   ...    ...      ...
# 196174  Making 2018 my epic skin year. I’ve locked dow...  False  1519643
# 196175  The perfect storm ☁️ wearing @boohoo rib knit ...    NaN  1519644
# 196176  Of all the Christmas movies, I relate to the G...    NaN  1519650
# 196177  Werbung\nGuten Morgen ihr Lieben. Ich gehe mal...    NaN  1403159
# 196178  Werbung\nEinen wunderschönen guten Morgen aus ...  False  1403164
#
#         Sponsorship label                 JSON file              Image files  \
# 0                       0  1354915397698488656.json  1354915397698488656.jpg
# 1                       0  1666974101448132749.json  1666974101448132749.jpg
# 2                       0  1768273356099895999.json  1768273356099895999.jpg
# 3                       0  1770557472379860655.json  1770557376598782147.jpg
# 4                       0  1899586748141399903.json  1899586748141399903.jpg
# ...                   ...                       ...                      ...
# 196174                  0  1689162745453535364.json  1689162599693269884.jpg
# 196175                  0  1695128267039160652.json  1695128267039160652.jpg
# 196176                  0  1926097425697935397.json  1926097425697935397.jpg
# 196177                  0  1717335338709878476.json  1717335338709878476.jpg
# 196178                  0  1768071743865642104.json  1768070774712909654.jpg
#
#               Name  Followers  Followees  Posts  ...  Year  Month Day Hour  \
# 0       Rocketgirl       6453        710   1059  ...  2016     10   6    7
# 1       Rocketgirl       6453        710   1059  ...  2017     12  10   20
# 2       Rocketgirl       6453        710   1059  ...  2018      4  29   15
# 3       Rocketgirl       6453        710   1059  ...  2018      5   2   18
# 4       Rocketgirl       6453        710   1059  ...  2018     10  27   19
# ...            ...        ...        ...    ...  ...   ...    ...  ..  ...
# 196174       Z o e       4487        858    713  ...  2018      1  10   11
# 196175       Z o e       4487        858    713  ...  2018      1  18   17
# 196176       Z o e       4487        858    713  ...  2018     12   3    9
# 196177      Zeynep      19215        401    149  ...  2018      2  18    8
# 196178      Zeynep      19215        401    149  ...  2018      4  29    8
#
#        Day of Week (Number)  Day of Week (String)  Is_English  \
# 0                         3              Thursday        True
# 1                         6                Sunday        True
# 2                         6                Sunday        True
# 3                         2             Wednesday        True
# 4                         5              Saturday        True
# ...                     ...                   ...         ...
# 196174                    2             Wednesday        True
# 196175                    3              Thursday        True
# 196176                    0                Monday        True
# 196177                    6                Sunday       False
# 196178                    6                Sunday       False
#
#         Detected_Language  Image_Count   image_0
# 0                      en            1  0.483804
# 1                      en            1  1.257535
# 2                      en            1  1.015909
# 3                      en            7  0.612580
# 4                      en            1  0.961807
# ...                   ...          ...       ...
# 196174                 en            2  0.160993
# 196175                 en            1  0.337574
# 196176                 en            1  0.860733
# 196177                 de            1  0.039804
# 196178                 de            1  0.701431
#
# [196179 rows x 25 columns]

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts',
                              'Year', 'Month', 'Day of Week (String)', 'Hour', 'Language', 'Is_English', 'Image_Count', 'Sponsorship label', 'is_video', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep #+ text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %%
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  is_video  \
# 0   00_rocketgirl  1354915397698488656         293              6     False
# 1   00_rocketgirl  1666974101448132749          73              2     False
# 2   00_rocketgirl  1768273356099895999         164              4     False
# 4   00_rocketgirl  1899586748141399903         116              2     False
# 9          0hkris  1514786978688118458         269              0     False
# 10         0hkris  1837331879491417999        1065             19     False
# 11         0hkris  1840089921320547693        1242              7     False
# 12         0hkris  1847365723795798774        1346              4     False
# 13        0ldisme  1653111532051112326        1139             28     False
# 14        0ldisme  1708204647056992205        1352             39     False
#
#     Sponsorship label  Followers  Followees  Posts  Year  Month  Hour  \
# 0                   0       6453        710   1059  2016     10     7
# 1                   0       6453        710   1059  2017     12    20
# 2                   0       6453        710   1059  2018      4    15
# 4                   0       6453        710   1059  2018     10    19
# 9                   0      12630       7069    261  2017      5    21
# 10                  0      12630       7069    261  2018      8    21
# 11                  0      12630       7069    261  2018      8    17
# 12                  0      12630       7069    261  2018      8    18
# 13                  0      18583        523    487  2017     11    17
# 14                  0      18583        523    487  2018      2    18
#
#    Day of Week (String)  Is_English  Image_Count
# 0              Thursday        True            1
# 1                Sunday        True            1
# 2                Sunday        True            1
# 4              Saturday        True            1
# 9                Sunday        True            1
# 10             Thursday        True            1
# 11               Monday        True            1
# 12             Thursday        True            1
# 13              Tuesday        True            1
# 14               Monday        True            1

# %% [markdown]
# Numerical columns

# %%
# Specify the columns you want to include in the descriptive statistics
columns_of_interest = ['like_count', 'comment_count', 'Followers', 'Followees', 'Posts']

# Generate descriptive statistics for these columns
descriptive_stats = data_2[columns_of_interest].describe()

# %%
latex_table = descriptive_stats.to_latex(float_format="%.0f")

# %%
print(latex_table)
# Out:
# \begin{tabular}{lrrrrr}
# \toprule
#  & like_count & comment_count & Followers & Followees & Posts \\
# \midrule
# count & 133642 & 133642 & 133642 & 133642 & 133642 \\
# mean & 3926 & 75 & 138656 & 1582 & 1269 \\
# std & 34946 & 917 & 1340448 & 3462 & 1687 \\
# min & 0 & 0 & 198 & 0 & 91 \\
# 25% & 206 & 7 & 7811 & 593 & 469 \\
# 50% & 612 & 24 & 20973 & 995 & 846 \\
# 75% & 1720 & 60 & 62617 & 1881 & 1545 \\
# max & 3850463 & 169030 & 119050781 & 304758 & 127520 \\
# \bottomrule
# \end{tabular}

# %% [markdown]
# Time columns
