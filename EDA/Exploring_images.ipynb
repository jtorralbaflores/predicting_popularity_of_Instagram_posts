# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Load the data
image_matrix = np.load('/content/drive/MyDrive/MSc Thesis Data Science/influencer_brands/images/data120_batch1.npy')
file_names = np.load('/content/drive/MyDrive/MSc Thesis Data Science/influencer_brands/images/filenames_batch1.npy')

# Example: Display the first image
first_image = image_matrix[1024]
plt.imshow(first_image)
plt.title(file_names[1024])
plt.show()

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# Load the data
image_matrix = np.load('/content/drive/MyDrive/MSc Thesis Data Science/influencer_brands/images/data120_batch2.npy')
file_names = np.load('/content/drive/MyDrive/MSc Thesis Data Science/influencer_brands/images/filenames_batch2.npy')

# Example: Display the first image
first_image = image_matrix[0]
plt.imshow(first_image)
plt.title(file_names[0])
plt.show()

# %%
print(file_names)
# Out:
# ['1000147795992383306.jpg' '1000897137384910510.jpg'
#  '1001214191829136169.jpg' ... '1626647444177881121.jpg'
#  '1626667980195957114.jpg' '1626681359185591275.jpg']
