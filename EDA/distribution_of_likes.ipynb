# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# Loading the data
data = pd.read_csv('/content/drive/MyDrive/MSc Thesis Data Science/influencer_brands/Data/Metadata/all_metadata_5.csv', lineterminator='\n')

# %% [markdown]
# Creating like proportion visualizations

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['like_count'], bins=50, kde=True)
plt.title('Distribution of Like Count')
plt.xlabel('Like Count')
plt.ylabel('Frequency')
plt.show()

# %%
top_1_percentile = data['like_count'].quantile(0.99)
top_5_percentile = data['like_count'].quantile(0.95)

print(f"Top 1% of likes start at: {top_1_percentile}")
print(f"Top 5% of likes start at: {top_5_percentile}")
# Out:
# Top 1% of likes start at: 62171.54000000001
# Top 5% of likes start at: 12062.100000000006

# %%
# For dropping top 1% data
trimmed_data = data[data['like_count'] <= top_1_percentile]

plt.figure(figsize=(10, 6))
sns.histplot(trimmed_data['like_count'], bins=50, kde=True)
plt.title('Distribution of Like Count (top 1% of data cutoff)')
plt.xlabel('Like Count')
plt.ylabel('Frequency')
plt.show()

# %%
top_1_percentile = data['like_count'].quantile(0.99)
top_5_percentile = data['like_count'].quantile(0.95)

print(f"Top 1% of likes start at: {top_1_percentile}")
print(f"Top 5% of likes start at: {top_5_percentile}")

# For dropping top 1% data
#trimmed_data = data[data['like_count'] <= top_1_percentile]

# Or, for dropping top 5% data
trimmed_data = data[data['like_count'] <= top_5_percentile]

plt.figure(figsize=(10, 6))
sns.histplot(trimmed_data['like_count'], bins=50, kde=True)
plt.title('')
plt.xlabel('Like Count')
plt.ylabel('Frequency')
# Save the plot as a JPEG file if needed
plt.savefig('/content/drive/MyDrive/Colab Notebooks/MSc thesis/EDA/out/like_distribution.jpg', format='jpg', dpi=300)
plt.show()
# Out:
# Top 1% of likes start at: 62171.54000000001
# Top 5% of likes start at: 12062.100000000006
