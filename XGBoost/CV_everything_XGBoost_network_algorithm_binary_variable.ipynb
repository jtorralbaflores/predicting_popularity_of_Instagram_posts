# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts',
                              'Month', 'Day of Week (String)', 'Hour', 'Language', 'Is_English', 'Image_Count', 'Sponsorship label', 'is_video']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep + text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)
# Out:
#         Username              post_id  like_count  comment_count  is_video  \
# 0  00_rocketgirl  1354915397698488656         293              6     False
# 1  00_rocketgirl  1666974101448132749          73              2     False
# 2  00_rocketgirl  1768273356099895999         164              4     False
# 3  00_rocketgirl  1770557472379860655         474             18     False
# 4  00_rocketgirl  1899586748141399903         116              2     False
# 5         0720_b  1828882589862019412        1835             13     False
# 6         0720_b  1996580229074923796        1170              2     False
# 7         0720_b  2021587997624266181         820              2     False
# 8         0720_b  2021587997624266181         820              2     False
# 9         0hkris  1514786978688118458         269              0     False
#
#    Sponsorship label  Followers  Followees  Posts  Month  ...  text_758  \
# 0                  0       6453        710   1059     10  ... -0.155746
# 1                  0       6453        710   1059     12  ... -0.247792
# 2                  0       6453        710   1059      4  ... -0.089539
# 3                  0       6453        710   1059      5  ... -0.215643
# 4                  0       6453        710   1059     10  ... -0.112963
# 5                  0      31521       2202    601      7  ...  0.013015
# 6                  0      31521       2202    601      3  ...  0.027090
# 7                  0      31521       2202    601      4  ...  0.043861
# 8                  0      31521       2202    601      4  ...  0.043861
# 9                  0      12630       7069    261      5  ... -0.147682
#
#    text_759  text_760  text_761  text_762  text_763  text_764  text_765  \
# 0 -0.017703 -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870
# 1  0.015757 -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263
# 2 -0.097885 -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142
# 3 -0.101936 -0.123704  0.029802  0.113963  0.098773 -0.108283 -0.082098
# 4 -0.036261 -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846
# 5 -0.100801 -0.067726  0.076079  0.248161  0.093687 -0.052417 -0.504811
# 6 -0.154764 -0.085396  0.070190  0.285331  0.098012 -0.022090 -0.441710
# 7 -0.152151 -0.037170  0.045965  0.204610  0.092008 -0.048374 -0.509754
# 8 -0.152151 -0.037170  0.045965  0.204610  0.092008 -0.048374 -0.509754
# 9 -0.036988 -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471
#
#    text_766  text_767
# 0  0.062999  0.075272
# 1 -0.012400  0.147600
# 2  0.094179  0.080168
# 3  0.045219  0.057346
# 4  0.141513  0.093924
# 5  0.080545 -0.086281
# 6  0.055267 -0.116288
# 7  0.074065 -0.092127
# 8  0.074065 -0.092127
# 9  0.012900  0.064740
#
# [10 rows x 2830 columns]

# %%
# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# Columns to one-hot encode
columns_to_encode = ['Month', 'Hour', 'Day of Week (String)', 'Image_Count']

# Apply one-hot encoding
data_2 = pd.get_dummies(data_2, columns=columns_to_encode)

# Find the new one-hot encoded columns
encoded_columns = data_2.columns[data_2.columns.str.startswith(tuple(columns_to_encode))]

# Convert only the new one-hot encoded columns and boolean columns to int
data_2[encoded_columns] = data_2[encoded_columns].astype(int)

# Convert English column to integer
data_2['Is_English'] = data_2['Is_English'].astype(int)
data_2['is_video'] = data_2['is_video'].astype(int)
data_2['Sponsorship label'] = data_2['Sponsorship label'].astype(int)

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Normalize the selected features
    columns_to_normalize = ['Followers', 'Followees', 'Posts']
    scaler = StandardScaler().fit(train_data[columns_to_normalize])
    train_data.loc[:, columns_to_normalize] = scaler.transform(train_data[columns_to_normalize])
    val_data.loc[:, columns_to_normalize] = scaler.transform(val_data[columns_to_normalize])
    test_data.loc[:, columns_to_normalize] = scaler.transform(test_data[columns_to_normalize])

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.33992	val-error:0.35459
# [1]	train-error:0.33286	val-error:0.34850
# [2]	train-error:0.32778	val-error:0.34508
# [3]	train-error:0.32521	val-error:0.34106
# [4]	train-error:0.32236	val-error:0.33935
# [5]	train-error:0.31992	val-error:0.33727
# [6]	train-error:0.31747	val-error:0.33608
# [7]	train-error:0.31667	val-error:0.33616
# [8]	train-error:0.31585	val-error:0.33482
# [9]	train-error:0.31429	val-error:0.33311
# [10]	train-error:0.31194	val-error:0.33229
# [11]	train-error:0.31149	val-error:0.33162
# [12]	train-error:0.30947	val-error:0.33014
# [13]	train-error:0.30808	val-error:0.32895
# [14]	train-error:0.30734	val-error:0.32962
# [15]	train-error:0.30579	val-error:0.32895
# [16]	train-error:0.30453	val-error:0.32977
# [17]	train-error:0.30298	val-error:0.32880
# [18]	train-error:0.30185	val-error:0.32865
# [19]	train-error:0.30099	val-error:0.32887
# [20]	train-error:0.29929	val-error:0.32776
# [21]	train-error:0.29821	val-error:0.32798
# [22]	train-error:0.29720	val-error:0.32635
# [23]	train-error:0.29564	val-error:0.32731
# [24]	train-error:0.29399	val-error:0.32694
# [25]	train-error:0.29250	val-error:0.32553
# [26]	train-error:0.29157	val-error:0.32553
# [27]	train-error:0.29020	val-error:0.32597
# [28]	train-error:0.28900	val-error:0.32716
# [29]	train-error:0.28745	val-error:0.32642
# [30]	train-error:0.28679	val-error:0.32545
# [31]	train-error:0.28623	val-error:0.32426
# [32]	train-error:0.28514	val-error:0.32583
# [33]	train-error:0.28427	val-error:0.32523
# [34]	train-error:0.28319	val-error:0.32545
# [35]	train-error:0.28210	val-error:0.32419
# [36]	train-error:0.28080	val-error:0.32441
# [37]	train-error:0.27967	val-error:0.32404
# [38]	train-error:0.27845	val-error:0.32203
# [39]	train-error:0.27719	val-error:0.32322
# [40]	train-error:0.27608	val-error:0.32196
# [41]	train-error:0.27567	val-error:0.32278
# [42]	train-error:0.27464	val-error:0.32218
# [43]	train-error:0.27354	val-error:0.32189
# [44]	train-error:0.27228	val-error:0.32374
# [45]	train-error:0.27102	val-error:0.32330
# [46]	train-error:0.26975	val-error:0.32203
# [47]	train-error:0.26924	val-error:0.32248
# [48]	train-error:0.26850	val-error:0.32211
# [49]	train-error:0.26714	val-error:0.32255
# [50]	train-error:0.26655	val-error:0.32255
# [51]	train-error:0.26594	val-error:0.32255
# [52]	train-error:0.26486	val-error:0.32337
# [53]	train-error:0.26422	val-error:0.32315
# [54]	train-error:0.26335	val-error:0.32159
# [55]	train-error:0.26255	val-error:0.32129
# [56]	train-error:0.26205	val-error:0.32241
# [57]	train-error:0.26102	val-error:0.32241
# [58]	train-error:0.26008	val-error:0.32084
# [59]	train-error:0.25927	val-error:0.32099
# [60]	train-error:0.25836	val-error:0.32136
# [61]	train-error:0.25737	val-error:0.31966
# [62]	train-error:0.25655	val-error:0.32018
# [63]	train-error:0.25603	val-error:0.31995
# [64]	train-error:0.25525	val-error:0.31847
# [65]	train-error:0.25475	val-error:0.31839
# [66]	train-error:0.25390	val-error:0.31936
# [67]	train-error:0.25312	val-error:0.31876
# [68]	train-error:0.25189	val-error:0.31802
# [69]	train-error:0.25142	val-error:0.31913
# [70]	train-error:0.25073	val-error:0.31943
# [71]	train-error:0.24970	val-error:0.31958
# [72]	train-error:0.24858	val-error:0.31869
# [73]	train-error:0.24769	val-error:0.31832
# [74]	train-error:0.24705	val-error:0.31795
# [75]	train-error:0.24623	val-error:0.31780
# [76]	train-error:0.24546	val-error:0.31780
# [77]	train-error:0.24424	val-error:0.31757
# [78]	train-error:0.24335	val-error:0.31817
# [79]	train-error:0.24273	val-error:0.31906
# [80]	train-error:0.24178	val-error:0.31802
# [81]	train-error:0.24115	val-error:0.31847
# [82]	train-error:0.24055	val-error:0.31913
# [83]	train-error:0.23958	val-error:0.31861
# [84]	train-error:0.23871	val-error:0.31832
# [85]	train-error:0.23841	val-error:0.31839
# [86]	train-error:0.23767	val-error:0.31869
# [87]	train-error:0.23719	val-error:0.31884
# [88]	train-error:0.23644	val-error:0.31861
# [89]	train-error:0.23512	val-error:0.31832
# [90]	train-error:0.23426	val-error:0.31809
# [91]	train-error:0.23351	val-error:0.31757
# [92]	train-error:0.23295	val-error:0.31787
# [93]	train-error:0.23246	val-error:0.31750
# [94]	train-error:0.23153	val-error:0.31780
# [95]	train-error:0.23071	val-error:0.31824
# [96]	train-error:0.22994	val-error:0.31780
# [97]	train-error:0.22917	val-error:0.31824
# [98]	train-error:0.22847	val-error:0.31824
# [99]	train-error:0.22748	val-error:0.31765
# [100]	train-error:0.22708	val-error:0.31817
# [101]	train-error:0.22680	val-error:0.31809
# [102]	train-error:0.22631	val-error:0.31847
# [103]	train-error:0.22519	val-error:0.31876
# [104]	train-error:0.22489	val-error:0.31802
# [105]	train-error:0.22385	val-error:0.31750
# [106]	train-error:0.22333	val-error:0.31683
# [107]	train-error:0.22267	val-error:0.31824
# [108]	train-error:0.22234	val-error:0.31832
# [109]	train-error:0.22109	val-error:0.31839
# [110]	train-error:0.22078	val-error:0.31824
# [111]	train-error:0.22030	val-error:0.31824
# [112]	train-error:0.21936	val-error:0.31854
# [113]	train-error:0.21864	val-error:0.31876
# [114]	train-error:0.21808	val-error:0.31899
# [115]	train-error:0.21751	val-error:0.31802
# [116]	train-error:0.21669	val-error:0.31876
# [117]	train-error:0.21607	val-error:0.31832
# [118]	train-error:0.21528	val-error:0.31765
# [119]	train-error:0.21470	val-error:0.31809
# [120]	train-error:0.21376	val-error:0.31809
# [121]	train-error:0.21321	val-error:0.31824
# [122]	train-error:0.21296	val-error:0.31824
# [123]	train-error:0.21278	val-error:0.31861
# [124]	train-error:0.21205	val-error:0.31884
# [125]	train-error:0.21157	val-error:0.31913
# Accuracy for iteration 1: 0.68
# Iteration 2
# [0]	train-error:0.33598	val-error:0.36167
# [1]	train-error:0.32926	val-error:0.35542
# [2]	train-error:0.32574	val-error:0.35046
# [3]	train-error:0.32298	val-error:0.35138
# [4]	train-error:0.32145	val-error:0.34947
# [5]	train-error:0.32029	val-error:0.34589
# [6]	train-error:0.31787	val-error:0.34558
# [7]	train-error:0.31682	val-error:0.34749
# [8]	train-error:0.31574	val-error:0.34589
# [9]	train-error:0.31378	val-error:0.34688
# [10]	train-error:0.31281	val-error:0.34596
# [11]	train-error:0.31179	val-error:0.34612
# [12]	train-error:0.31047	val-error:0.34695
# [13]	train-error:0.30895	val-error:0.34406
# [14]	train-error:0.30784	val-error:0.34612
# [15]	train-error:0.30636	val-error:0.34413
# [16]	train-error:0.30455	val-error:0.34497
# [17]	train-error:0.30356	val-error:0.34192
# [18]	train-error:0.30237	val-error:0.34162
# [19]	train-error:0.30096	val-error:0.34147
# [20]	train-error:0.29950	val-error:0.34299
# [21]	train-error:0.29833	val-error:0.34124
# [22]	train-error:0.29653	val-error:0.34040
# [23]	train-error:0.29554	val-error:0.33979
# [24]	train-error:0.29398	val-error:0.33872
# [25]	train-error:0.29265	val-error:0.33819
# [26]	train-error:0.29059	val-error:0.33735
# [27]	train-error:0.28931	val-error:0.33788
# [28]	train-error:0.28785	val-error:0.33727
# [29]	train-error:0.28714	val-error:0.33636
# [30]	train-error:0.28615	val-error:0.33422
# [31]	train-error:0.28440	val-error:0.33605
# [32]	train-error:0.28371	val-error:0.33560
# [33]	train-error:0.28252	val-error:0.33582
# [34]	train-error:0.28153	val-error:0.33537
# [35]	train-error:0.28013	val-error:0.33560
# [36]	train-error:0.27924	val-error:0.33476
# [37]	train-error:0.27865	val-error:0.33476
# [38]	train-error:0.27775	val-error:0.33392
# [39]	train-error:0.27626	val-error:0.33316
# [40]	train-error:0.27538	val-error:0.33277
# [41]	train-error:0.27432	val-error:0.33064
# [42]	train-error:0.27288	val-error:0.32850
# [43]	train-error:0.27215	val-error:0.32896
# [44]	train-error:0.27174	val-error:0.32942
# [45]	train-error:0.27017	val-error:0.32835
# [46]	train-error:0.26901	val-error:0.32873
# [47]	train-error:0.26832	val-error:0.32820
# [48]	train-error:0.26712	val-error:0.32744
# [49]	train-error:0.26644	val-error:0.32790
# [50]	train-error:0.26520	val-error:0.32805
# [51]	train-error:0.26407	val-error:0.32744
# [52]	train-error:0.26340	val-error:0.32812
# [53]	train-error:0.26230	val-error:0.32934
# [54]	train-error:0.26128	val-error:0.32873
# [55]	train-error:0.26048	val-error:0.32790
# [56]	train-error:0.25936	val-error:0.32736
# [57]	train-error:0.25841	val-error:0.32835
# [58]	train-error:0.25789	val-error:0.32774
# [59]	train-error:0.25715	val-error:0.32645
# [60]	train-error:0.25601	val-error:0.32645
# [61]	train-error:0.25524	val-error:0.32690
# [62]	train-error:0.25454	val-error:0.32622
# [63]	train-error:0.25424	val-error:0.32576
# [64]	train-error:0.25301	val-error:0.32523
# [65]	train-error:0.25237	val-error:0.32469
# [66]	train-error:0.25171	val-error:0.32485
# [67]	train-error:0.25097	val-error:0.32469
# [68]	train-error:0.25001	val-error:0.32485
# [69]	train-error:0.24921	val-error:0.32507
# [70]	train-error:0.24864	val-error:0.32454
# [71]	train-error:0.24769	val-error:0.32523
# [72]	train-error:0.24718	val-error:0.32538
# [73]	train-error:0.24621	val-error:0.32446

# %%
import numpy as np
from scipy.stats import sem, t
from scipy import mean

# Assuming accuracies are stored in the 'accuracies' list as per previous example
accuracies = np.array(accuracies)

# Calculate the mean accuracy
mean_accuracy = np.mean(accuracies)

# Calculate the standard error of the mean
std_error = sem(accuracies)

# Determine the size of the accuracies array
n = len(accuracies)

# Use the t-distribution to calculate a 95% confidence interval
confidence = 0.95
h = std_error * t.ppf((1 + confidence) / 2, n - 1)

# Print the mean accuracy and confidence interval
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"95% Confidence interval: {mean_accuracy - h:.5f} - {mean_accuracy + h:.5f}")
# Out:
# Mean Accuracy: 0.68
# 95% Confidence interval: 0.67703 - 0.68508

# %% [markdown]
# Step 3: start with the LGB algorithm

# %%
y_pred = bst.predict(dtest)
print(y_pred)

plt.figure(figsize=(10, 6))
sns.histplot(y_pred, bins=30, kde=True)
plt.title('Distribution of popularity XGBoost')
plt.xlabel('popularity')
plt.ylabel('Frequency')
plt.savefig('/content/drive/MyDrive/Colab Notebooks/MSc thesis/Modeling/Out/XGBoost_predicted_popularity_value.png')  # Saving the plot
plt.show()
# Out:
# [0.23355103 0.19073103 0.25095627 ... 0.58571947 0.06705485 0.8909842 ]

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.67      0.70      0.69      6792
#         High       0.69      0.65      0.67      6792
#
#     accuracy                           0.68     13584
#    macro avg       0.68      0.68      0.68     13584
# weighted avg       0.68      0.68      0.68     13584

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.savefig('/content/drive/MyDrive/Colab Notebooks/MSc thesis/Modeling/Out/XGBoost_confusion_matrix.png')  # Saving the plot
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.savefig('/content/drive/MyDrive/Colab Notebooks/MSc thesis/Modeling/Out/XGBoost_error_rates_by_prob_bins.png')  # Saving the plot
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.67      0.71      0.69      6336
#         High       0.70      0.65      0.67      6336
#
#     accuracy                           0.68     12672
#    macro avg       0.68      0.68      0.68     12672
# weighted avg       0.68      0.68      0.68     12672
