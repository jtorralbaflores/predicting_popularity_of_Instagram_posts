# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = image_columns + additional_columns_to_keep #+ text_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2 = data_2[data_2['Image_Count'] <= 1]
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Image_Count   image_0   image_1   image_2   image_3  ...  image_2038  \
# 0             1  0.483804  4.411579  0.103043  0.694330  ...    1.348099
# 1             1  1.257535  4.292836  0.637026  0.038215  ...    0.062803
# 2             1  1.015909  4.928564  0.049328  1.360145  ...    0.912411
# 4             1  0.961807  3.994127  0.116529  1.330238  ...    0.236971
# 9             1  1.316597  1.515859  0.067210  2.473874  ...    0.688856
# 10            1  1.682237  1.290816  0.079366  0.259502  ...    0.732811
# 11            1  0.923607  3.838140  0.041025  0.159674  ...    0.067140
# 12            1  0.044586  1.376372  0.007699  0.149779  ...    0.488087
# 13            1  0.012054  0.549083  0.087380  0.054316  ...    0.000000
# 14            1  0.587146  4.310180  0.034403  0.048306  ...    0.000000
#
#     image_2039  image_2040  image_2041  image_2042  image_2043  image_2044  \
# 0     1.255268    1.463130    0.009248    0.058511    0.376918    0.074638
# 1     1.595342    1.707724    0.503333    0.000000    0.247264    0.000000
# 2     0.933246    0.092337    0.000000    0.739149    0.053084    0.286910
# 4     0.304974    0.508712    0.007309    0.041686    0.251861    0.332315
# 9     0.029724    1.511134    2.223945    0.530757    1.199176    0.185630
# 10    0.068392    1.555978    1.935349    0.074037    0.000000    0.388744
# 11    0.983345    1.730492    1.107379    0.053516    0.016675    0.337402
# 12    0.069210    1.433544    1.099280    0.061995    0.201946    0.786074
# 13    0.250658    0.149904    0.183440    0.350276    0.032225    0.459521
# 14    0.106569    0.246567    0.022366    0.106139    0.228331    0.154189
#
#     image_2045  image_2046  image_2047
# 0     0.010091    2.309669    0.894978
# 1     0.219100    0.410729    0.398495
# 2     0.608811    2.130039    1.679261
# 4     0.708797    0.688740    1.216255
# 9     0.110657    0.000000    0.806424
# 10    0.005011    0.227181    0.187945
# 11    2.163658    1.009122    0.403215
# 12    0.799035    0.000000    0.824184
# 13    1.822460    0.957111    0.937546
# 14    0.998335    0.033519    2.437387
#
# [10 rows x 2054 columns]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %%
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Image_Count   image_0   image_1   image_2   image_3  ...  image_2039  \
# 0             1  0.483804  4.411579  0.103043  0.694330  ...    1.255268
# 1             1  1.257535  4.292836  0.637026  0.038215  ...    1.595342
# 2             1  1.015909  4.928564  0.049328  1.360145  ...    0.933246
# 4             1  0.961807  3.994127  0.116529  1.330238  ...    0.304974
# 9             1  1.316597  1.515859  0.067210  2.473874  ...    0.029724
# 10            1  1.682237  1.290816  0.079366  0.259502  ...    0.068392
# 11            1  0.923607  3.838140  0.041025  0.159674  ...    0.983345
# 12            1  0.044586  1.376372  0.007699  0.149779  ...    0.069210
# 13            1  0.012054  0.549083  0.087380  0.054316  ...    0.250658
# 14            1  0.587146  4.310180  0.034403  0.048306  ...    0.106569
#
#     image_2040  image_2041  image_2042  image_2043  image_2044  image_2045  \
# 0     1.463130    0.009248    0.058511    0.376918    0.074638    0.010091
# 1     1.707724    0.503333    0.000000    0.247264    0.000000    0.219100
# 2     0.092337    0.000000    0.739149    0.053084    0.286910    0.608811
# 4     0.508712    0.007309    0.041686    0.251861    0.332315    0.708797
# 9     1.511134    2.223945    0.530757    1.199176    0.185630    0.110657
# 10    1.555978    1.935349    0.074037    0.000000    0.388744    0.005011
# 11    1.730492    1.107379    0.053516    0.016675    0.337402    2.163658
# 12    1.433544    1.099280    0.061995    0.201946    0.786074    0.799035
# 13    0.149904    0.183440    0.350276    0.032225    0.459521    1.822460
# 14    0.246567    0.022366    0.106139    0.228331    0.154189    0.998335
#
#     image_2046  image_2047  popularity
# 0     2.309669    0.894978    0.046335
# 1     0.410729    0.398495    0.011623
# 2     2.130039    1.679261    0.026034
# 4     0.688740    1.216255    0.018286
# 9     0.000000    0.806424    0.021298
# 10    0.227181    0.187945    0.085827
# 11    1.009122    0.403215    0.098892
# 12    0.000000    0.824184    0.106888
# 13    0.957111    0.937546    0.062799
# 14    0.033519    2.437387    0.074853
#
# [10 rows x 2055 columns]

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.43024	val-error:0.45272
# [1]	train-error:0.42121	val-error:0.44031
# [2]	train-error:0.41691	val-error:0.43860
# [3]	train-error:0.41157	val-error:0.43599
# [4]	train-error:0.40827	val-error:0.43414
# [5]	train-error:0.40586	val-error:0.43339
# [6]	train-error:0.40492	val-error:0.43101
# [7]	train-error:0.40225	val-error:0.43139
# [8]	train-error:0.40126	val-error:0.43101
# [9]	train-error:0.39973	val-error:0.42968
# [10]	train-error:0.39865	val-error:0.42938
# [11]	train-error:0.39639	val-error:0.43161
# [12]	train-error:0.39478	val-error:0.43265
# [13]	train-error:0.39275	val-error:0.43153
# [14]	train-error:0.39137	val-error:0.42901
# [15]	train-error:0.38896	val-error:0.42960
# [16]	train-error:0.38709	val-error:0.42916
# [17]	train-error:0.38548	val-error:0.43146
# [18]	train-error:0.38460	val-error:0.42938
# [19]	train-error:0.38285	val-error:0.43094
# [20]	train-error:0.38092	val-error:0.43064
# [21]	train-error:0.37897	val-error:0.43079
# [22]	train-error:0.37835	val-error:0.43161
# [23]	train-error:0.37674	val-error:0.43146
# [24]	train-error:0.37442	val-error:0.42945
# [25]	train-error:0.37302	val-error:0.43049
# [26]	train-error:0.37160	val-error:0.42997
# [27]	train-error:0.36964	val-error:0.43027
# [28]	train-error:0.36803	val-error:0.43064
# [29]	train-error:0.36616	val-error:0.42893
# [30]	train-error:0.36526	val-error:0.42938
# [31]	train-error:0.36367	val-error:0.43020
# [32]	train-error:0.36179	val-error:0.42901
# [33]	train-error:0.36025	val-error:0.42819
# [34]	train-error:0.35861	val-error:0.42618
# [35]	train-error:0.35664	val-error:0.42797
# [36]	train-error:0.35470	val-error:0.42759
# [37]	train-error:0.35253	val-error:0.42960
# [38]	train-error:0.35085	val-error:0.43034
# [39]	train-error:0.34895	val-error:0.42938
# [40]	train-error:0.34710	val-error:0.43020
# [41]	train-error:0.34537	val-error:0.43012
# [42]	train-error:0.34453	val-error:0.43049
# [43]	train-error:0.34376	val-error:0.43057
# [44]	train-error:0.34226	val-error:0.42953
# [45]	train-error:0.34046	val-error:0.42834
# [46]	train-error:0.33894	val-error:0.42886
# [47]	train-error:0.33710	val-error:0.42908
# [48]	train-error:0.33539	val-error:0.42864
# [49]	train-error:0.33371	val-error:0.43005
# [50]	train-error:0.33188	val-error:0.43161
# [51]	train-error:0.33023	val-error:0.43049
# [52]	train-error:0.32853	val-error:0.43049
# [53]	train-error:0.32688	val-error:0.42878
# [54]	train-error:0.32502	val-error:0.42982
# Accuracy for iteration 1: 0.57
# Iteration 2
# [0]	train-error:0.43499	val-error:0.44278
# [1]	train-error:0.42621	val-error:0.44004
# [2]	train-error:0.42004	val-error:0.44332
# [3]	train-error:0.41536	val-error:0.43958
# [4]	train-error:0.41123	val-error:0.43783
# [5]	train-error:0.40933	val-error:0.43760
# [6]	train-error:0.40662	val-error:0.43730
# [7]	train-error:0.40409	val-error:0.43409
# [8]	train-error:0.40173	val-error:0.43127
# [9]	train-error:0.39990	val-error:0.43120
# [10]	train-error:0.39838	val-error:0.43036
# [11]	train-error:0.39595	val-error:0.43104
# [12]	train-error:0.39431	val-error:0.43059
# [13]	train-error:0.39265	val-error:0.43120
# [14]	train-error:0.39101	val-error:0.43021
# [15]	train-error:0.38959	val-error:0.43112
# [16]	train-error:0.38838	val-error:0.42998
# [17]	train-error:0.38653	val-error:0.42990
# [18]	train-error:0.38421	val-error:0.42952
# [19]	train-error:0.38323	val-error:0.42944
# [20]	train-error:0.38125	val-error:0.42944
# [21]	train-error:0.37947	val-error:0.42860
# [22]	train-error:0.37761	val-error:0.42784
# [23]	train-error:0.37560	val-error:0.42899
# [24]	train-error:0.37394	val-error:0.42967
# [25]	train-error:0.37222	val-error:0.42769
# [26]	train-error:0.37109	val-error:0.42868
# [27]	train-error:0.36991	val-error:0.42777
# [28]	train-error:0.36768	val-error:0.42815
# [29]	train-error:0.36706	val-error:0.42746
# [30]	train-error:0.36531	val-error:0.42921
# [31]	train-error:0.36307	val-error:0.42815
# [32]	train-error:0.36183	val-error:0.42754
# [33]	train-error:0.36013	val-error:0.42777
# [34]	train-error:0.35910	val-error:0.42822
# [35]	train-error:0.35725	val-error:0.42761
# [36]	train-error:0.35563	val-error:0.42647
# [37]	train-error:0.35405	val-error:0.42632
# [38]	train-error:0.35242	val-error:0.42563
# [39]	train-error:0.35059	val-error:0.42609
# [40]	train-error:0.34951	val-error:0.42639
# [41]	train-error:0.34757	val-error:0.42594
# [42]	train-error:0.34568	val-error:0.42609
# [43]	train-error:0.34477	val-error:0.42616
# [44]	train-error:0.34305	val-error:0.42609
# [45]	train-error:0.34141	val-error:0.42700
# [46]	train-error:0.34015	val-error:0.42693
# [47]	train-error:0.33802	val-error:0.42677
# [48]	train-error:0.33719	val-error:0.42738
# [49]	train-error:0.33617	val-error:0.42647
# [50]	train-error:0.33398	val-error:0.42487
# [51]	train-error:0.33243	val-error:0.42502
# [52]	train-error:0.33069	val-error:0.42533
# [53]	train-error:0.32867	val-error:0.42555
# [54]	train-error:0.32733	val-error:0.42555
# [55]	train-error:0.32625	val-error:0.42472
# [56]	train-error:0.32467	val-error:0.42464
# [57]	train-error:0.32340	val-error:0.42548
# [58]	train-error:0.32159	val-error:0.42624
# [59]	train-error:0.32101	val-error:0.42548
# [60]	train-error:0.31932	val-error:0.42456
# [61]	train-error:0.31906	val-error:0.42433
# [62]	train-error:0.31720	val-error:0.42525
# [63]	train-error:0.31569	val-error:0.42571
# [64]	train-error:0.31411	val-error:0.42487
# [65]	train-error:0.31272	val-error:0.42510
# [66]	train-error:0.31099	val-error:0.42433
# [67]	train-error:0.31020	val-error:0.42548
# [68]	train-error:0.30894	val-error:0.42555
# [69]	train-error:0.30776	val-error:0.42449
# [70]	train-error:0.30602	val-error:0.42494
# [71]	train-error:0.30474	val-error:0.42472
# [72]	train-error:0.30376	val-error:0.42502
# [73]	train-error:0.30222	val-error:0.42433
# [74]	train-error:0.30135	val-error:0.42586
# [75]	train-error:0.29956	val-error:0.42555
# [76]	train-error:0.29791	val-error:0.42586
# [77]	train-error:0.29671	val-error:0.42647
# [78]	train-error:0.29560	val-error:0.42738
# [79]	train-error:0.29392	val-error:0.42769
# [80]	train-error:0.29276	val-error:0.42868
# Accuracy for iteration 2: 0.57
# Iteration 3
# [0]	train-error:0.43265	val-error:0.44894
# [1]	train-error:0.42278	val-error:0.44209
# [2]	train-error:0.41818	val-error:0.44113
# [3]	train-error:0.41508	val-error:0.44061
# [4]	train-error:0.41239	val-error:0.44128
# [5]	train-error:0.41094	val-error:0.43693
# [6]	train-error:0.40808	val-error:0.43590
# [7]	train-error:0.40582	val-error:0.43641
# [8]	train-error:0.40414	val-error:0.43833
# [9]	train-error:0.40251	val-error:0.43700
# [10]	train-error:0.40086	val-error:0.43671
# [11]	train-error:0.39897	val-error:0.43398
# [12]	train-error:0.39696	val-error:0.43391
# [13]	train-error:0.39554	val-error:0.43523
# [14]	train-error:0.39450	val-error:0.43575
# [15]	train-error:0.39306	val-error:0.43604
# [16]	train-error:0.39096	val-error:0.43553
# [17]	train-error:0.38937	val-error:0.43590
# [18]	train-error:0.38825	val-error:0.43435
# [19]	train-error:0.38626	val-error:0.43516
# [20]	train-error:0.38423	val-error:0.43560
# [21]	train-error:0.38179	val-error:0.43568
# [22]	train-error:0.38084	val-error:0.43494
# [23]	train-error:0.37894	val-error:0.43361
# [24]	train-error:0.37695	val-error:0.43369
# [25]	train-error:0.37510	val-error:0.43347
# [26]	train-error:0.37370	val-error:0.43413
# [27]	train-error:0.37209	val-error:0.43501
# [28]	train-error:0.37037	val-error:0.43516
# [29]	train-error:0.36910	val-error:0.43553
# [30]	train-error:0.36695	val-error:0.43391
# [31]	train-error:0.36533	val-error:0.43523
# [32]	train-error:0.36425	val-error:0.43649
# [33]	train-error:0.36178	val-error:0.43560
# [34]	train-error:0.36011	val-error:0.43604
# [35]	train-error:0.35791	val-error:0.43538
# [36]	train-error:0.35629	val-error:0.43568
# [37]	train-error:0.35456	val-error:0.43494
# [38]	train-error:0.35361	val-error:0.43487
# [39]	train-error:0.35150	val-error:0.43553
# [40]	train-error:0.34930	val-error:0.43501
# [41]	train-error:0.34750	val-error:0.43531
# [42]	train-error:0.34623	val-error:0.43501
# [43]	train-error:0.34449	val-error:0.43487
# [44]	train-error:0.34242	val-error:0.43479
# [45]	train-error:0.34125	val-error:0.43472
# Accuracy for iteration 3: 0.57
# Iteration 4
# [0]	train-error:0.43037	val-error:0.45251
# [1]	train-error:0.42004	val-error:0.44782
# [2]	train-error:0.41466	val-error:0.44208
# [3]	train-error:0.41243	val-error:0.43962
# [4]	train-error:0.40951	val-error:0.44073
# [5]	train-error:0.40629	val-error:0.43999
# [6]	train-error:0.40312	val-error:0.43842
# [7]	train-error:0.40251	val-error:0.43947
# [8]	train-error:0.40025	val-error:0.43842
# [9]	train-error:0.39882	val-error:0.43760
# [10]	train-error:0.39783	val-error:0.43783
# [11]	train-error:0.39616	val-error:0.43820
# [12]	train-error:0.39395	val-error:0.43730
# [13]	train-error:0.39234	val-error:0.43693
# [14]	train-error:0.39106	val-error:0.43693
# [15]	train-error:0.39014	val-error:0.43745
# [16]	train-error:0.38812	val-error:0.43820
# [17]	train-error:0.38690	val-error:0.43723
# [18]	train-error:0.38591	val-error:0.43723
# [19]	train-error:0.38386	val-error:0.43641
# [20]	train-error:0.38254	val-error:0.43648
# [21]	train-error:0.38117	val-error:0.43648
# [22]	train-error:0.37904	val-error:0.43686
# [23]	train-error:0.37719	val-error:0.43708
# [24]	train-error:0.37594	val-error:0.43768
# [25]	train-error:0.37422	val-error:0.43663
# [26]	train-error:0.37146	val-error:0.43783
# [27]	train-error:0.37009	val-error:0.43641
# [28]	train-error:0.36868	val-error:0.43648
# [29]	train-error:0.36745	val-error:0.43537
# [30]	train-error:0.36550	val-error:0.43559
# [31]	train-error:0.36434	val-error:0.43648
# [32]	train-error:0.36284	val-error:0.43596
# [33]	train-error:0.36191	val-error:0.43648
# [34]	train-error:0.36024	val-error:0.43537
# [35]	train-error:0.35784	val-error:0.43581
# [36]	train-error:0.35602	val-error:0.43388
# [37]	train-error:0.35458	val-error:0.43320
# [38]	train-error:0.35267	val-error:0.43253
# [39]	train-error:0.35043	val-error:0.43484
# [40]	train-error:0.34922	val-error:0.43514
# [41]	train-error:0.34787	val-error:0.43596
# [42]	train-error:0.34660	val-error:0.43611
# [43]	train-error:0.34403	val-error:0.43514
# [44]	train-error:0.34265	val-error:0.43566
# [45]	train-error:0.34101	val-error:0.43850
# [46]	train-error:0.34019	val-error:0.43820
# [47]	train-error:0.33831	val-error:0.43753
# [48]	train-error:0.33666	val-error:0.43835
# [49]	train-error:0.33500	val-error:0.43745
# [50]	train-error:0.33282	val-error:0.43604
# [51]	train-error:0.33167	val-error:0.43611
# [52]	train-error:0.32906	val-error:0.43663
# [53]	train-error:0.32758	val-error:0.43566
# [54]	train-error:0.32611	val-error:0.43574
# [55]	train-error:0.32482	val-error:0.43656
# [56]	train-error:0.32418	val-error:0.43738
# [57]	train-error:0.32272	val-error:0.43589
# Accuracy for iteration 4: 0.56
# Iteration 5
# [0]	train-error:0.42766	val-error:0.45881
# [1]	train-error:0.42029	val-error:0.44947
# [2]	train-error:0.41537	val-error:0.44849
# [3]	train-error:0.41251	val-error:0.44683
# [4]	train-error:0.41002	val-error:0.44630
# [5]	train-error:0.40850	val-error:0.44804
# [6]	train-error:0.40585	val-error:0.44713
# [7]	train-error:0.40444	val-error:0.44698
# [8]	train-error:0.40233	val-error:0.44758
# [9]	train-error:0.40028	val-error:0.44804
# [10]	train-error:0.39776	val-error:0.44638
# [11]	train-error:0.39593	val-error:0.44480
# [12]	train-error:0.39485	val-error:0.44615
# [13]	train-error:0.39387	val-error:0.44419
# [14]	train-error:0.39183	val-error:0.44457
# [15]	train-error:0.38983	val-error:0.44329
# [16]	train-error:0.38840	val-error:0.44284
# [17]	train-error:0.38710	val-error:0.44351
# [18]	train-error:0.38566	val-error:0.44254
# [19]	train-error:0.38324	val-error:0.44254
# [20]	train-error:0.38174	val-error:0.44201
# [21]	train-error:0.38008	val-error:0.44261
# [22]	train-error:0.37868	val-error:0.44246
# [23]	train-error:0.37702	val-error:0.44351
# [24]	train-error:0.37483	val-error:0.44261
# [25]	train-error:0.37312	val-error:0.44231
# [26]	train-error:0.37179	val-error:0.44012
# [27]	train-error:0.37028	val-error:0.44095
# [28]	train-error:0.36892	val-error:0.44020
# [29]	train-error:0.36715	val-error:0.44035
# [30]	train-error:0.36539	val-error:0.44110
# [31]	train-error:0.36360	val-error:0.43967
# [32]	train-error:0.36218	val-error:0.43975
# [33]	train-error:0.36108	val-error:0.44080
# [34]	train-error:0.35863	val-error:0.44073
# [35]	train-error:0.35742	val-error:0.44080
# [36]	train-error:0.35502	val-error:0.43990
# [37]	train-error:0.35308	val-error:0.44043
# [38]	train-error:0.35169	val-error:0.43967
# [39]	train-error:0.35106	val-error:0.43990
# [40]	train-error:0.34881	val-error:0.43945
# [41]	train-error:0.34684	val-error:0.43899
# [42]	train-error:0.34544	val-error:0.43892
# [43]	train-error:0.34360	val-error:0.43801
# [44]	train-error:0.34182	val-error:0.43764
# [45]	train-error:0.34085	val-error:0.43794
# [46]	train-error:0.33896	val-error:0.43718
# [47]	train-error:0.33716	val-error:0.43651
# [48]	train-error:0.33516	val-error:0.43643
# [49]	train-error:0.33383	val-error:0.43620
# [50]	train-error:0.33247	val-error:0.43749
# [51]	train-error:0.33078	val-error:0.43703
# [52]	train-error:0.32898	val-error:0.43869
# [53]	train-error:0.32818	val-error:0.43779
# [54]	train-error:0.32685	val-error:0.43779
# [55]	train-error:0.32499	val-error:0.43794
# [56]	train-error:0.32382	val-error:0.43809
# [57]	train-error:0.32216	val-error:0.43801
# [58]	train-error:0.32055	val-error:0.43899
# [59]	train-error:0.31903	val-error:0.43914
# [60]	train-error:0.31747	val-error:0.43929
# [61]	train-error:0.31610	val-error:0.43839
# [62]	train-error:0.31502	val-error:0.43960
# [63]	train-error:0.31345	val-error:0.43809
# [64]	train-error:0.31142	val-error:0.43862
# [65]	train-error:0.31028	val-error:0.43862
# [66]	train-error:0.30882	val-error:0.43854
# [67]	train-error:0.30729	val-error:0.43824
# [68]	train-error:0.30602	val-error:0.43779
# [69]	train-error:0.30506	val-error:0.43658
# Accuracy for iteration 5: 0.56
# Iteration 6
# [0]	train-error:0.42890	val-error:0.45305
# [1]	train-error:0.42287	val-error:0.44410
# [2]	train-error:0.41909	val-error:0.44335
# [3]	train-error:0.41536	val-error:0.44184
# [4]	train-error:0.41174	val-error:0.43861
# [5]	train-error:0.40919	val-error:0.43974
# [6]	train-error:0.40720	val-error:0.43771
# [7]	train-error:0.40548	val-error:0.43733
# [8]	train-error:0.40332	val-error:0.43778
# [9]	train-error:0.40013	val-error:0.43771
# [10]	train-error:0.39932	val-error:0.43726
# [11]	train-error:0.39664	val-error:0.43410
# [12]	train-error:0.39452	val-error:0.43590
# [13]	train-error:0.39320	val-error:0.43680
# [14]	train-error:0.39165	val-error:0.43688
# [15]	train-error:0.39047	val-error:0.43560
# [16]	train-error:0.38868	val-error:0.43703
# [17]	train-error:0.38655	val-error:0.43643
# [18]	train-error:0.38528	val-error:0.43530
# [19]	train-error:0.38315	val-error:0.43635
# [20]	train-error:0.38172	val-error:0.43432
# [21]	train-error:0.37956	val-error:0.43364
# [22]	train-error:0.37813	val-error:0.43349
# [23]	train-error:0.37732	val-error:0.43417
# [24]	train-error:0.37543	val-error:0.43357
# [25]	train-error:0.37320	val-error:0.43507
# [26]	train-error:0.37194	val-error:0.43395
# [27]	train-error:0.37009	val-error:0.43583
# [28]	train-error:0.36818	val-error:0.43455
# [29]	train-error:0.36659	val-error:0.43379
# [30]	train-error:0.36546	val-error:0.43410
# [31]	train-error:0.36451	val-error:0.43357
# [32]	train-error:0.36281	val-error:0.43312
# [33]	train-error:0.36090	val-error:0.43184
# [34]	train-error:0.35941	val-error:0.43139
# [35]	train-error:0.35776	val-error:0.43274
# [36]	train-error:0.35650	val-error:0.43214
# [37]	train-error:0.35463	val-error:0.43094
# [38]	train-error:0.35327	val-error:0.43282
# [39]	train-error:0.35184	val-error:0.43252
# [40]	train-error:0.35064	val-error:0.43214
# [41]	train-error:0.34907	val-error:0.43334
# [42]	train-error:0.34810	val-error:0.43327
# [43]	train-error:0.34539	val-error:0.43259
# [44]	train-error:0.34355	val-error:0.43274
# [45]	train-error:0.34200	val-error:0.43372
# [46]	train-error:0.34035	val-error:0.43364
# [47]	train-error:0.33967	val-error:0.43327
# [48]	train-error:0.33780	val-error:0.43267
# [49]	train-error:0.33654	val-error:0.43274
# [50]	train-error:0.33492	val-error:0.43259
# [51]	train-error:0.33318	val-error:0.43199
# [52]	train-error:0.33216	val-error:0.43312
# [53]	train-error:0.33050	val-error:0.43402
# [54]	train-error:0.32919	val-error:0.43282
# [55]	train-error:0.32823	val-error:0.43395
# [56]	train-error:0.32682	val-error:0.43379
# [57]	train-error:0.32545	val-error:0.43372
# Accuracy for iteration 6: 0.57
# Iteration 7
# [0]	train-error:0.43187	val-error:0.45186
# [1]	train-error:0.42623	val-error:0.44766
# [2]	train-error:0.42127	val-error:0.45068
# [3]	train-error:0.41655	val-error:0.44582
# [4]	train-error:0.41255	val-error:0.44236
# [5]	train-error:0.41026	val-error:0.43986
# [6]	train-error:0.40772	val-error:0.43721
# [7]	train-error:0.40525	val-error:0.43809
# [8]	train-error:0.40289	val-error:0.43802
# [9]	train-error:0.40151	val-error:0.43875
# [10]	train-error:0.39975	val-error:0.43802
# [11]	train-error:0.39680	val-error:0.43698
# [12]	train-error:0.39535	val-error:0.43765
# [13]	train-error:0.39357	val-error:0.43713
# [14]	train-error:0.39208	val-error:0.43787
# [15]	train-error:0.39034	val-error:0.43595
# [16]	train-error:0.38951	val-error:0.43617
# [17]	train-error:0.38779	val-error:0.43640
# [18]	train-error:0.38549	val-error:0.43632
# [19]	train-error:0.38422	val-error:0.43544
# [20]	train-error:0.38266	val-error:0.43588
# [21]	train-error:0.38159	val-error:0.43595
# [22]	train-error:0.38013	val-error:0.43514
# [23]	train-error:0.37862	val-error:0.43559
# [24]	train-error:0.37643	val-error:0.43500
# [25]	train-error:0.37407	val-error:0.43500
# [26]	train-error:0.37179	val-error:0.43478
# [27]	train-error:0.36983	val-error:0.43537
# [28]	train-error:0.36770	val-error:0.43448
# [29]	train-error:0.36621	val-error:0.43551
# [30]	train-error:0.36473	val-error:0.43537
# [31]	train-error:0.36296	val-error:0.43522
# [32]	train-error:0.36151	val-error:0.43404
# [33]	train-error:0.35999	val-error:0.43514
# [34]	train-error:0.35861	val-error:0.43610
# [35]	train-error:0.35746	val-error:0.43647
# [36]	train-error:0.35636	val-error:0.43529
# [37]	train-error:0.35449	val-error:0.43426
# [38]	train-error:0.35212	val-error:0.43389
# [39]	train-error:0.35033	val-error:0.43441
# [40]	train-error:0.34919	val-error:0.43514
# [41]	train-error:0.34731	val-error:0.43411
# [42]	train-error:0.34599	val-error:0.43397
# [43]	train-error:0.34449	val-error:0.43463
# [44]	train-error:0.34327	val-error:0.43375
# [45]	train-error:0.34125	val-error:0.43367
# [46]	train-error:0.33986	val-error:0.43389
# [47]	train-error:0.33870	val-error:0.43426
# [48]	train-error:0.33725	val-error:0.43522
# [49]	train-error:0.33501	val-error:0.43647
# [50]	train-error:0.33329	val-error:0.43662
# [51]	train-error:0.33169	val-error:0.43676
# [52]	train-error:0.33030	val-error:0.43647
# [53]	train-error:0.32866	val-error:0.43456
# [54]	train-error:0.32779	val-error:0.43345
# [55]	train-error:0.32583	val-error:0.43507
# [56]	train-error:0.32436	val-error:0.43478
# [57]	train-error:0.32217	val-error:0.43500
# [58]	train-error:0.32027	val-error:0.43419
# [59]	train-error:0.31924	val-error:0.43507
# [60]	train-error:0.31805	val-error:0.43419
# [61]	train-error:0.31721	val-error:0.43448
# [62]	train-error:0.31577	val-error:0.43492
# [63]	train-error:0.31372	val-error:0.43595
# [64]	train-error:0.31218	val-error:0.43382
# [65]	train-error:0.31164	val-error:0.43559
# [66]	train-error:0.31007	val-error:0.43603
# [67]	train-error:0.30948	val-error:0.43603
# [68]	train-error:0.30798	val-error:0.43588
# [69]	train-error:0.30657	val-error:0.43706
# [70]	train-error:0.30499	val-error:0.43573
# [71]	train-error:0.30431	val-error:0.43647
# [72]	train-error:0.30266	val-error:0.43588
# [73]	train-error:0.30083	val-error:0.43588
# [74]	train-error:0.29952	val-error:0.43573
# Accuracy for iteration 7: 0.57
# Average Accuracy across 7 iterations: 0.57

# %%
import numpy as np
from scipy.stats import sem, t
from scipy import mean

# Assuming accuracies are stored in the 'accuracies' list as per previous example
accuracies = np.array(accuracies)

# Calculate the mean accuracy
mean_accuracy = np.mean(accuracies)

# Calculate the standard error of the mean
std_error = sem(accuracies)

# Determine the size of the accuracies array
n = len(accuracies)

# Use the t-distribution to calculate a 95% confidence interval
confidence = 0.95
h = std_error * t.ppf((1 + confidence) / 2, n - 1)

# Print the mean accuracy and confidence interval
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"95% Confidence interval: {mean_accuracy - h:.5f} - {mean_accuracy + h:.5f}")
# Out:
# Mean Accuracy: 0.57
# 95% Confidence interval: 0.56151 - 0.57049

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.57      0.53      0.55      6792
#         High       0.56      0.60      0.58      6792
#
#     accuracy                           0.56     13584
#    macro avg       0.56      0.56      0.56     13584
# weighted avg       0.56      0.56      0.56     13584

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.57      0.54      0.56      6336
#         High       0.57      0.60      0.58      6336
#
#     accuracy                           0.57     12672
#    macro avg       0.57      0.57      0.57     12672
# weighted avg       0.57      0.57      0.57     12672
