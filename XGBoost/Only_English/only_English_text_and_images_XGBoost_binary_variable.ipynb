# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Image_Count', 'Is_English']

# Combine both lists of columns to keep
columns_to_keep = image_columns + additional_columns_to_keep + text_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2 = data_2[data_2['Image_Count'] <= 1]
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Is_English  Image_Count   image_0   image_1   image_2  ...  text_758  \
# 0         True            1  0.483804  4.411579  0.103043  ... -0.155746
# 1         True            1  1.257535  4.292836  0.637026  ... -0.247792
# 2         True            1  1.015909  4.928564  0.049328  ... -0.089539
# 4         True            1  0.961807  3.994127  0.116529  ... -0.112963
# 9         True            1  1.316597  1.515859  0.067210  ... -0.147682
# 10        True            1  1.682237  1.290816  0.079366  ... -0.009259
# 11        True            1  0.923607  3.838140  0.041025  ... -0.092988
# 12        True            1  0.044586  1.376372  0.007699  ... -0.161618
# 13        True            1  0.012054  0.549083  0.087380  ... -0.162583
# 14        True            1  0.587146  4.310180  0.034403  ... -0.114496
#
#     text_759  text_760  text_761  text_762  text_763  text_764  text_765  \
# 0  -0.017703 -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870
# 1   0.015757 -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263
# 2  -0.097885 -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142
# 4  -0.036261 -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846
# 9  -0.036988 -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471
# 10 -0.165627  0.198171  0.093986  0.176528  0.140797  0.070081 -0.168545
# 11 -0.083701  0.228142  0.049256  0.080081  0.093756  0.086833 -0.163537
# 12 -0.178489  0.159561 -0.046662  0.182022  0.127947  0.299180 -0.091949
# 13  0.028141 -0.179497  0.085646  0.179977  0.134104  0.239402  0.052813
# 14 -0.001124 -0.172151  0.021455  0.215737  0.150555  0.408500 -0.234415
#
#     text_766  text_767
# 0   0.062999  0.075272
# 1  -0.012400  0.147600
# 2   0.094179  0.080168
# 4   0.141513  0.093924
# 9   0.012900  0.064740
# 10  0.107152  0.057365
# 11  0.100750  0.096130
# 12  0.096147  0.045425
# 13  0.030690 -0.044792
# 14  0.109303 -0.072184
#
# [10 rows x 2823 columns]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.41530	val-error:0.44647
# [1]	train-error:0.39765	val-error:0.43494
# [2]	train-error:0.39045	val-error:0.43318
# [3]	train-error:0.38455	val-error:0.43090
# [4]	train-error:0.37934	val-error:0.42641
# [5]	train-error:0.37680	val-error:0.42685
# [6]	train-error:0.37469	val-error:0.42703
# [7]	train-error:0.37141	val-error:0.42650
# [8]	train-error:0.36894	val-error:0.42588
# [9]	train-error:0.36623	val-error:0.42236
# [10]	train-error:0.36268	val-error:0.42280
# [11]	train-error:0.36168	val-error:0.42148
# [12]	train-error:0.36044	val-error:0.42113
# [13]	train-error:0.35825	val-error:0.42113
# [14]	train-error:0.35592	val-error:0.42043
# [15]	train-error:0.35362	val-error:0.41902
# [16]	train-error:0.35193	val-error:0.41920
# [17]	train-error:0.34958	val-error:0.41990
# [18]	train-error:0.34808	val-error:0.41849
# [19]	train-error:0.34547	val-error:0.41955
# [20]	train-error:0.34388	val-error:0.41779
# [21]	train-error:0.34219	val-error:0.41717
# [22]	train-error:0.34174	val-error:0.41541
# [23]	train-error:0.34092	val-error:0.41620
# [24]	train-error:0.33923	val-error:0.41524
# [25]	train-error:0.33597	val-error:0.41594
# [26]	train-error:0.33492	val-error:0.41594
# [27]	train-error:0.33288	val-error:0.41471
# [28]	train-error:0.33115	val-error:0.41321
# [29]	train-error:0.32934	val-error:0.41339
# [30]	train-error:0.32701	val-error:0.41471
# [31]	train-error:0.32558	val-error:0.41392
# [32]	train-error:0.32398	val-error:0.41119
# [33]	train-error:0.32206	val-error:0.40952
# [34]	train-error:0.32000	val-error:0.41189
# [35]	train-error:0.31871	val-error:0.41295
# [36]	train-error:0.31689	val-error:0.41137
# [37]	train-error:0.31513	val-error:0.41093
# [38]	train-error:0.31308	val-error:0.41040
# [39]	train-error:0.31201	val-error:0.41057
# [40]	train-error:0.31049	val-error:0.40943
# [41]	train-error:0.30930	val-error:0.40943
# [42]	train-error:0.30771	val-error:0.40811
# [43]	train-error:0.30620	val-error:0.40785
# [44]	train-error:0.30428	val-error:0.40899
# [45]	train-error:0.30227	val-error:0.40846
# [46]	train-error:0.30104	val-error:0.40626
# [47]	train-error:0.29975	val-error:0.40732
# [48]	train-error:0.29781	val-error:0.40750
# [49]	train-error:0.29685	val-error:0.40662
# [50]	train-error:0.29537	val-error:0.40653
# [51]	train-error:0.29373	val-error:0.40521
# [52]	train-error:0.29219	val-error:0.40345
# [53]	train-error:0.29095	val-error:0.40556
# [54]	train-error:0.28981	val-error:0.40706
# [55]	train-error:0.28861	val-error:0.40794
# [56]	train-error:0.28788	val-error:0.40741
# [57]	train-error:0.28634	val-error:0.40925
# [58]	train-error:0.28468	val-error:0.40697
# [59]	train-error:0.28378	val-error:0.40864
# [60]	train-error:0.28188	val-error:0.40750
# [61]	train-error:0.28145	val-error:0.40750
# [62]	train-error:0.28030	val-error:0.40565
# [63]	train-error:0.27891	val-error:0.40758
# [64]	train-error:0.27776	val-error:0.40802
# [65]	train-error:0.27691	val-error:0.40820
# [66]	train-error:0.27550	val-error:0.40741
# [67]	train-error:0.27451	val-error:0.40626
# [68]	train-error:0.27321	val-error:0.40776
# [69]	train-error:0.27209	val-error:0.40758
# [70]	train-error:0.27130	val-error:0.40802
# [71]	train-error:0.26973	val-error:0.40890
# Accuracy for iteration 1: 0.59
# Iteration 2
# [0]	train-error:0.41590	val-error:0.43552
# [1]	train-error:0.40209	val-error:0.42549
# [2]	train-error:0.39750	val-error:0.42558
# [3]	train-error:0.38820	val-error:0.41423
# [4]	train-error:0.38198	val-error:0.40860
# [5]	train-error:0.37810	val-error:0.41045
# [6]	train-error:0.37485	val-error:0.40825
# [7]	train-error:0.37325	val-error:0.40596
# [8]	train-error:0.37014	val-error:0.40500
# [9]	train-error:0.36636	val-error:0.40693
# [10]	train-error:0.36352	val-error:0.40535
# [11]	train-error:0.36304	val-error:0.40535
# [12]	train-error:0.36019	val-error:0.40491
# [13]	train-error:0.35822	val-error:0.40385
# [14]	train-error:0.35693	val-error:0.40385
# [15]	train-error:0.35406	val-error:0.40403
# [16]	train-error:0.35212	val-error:0.40192
# [17]	train-error:0.35024	val-error:0.40016
# [18]	train-error:0.34796	val-error:0.40218
# [19]	train-error:0.34541	val-error:0.40007
# [20]	train-error:0.34294	val-error:0.39849
# [21]	train-error:0.34178	val-error:0.39866
# [22]	train-error:0.34046	val-error:0.39857
# [23]	train-error:0.33814	val-error:0.39655
# [24]	train-error:0.33679	val-error:0.39664
# [25]	train-error:0.33455	val-error:0.39726
# [26]	train-error:0.33291	val-error:0.39558
# [27]	train-error:0.33128	val-error:0.39374
# [28]	train-error:0.32880	val-error:0.39576
# [29]	train-error:0.32674	val-error:0.39418
# [30]	train-error:0.32522	val-error:0.39418
# [31]	train-error:0.32435	val-error:0.39462
# [32]	train-error:0.32241	val-error:0.39365
# [33]	train-error:0.32094	val-error:0.39400
# [34]	train-error:0.31912	val-error:0.39303
# [35]	train-error:0.31738	val-error:0.39365
# [36]	train-error:0.31536	val-error:0.39268
# [37]	train-error:0.31374	val-error:0.39453
# [38]	train-error:0.31268	val-error:0.39479
# [39]	train-error:0.31160	val-error:0.39594
# [40]	train-error:0.31027	val-error:0.39585
# [41]	train-error:0.30793	val-error:0.39646
# [42]	train-error:0.30692	val-error:0.39462
# [43]	train-error:0.30529	val-error:0.39479
# [44]	train-error:0.30434	val-error:0.39409
# [45]	train-error:0.30258	val-error:0.39277
# [46]	train-error:0.30126	val-error:0.39382
# [47]	train-error:0.29976	val-error:0.39523
# [48]	train-error:0.29927	val-error:0.39470
# [49]	train-error:0.29805	val-error:0.39418
# [50]	train-error:0.29675	val-error:0.39567
# [51]	train-error:0.29558	val-error:0.39558
# [52]	train-error:0.29327	val-error:0.39426
# [53]	train-error:0.29188	val-error:0.39251
# [54]	train-error:0.29085	val-error:0.39303
# [55]	train-error:0.28970	val-error:0.39127
# [56]	train-error:0.28929	val-error:0.39180
# [57]	train-error:0.28737	val-error:0.39163
# [58]	train-error:0.28651	val-error:0.39268
# [59]	train-error:0.28472	val-error:0.39303
# [60]	train-error:0.28374	val-error:0.39356
# [61]	train-error:0.28175	val-error:0.39470
# [62]	train-error:0.28064	val-error:0.39277
# [63]	train-error:0.27890	val-error:0.39426
# [64]	train-error:0.27765	val-error:0.39435
# [65]	train-error:0.27654	val-error:0.39330
# [66]	train-error:0.27515	val-error:0.39277
# [67]	train-error:0.27382	val-error:0.39321
# [68]	train-error:0.27252	val-error:0.39207
# [69]	train-error:0.27137	val-error:0.39171
# [70]	train-error:0.27056	val-error:0.39189
# [71]	train-error:0.26970	val-error:0.39110
# [72]	train-error:0.26925	val-error:0.39215
# [73]	train-error:0.26765	val-error:0.39312
# [74]	train-error:0.26626	val-error:0.39356
# [75]	train-error:0.26542	val-error:0.39347
# [76]	train-error:0.26464	val-error:0.39251
# [77]	train-error:0.26337	val-error:0.39242
# [78]	train-error:0.26250	val-error:0.39303
# [79]	train-error:0.26172	val-error:0.39198
# [80]	train-error:0.26079	val-error:0.39163
# [81]	train-error:0.25960	val-error:0.39057
# [82]	train-error:0.25874	val-error:0.39022
# [83]	train-error:0.25743	val-error:0.39039
# [84]	train-error:0.25614	val-error:0.39119
# [85]	train-error:0.25517	val-error:0.39233
# [86]	train-error:0.25401	val-error:0.39224
# [87]	train-error:0.25252	val-error:0.39268
# [88]	train-error:0.25118	val-error:0.39295
# [89]	train-error:0.24934	val-error:0.39277
# [90]	train-error:0.24833	val-error:0.39268
# [91]	train-error:0.24722	val-error:0.39374
# [92]	train-error:0.24591	val-error:0.39321
# [93]	train-error:0.24435	val-error:0.39576
# [94]	train-error:0.24337	val-error:0.39558
# [95]	train-error:0.24251	val-error:0.39620
# [96]	train-error:0.24150	val-error:0.39532
# [97]	train-error:0.24053	val-error:0.39462
# [98]	train-error:0.23905	val-error:0.39514
# [99]	train-error:0.23788	val-error:0.39444
# [100]	train-error:0.23678	val-error:0.39382
# [101]	train-error:0.23561	val-error:0.39479
# [102]	train-error:0.23459	val-error:0.39470
# Accuracy for iteration 2: 0.59
# Iteration 3
# [0]	train-error:0.41575	val-error:0.42357
# [1]	train-error:0.40187	val-error:0.41470
# [2]	train-error:0.39258	val-error:0.41143
# [3]	train-error:0.38924	val-error:0.40850
# [4]	train-error:0.38405	val-error:0.40617
# [5]	train-error:0.37878	val-error:0.40160
# [6]	train-error:0.37480	val-error:0.40307
# [7]	train-error:0.37109	val-error:0.40238
# [8]	train-error:0.36800	val-error:0.40488
# [9]	train-error:0.36548	val-error:0.40307
# [10]	train-error:0.36379	val-error:0.40048
# [11]	train-error:0.36160	val-error:0.39824
# [12]	train-error:0.35980	val-error:0.39807
# [13]	train-error:0.35748	val-error:0.39885
# [14]	train-error:0.35575	val-error:0.39850
# [15]	train-error:0.35259	val-error:0.39988
# [16]	train-error:0.35057	val-error:0.40005
# [17]	train-error:0.34828	val-error:0.40040
# [18]	train-error:0.34764	val-error:0.39867
# [19]	train-error:0.34536	val-error:0.39764
# [20]	train-error:0.34316	val-error:0.39790
# [21]	train-error:0.34175	val-error:0.39497
# [22]	train-error:0.33912	val-error:0.39531
# [23]	train-error:0.33786	val-error:0.39531
# [24]	train-error:0.33536	val-error:0.39678
# [25]	train-error:0.33369	val-error:0.39385
# [26]	train-error:0.33197	val-error:0.39333
# [27]	train-error:0.33071	val-error:0.39178
# [28]	train-error:0.32904	val-error:0.39066
# [29]	train-error:0.32823	val-error:0.39178
# [30]	train-error:0.32560	val-error:0.39075
# [31]	train-error:0.32450	val-error:0.39049
# [32]	train-error:0.32255	val-error:0.38997
# [33]	train-error:0.32133	val-error:0.38988
# [34]	train-error:0.31935	val-error:0.39032
# [35]	train-error:0.31811	val-error:0.39144
# [36]	train-error:0.31579	val-error:0.39187
# [37]	train-error:0.31439	val-error:0.38997
# [38]	train-error:0.31334	val-error:0.38945
# [39]	train-error:0.31192	val-error:0.38868
# [40]	train-error:0.31047	val-error:0.38937
# [41]	train-error:0.30875	val-error:0.38894
# [42]	train-error:0.30779	val-error:0.38868
# [43]	train-error:0.30660	val-error:0.38790
# [44]	train-error:0.30505	val-error:0.38842
# [45]	train-error:0.30414	val-error:0.38782
# [46]	train-error:0.30181	val-error:0.38842
# [47]	train-error:0.30033	val-error:0.39109
# [48]	train-error:0.29856	val-error:0.39092
# [49]	train-error:0.29673	val-error:0.38997
# [50]	train-error:0.29546	val-error:0.39014
# [51]	train-error:0.29417	val-error:0.38928
# [52]	train-error:0.29274	val-error:0.39118
# [53]	train-error:0.29119	val-error:0.39057
# [54]	train-error:0.29020	val-error:0.39032
# [55]	train-error:0.28862	val-error:0.38971
# [56]	train-error:0.28744	val-error:0.38920
# [57]	train-error:0.28631	val-error:0.38928
# [58]	train-error:0.28453	val-error:0.38963
# [59]	train-error:0.28364	val-error:0.38988
# [60]	train-error:0.28193	val-error:0.38911
# [61]	train-error:0.28046	val-error:0.38963
# [62]	train-error:0.27897	val-error:0.38876
# [63]	train-error:0.27823	val-error:0.38773
# [64]	train-error:0.27693	val-error:0.38876
# [65]	train-error:0.27559	val-error:0.38842
# [66]	train-error:0.27366	val-error:0.38868
# [67]	train-error:0.27240	val-error:0.38920
# [68]	train-error:0.27098	val-error:0.39014
# [69]	train-error:0.26979	val-error:0.39152
# [70]	train-error:0.26926	val-error:0.39014
# [71]	train-error:0.26819	val-error:0.38988
# [72]	train-error:0.26677	val-error:0.38945
# [73]	train-error:0.26556	val-error:0.38825
# [74]	train-error:0.26396	val-error:0.38627
# [75]	train-error:0.26317	val-error:0.38644
# [76]	train-error:0.26202	val-error:0.38609
# [77]	train-error:0.26092	val-error:0.38773
# [78]	train-error:0.25995	val-error:0.38773
# [79]	train-error:0.25894	val-error:0.38790
# [80]	train-error:0.25716	val-error:0.38851
# [81]	train-error:0.25617	val-error:0.38773
# [82]	train-error:0.25486	val-error:0.38885
# [83]	train-error:0.25305	val-error:0.39014
# [84]	train-error:0.25138	val-error:0.39049
# [85]	train-error:0.25037	val-error:0.39083
# [86]	train-error:0.24939	val-error:0.39066
# [87]	train-error:0.24873	val-error:0.39126
# [88]	train-error:0.24809	val-error:0.39135
# [89]	train-error:0.24664	val-error:0.39264
# [90]	train-error:0.24579	val-error:0.39204
# [91]	train-error:0.24496	val-error:0.39161
# [92]	train-error:0.24429	val-error:0.39126
# [93]	train-error:0.24324	val-error:0.39169
# [94]	train-error:0.24204	val-error:0.39212
# [95]	train-error:0.24063	val-error:0.39100
# Accuracy for iteration 3: 0.59
# Iteration 4
# [0]	train-error:0.41271	val-error:0.44049
# [1]	train-error:0.39816	val-error:0.43415
# [2]	train-error:0.39051	val-error:0.43183
# [3]	train-error:0.38667	val-error:0.43066
# [4]	train-error:0.38165	val-error:0.43058
# [5]	train-error:0.37813	val-error:0.42897
# [6]	train-error:0.37355	val-error:0.42441
# [7]	train-error:0.37132	val-error:0.42664
# [8]	train-error:0.36868	val-error:0.42182
# [9]	train-error:0.36746	val-error:0.42307
# [10]	train-error:0.36460	val-error:0.42236
# [11]	train-error:0.36219	val-error:0.42084
# [12]	train-error:0.36050	val-error:0.42057
# [13]	train-error:0.35837	val-error:0.41753
# [14]	train-error:0.35709	val-error:0.41833
# [15]	train-error:0.35493	val-error:0.41753
# [16]	train-error:0.35366	val-error:0.41539
# [17]	train-error:0.35130	val-error:0.41431
# [18]	train-error:0.34836	val-error:0.41431
# [19]	train-error:0.34701	val-error:0.41485
# [20]	train-error:0.34473	val-error:0.41262
# [21]	train-error:0.34353	val-error:0.41262
# [22]	train-error:0.34065	val-error:0.41137
# [23]	train-error:0.33921	val-error:0.41128
# [24]	train-error:0.33738	val-error:0.41217
# [25]	train-error:0.33474	val-error:0.41145
# [26]	train-error:0.33319	val-error:0.41083
# [27]	train-error:0.32974	val-error:0.40949
# [28]	train-error:0.32828	val-error:0.41119
# [29]	train-error:0.32647	val-error:0.40913
# [30]	train-error:0.32509	val-error:0.41020
# [31]	train-error:0.32342	val-error:0.41011
# [32]	train-error:0.32236	val-error:0.40967
# [33]	train-error:0.32026	val-error:0.40931
# [34]	train-error:0.31936	val-error:0.40868
# [35]	train-error:0.31771	val-error:0.40815
# [36]	train-error:0.31658	val-error:0.40967
# [37]	train-error:0.31488	val-error:0.40940
# [38]	train-error:0.31326	val-error:0.40994
# [39]	train-error:0.31153	val-error:0.41038
# [40]	train-error:0.30974	val-error:0.40886
# [41]	train-error:0.30814	val-error:0.40833
# [42]	train-error:0.30687	val-error:0.40797
# [43]	train-error:0.30507	val-error:0.40913
# [44]	train-error:0.30416	val-error:0.41047
# [45]	train-error:0.30213	val-error:0.40931
# [46]	train-error:0.30123	val-error:0.40895
# [47]	train-error:0.29993	val-error:0.40895
# [48]	train-error:0.29807	val-error:0.40922
# [49]	train-error:0.29654	val-error:0.40815
# [50]	train-error:0.29541	val-error:0.40815
# [51]	train-error:0.29462	val-error:0.40815
# [52]	train-error:0.29384	val-error:0.40895
# [53]	train-error:0.29261	val-error:0.40860
# [54]	train-error:0.29130	val-error:0.40743
# [55]	train-error:0.28981	val-error:0.40851
# [56]	train-error:0.28853	val-error:0.40761
# [57]	train-error:0.28695	val-error:0.40690
# [58]	train-error:0.28548	val-error:0.40627
# [59]	train-error:0.28407	val-error:0.40672
# [60]	train-error:0.28297	val-error:0.40734
# [61]	train-error:0.28118	val-error:0.40583
# [62]	train-error:0.28009	val-error:0.40475
# [63]	train-error:0.27860	val-error:0.40457
# [64]	train-error:0.27754	val-error:0.40565
# [65]	train-error:0.27686	val-error:0.40475
# [66]	train-error:0.27562	val-error:0.40681
# [67]	train-error:0.27400	val-error:0.40529
# [68]	train-error:0.27280	val-error:0.40511
# [69]	train-error:0.27086	val-error:0.40708
# [70]	train-error:0.26948	val-error:0.40734
# [71]	train-error:0.26848	val-error:0.40627
# [72]	train-error:0.26733	val-error:0.40422
# [73]	train-error:0.26587	val-error:0.40323
# [74]	train-error:0.26463	val-error:0.40466
# [75]	train-error:0.26332	val-error:0.40484
# [76]	train-error:0.26200	val-error:0.40475
# [77]	train-error:0.26112	val-error:0.40475
# [78]	train-error:0.26000	val-error:0.40547
# [79]	train-error:0.25883	val-error:0.40457
# [80]	train-error:0.25784	val-error:0.40547
# [81]	train-error:0.25688	val-error:0.40583
# [82]	train-error:0.25570	val-error:0.40556
# [83]	train-error:0.25471	val-error:0.40574
# [84]	train-error:0.25365	val-error:0.40538
# [85]	train-error:0.25185	val-error:0.40690
# [86]	train-error:0.25092	val-error:0.40493
# [87]	train-error:0.24979	val-error:0.40591
# [88]	train-error:0.24845	val-error:0.40502
# [89]	train-error:0.24754	val-error:0.40654
# [90]	train-error:0.24654	val-error:0.40618
# [91]	train-error:0.24580	val-error:0.40681
# [92]	train-error:0.24439	val-error:0.40717
# Accuracy for iteration 4: 0.60
# Iteration 5
# [0]	train-error:0.41613	val-error:0.44578
# [1]	train-error:0.40483	val-error:0.44394
# [2]	train-error:0.39397	val-error:0.43726
# [3]	train-error:0.38685	val-error:0.43207
# [4]	train-error:0.38231	val-error:0.42909
# [5]	train-error:0.37987	val-error:0.42592
# [6]	train-error:0.37698	val-error:0.42320
# [7]	train-error:0.37329	val-error:0.42417
# [8]	train-error:0.37056	val-error:0.42373
# [9]	train-error:0.36728	val-error:0.42214
# [10]	train-error:0.36593	val-error:0.42250
# [11]	train-error:0.36359	val-error:0.41863
# [12]	train-error:0.36068	val-error:0.42074
# [13]	train-error:0.35835	val-error:0.42241
# [14]	train-error:0.35763	val-error:0.41995
# [15]	train-error:0.35530	val-error:0.42083
# [16]	train-error:0.35361	val-error:0.41960
# [17]	train-error:0.35253	val-error:0.41784
# [18]	train-error:0.35017	val-error:0.41872
# [19]	train-error:0.34799	val-error:0.41880
# [20]	train-error:0.34682	val-error:0.41880
# [21]	train-error:0.34425	val-error:0.41801
# [22]	train-error:0.34222	val-error:0.41687
# [23]	train-error:0.33942	val-error:0.41714
# [24]	train-error:0.33833	val-error:0.41634
# [25]	train-error:0.33551	val-error:0.41555
# [26]	train-error:0.33445	val-error:0.41344
# [27]	train-error:0.33206	val-error:0.41555
# [28]	train-error:0.32984	val-error:0.41617
# [29]	train-error:0.32845	val-error:0.41485
# [30]	train-error:0.32704	val-error:0.41511
# [31]	train-error:0.32550	val-error:0.41467
# [32]	train-error:0.32349	val-error:0.41309
# [33]	train-error:0.32222	val-error:0.41186
# [34]	train-error:0.32069	val-error:0.41344
# [35]	train-error:0.31957	val-error:0.41309
# [36]	train-error:0.31828	val-error:0.41432
# [37]	train-error:0.31644	val-error:0.41292
# [38]	train-error:0.31481	val-error:0.41239
# [39]	train-error:0.31316	val-error:0.41257
# [40]	train-error:0.31176	val-error:0.41151
# [41]	train-error:0.31020	val-error:0.41265
# [42]	train-error:0.30839	val-error:0.41098
# [43]	train-error:0.30650	val-error:0.41046
# [44]	train-error:0.30501	val-error:0.41134
# [45]	train-error:0.30383	val-error:0.41037
# [46]	train-error:0.30278	val-error:0.41195
# [47]	train-error:0.30065	val-error:0.41230
# [48]	train-error:0.29971	val-error:0.41292
# [49]	train-error:0.29741	val-error:0.41344
# [50]	train-error:0.29607	val-error:0.41230
# [51]	train-error:0.29471	val-error:0.41257
# [52]	train-error:0.29326	val-error:0.41362
# [53]	train-error:0.29216	val-error:0.41248
# [54]	train-error:0.29060	val-error:0.41169
# [55]	train-error:0.28913	val-error:0.41028
# [56]	train-error:0.28809	val-error:0.41002
# [57]	train-error:0.28634	val-error:0.41134
# [58]	train-error:0.28491	val-error:0.41081
# [59]	train-error:0.28358	val-error:0.41230
# [60]	train-error:0.28256	val-error:0.41169
# [61]	train-error:0.28115	val-error:0.41002
# [62]	train-error:0.27956	val-error:0.41142
# [63]	train-error:0.27869	val-error:0.41142
# [64]	train-error:0.27694	val-error:0.41160
# [65]	train-error:0.27606	val-error:0.41151
# [66]	train-error:0.27471	val-error:0.41178
# [67]	train-error:0.27299	val-error:0.41142
# [68]	train-error:0.27230	val-error:0.41090
# [69]	train-error:0.27066	val-error:0.41125
# [70]	train-error:0.26995	val-error:0.41134
# [71]	train-error:0.26865	val-error:0.41098
# [72]	train-error:0.26716	val-error:0.41160
# [73]	train-error:0.26653	val-error:0.41160
# [74]	train-error:0.26594	val-error:0.41178
# [75]	train-error:0.26456	val-error:0.41213
# Accuracy for iteration 5: 0.59
# Iteration 6
# [0]	train-error:0.41662	val-error:0.44821
# [1]	train-error:0.40475	val-error:0.43321
# [2]	train-error:0.39242	val-error:0.42933
# [3]	train-error:0.38658	val-error:0.43201
# [4]	train-error:0.38255	val-error:0.43118
# [5]	train-error:0.37727	val-error:0.42766
# [6]	train-error:0.37371	val-error:0.42618
# [7]	train-error:0.37290	val-error:0.42414
# [8]	train-error:0.36984	val-error:0.42368
# [9]	train-error:0.36670	val-error:0.42109
# [10]	train-error:0.36382	val-error:0.42081
# [11]	train-error:0.36291	val-error:0.41951
# [12]	train-error:0.36156	val-error:0.41572
# [13]	train-error:0.35858	val-error:0.41674
# [14]	train-error:0.35618	val-error:0.41720
# [15]	train-error:0.35455	val-error:0.41877
# [16]	train-error:0.35181	val-error:0.41433
# [17]	train-error:0.35059	val-error:0.41544
# [18]	train-error:0.34918	val-error:0.41646
# [19]	train-error:0.34734	val-error:0.41526
# [20]	train-error:0.34566	val-error:0.41609
# [21]	train-error:0.34386	val-error:0.41313
# [22]	train-error:0.34196	val-error:0.41026
# [23]	train-error:0.34022	val-error:0.40952
# [24]	train-error:0.33764	val-error:0.40915
# [25]	train-error:0.33591	val-error:0.40887
# [26]	train-error:0.33441	val-error:0.40766
# [27]	train-error:0.33234	val-error:0.40535
# [28]	train-error:0.33020	val-error:0.40489
# [29]	train-error:0.32795	val-error:0.40535
# [30]	train-error:0.32622	val-error:0.40507
# [31]	train-error:0.32454	val-error:0.40637
# [32]	train-error:0.32352	val-error:0.40683
# [33]	train-error:0.32195	val-error:0.40646
# [34]	train-error:0.32048	val-error:0.40729
# [35]	train-error:0.31974	val-error:0.40554
# [36]	train-error:0.31806	val-error:0.40526
# [37]	train-error:0.31624	val-error:0.40628
# [38]	train-error:0.31450	val-error:0.40683
# [39]	train-error:0.31215	val-error:0.40554
# [40]	train-error:0.31085	val-error:0.40498
# [41]	train-error:0.30907	val-error:0.40591
# [42]	train-error:0.30773	val-error:0.40609
# [43]	train-error:0.30614	val-error:0.40544
# [44]	train-error:0.30430	val-error:0.40470
# [45]	train-error:0.30352	val-error:0.40341
# [46]	train-error:0.30212	val-error:0.40461
# [47]	train-error:0.30052	val-error:0.40498
# [48]	train-error:0.29924	val-error:0.40479
# [49]	train-error:0.29773	val-error:0.40489
# [50]	train-error:0.29638	val-error:0.40415
# [51]	train-error:0.29493	val-error:0.40535
# [52]	train-error:0.29383	val-error:0.40517
# [53]	train-error:0.29243	val-error:0.40415
# [54]	train-error:0.29063	val-error:0.40405
# [55]	train-error:0.28947	val-error:0.40442
# [56]	train-error:0.28710	val-error:0.40387
# [57]	train-error:0.28586	val-error:0.40433
# [58]	train-error:0.28517	val-error:0.40359
# [59]	train-error:0.28365	val-error:0.40257
# [60]	train-error:0.28262	val-error:0.40165
# [61]	train-error:0.28149	val-error:0.40257
# [62]	train-error:0.28010	val-error:0.40128
# [63]	train-error:0.27866	val-error:0.40276
# [64]	train-error:0.27766	val-error:0.40230
# [65]	train-error:0.27561	val-error:0.40396
# [66]	train-error:0.27453	val-error:0.40405
# [67]	train-error:0.27344	val-error:0.40331
# [68]	train-error:0.27201	val-error:0.40378
# [69]	train-error:0.27073	val-error:0.40424
# [70]	train-error:0.27009	val-error:0.40433
# [71]	train-error:0.26904	val-error:0.40470
# [72]	train-error:0.26755	val-error:0.40442
# [73]	train-error:0.26657	val-error:0.40378
# [74]	train-error:0.26566	val-error:0.40405
# [75]	train-error:0.26422	val-error:0.40646
# [76]	train-error:0.26302	val-error:0.40628
# [77]	train-error:0.26202	val-error:0.40646
# [78]	train-error:0.26085	val-error:0.40600
# [79]	train-error:0.25957	val-error:0.40554
# [80]	train-error:0.25845	val-error:0.40507
# [81]	train-error:0.25737	val-error:0.40489
# Accuracy for iteration 6: 0.59
# Iteration 7
# [0]	train-error:0.41613	val-error:0.43698
# [1]	train-error:0.40210	val-error:0.43260
# [2]	train-error:0.39579	val-error:0.42151
# [3]	train-error:0.38833	val-error:0.41927
# [4]	train-error:0.38457	val-error:0.41807
# [5]	train-error:0.38107	val-error:0.41609
# [6]	train-error:0.37546	val-error:0.41386
# [7]	train-error:0.37331	val-error:0.40870
# [8]	train-error:0.36941	val-error:0.40990
# [9]	train-error:0.36605	val-error:0.40956
# [10]	train-error:0.36444	val-error:0.40801
# [11]	train-error:0.36300	val-error:0.40827
# [12]	train-error:0.36096	val-error:0.40672
# [13]	train-error:0.35841	val-error:0.40492
# [14]	train-error:0.35624	val-error:0.40518
# [15]	train-error:0.35459	val-error:0.40191
# [16]	train-error:0.35273	val-error:0.40131
# [17]	train-error:0.35004	val-error:0.40165
# [18]	train-error:0.34788	val-error:0.40191
# [19]	train-error:0.34635	val-error:0.40105
# [20]	train-error:0.34415	val-error:0.39864
# [21]	train-error:0.34241	val-error:0.39864
# [22]	train-error:0.34040	val-error:0.39864
# [23]	train-error:0.33864	val-error:0.39847
# [24]	train-error:0.33697	val-error:0.39890
# [25]	train-error:0.33459	val-error:0.39752
# [26]	train-error:0.33277	val-error:0.39838
# [27]	train-error:0.33131	val-error:0.39924
# [28]	train-error:0.32928	val-error:0.40002
# [29]	train-error:0.32717	val-error:0.39899
# [30]	train-error:0.32571	val-error:0.40079
# [31]	train-error:0.32467	val-error:0.39976
# [32]	train-error:0.32347	val-error:0.39976
# [33]	train-error:0.32180	val-error:0.39873
# [34]	train-error:0.32028	val-error:0.39821
# [35]	train-error:0.31889	val-error:0.39942
# [36]	train-error:0.31709	val-error:0.39890
# [37]	train-error:0.31549	val-error:0.39718
# [38]	train-error:0.31389	val-error:0.39623
# [39]	train-error:0.31165	val-error:0.39529
# [40]	train-error:0.31051	val-error:0.39615
# [41]	train-error:0.30855	val-error:0.39580
# [42]	train-error:0.30721	val-error:0.39598
# [43]	train-error:0.30556	val-error:0.39580
# [44]	train-error:0.30430	val-error:0.39503
# [45]	train-error:0.30217	val-error:0.39589
# [46]	train-error:0.30081	val-error:0.39580
# [47]	train-error:0.29859	val-error:0.39770
# [48]	train-error:0.29805	val-error:0.39727
# [49]	train-error:0.29688	val-error:0.39838
# [50]	train-error:0.29590	val-error:0.39692
# [51]	train-error:0.29505	val-error:0.39615
# [52]	train-error:0.29372	val-error:0.39709
# [53]	train-error:0.29234	val-error:0.39572
# [54]	train-error:0.29057	val-error:0.39537
# [55]	train-error:0.28837	val-error:0.39658
# [56]	train-error:0.28706	val-error:0.39503
# [57]	train-error:0.28595	val-error:0.39374
# [58]	train-error:0.28425	val-error:0.39460
# [59]	train-error:0.28299	val-error:0.39486
# [60]	train-error:0.28234	val-error:0.39305
# [61]	train-error:0.28079	val-error:0.39262
# [62]	train-error:0.27911	val-error:0.39142
# [63]	train-error:0.27756	val-error:0.39013
# [64]	train-error:0.27606	val-error:0.39108
# [65]	train-error:0.27482	val-error:0.39065
# [66]	train-error:0.27405	val-error:0.39090
# [67]	train-error:0.27291	val-error:0.39125
# [68]	train-error:0.27101	val-error:0.39090
# [69]	train-error:0.26921	val-error:0.39090
# [70]	train-error:0.26813	val-error:0.39168
# [71]	train-error:0.26618	val-error:0.39245
# [72]	train-error:0.26533	val-error:0.39108
# [73]	train-error:0.26446	val-error:0.39030
# [74]	train-error:0.26325	val-error:0.39125
# [75]	train-error:0.26229	val-error:0.39151
# [76]	train-error:0.26084	val-error:0.39168
# [77]	train-error:0.25981	val-error:0.39168
# [78]	train-error:0.25898	val-error:0.39142
# [79]	train-error:0.25768	val-error:0.39151
# [80]	train-error:0.25585	val-error:0.39176
# [81]	train-error:0.25492	val-error:0.39151
# [82]	train-error:0.25390	val-error:0.39185
# [83]	train-error:0.25342	val-error:0.39133
# Accuracy for iteration 7: 0.60
# Average Accuracy across 7 iterations: 0.59

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.59076 - 0.60267

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.61      0.59      0.60      5816
#         High       0.61      0.63      0.62      5816
#
#     accuracy                           0.61     11632
#    macro avg       0.61      0.61      0.61     11632
# weighted avg       0.61      0.61      0.61     11632

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.60      0.58      0.59      5513
#         High       0.59      0.61      0.60      5512
#
#     accuracy                           0.60     11025
#    macro avg       0.60      0.60      0.60     11025
# weighted avg       0.60      0.60      0.60     11025
