# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = text_columns + additional_columns_to_keep #+ image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2 = data_2[data_2['Image_Count'] <= 1]
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Is_English  Image_Count    text_0    text_1    text_2  ...  text_758  \
# 0         True            1  0.038798 -0.013620 -0.028838  ... -0.155746
# 1         True            1  0.036927  0.168833  0.037493  ... -0.247792
# 2         True            1  0.075085 -0.030041 -0.088772  ... -0.089539
# 4         True            1  0.063160  0.008341 -0.013197  ... -0.112963
# 9         True            1 -0.028073  0.147198 -0.072839  ... -0.147682
# 10        True            1  0.050338  0.012619 -0.037740  ... -0.009259
# 11        True            1  0.087523 -0.017718  0.045246  ... -0.092988
# 12        True            1  0.129532 -0.088060  0.060749  ... -0.161618
# 13        True            1 -0.017063  0.163560  0.079621  ... -0.162583
# 14        True            1  0.026620 -0.022259  0.029860  ... -0.114496
#
#     text_759  text_760  text_761  text_762  text_763  text_764  text_765  \
# 0  -0.017703 -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870
# 1   0.015757 -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263
# 2  -0.097885 -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142
# 4  -0.036261 -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846
# 9  -0.036988 -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471
# 10 -0.165627  0.198171  0.093986  0.176528  0.140797  0.070081 -0.168545
# 11 -0.083701  0.228142  0.049256  0.080081  0.093756  0.086833 -0.163537
# 12 -0.178489  0.159561 -0.046662  0.182022  0.127947  0.299180 -0.091949
# 13  0.028141 -0.179497  0.085646  0.179977  0.134104  0.239402  0.052813
# 14 -0.001124 -0.172151  0.021455  0.215737  0.150555  0.408500 -0.234415
#
#     text_766  text_767
# 0   0.062999  0.075272
# 1  -0.012400  0.147600
# 2   0.094179  0.080168
# 4   0.141513  0.093924
# 9   0.012900  0.064740
# 10  0.107152  0.057365
# 11  0.100750  0.096130
# 12  0.096147  0.045425
# 13  0.030690 -0.044792
# 14  0.109303 -0.072184
#
# [10 rows x 775 columns]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))
# Out:
# <ipython-input-7-747e2ff0d805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.42656	val-error:0.44884
# [1]	train-error:0.40891	val-error:0.44955
# [2]	train-error:0.40285	val-error:0.44541
# [3]	train-error:0.39435	val-error:0.44084
# [4]	train-error:0.39207	val-error:0.43890
# [5]	train-error:0.38819	val-error:0.43723
# [6]	train-error:0.38591	val-error:0.43213
# [7]	train-error:0.38341	val-error:0.43204
# [8]	train-error:0.38084	val-error:0.43019
# [9]	train-error:0.37843	val-error:0.43037
# [10]	train-error:0.37694	val-error:0.42984
# [11]	train-error:0.37549	val-error:0.42738
# [12]	train-error:0.37326	val-error:0.42667
# [13]	train-error:0.37065	val-error:0.42588
# [14]	train-error:0.36911	val-error:0.42861
# [15]	train-error:0.36739	val-error:0.42861
# [16]	train-error:0.36452	val-error:0.42615
# [17]	train-error:0.36196	val-error:0.42773
# [18]	train-error:0.35982	val-error:0.42641
# [19]	train-error:0.35749	val-error:0.42395
# [20]	train-error:0.35524	val-error:0.42298
# [21]	train-error:0.35274	val-error:0.42315
# [22]	train-error:0.35124	val-error:0.41937
# [23]	train-error:0.35014	val-error:0.41937
# [24]	train-error:0.34709	val-error:0.41717
# [25]	train-error:0.34582	val-error:0.41840
# [26]	train-error:0.34437	val-error:0.41937
# [27]	train-error:0.34334	val-error:0.42025
# [28]	train-error:0.34176	val-error:0.41849
# [29]	train-error:0.34037	val-error:0.41884
# [30]	train-error:0.33890	val-error:0.41656
# [31]	train-error:0.33761	val-error:0.41735
# [32]	train-error:0.33508	val-error:0.41515
# [33]	train-error:0.33459	val-error:0.41568
# [34]	train-error:0.33390	val-error:0.41603
# [35]	train-error:0.33295	val-error:0.41445
# [36]	train-error:0.33162	val-error:0.41365
# [37]	train-error:0.33024	val-error:0.41480
# [38]	train-error:0.32882	val-error:0.41374
# [39]	train-error:0.32738	val-error:0.41445
# [40]	train-error:0.32550	val-error:0.41277
# [41]	train-error:0.32493	val-error:0.41260
# [42]	train-error:0.32304	val-error:0.41304
# [43]	train-error:0.32231	val-error:0.41189
# [44]	train-error:0.32118	val-error:0.41119
# [45]	train-error:0.31973	val-error:0.41154
# [46]	train-error:0.31856	val-error:0.41093
# [47]	train-error:0.31700	val-error:0.41022
# [48]	train-error:0.31597	val-error:0.41163
# [49]	train-error:0.31513	val-error:0.41145
# [50]	train-error:0.31387	val-error:0.41233
# [51]	train-error:0.31308	val-error:0.41137
# [52]	train-error:0.31173	val-error:0.41181
# [53]	train-error:0.31036	val-error:0.41181
# [54]	train-error:0.30915	val-error:0.41181
# [55]	train-error:0.30860	val-error:0.41154
# [56]	train-error:0.30737	val-error:0.41075
# [57]	train-error:0.30628	val-error:0.41216
# [58]	train-error:0.30440	val-error:0.41242
# [59]	train-error:0.30295	val-error:0.41154
# [60]	train-error:0.30162	val-error:0.41189
# [61]	train-error:0.30095	val-error:0.41163
# [62]	train-error:0.29956	val-error:0.41128
# [63]	train-error:0.29816	val-error:0.41251
# [64]	train-error:0.29718	val-error:0.41181
# [65]	train-error:0.29585	val-error:0.41225
# [66]	train-error:0.29513	val-error:0.41233
# Accuracy for iteration 1: 0.58
# Iteration 2
# [0]	train-error:0.42465	val-error:0.43552
# [1]	train-error:0.41138	val-error:0.43473
# [2]	train-error:0.40287	val-error:0.42980
# [3]	train-error:0.39602	val-error:0.43095
# [4]	train-error:0.39219	val-error:0.42866
# [5]	train-error:0.38848	val-error:0.42646
# [6]	train-error:0.38538	val-error:0.42417
# [7]	train-error:0.38249	val-error:0.42391
# [8]	train-error:0.38021	val-error:0.42461
# [9]	train-error:0.37785	val-error:0.42118
# [10]	train-error:0.37520	val-error:0.41810
# [11]	train-error:0.37292	val-error:0.41846
# [12]	train-error:0.37032	val-error:0.41731
# [13]	train-error:0.36820	val-error:0.41731
# [14]	train-error:0.36623	val-error:0.41925
# [15]	train-error:0.36454	val-error:0.41722
# [16]	train-error:0.36312	val-error:0.41784
# [17]	train-error:0.36160	val-error:0.41916
# [18]	train-error:0.35848	val-error:0.41775
# [19]	train-error:0.35729	val-error:0.41775
# [20]	train-error:0.35649	val-error:0.41907
# [21]	train-error:0.35403	val-error:0.42004
# [22]	train-error:0.35253	val-error:0.41758
# [23]	train-error:0.35064	val-error:0.41687
# [24]	train-error:0.34798	val-error:0.41599
# [25]	train-error:0.34723	val-error:0.41538
# [26]	train-error:0.34501	val-error:0.41212
# [27]	train-error:0.34331	val-error:0.41177
# [28]	train-error:0.34145	val-error:0.41291
# [29]	train-error:0.34060	val-error:0.41335
# [30]	train-error:0.33853	val-error:0.41115
# [31]	train-error:0.33719	val-error:0.41071
# [32]	train-error:0.33575	val-error:0.40957
# [33]	train-error:0.33385	val-error:0.41063
# [34]	train-error:0.33210	val-error:0.41010
# [35]	train-error:0.33136	val-error:0.41080
# [36]	train-error:0.33001	val-error:0.41071
# [37]	train-error:0.32864	val-error:0.41212
# [38]	train-error:0.32746	val-error:0.41203
# [39]	train-error:0.32625	val-error:0.41115
# [40]	train-error:0.32502	val-error:0.41089
# [41]	train-error:0.32306	val-error:0.41177
# [42]	train-error:0.32230	val-error:0.40966
# [43]	train-error:0.32017	val-error:0.40913
# [44]	train-error:0.31957	val-error:0.40957
# [45]	train-error:0.31827	val-error:0.40764
# [46]	train-error:0.31649	val-error:0.40799
# [47]	train-error:0.31555	val-error:0.40966
# [48]	train-error:0.31397	val-error:0.41089
# [49]	train-error:0.31315	val-error:0.41063
# [50]	train-error:0.31151	val-error:0.41089
# [51]	train-error:0.30991	val-error:0.41203
# [52]	train-error:0.30896	val-error:0.41133
# [53]	train-error:0.30786	val-error:0.41168
# [54]	train-error:0.30677	val-error:0.41186
# [55]	train-error:0.30547	val-error:0.41371
# [56]	train-error:0.30356	val-error:0.41177
# [57]	train-error:0.30225	val-error:0.41133
# [58]	train-error:0.30106	val-error:0.41203
# [59]	train-error:0.29987	val-error:0.41265
# [60]	train-error:0.29916	val-error:0.41450
# [61]	train-error:0.29826	val-error:0.41239
# [62]	train-error:0.29736	val-error:0.41283
# [63]	train-error:0.29600	val-error:0.41203
# [64]	train-error:0.29519	val-error:0.41054
# Accuracy for iteration 2: 0.58
# Iteration 3
# [0]	train-error:0.42672	val-error:0.44089
# [1]	train-error:0.40892	val-error:0.43917
# [2]	train-error:0.40117	val-error:0.42702
# [3]	train-error:0.39609	val-error:0.42452
# [4]	train-error:0.38979	val-error:0.42168
# [5]	train-error:0.38727	val-error:0.42220
# [6]	train-error:0.38383	val-error:0.42194
# [7]	train-error:0.37992	val-error:0.41642
# [8]	train-error:0.37865	val-error:0.41418
# [9]	train-error:0.37565	val-error:0.41780
# [10]	train-error:0.37335	val-error:0.41789
# [11]	train-error:0.37148	val-error:0.41703
# [12]	train-error:0.36875	val-error:0.41496
# [13]	train-error:0.36680	val-error:0.41668
# [14]	train-error:0.36492	val-error:0.41616
# [15]	train-error:0.36311	val-error:0.41470
# [16]	train-error:0.36037	val-error:0.41401
# [17]	train-error:0.35874	val-error:0.41358
# [18]	train-error:0.35766	val-error:0.41255
# [19]	train-error:0.35558	val-error:0.41289
# [20]	train-error:0.35371	val-error:0.41470
# [21]	train-error:0.35338	val-error:0.41410
# [22]	train-error:0.35126	val-error:0.41375
# [23]	train-error:0.34888	val-error:0.41444
# [24]	train-error:0.34714	val-error:0.41349
# [25]	train-error:0.34598	val-error:0.41177
# [26]	train-error:0.34488	val-error:0.41384
# [27]	train-error:0.34432	val-error:0.41367
# [28]	train-error:0.34277	val-error:0.41272
# [29]	train-error:0.34170	val-error:0.41332
# [30]	train-error:0.34018	val-error:0.41444
# [31]	train-error:0.33750	val-error:0.41315
# [32]	train-error:0.33570	val-error:0.41315
# [33]	train-error:0.33443	val-error:0.41056
# [34]	train-error:0.33377	val-error:0.41039
# [35]	train-error:0.33214	val-error:0.41125
# [36]	train-error:0.33080	val-error:0.41151
# [37]	train-error:0.32940	val-error:0.41220
# [38]	train-error:0.32798	val-error:0.41013
# [39]	train-error:0.32664	val-error:0.40987
# [40]	train-error:0.32501	val-error:0.40884
# [41]	train-error:0.32395	val-error:0.41031
# [42]	train-error:0.32259	val-error:0.41013
# [43]	train-error:0.32128	val-error:0.40927
# [44]	train-error:0.31954	val-error:0.40858
# [45]	train-error:0.31915	val-error:0.41031
# [46]	train-error:0.31760	val-error:0.41091
# [47]	train-error:0.31658	val-error:0.41125
# [48]	train-error:0.31521	val-error:0.41143
# [49]	train-error:0.31399	val-error:0.41134
# [50]	train-error:0.31352	val-error:0.41022
# [51]	train-error:0.31247	val-error:0.41048
# [52]	train-error:0.31162	val-error:0.41074
# [53]	train-error:0.31026	val-error:0.40927
# [54]	train-error:0.31010	val-error:0.40962
# [55]	train-error:0.30870	val-error:0.40987
# [56]	train-error:0.30705	val-error:0.41143
# [57]	train-error:0.30587	val-error:0.41151
# [58]	train-error:0.30559	val-error:0.41246
# [59]	train-error:0.30438	val-error:0.41160
# [60]	train-error:0.30339	val-error:0.41074
# [61]	train-error:0.30180	val-error:0.41048
# [62]	train-error:0.30111	val-error:0.41048
# [63]	train-error:0.29987	val-error:0.41013
# [64]	train-error:0.29877	val-error:0.40927
# Accuracy for iteration 3: 0.59
# Iteration 4
# [0]	train-error:0.42757	val-error:0.45979
# [1]	train-error:0.41111	val-error:0.44961
# [2]	train-error:0.40051	val-error:0.43665
# [3]	train-error:0.39486	val-error:0.43576
# [4]	train-error:0.39104	val-error:0.43227
# [5]	train-error:0.38732	val-error:0.42986
# [6]	train-error:0.38458	val-error:0.42718
# [7]	train-error:0.38030	val-error:0.42834
# [8]	train-error:0.37889	val-error:0.42718
# [9]	train-error:0.37574	val-error:0.42781
# [10]	train-error:0.37289	val-error:0.42638
# [11]	train-error:0.37155	val-error:0.42378
# [12]	train-error:0.36878	val-error:0.42548
# [13]	train-error:0.36709	val-error:0.42655
# [14]	train-error:0.36482	val-error:0.42414
# [15]	train-error:0.36295	val-error:0.42343
# [16]	train-error:0.36053	val-error:0.42370
# [17]	train-error:0.35912	val-error:0.42432
# [18]	train-error:0.35693	val-error:0.42352
# [19]	train-error:0.35548	val-error:0.42316
# [20]	train-error:0.35356	val-error:0.42227
# [21]	train-error:0.35227	val-error:0.42298
# [22]	train-error:0.35135	val-error:0.42432
# [23]	train-error:0.34907	val-error:0.42325
# [24]	train-error:0.34807	val-error:0.42325
# [25]	train-error:0.34606	val-error:0.42316
# [26]	train-error:0.34499	val-error:0.42566
# [27]	train-error:0.34320	val-error:0.42378
# [28]	train-error:0.34181	val-error:0.42262
# [29]	train-error:0.34049	val-error:0.42218
# [30]	train-error:0.33827	val-error:0.42209
# [31]	train-error:0.33656	val-error:0.42164
# [32]	train-error:0.33525	val-error:0.42191
# [33]	train-error:0.33432	val-error:0.42128
# [34]	train-error:0.33271	val-error:0.42236
# [35]	train-error:0.33151	val-error:0.42066
# [36]	train-error:0.32982	val-error:0.42075
# [37]	train-error:0.32773	val-error:0.41887
# [38]	train-error:0.32647	val-error:0.41950
# [39]	train-error:0.32474	val-error:0.41825
# [40]	train-error:0.32400	val-error:0.41860
# [41]	train-error:0.32206	val-error:0.41887
# [42]	train-error:0.32084	val-error:0.41842
# [43]	train-error:0.31964	val-error:0.41771
# [44]	train-error:0.31799	val-error:0.41762
# [45]	train-error:0.31710	val-error:0.41789
# [46]	train-error:0.31583	val-error:0.41708
# [47]	train-error:0.31458	val-error:0.41664
# [48]	train-error:0.31266	val-error:0.41539
# [49]	train-error:0.31221	val-error:0.41530
# [50]	train-error:0.31158	val-error:0.41530
# [51]	train-error:0.30949	val-error:0.41664
# [52]	train-error:0.30945	val-error:0.41690
# [53]	train-error:0.30836	val-error:0.41637
# [54]	train-error:0.30699	val-error:0.41592
# [55]	train-error:0.30593	val-error:0.41690
# [56]	train-error:0.30516	val-error:0.41735
# [57]	train-error:0.30419	val-error:0.41664
# [58]	train-error:0.30346	val-error:0.41556
# [59]	train-error:0.30237	val-error:0.41539
# [60]	train-error:0.30126	val-error:0.41449
# [61]	train-error:0.29996	val-error:0.41592
# [62]	train-error:0.29902	val-error:0.41717
# [63]	train-error:0.29740	val-error:0.41726
# [64]	train-error:0.29676	val-error:0.41753
# [65]	train-error:0.29589	val-error:0.41771
# [66]	train-error:0.29491	val-error:0.41941
# [67]	train-error:0.29385	val-error:0.41932
# [68]	train-error:0.29327	val-error:0.41896
# [69]	train-error:0.29227	val-error:0.41789
# [70]	train-error:0.29155	val-error:0.41726
# [71]	train-error:0.29079	val-error:0.41610
# [72]	train-error:0.28915	val-error:0.41539
# [73]	train-error:0.28862	val-error:0.41628
# [74]	train-error:0.28750	val-error:0.41717
# [75]	train-error:0.28667	val-error:0.41717
# [76]	train-error:0.28538	val-error:0.41699
# [77]	train-error:0.28413	val-error:0.41574
# [78]	train-error:0.28320	val-error:0.41565
# [79]	train-error:0.28254	val-error:0.41512
# Accuracy for iteration 4: 0.59
# Iteration 5
# [0]	train-error:0.42322	val-error:0.44938
# [1]	train-error:0.41351	val-error:0.44622
# [2]	train-error:0.40490	val-error:0.44130
# [3]	train-error:0.39736	val-error:0.43779
# [4]	train-error:0.39287	val-error:0.43699
# [5]	train-error:0.38955	val-error:0.43541
# [6]	train-error:0.38551	val-error:0.43682
# [7]	train-error:0.38256	val-error:0.43383
# [8]	train-error:0.37977	val-error:0.43234
# [9]	train-error:0.37728	val-error:0.42970
# [10]	train-error:0.37440	val-error:0.43286
# [11]	train-error:0.37199	val-error:0.42847
# [12]	train-error:0.36946	val-error:0.42830
# [13]	train-error:0.36799	val-error:0.43058
# [14]	train-error:0.36564	val-error:0.42996
# [15]	train-error:0.36314	val-error:0.42909
# [16]	train-error:0.36176	val-error:0.42759
# [17]	train-error:0.36088	val-error:0.42531
# [18]	train-error:0.35868	val-error:0.42329
# [19]	train-error:0.35654	val-error:0.42513
# [20]	train-error:0.35466	val-error:0.42583
# [21]	train-error:0.35279	val-error:0.42302
# [22]	train-error:0.35055	val-error:0.42390
# [23]	train-error:0.34935	val-error:0.42302
# [24]	train-error:0.34797	val-error:0.42258
# [25]	train-error:0.34589	val-error:0.42267
# [26]	train-error:0.34438	val-error:0.42399
# [27]	train-error:0.34469	val-error:0.42276
# [28]	train-error:0.34225	val-error:0.42408
# [29]	train-error:0.34077	val-error:0.42302
# [30]	train-error:0.33852	val-error:0.42346
# [31]	train-error:0.33758	val-error:0.42425
# [32]	train-error:0.33609	val-error:0.42373
# [33]	train-error:0.33471	val-error:0.42373
# [34]	train-error:0.33287	val-error:0.42417
# [35]	train-error:0.33147	val-error:0.42293
# [36]	train-error:0.33071	val-error:0.42381
# [37]	train-error:0.32946	val-error:0.42293
# [38]	train-error:0.32796	val-error:0.42258
# [39]	train-error:0.32704	val-error:0.42232
# [40]	train-error:0.32578	val-error:0.42162
# [41]	train-error:0.32483	val-error:0.42258
# [42]	train-error:0.32312	val-error:0.42065
# [43]	train-error:0.32192	val-error:0.42100
# [44]	train-error:0.32054	val-error:0.41880
# [45]	train-error:0.31917	val-error:0.42012
# [46]	train-error:0.31878	val-error:0.41977
# [47]	train-error:0.31710	val-error:0.42100
# [48]	train-error:0.31613	val-error:0.42091
# [49]	train-error:0.31488	val-error:0.42012
# [50]	train-error:0.31342	val-error:0.41960
# [51]	train-error:0.31220	val-error:0.41687
# [52]	train-error:0.31107	val-error:0.41608
# [53]	train-error:0.31041	val-error:0.41705
# [54]	train-error:0.30881	val-error:0.41670
# [55]	train-error:0.30821	val-error:0.41828
# [56]	train-error:0.30709	val-error:0.41749
# [57]	train-error:0.30593	val-error:0.42004
# [58]	train-error:0.30531	val-error:0.41924
# [59]	train-error:0.30397	val-error:0.41863
# [60]	train-error:0.30268	val-error:0.41924
# [61]	train-error:0.30078	val-error:0.41819
# [62]	train-error:0.29954	val-error:0.41819
# [63]	train-error:0.29812	val-error:0.41907
# [64]	train-error:0.29673	val-error:0.41837
# [65]	train-error:0.29570	val-error:0.41845
# [66]	train-error:0.29499	val-error:0.41933
# [67]	train-error:0.29353	val-error:0.41775
# [68]	train-error:0.29186	val-error:0.41766
# [69]	train-error:0.29119	val-error:0.41731
# [70]	train-error:0.29066	val-error:0.41731
# [71]	train-error:0.28965	val-error:0.41740
# [72]	train-error:0.28795	val-error:0.41687
# Accuracy for iteration 5: 0.58
# Iteration 6
# [0]	train-error:0.42171	val-error:0.45413
# [1]	train-error:0.41062	val-error:0.44377
# [2]	train-error:0.40250	val-error:0.44358
# [3]	train-error:0.39742	val-error:0.43941
# [4]	train-error:0.39326	val-error:0.44034
# [5]	train-error:0.38878	val-error:0.43590
# [6]	train-error:0.38543	val-error:0.43506
# [7]	train-error:0.38285	val-error:0.43479
# [8]	train-error:0.38172	val-error:0.43108
# [9]	train-error:0.37931	val-error:0.43201
# [10]	train-error:0.37590	val-error:0.43164
# [11]	train-error:0.37406	val-error:0.42923
# [12]	train-error:0.37167	val-error:0.42812
# [13]	train-error:0.36915	val-error:0.42803
# [14]	train-error:0.36692	val-error:0.42609
# [15]	train-error:0.36441	val-error:0.42590
# [16]	train-error:0.36251	val-error:0.42470
# [17]	train-error:0.36062	val-error:0.42340
# [18]	train-error:0.35922	val-error:0.42136
# [19]	train-error:0.35774	val-error:0.42460
# [20]	train-error:0.35526	val-error:0.42553
# [21]	train-error:0.35324	val-error:0.42534
# [22]	train-error:0.35183	val-error:0.42386
# [23]	train-error:0.35059	val-error:0.42451
# [24]	train-error:0.34837	val-error:0.42349
# [25]	train-error:0.34670	val-error:0.42414
# [26]	train-error:0.34498	val-error:0.42349
# [27]	train-error:0.34327	val-error:0.42229
# [28]	train-error:0.34201	val-error:0.42201
# [29]	train-error:0.34110	val-error:0.42090
# [30]	train-error:0.33948	val-error:0.42118
# [31]	train-error:0.33816	val-error:0.42173
# [32]	train-error:0.33728	val-error:0.41896
# [33]	train-error:0.33638	val-error:0.41849
# [34]	train-error:0.33496	val-error:0.41896
# [35]	train-error:0.33378	val-error:0.42072
# [36]	train-error:0.33207	val-error:0.41933
# [37]	train-error:0.33068	val-error:0.41942
# [38]	train-error:0.32874	val-error:0.41961
# [39]	train-error:0.32758	val-error:0.42081
# [40]	train-error:0.32526	val-error:0.42035
# [41]	train-error:0.32375	val-error:0.42072
# [42]	train-error:0.32301	val-error:0.42183
# [43]	train-error:0.32173	val-error:0.42062
# [44]	train-error:0.31948	val-error:0.42164
# [45]	train-error:0.31862	val-error:0.41970
# [46]	train-error:0.31737	val-error:0.41896
# [47]	train-error:0.31561	val-error:0.42044
# [48]	train-error:0.31447	val-error:0.42183
# [49]	train-error:0.31333	val-error:0.42257
# [50]	train-error:0.31220	val-error:0.42127
# [51]	train-error:0.31161	val-error:0.42201
# [52]	train-error:0.31074	val-error:0.42053
# [53]	train-error:0.30969	val-error:0.42090
# Accuracy for iteration 6: 0.58
# Iteration 7
# [0]	train-error:0.42878	val-error:0.44464
# [1]	train-error:0.41148	val-error:0.44343
# [2]	train-error:0.40195	val-error:0.43569
# [3]	train-error:0.39562	val-error:0.43294
# [4]	train-error:0.39238	val-error:0.43415
# [5]	train-error:0.38813	val-error:0.43312
# [6]	train-error:0.38612	val-error:0.43088
# [7]	train-error:0.38244	val-error:0.42469
# [8]	train-error:0.37979	val-error:0.42667
# [9]	train-error:0.37716	val-error:0.42684
# [10]	train-error:0.37409	val-error:0.42564
# [11]	train-error:0.37199	val-error:0.42469
# [12]	train-error:0.36966	val-error:0.42460
# [13]	train-error:0.36816	val-error:0.42452
# [14]	train-error:0.36627	val-error:0.42280
# [15]	train-error:0.36331	val-error:0.42331
# [16]	train-error:0.36187	val-error:0.42134
# [17]	train-error:0.36007	val-error:0.42331
# [18]	train-error:0.35893	val-error:0.42185
# [19]	train-error:0.35647	val-error:0.42031
# [20]	train-error:0.35570	val-error:0.42039
# [21]	train-error:0.35354	val-error:0.42117
# [22]	train-error:0.35179	val-error:0.41798
# [23]	train-error:0.35028	val-error:0.41721
# [24]	train-error:0.34846	val-error:0.41781
# [25]	train-error:0.34719	val-error:0.41893
# [26]	train-error:0.34437	val-error:0.41824
# [27]	train-error:0.34308	val-error:0.41618
# [28]	train-error:0.34131	val-error:0.41798
# [29]	train-error:0.33978	val-error:0.41893
# [30]	train-error:0.33870	val-error:0.41738
# [31]	train-error:0.33744	val-error:0.41747
# [32]	train-error:0.33558	val-error:0.41670
# [33]	train-error:0.33448	val-error:0.41549
# [34]	train-error:0.33294	val-error:0.41360
# [35]	train-error:0.33236	val-error:0.41541
# [36]	train-error:0.33081	val-error:0.41429
# [37]	train-error:0.32876	val-error:0.41523
# [38]	train-error:0.32716	val-error:0.41515
# [39]	train-error:0.32557	val-error:0.41360
# [40]	train-error:0.32432	val-error:0.41343
# [41]	train-error:0.32272	val-error:0.41360
# [42]	train-error:0.32097	val-error:0.41317
# [43]	train-error:0.32027	val-error:0.41386
# [44]	train-error:0.31882	val-error:0.41480
# [45]	train-error:0.31720	val-error:0.41360
# [46]	train-error:0.31569	val-error:0.41480
# [47]	train-error:0.31480	val-error:0.41429
# [48]	train-error:0.31408	val-error:0.41429
# [49]	train-error:0.31348	val-error:0.41334
# [50]	train-error:0.31183	val-error:0.41231
# [51]	train-error:0.31065	val-error:0.41317
# [52]	train-error:0.30938	val-error:0.41205
# [53]	train-error:0.30856	val-error:0.41343
# [54]	train-error:0.30699	val-error:0.41308
# [55]	train-error:0.30566	val-error:0.41197
# [56]	train-error:0.30446	val-error:0.41137
# [57]	train-error:0.30351	val-error:0.41222
# [58]	train-error:0.30188	val-error:0.41291
# [59]	train-error:0.30104	val-error:0.41308
# [60]	train-error:0.29997	val-error:0.41351
# [61]	train-error:0.29851	val-error:0.41360
# [62]	train-error:0.29765	val-error:0.41308
# [63]	train-error:0.29685	val-error:0.41283
# [64]	train-error:0.29571	val-error:0.41334
# [65]	train-error:0.29470	val-error:0.41463
# [66]	train-error:0.29365	val-error:0.41532
# [67]	train-error:0.29238	val-error:0.41584
# [68]	train-error:0.29118	val-error:0.41394
# [69]	train-error:0.29025	val-error:0.41480
# [70]	train-error:0.28962	val-error:0.41549
# [71]	train-error:0.28816	val-error:0.41446
# [72]	train-error:0.28661	val-error:0.41549
# [73]	train-error:0.28641	val-error:0.41480
# [74]	train-error:0.28520	val-error:0.41515
# [75]	train-error:0.28362	val-error:0.41523
# Accuracy for iteration 7: 0.59
# Average Accuracy across 7 iterations: 0.59

# %%
import numpy as np
from scipy.stats import sem, t
from scipy import mean

# Assuming accuracies are stored in the 'accuracies' list as per previous example
accuracies = np.array(accuracies)

# Calculate the mean accuracy
mean_accuracy = np.mean(accuracies)

# Calculate the standard error of the mean
std_error = sem(accuracies)

# Determine the size of the accuracies array
n = len(accuracies)

# Use the t-distribution to calculate a 95% confidence interval
confidence = 0.95
h = std_error * t.ppf((1 + confidence) / 2, n - 1)

# Print the mean accuracy and confidence interval
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"95% Confidence interval: {mean_accuracy - h:.5f} - {mean_accuracy + h:.5f}")
# Out:
# Mean Accuracy: 0.59
# 95% Confidence interval: 0.58239 - 0.58959

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.58      0.59      0.59      5816
#         High       0.59      0.58      0.58      5816
#
#     accuracy                           0.58     11632
#    macro avg       0.58      0.58      0.58     11632
# weighted avg       0.58      0.58      0.58     11632

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.59      0.59      0.59      5513
#         High       0.59      0.59      0.59      5512
#
#     accuracy                           0.59     11025
#    macro avg       0.59      0.59      0.59     11025
# weighted avg       0.59      0.59      0.59     11025
