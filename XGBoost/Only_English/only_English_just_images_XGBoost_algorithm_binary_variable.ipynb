# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = image_columns + additional_columns_to_keep #+ text_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2 = data_2[data_2['Image_Count'] <= 1]
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Is_English  Image_Count   image_0   image_1   image_2  ...  image_2038  \
# 0         True            1  0.483804  4.411579  0.103043  ...    1.348099
# 1         True            1  1.257535  4.292836  0.637026  ...    0.062803
# 2         True            1  1.015909  4.928564  0.049328  ...    0.912411
# 4         True            1  0.961807  3.994127  0.116529  ...    0.236971
# 9         True            1  1.316597  1.515859  0.067210  ...    0.688856
# 10        True            1  1.682237  1.290816  0.079366  ...    0.732811
# 11        True            1  0.923607  3.838140  0.041025  ...    0.067140
# 12        True            1  0.044586  1.376372  0.007699  ...    0.488087
# 13        True            1  0.012054  0.549083  0.087380  ...    0.000000
# 14        True            1  0.587146  4.310180  0.034403  ...    0.000000
#
#     image_2039  image_2040  image_2041  image_2042  image_2043  image_2044  \
# 0     1.255268    1.463130    0.009248    0.058511    0.376918    0.074638
# 1     1.595342    1.707724    0.503333    0.000000    0.247264    0.000000
# 2     0.933246    0.092337    0.000000    0.739149    0.053084    0.286910
# 4     0.304974    0.508712    0.007309    0.041686    0.251861    0.332315
# 9     0.029724    1.511134    2.223945    0.530757    1.199176    0.185630
# 10    0.068392    1.555978    1.935349    0.074037    0.000000    0.388744
# 11    0.983345    1.730492    1.107379    0.053516    0.016675    0.337402
# 12    0.069210    1.433544    1.099280    0.061995    0.201946    0.786074
# 13    0.250658    0.149904    0.183440    0.350276    0.032225    0.459521
# 14    0.106569    0.246567    0.022366    0.106139    0.228331    0.154189
#
#     image_2045  image_2046  image_2047
# 0     0.010091    2.309669    0.894978
# 1     0.219100    0.410729    0.398495
# 2     0.608811    2.130039    1.679261
# 4     0.708797    0.688740    1.216255
# 9     0.110657    0.000000    0.806424
# 10    0.005011    0.227181    0.187945
# 11    2.163658    1.009122    0.403215
# 12    0.799035    0.000000    0.824184
# 13    1.822460    0.957111    0.937546
# 14    0.998335    0.033519    2.437387
#
# [10 rows x 2055 columns]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))
# Out:
# <ipython-input-7-747e2ff0d805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.42636	val-error:0.44796
# [1]	train-error:0.41546	val-error:0.44612
# [2]	train-error:0.41031	val-error:0.44752
# [3]	train-error:0.40695	val-error:0.44049
# [4]	train-error:0.40352	val-error:0.44356
# [5]	train-error:0.39927	val-error:0.44312
# [6]	train-error:0.39780	val-error:0.44400
# [7]	train-error:0.39512	val-error:0.44436
# [8]	train-error:0.39326	val-error:0.44480
# [9]	train-error:0.39111	val-error:0.44233
# [10]	train-error:0.38862	val-error:0.44101
# [11]	train-error:0.38687	val-error:0.44040
# [12]	train-error:0.38548	val-error:0.44172
# [13]	train-error:0.38386	val-error:0.43890
# [14]	train-error:0.38334	val-error:0.43670
# [15]	train-error:0.38207	val-error:0.43793
# [16]	train-error:0.38025	val-error:0.43661
# [17]	train-error:0.37800	val-error:0.43565
# [18]	train-error:0.37785	val-error:0.43521
# [19]	train-error:0.37603	val-error:0.43547
# [20]	train-error:0.37393	val-error:0.43661
# [21]	train-error:0.37118	val-error:0.43785
# [22]	train-error:0.37005	val-error:0.43565
# [23]	train-error:0.36862	val-error:0.43556
# [24]	train-error:0.36672	val-error:0.43714
# [25]	train-error:0.36473	val-error:0.43670
# [26]	train-error:0.36303	val-error:0.43793
# [27]	train-error:0.36124	val-error:0.43705
# [28]	train-error:0.35929	val-error:0.43714
# [29]	train-error:0.35752	val-error:0.43785
# [30]	train-error:0.35529	val-error:0.43714
# [31]	train-error:0.35377	val-error:0.43679
# [32]	train-error:0.35158	val-error:0.43899
# [33]	train-error:0.35043	val-error:0.43697
# [34]	train-error:0.34843	val-error:0.43837
# [35]	train-error:0.34721	val-error:0.43697
# [36]	train-error:0.34451	val-error:0.43591
# [37]	train-error:0.34354	val-error:0.43582
# Accuracy for iteration 1: 0.56
# Iteration 2
# [0]	train-error:0.42312	val-error:0.43552
# [1]	train-error:0.41526	val-error:0.43385
# [2]	train-error:0.41180	val-error:0.43306
# [3]	train-error:0.40808	val-error:0.43605
# [4]	train-error:0.40507	val-error:0.43605
# [5]	train-error:0.40183	val-error:0.43499
# [6]	train-error:0.39989	val-error:0.43235
# [7]	train-error:0.39885	val-error:0.43552
# [8]	train-error:0.39652	val-error:0.43209
# [9]	train-error:0.39482	val-error:0.42963
# [10]	train-error:0.39298	val-error:0.42910
# [11]	train-error:0.39053	val-error:0.43077
# [12]	train-error:0.38942	val-error:0.43024
# [13]	train-error:0.38726	val-error:0.43086
# [14]	train-error:0.38503	val-error:0.43015
# [15]	train-error:0.38336	val-error:0.43183
# [16]	train-error:0.38131	val-error:0.42910
# [17]	train-error:0.37933	val-error:0.42884
# [18]	train-error:0.37795	val-error:0.42936
# [19]	train-error:0.37592	val-error:0.42716
# [20]	train-error:0.37392	val-error:0.42822
# [21]	train-error:0.37312	val-error:0.42796
# [22]	train-error:0.37109	val-error:0.42752
# [23]	train-error:0.36976	val-error:0.42646
# [24]	train-error:0.36709	val-error:0.42488
# [25]	train-error:0.36503	val-error:0.42549
# [26]	train-error:0.36449	val-error:0.42628
# [27]	train-error:0.36297	val-error:0.42576
# [28]	train-error:0.36025	val-error:0.42532
# [29]	train-error:0.35834	val-error:0.42470
# [30]	train-error:0.35641	val-error:0.42523
# [31]	train-error:0.35546	val-error:0.42461
# [32]	train-error:0.35319	val-error:0.42400
# [33]	train-error:0.35229	val-error:0.42321
# [34]	train-error:0.35027	val-error:0.42338
# [35]	train-error:0.34888	val-error:0.42488
# [36]	train-error:0.34652	val-error:0.42444
# [37]	train-error:0.34472	val-error:0.42672
# [38]	train-error:0.34298	val-error:0.42532
# [39]	train-error:0.34068	val-error:0.42576
# [40]	train-error:0.33870	val-error:0.42514
# [41]	train-error:0.33672	val-error:0.42294
# [42]	train-error:0.33400	val-error:0.42259
# [43]	train-error:0.33312	val-error:0.42479
# [44]	train-error:0.33130	val-error:0.42426
# [45]	train-error:0.33063	val-error:0.42365
# [46]	train-error:0.32849	val-error:0.42365
# [47]	train-error:0.32702	val-error:0.42435
# [48]	train-error:0.32454	val-error:0.42329
# [49]	train-error:0.32276	val-error:0.42347
# [50]	train-error:0.32122	val-error:0.42347
# [51]	train-error:0.31886	val-error:0.42470
# [52]	train-error:0.31806	val-error:0.42496
# [53]	train-error:0.31579	val-error:0.42285
# [54]	train-error:0.31431	val-error:0.42417
# [55]	train-error:0.31307	val-error:0.42576
# [56]	train-error:0.31097	val-error:0.42734
# [57]	train-error:0.30947	val-error:0.42699
# [58]	train-error:0.30826	val-error:0.42514
# [59]	train-error:0.30649	val-error:0.42294
# [60]	train-error:0.30461	val-error:0.42593
# [61]	train-error:0.30331	val-error:0.42725
# [62]	train-error:0.30197	val-error:0.42470
# Accuracy for iteration 2: 0.56
# Iteration 3
# [0]	train-error:0.42554	val-error:0.44132
# [1]	train-error:0.41790	val-error:0.43555
# [2]	train-error:0.41377	val-error:0.43193
# [3]	train-error:0.41066	val-error:0.43253
# [4]	train-error:0.40564	val-error:0.42857
# [5]	train-error:0.40113	val-error:0.42728
# [6]	train-error:0.39748	val-error:0.42642
# [7]	train-error:0.39651	val-error:0.42840
# [8]	train-error:0.39436	val-error:0.42633
# [9]	train-error:0.39199	val-error:0.42668
# [10]	train-error:0.39007	val-error:0.42392
# [11]	train-error:0.38840	val-error:0.42366
# [12]	train-error:0.38623	val-error:0.42237
# [13]	train-error:0.38369	val-error:0.42151
# [14]	train-error:0.38192	val-error:0.42064
# [15]	train-error:0.38060	val-error:0.42056
# [16]	train-error:0.37879	val-error:0.42073
# [17]	train-error:0.37591	val-error:0.42159
# [18]	train-error:0.37457	val-error:0.42125
# [19]	train-error:0.37299	val-error:0.42271
# [20]	train-error:0.37127	val-error:0.42056
# [21]	train-error:0.36974	val-error:0.42116
# [22]	train-error:0.36808	val-error:0.42099
# [23]	train-error:0.36612	val-error:0.42056
# [24]	train-error:0.36448	val-error:0.42116
# [25]	train-error:0.36203	val-error:0.42056
# [26]	train-error:0.35996	val-error:0.41909
# [27]	train-error:0.35801	val-error:0.41918
# [28]	train-error:0.35600	val-error:0.42090
# [29]	train-error:0.35464	val-error:0.42220
# [30]	train-error:0.35304	val-error:0.42245
# [31]	train-error:0.35113	val-error:0.42176
# [32]	train-error:0.34932	val-error:0.42237
# [33]	train-error:0.34760	val-error:0.42168
# [34]	train-error:0.34538	val-error:0.42159
# [35]	train-error:0.34329	val-error:0.42211
# [36]	train-error:0.34177	val-error:0.42314
# [37]	train-error:0.34021	val-error:0.42176
# [38]	train-error:0.33906	val-error:0.42271
# [39]	train-error:0.33679	val-error:0.42452
# [40]	train-error:0.33535	val-error:0.42400
# [41]	train-error:0.33364	val-error:0.42375
# [42]	train-error:0.33193	val-error:0.42263
# [43]	train-error:0.33028	val-error:0.42254
# [44]	train-error:0.32815	val-error:0.42237
# [45]	train-error:0.32648	val-error:0.42168
# [46]	train-error:0.32406	val-error:0.42280
# Accuracy for iteration 3: 0.56
# Iteration 4
# [0]	train-error:0.42776	val-error:0.45220
# [1]	train-error:0.41641	val-error:0.44451
# [2]	train-error:0.41132	val-error:0.44353
# [3]	train-error:0.40727	val-error:0.44076
# [4]	train-error:0.40506	val-error:0.44273
# [5]	train-error:0.40329	val-error:0.44157
# [6]	train-error:0.39979	val-error:0.44192
# [7]	train-error:0.39917	val-error:0.43853
# [8]	train-error:0.39637	val-error:0.44058
# [9]	train-error:0.39383	val-error:0.44076
# [10]	train-error:0.39183	val-error:0.43978
# [11]	train-error:0.38991	val-error:0.44023
# [12]	train-error:0.38716	val-error:0.43862
# [13]	train-error:0.38580	val-error:0.43942
# [14]	train-error:0.38301	val-error:0.44058
# [15]	train-error:0.38176	val-error:0.43942
# [16]	train-error:0.37983	val-error:0.43835
# [17]	train-error:0.37865	val-error:0.43844
# [18]	train-error:0.37615	val-error:0.43978
# [19]	train-error:0.37444	val-error:0.43951
# [20]	train-error:0.37353	val-error:0.43969
# [21]	train-error:0.37122	val-error:0.43719
# [22]	train-error:0.36982	val-error:0.43826
# [23]	train-error:0.36836	val-error:0.43737
# [24]	train-error:0.36617	val-error:0.43692
# [25]	train-error:0.36419	val-error:0.43737
# [26]	train-error:0.36298	val-error:0.43862
# [27]	train-error:0.36164	val-error:0.43486
# [28]	train-error:0.35912	val-error:0.43469
# [29]	train-error:0.35792	val-error:0.43513
# [30]	train-error:0.35668	val-error:0.43629
# [31]	train-error:0.35555	val-error:0.43585
# [32]	train-error:0.35348	val-error:0.43576
# [33]	train-error:0.35272	val-error:0.43620
# [34]	train-error:0.35084	val-error:0.43522
# [35]	train-error:0.34997	val-error:0.43495
# [36]	train-error:0.34832	val-error:0.43522
# [37]	train-error:0.34660	val-error:0.43504
# [38]	train-error:0.34534	val-error:0.43504
# [39]	train-error:0.34372	val-error:0.43665
# [40]	train-error:0.34234	val-error:0.43629
# [41]	train-error:0.33986	val-error:0.43665
# [42]	train-error:0.33814	val-error:0.43772
# [43]	train-error:0.33656	val-error:0.43763
# [44]	train-error:0.33419	val-error:0.43674
# [45]	train-error:0.33211	val-error:0.43763
# [46]	train-error:0.33018	val-error:0.43763
# [47]	train-error:0.32857	val-error:0.43656
# Accuracy for iteration 4: 0.56
# Iteration 5
# [0]	train-error:0.42752	val-error:0.45062
# [1]	train-error:0.41730	val-error:0.45387
# [2]	train-error:0.41105	val-error:0.45009
# [3]	train-error:0.40755	val-error:0.44824
# [4]	train-error:0.40358	val-error:0.44684
# [5]	train-error:0.40181	val-error:0.44736
# [6]	train-error:0.40022	val-error:0.44359
# [7]	train-error:0.39877	val-error:0.44578
# [8]	train-error:0.39599	val-error:0.44736
# [9]	train-error:0.39375	val-error:0.44490
# [10]	train-error:0.39281	val-error:0.44666
# [11]	train-error:0.38954	val-error:0.44525
# [12]	train-error:0.38811	val-error:0.44455
# [13]	train-error:0.38639	val-error:0.44587
# [14]	train-error:0.38457	val-error:0.44675
# [15]	train-error:0.38220	val-error:0.44745
# [16]	train-error:0.38057	val-error:0.44789
# [17]	train-error:0.37783	val-error:0.44745
# [18]	train-error:0.37653	val-error:0.44605
# [19]	train-error:0.37459	val-error:0.44438
# [20]	train-error:0.37324	val-error:0.44209
# [21]	train-error:0.37172	val-error:0.44341
# [22]	train-error:0.37025	val-error:0.44341
# [23]	train-error:0.36856	val-error:0.44244
# [24]	train-error:0.36721	val-error:0.44385
# [25]	train-error:0.36528	val-error:0.44385
# [26]	train-error:0.36328	val-error:0.44350
# [27]	train-error:0.36126	val-error:0.44200
# [28]	train-error:0.35997	val-error:0.44183
# [29]	train-error:0.35852	val-error:0.44288
# [30]	train-error:0.35572	val-error:0.44200
# [31]	train-error:0.35409	val-error:0.44359
# [32]	train-error:0.35198	val-error:0.44359
# [33]	train-error:0.35069	val-error:0.44341
# [34]	train-error:0.34833	val-error:0.44288
# [35]	train-error:0.34711	val-error:0.44306
# [36]	train-error:0.34520	val-error:0.44077
# [37]	train-error:0.34308	val-error:0.44016
# [38]	train-error:0.34242	val-error:0.44042
# [39]	train-error:0.34095	val-error:0.43972
# [40]	train-error:0.33922	val-error:0.44104
# [41]	train-error:0.33738	val-error:0.44218
# [42]	train-error:0.33565	val-error:0.44411
# [43]	train-error:0.33378	val-error:0.44394
# [44]	train-error:0.33190	val-error:0.44411
# [45]	train-error:0.33082	val-error:0.44306
# [46]	train-error:0.32848	val-error:0.44332
# [47]	train-error:0.32658	val-error:0.44174
# [48]	train-error:0.32524	val-error:0.44218
# [49]	train-error:0.32337	val-error:0.44209
# [50]	train-error:0.32104	val-error:0.44253
# [51]	train-error:0.31913	val-error:0.44148
# [52]	train-error:0.31708	val-error:0.44112
# [53]	train-error:0.31540	val-error:0.44192
# [54]	train-error:0.31457	val-error:0.44192
# [55]	train-error:0.31297	val-error:0.44297
# [56]	train-error:0.31159	val-error:0.44253
# [57]	train-error:0.30993	val-error:0.44069
# [58]	train-error:0.30764	val-error:0.44112
# Accuracy for iteration 5: 0.56
# Iteration 6
# [0]	train-error:0.42702	val-error:0.44969
# [1]	train-error:0.41495	val-error:0.44728
# [2]	train-error:0.41038	val-error:0.44571
# [3]	train-error:0.40825	val-error:0.44534
# [4]	train-error:0.40378	val-error:0.44367
# [5]	train-error:0.40019	val-error:0.44265
# [6]	train-error:0.39813	val-error:0.44145
# [7]	train-error:0.39646	val-error:0.44238
# [8]	train-error:0.39450	val-error:0.44182
# [9]	train-error:0.39322	val-error:0.44025
# [10]	train-error:0.39173	val-error:0.44136
# [11]	train-error:0.39015	val-error:0.44321
# [12]	train-error:0.38808	val-error:0.44006
# [13]	train-error:0.38610	val-error:0.43904
# [14]	train-error:0.38369	val-error:0.43886
# [15]	train-error:0.38218	val-error:0.43886
# [16]	train-error:0.38090	val-error:0.43858
# [17]	train-error:0.37842	val-error:0.43830
# [18]	train-error:0.37742	val-error:0.43775
# [19]	train-error:0.37522	val-error:0.43766
# [20]	train-error:0.37352	val-error:0.43590
# [21]	train-error:0.37195	val-error:0.43479
# [22]	train-error:0.37034	val-error:0.43562
# [23]	train-error:0.36876	val-error:0.43655
# [24]	train-error:0.36801	val-error:0.43636
# [25]	train-error:0.36647	val-error:0.43618
# [26]	train-error:0.36416	val-error:0.43710
# [27]	train-error:0.36262	val-error:0.43534
# [28]	train-error:0.36111	val-error:0.43479
# [29]	train-error:0.35931	val-error:0.43608
# [30]	train-error:0.35758	val-error:0.43414
# [31]	train-error:0.35641	val-error:0.43673
# [32]	train-error:0.35473	val-error:0.43618
# [33]	train-error:0.35210	val-error:0.43775
# [34]	train-error:0.35100	val-error:0.43701
# [35]	train-error:0.34911	val-error:0.43682
# [36]	train-error:0.34734	val-error:0.43747
# [37]	train-error:0.34567	val-error:0.43710
# [38]	train-error:0.34475	val-error:0.43719
# [39]	train-error:0.34320	val-error:0.43645
# [40]	train-error:0.34170	val-error:0.43655
# [41]	train-error:0.33985	val-error:0.43608
# [42]	train-error:0.33729	val-error:0.43562
# [43]	train-error:0.33633	val-error:0.43608
# [44]	train-error:0.33549	val-error:0.43618
# [45]	train-error:0.33365	val-error:0.43553
# [46]	train-error:0.33178	val-error:0.43664
# [47]	train-error:0.33034	val-error:0.43618
# [48]	train-error:0.32863	val-error:0.43803
# [49]	train-error:0.32602	val-error:0.43747
# [50]	train-error:0.32386	val-error:0.43812
# Accuracy for iteration 6: 0.57
# Iteration 7
# [0]	train-error:0.42538	val-error:0.43277
# [1]	train-error:0.41762	val-error:0.43260
# [2]	train-error:0.41059	val-error:0.43423
# [3]	train-error:0.40712	val-error:0.43243
# [4]	train-error:0.40466	val-error:0.42933
# [5]	train-error:0.40127	val-error:0.42658
# [6]	train-error:0.40032	val-error:0.42899
# [7]	train-error:0.39666	val-error:0.43140
# [8]	train-error:0.39398	val-error:0.43002
# [9]	train-error:0.39262	val-error:0.42959
# [10]	train-error:0.38969	val-error:0.42779
# [11]	train-error:0.38796	val-error:0.42830
# [12]	train-error:0.38636	val-error:0.42744
# [13]	train-error:0.38383	val-error:0.42787
# [14]	train-error:0.38188	val-error:0.42650
# [15]	train-error:0.38038	val-error:0.42701
# [16]	train-error:0.37861	val-error:0.42736
# [17]	train-error:0.37622	val-error:0.42822
# [18]	train-error:0.37564	val-error:0.42693
# [19]	train-error:0.37369	val-error:0.42770
# [20]	train-error:0.37211	val-error:0.42804
# [21]	train-error:0.36928	val-error:0.42443
# [22]	train-error:0.36699	val-error:0.42701
# [23]	train-error:0.36530	val-error:0.42675
# [24]	train-error:0.36382	val-error:0.42495
# [25]	train-error:0.36208	val-error:0.42787
# [26]	train-error:0.36062	val-error:0.42598
# [27]	train-error:0.35889	val-error:0.42521
# [28]	train-error:0.35682	val-error:0.42701
# [29]	train-error:0.35537	val-error:0.42658
# [30]	train-error:0.35314	val-error:0.42607
# [31]	train-error:0.35087	val-error:0.42589
# [32]	train-error:0.34921	val-error:0.42589
# [33]	train-error:0.34802	val-error:0.42641
# [34]	train-error:0.34593	val-error:0.42598
# [35]	train-error:0.34430	val-error:0.42607
# [36]	train-error:0.34307	val-error:0.42667
# [37]	train-error:0.34070	val-error:0.42572
# [38]	train-error:0.33887	val-error:0.42641
# [39]	train-error:0.33723	val-error:0.42727
# [40]	train-error:0.33568	val-error:0.42572
# Accuracy for iteration 7: 0.57
# Average Accuracy across 7 iterations: 0.56

# %%
import numpy as np
from scipy.stats import sem, t
from scipy import mean

# Assuming accuracies are stored in the 'accuracies' list as per previous example
accuracies = np.array(accuracies)

# Calculate the mean accuracy
mean_accuracy = np.mean(accuracies)

# Calculate the standard error of the mean
std_error = sem(accuracies)

# Determine the size of the accuracies array
n = len(accuracies)

# Use the t-distribution to calculate a 95% confidence interval
confidence = 0.95
h = std_error * t.ppf((1 + confidence) / 2, n - 1)

# Print the mean accuracy and confidence interval
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"95% Confidence interval: {mean_accuracy - h:.5f} - {mean_accuracy + h:.5f}")
# Out:
# Mean Accuracy: 0.56
# 95% Confidence interval: 0.56023 - 0.56664

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.58      0.53      0.55      5816
#         High       0.57      0.62      0.59      5816
#
#     accuracy                           0.57     11632
#    macro avg       0.57      0.57      0.57     11632
# weighted avg       0.57      0.57      0.57     11632

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.57      0.54      0.56      5513
#         High       0.56      0.60      0.58      5512
#
#     accuracy                           0.57     11025
#    macro avg       0.57      0.57      0.57     11025
# weighted avg       0.57      0.57      0.57     11025
