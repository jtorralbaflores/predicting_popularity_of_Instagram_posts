# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep + text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2 = data_2[data_2['Image_Count'] <= 1]
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Followees  Posts  Is_English  Image_Count   image_0  ...  text_758  \
# 0         710   1059        True            1  0.483804  ... -0.155746
# 1         710   1059        True            1  1.257535  ... -0.247792
# 2         710   1059        True            1  1.015909  ... -0.089539
# 4         710   1059        True            1  0.961807  ... -0.112963
# 9        7069    261        True            1  1.316597  ... -0.147682
# 10       7069    261        True            1  1.682237  ... -0.009259
# 11       7069    261        True            1  0.923607  ... -0.092988
# 12       7069    261        True            1  0.044586  ... -0.161618
# 13        523    487        True            1  0.012054  ... -0.162583
# 14        523    487        True            1  0.587146  ... -0.114496
#
#     text_759  text_760  text_761  text_762  text_763  text_764  text_765  \
# 0  -0.017703 -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870
# 1   0.015757 -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263
# 2  -0.097885 -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142
# 4  -0.036261 -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846
# 9  -0.036988 -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471
# 10 -0.165627  0.198171  0.093986  0.176528  0.140797  0.070081 -0.168545
# 11 -0.083701  0.228142  0.049256  0.080081  0.093756  0.086833 -0.163537
# 12 -0.178489  0.159561 -0.046662  0.182022  0.127947  0.299180 -0.091949
# 13  0.028141 -0.179497  0.085646  0.179977  0.134104  0.239402  0.052813
# 14 -0.001124 -0.172151  0.021455  0.215737  0.150555  0.408500 -0.234415
#
#     text_766  text_767
# 0   0.062999  0.075272
# 1  -0.012400  0.147600
# 2   0.094179  0.080168
# 4   0.141513  0.093924
# 9   0.012900  0.064740
# 10  0.107152  0.057365
# 11  0.100750  0.096130
# 12  0.096147  0.045425
# 13  0.030690 -0.044792
# 14  0.109303 -0.072184
#
# [10 rows x 2825 columns]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))
# Out:
# <ipython-input-7-747e2ff0d805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Normalize the selected features
    columns_to_normalize = ['Followers', 'Followees', 'Posts']
    scaler = StandardScaler().fit(train_data[columns_to_normalize])
    train_data.loc[:, columns_to_normalize] = scaler.transform(train_data[columns_to_normalize])
    val_data.loc[:, columns_to_normalize] = scaler.transform(val_data[columns_to_normalize])
    test_data.loc[:, columns_to_normalize] = scaler.transform(test_data[columns_to_normalize])

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.33641	val-error:0.35594
# [1]	train-error:0.32745	val-error:0.34855
# [2]	train-error:0.32468	val-error:0.34952
# [3]	train-error:0.32213	val-error:0.34547
# [4]	train-error:0.31892	val-error:0.34275
# [5]	train-error:0.31630	val-error:0.34064
# [6]	train-error:0.31440	val-error:0.33932
# [7]	train-error:0.31196	val-error:0.34020
# [8]	train-error:0.31041	val-error:0.33808
# [9]	train-error:0.30907	val-error:0.33703
# [10]	train-error:0.30696	val-error:0.33791
# [11]	train-error:0.30594	val-error:0.33738
# [12]	train-error:0.30372	val-error:0.33518
# [13]	train-error:0.30316	val-error:0.33465
# [14]	train-error:0.30194	val-error:0.33474
# [15]	train-error:0.30051	val-error:0.33527
# [16]	train-error:0.29914	val-error:0.33430
# [17]	train-error:0.29818	val-error:0.33272
# [18]	train-error:0.29746	val-error:0.33333
# [19]	train-error:0.29595	val-error:0.33333
# [20]	train-error:0.29483	val-error:0.33342
# [21]	train-error:0.29313	val-error:0.33210
# [22]	train-error:0.29207	val-error:0.33105
# [23]	train-error:0.29024	val-error:0.32911
# [24]	train-error:0.28900	val-error:0.32779
# [25]	train-error:0.28789	val-error:0.32665
# [26]	train-error:0.28638	val-error:0.32735
# [27]	train-error:0.28536	val-error:0.32594
# [28]	train-error:0.28378	val-error:0.32621
# [29]	train-error:0.28253	val-error:0.32700
# [30]	train-error:0.28084	val-error:0.32594
# [31]	train-error:0.27961	val-error:0.32454
# [32]	train-error:0.27848	val-error:0.32542
# [33]	train-error:0.27723	val-error:0.32550
# [34]	train-error:0.27577	val-error:0.32471
# [35]	train-error:0.27471	val-error:0.32401
# [36]	train-error:0.27353	val-error:0.32304
# [37]	train-error:0.27238	val-error:0.32322
# [38]	train-error:0.27147	val-error:0.32295
# [39]	train-error:0.27016	val-error:0.32392
# [40]	train-error:0.26864	val-error:0.32225
# [41]	train-error:0.26731	val-error:0.32225
# [42]	train-error:0.26667	val-error:0.32348
# [43]	train-error:0.26552	val-error:0.32269
# [44]	train-error:0.26422	val-error:0.32348
# [45]	train-error:0.26329	val-error:0.32357
# [46]	train-error:0.26239	val-error:0.32190
# [47]	train-error:0.26168	val-error:0.32084
# [48]	train-error:0.25974	val-error:0.32110
# [49]	train-error:0.25907	val-error:0.32190
# [50]	train-error:0.25798	val-error:0.32110
# [51]	train-error:0.25728	val-error:0.32067
# [52]	train-error:0.25632	val-error:0.32023
# [53]	train-error:0.25509	val-error:0.32023
# [54]	train-error:0.25448	val-error:0.32031
# [55]	train-error:0.25325	val-error:0.31970
# [56]	train-error:0.25268	val-error:0.31943
# [57]	train-error:0.25178	val-error:0.32058
# [58]	train-error:0.25067	val-error:0.31926
# [59]	train-error:0.25017	val-error:0.31961
# [60]	train-error:0.24933	val-error:0.31847
# [61]	train-error:0.24809	val-error:0.31891
# [62]	train-error:0.24735	val-error:0.31979
# [63]	train-error:0.24637	val-error:0.31767
# [64]	train-error:0.24578	val-error:0.31794
# [65]	train-error:0.24475	val-error:0.31732
# [66]	train-error:0.24378	val-error:0.31679
# [67]	train-error:0.24273	val-error:0.31697
# [68]	train-error:0.24171	val-error:0.31811
# [69]	train-error:0.24047	val-error:0.31794
# [70]	train-error:0.23936	val-error:0.31811
# [71]	train-error:0.23859	val-error:0.31715
# [72]	train-error:0.23766	val-error:0.31759
# [73]	train-error:0.23690	val-error:0.31794
# [74]	train-error:0.23628	val-error:0.31864
# [75]	train-error:0.23528	val-error:0.31785
# [76]	train-error:0.23437	val-error:0.31759
# [77]	train-error:0.23356	val-error:0.31785
# [78]	train-error:0.23244	val-error:0.31776
# [79]	train-error:0.23197	val-error:0.31829
# [80]	train-error:0.23174	val-error:0.31864
# [81]	train-error:0.23080	val-error:0.31917
# [82]	train-error:0.23011	val-error:0.31917
# [83]	train-error:0.22949	val-error:0.31820
# [84]	train-error:0.22844	val-error:0.31794
# [85]	train-error:0.22735	val-error:0.31873
# Accuracy for iteration 1: 0.69
# Iteration 2
# [0]	train-error:0.33541	val-error:0.35644
# [1]	train-error:0.32724	val-error:0.34368
# [2]	train-error:0.32318	val-error:0.34105
# [3]	train-error:0.32070	val-error:0.33594
# [4]	train-error:0.31871	val-error:0.33568
# [5]	train-error:0.31717	val-error:0.33304
# [6]	train-error:0.31486	val-error:0.33348
# [7]	train-error:0.31369	val-error:0.33638
# [8]	train-error:0.31123	val-error:0.33251
# [9]	train-error:0.31065	val-error:0.33242
# [10]	train-error:0.30885	val-error:0.33137
# [11]	train-error:0.30792	val-error:0.32979
# [12]	train-error:0.30647	val-error:0.32926
# [13]	train-error:0.30545	val-error:0.32847
# [14]	train-error:0.30344	val-error:0.32723
# [15]	train-error:0.30190	val-error:0.32715
# [16]	train-error:0.30081	val-error:0.32679
# [17]	train-error:0.29945	val-error:0.32512
# [18]	train-error:0.29774	val-error:0.32398
# [19]	train-error:0.29666	val-error:0.32424
# [20]	train-error:0.29490	val-error:0.32275
# [21]	train-error:0.29298	val-error:0.31976
# [22]	train-error:0.29211	val-error:0.31985
# [23]	train-error:0.29044	val-error:0.31932
# [24]	train-error:0.28933	val-error:0.31791
# [25]	train-error:0.28787	val-error:0.31641
# [26]	train-error:0.28656	val-error:0.31773
# [27]	train-error:0.28571	val-error:0.31589
# [28]	train-error:0.28460	val-error:0.31659
# [29]	train-error:0.28298	val-error:0.31580
# [30]	train-error:0.28187	val-error:0.31510
# [31]	train-error:0.28061	val-error:0.31545
# [32]	train-error:0.27887	val-error:0.31510
# [33]	train-error:0.27802	val-error:0.31703
# [34]	train-error:0.27682	val-error:0.31492
# [35]	train-error:0.27554	val-error:0.31413
# [36]	train-error:0.27438	val-error:0.31466
# [37]	train-error:0.27343	val-error:0.31386
# [38]	train-error:0.27118	val-error:0.31351
# [39]	train-error:0.27017	val-error:0.31334
# [40]	train-error:0.26946	val-error:0.31342
# [41]	train-error:0.26866	val-error:0.31316
# [42]	train-error:0.26759	val-error:0.31237
# [43]	train-error:0.26654	val-error:0.31281
# [44]	train-error:0.26554	val-error:0.31237
# [45]	train-error:0.26389	val-error:0.31158
# [46]	train-error:0.26353	val-error:0.31246
# [47]	train-error:0.26234	val-error:0.31246
# [48]	train-error:0.26140	val-error:0.31228
# [49]	train-error:0.26012	val-error:0.31043
# [50]	train-error:0.25957	val-error:0.31061
# [51]	train-error:0.25857	val-error:0.31017
# [52]	train-error:0.25805	val-error:0.30982
# [53]	train-error:0.25712	val-error:0.30885
# [54]	train-error:0.25649	val-error:0.30903
# [55]	train-error:0.25574	val-error:0.30964
# [56]	train-error:0.25455	val-error:0.31026
# [57]	train-error:0.25356	val-error:0.30955
# [58]	train-error:0.25238	val-error:0.30832
# [59]	train-error:0.25167	val-error:0.30876
# [60]	train-error:0.25081	val-error:0.30753
# [61]	train-error:0.25004	val-error:0.30806
# [62]	train-error:0.24910	val-error:0.30815
# [63]	train-error:0.24803	val-error:0.30709
# [64]	train-error:0.24720	val-error:0.30894
# [65]	train-error:0.24660	val-error:0.30850
# [66]	train-error:0.24585	val-error:0.30762
# [67]	train-error:0.24500	val-error:0.30691
# [68]	train-error:0.24408	val-error:0.30788
# [69]	train-error:0.24326	val-error:0.30691
# [70]	train-error:0.24234	val-error:0.30551
# [71]	train-error:0.24152	val-error:0.30700
# [72]	train-error:0.24037	val-error:0.30691
# [73]	train-error:0.23894	val-error:0.30656
# [74]	train-error:0.23842	val-error:0.30683
# [75]	train-error:0.23760	val-error:0.30647
# [76]	train-error:0.23644	val-error:0.30718
# [77]	train-error:0.23537	val-error:0.30639
# [78]	train-error:0.23416	val-error:0.30577
# [79]	train-error:0.23333	val-error:0.30647
# [80]	train-error:0.23241	val-error:0.30683
# [81]	train-error:0.23173	val-error:0.30595
# [82]	train-error:0.23082	val-error:0.30595
# [83]	train-error:0.22976	val-error:0.30718
# [84]	train-error:0.22877	val-error:0.30621
# [85]	train-error:0.22776	val-error:0.30612
# [86]	train-error:0.22667	val-error:0.30515
# [87]	train-error:0.22562	val-error:0.30577
# [88]	train-error:0.22511	val-error:0.30568
# [89]	train-error:0.22385	val-error:0.30533
# [90]	train-error:0.22306	val-error:0.30612
# [91]	train-error:0.22194	val-error:0.30542
# [92]	train-error:0.22113	val-error:0.30551
# [93]	train-error:0.22072	val-error:0.30586
# [94]	train-error:0.22011	val-error:0.30586
# [95]	train-error:0.21913	val-error:0.30595
# [96]	train-error:0.21851	val-error:0.30577
# [97]	train-error:0.21802	val-error:0.30524
# [98]	train-error:0.21720	val-error:0.30533
# [99]	train-error:0.21664	val-error:0.30542
# [100]	train-error:0.21532	val-error:0.30542
# [101]	train-error:0.21475	val-error:0.30507
# [102]	train-error:0.21423	val-error:0.30489
# [103]	train-error:0.21326	val-error:0.30498
# [104]	train-error:0.21255	val-error:0.30489
# [105]	train-error:0.21182	val-error:0.30410
# [106]	train-error:0.21033	val-error:0.30401
# [107]	train-error:0.20931	val-error:0.30524
# [108]	train-error:0.20875	val-error:0.30498
# [109]	train-error:0.20773	val-error:0.30542
# [110]	train-error:0.20711	val-error:0.30603
# [111]	train-error:0.20653	val-error:0.30612
# [112]	train-error:0.20595	val-error:0.30568
# [113]	train-error:0.20458	val-error:0.30445
# [114]	train-error:0.20362	val-error:0.30524
# [115]	train-error:0.20368	val-error:0.30498
# [116]	train-error:0.20281	val-error:0.30489
# [117]	train-error:0.20184	val-error:0.30489
# [118]	train-error:0.20122	val-error:0.30603
# [119]	train-error:0.20062	val-error:0.30630
# [120]	train-error:0.20000	val-error:0.30691
# [121]	train-error:0.19934	val-error:0.30559
# [122]	train-error:0.19893	val-error:0.30595
# [123]	train-error:0.19823	val-error:0.30568
# [124]	train-error:0.19714	val-error:0.30612
# [125]	train-error:0.19673	val-error:0.30551
# Accuracy for iteration 2: 0.68
# Iteration 3
# [0]	train-error:0.33615	val-error:0.34775
# [1]	train-error:0.32718	val-error:0.34094
# [2]	train-error:0.32567	val-error:0.33801
# [3]	train-error:0.32205	val-error:0.33198
# [4]	train-error:0.32094	val-error:0.33069
# [5]	train-error:0.31872	val-error:0.32750
# [6]	train-error:0.31618	val-error:0.32905
# [7]	train-error:0.31386	val-error:0.32716
# [8]	train-error:0.31227	val-error:0.32673
# [9]	train-error:0.31051	val-error:0.32595
# [10]	train-error:0.30910	val-error:0.32500
# [11]	train-error:0.30708	val-error:0.32406
# [12]	train-error:0.30562	val-error:0.32242
# [13]	train-error:0.30432	val-error:0.32139
# [14]	train-error:0.30259	val-error:0.32225
# [15]	train-error:0.30096	val-error:0.32156
# [16]	train-error:0.30003	val-error:0.32139
# [17]	train-error:0.29835	val-error:0.32061
# [18]	train-error:0.29728	val-error:0.32009
# [19]	train-error:0.29557	val-error:0.31880
# [20]	train-error:0.29444	val-error:0.31803
# [21]	train-error:0.29377	val-error:0.31699
# [22]	train-error:0.29199	val-error:0.31527
# [23]	train-error:0.29067	val-error:0.31535
# [24]	train-error:0.28925	val-error:0.31570
# [25]	train-error:0.28678	val-error:0.31553
# [26]	train-error:0.28517	val-error:0.31415
# [27]	train-error:0.28411	val-error:0.31251
# [28]	train-error:0.28339	val-error:0.31320
# [29]	train-error:0.28190	val-error:0.31113
# [30]	train-error:0.28095	val-error:0.31139
# [31]	train-error:0.28017	val-error:0.31139
# [32]	train-error:0.27960	val-error:0.31062
# [33]	train-error:0.27862	val-error:0.31174
# [34]	train-error:0.27721	val-error:0.30915
# [35]	train-error:0.27565	val-error:0.31027
# [36]	train-error:0.27463	val-error:0.30924
# [37]	train-error:0.27300	val-error:0.31079
# [38]	train-error:0.27179	val-error:0.30829
# [39]	train-error:0.27060	val-error:0.30777
# [40]	train-error:0.27005	val-error:0.30898
# [41]	train-error:0.26884	val-error:0.30889
# [42]	train-error:0.26747	val-error:0.30812
# [43]	train-error:0.26637	val-error:0.30769
# [44]	train-error:0.26585	val-error:0.30829
# [45]	train-error:0.26476	val-error:0.30717
# [46]	train-error:0.26360	val-error:0.30837
# [47]	train-error:0.26269	val-error:0.30665
# [48]	train-error:0.26178	val-error:0.30639
# [49]	train-error:0.26081	val-error:0.30657
# [50]	train-error:0.26015	val-error:0.30596
# [51]	train-error:0.25903	val-error:0.30691
# [52]	train-error:0.25761	val-error:0.30657
# [53]	train-error:0.25653	val-error:0.30725
# [54]	train-error:0.25568	val-error:0.30613
# [55]	train-error:0.25509	val-error:0.30613
# [56]	train-error:0.25367	val-error:0.30553
# [57]	train-error:0.25371	val-error:0.30570
# [58]	train-error:0.25281	val-error:0.30536
# [59]	train-error:0.25181	val-error:0.30493
# [60]	train-error:0.25104	val-error:0.30450
# [61]	train-error:0.24978	val-error:0.30303
# [62]	train-error:0.24906	val-error:0.30295
# [63]	train-error:0.24814	val-error:0.30200
# [64]	train-error:0.24713	val-error:0.30286
# [65]	train-error:0.24632	val-error:0.30303
# [66]	train-error:0.24491	val-error:0.30355
# [67]	train-error:0.24387	val-error:0.30346
# [68]	train-error:0.24341	val-error:0.30381
# [69]	train-error:0.24245	val-error:0.30295
# [70]	train-error:0.24213	val-error:0.30286
# [71]	train-error:0.24063	val-error:0.30364
# [72]	train-error:0.24003	val-error:0.30424
# [73]	train-error:0.23889	val-error:0.30321
# [74]	train-error:0.23780	val-error:0.30381
# [75]	train-error:0.23688	val-error:0.30372
# [76]	train-error:0.23599	val-error:0.30389
# [77]	train-error:0.23514	val-error:0.30303
# [78]	train-error:0.23445	val-error:0.30364
# [79]	train-error:0.23300	val-error:0.30458
# [80]	train-error:0.23194	val-error:0.30355
# [81]	train-error:0.23139	val-error:0.30321
# [82]	train-error:0.23094	val-error:0.30277
# [83]	train-error:0.23034	val-error:0.30183
# [84]	train-error:0.22951	val-error:0.30217
# [85]	train-error:0.22832	val-error:0.30329
# [86]	train-error:0.22788	val-error:0.30252
# [87]	train-error:0.22714	val-error:0.30226
# [88]	train-error:0.22628	val-error:0.30346
# [89]	train-error:0.22564	val-error:0.30424
# [90]	train-error:0.22442	val-error:0.30372
# [91]	train-error:0.22351	val-error:0.30364
# [92]	train-error:0.22259	val-error:0.30312
# [93]	train-error:0.22150	val-error:0.30303
# [94]	train-error:0.22054	val-error:0.30286
# [95]	train-error:0.21995	val-error:0.30389
# [96]	train-error:0.21934	val-error:0.30355
# [97]	train-error:0.21823	val-error:0.30286
# [98]	train-error:0.21757	val-error:0.30071
# [99]	train-error:0.21632	val-error:0.30088
# [100]	train-error:0.21559	val-error:0.30131
# [101]	train-error:0.21510	val-error:0.30062
# [102]	train-error:0.21447	val-error:0.30088
# [103]	train-error:0.21395	val-error:0.30097
# [104]	train-error:0.21258	val-error:0.30183
# [105]	train-error:0.21161	val-error:0.30097
# [106]	train-error:0.21075	val-error:0.30191
# [107]	train-error:0.21012	val-error:0.30122
# [108]	train-error:0.20948	val-error:0.30183
# [109]	train-error:0.20891	val-error:0.30062
# [110]	train-error:0.20854	val-error:0.30174
# [111]	train-error:0.20773	val-error:0.30088
# [112]	train-error:0.20717	val-error:0.30045
# [113]	train-error:0.20645	val-error:0.30122
# [114]	train-error:0.20573	val-error:0.30036
# [115]	train-error:0.20525	val-error:0.30019
# [116]	train-error:0.20464	val-error:0.29993
# [117]	train-error:0.20387	val-error:0.29976
# [118]	train-error:0.20301	val-error:0.29872
# [119]	train-error:0.20261	val-error:0.29864
# [120]	train-error:0.20197	val-error:0.29933
# [121]	train-error:0.20112	val-error:0.29941
# [122]	train-error:0.20069	val-error:0.29950
# [123]	train-error:0.19981	val-error:0.29959
# [124]	train-error:0.19888	val-error:0.29881
# [125]	train-error:0.19804	val-error:0.29933
# [126]	train-error:0.19750	val-error:0.30071
# [127]	train-error:0.19657	val-error:0.30036
# [128]	train-error:0.19581	val-error:0.30097
# [129]	train-error:0.19518	val-error:0.30062
# [130]	train-error:0.19445	val-error:0.30148
# [131]	train-error:0.19380	val-error:0.30114
# [132]	train-error:0.19335	val-error:0.30140
# [133]	train-error:0.19236	val-error:0.30226
# [134]	train-error:0.19167	val-error:0.30191
# [135]	train-error:0.19080	val-error:0.30191
# [136]	train-error:0.18969	val-error:0.30243
# [137]	train-error:0.18891	val-error:0.30260
# [138]	train-error:0.18869	val-error:0.30209
# [139]	train-error:0.18782	val-error:0.30209
# Accuracy for iteration 3: 0.68
# Iteration 4
# [0]	train-error:0.33438	val-error:0.35508
# [1]	train-error:0.32626	val-error:0.34274
# [2]	train-error:0.32260	val-error:0.34328
# [3]	train-error:0.32089	val-error:0.34266
# [4]	train-error:0.31782	val-error:0.33908
# [5]	train-error:0.31578	val-error:0.33515
# [6]	train-error:0.31375	val-error:0.33667
# [7]	train-error:0.31211	val-error:0.33613
# [8]	train-error:0.31111	val-error:0.33586
# [9]	train-error:0.30911	val-error:0.33524
# [10]	train-error:0.30754	val-error:0.33613
# [11]	train-error:0.30568	val-error:0.33444
# [12]	train-error:0.30398	val-error:0.33604
# [13]	train-error:0.30362	val-error:0.33310
# [14]	train-error:0.30323	val-error:0.33452
# [15]	train-error:0.30221	val-error:0.33372
# [16]	train-error:0.30064	val-error:0.33408
# [17]	train-error:0.29907	val-error:0.33524
# [18]	train-error:0.29764	val-error:0.33301
# [19]	train-error:0.29592	val-error:0.33301
# [20]	train-error:0.29451	val-error:0.33059
# [21]	train-error:0.29365	val-error:0.32952
# [22]	train-error:0.29264	val-error:0.32925
# [23]	train-error:0.29122	val-error:0.32916
# [24]	train-error:0.28964	val-error:0.32872
# [25]	train-error:0.28842	val-error:0.32872
# [26]	train-error:0.28642	val-error:0.32693
# [27]	train-error:0.28549	val-error:0.32541
# [28]	train-error:0.28372	val-error:0.32487
# [29]	train-error:0.28175	val-error:0.32461
# [30]	train-error:0.28017	val-error:0.32362
# [31]	train-error:0.27976	val-error:0.32345
# [32]	train-error:0.27847	val-error:0.32380
# [33]	train-error:0.27709	val-error:0.32255
# [34]	train-error:0.27595	val-error:0.32246
# [35]	train-error:0.27433	val-error:0.32139
# [36]	train-error:0.27350	val-error:0.32059
# [37]	train-error:0.27227	val-error:0.32041
# [38]	train-error:0.27147	val-error:0.32130
# [39]	train-error:0.27007	val-error:0.32353
# [40]	train-error:0.26863	val-error:0.32246
# [41]	train-error:0.26785	val-error:0.32148
# [42]	train-error:0.26691	val-error:0.32193
# [43]	train-error:0.26591	val-error:0.32032
# [44]	train-error:0.26465	val-error:0.32068
# [45]	train-error:0.26379	val-error:0.32175
# [46]	train-error:0.26244	val-error:0.32121
# [47]	train-error:0.26164	val-error:0.32005
# [48]	train-error:0.26079	val-error:0.32050
# [49]	train-error:0.26039	val-error:0.32157
# [50]	train-error:0.25848	val-error:0.32148
# [51]	train-error:0.25827	val-error:0.32121
# [52]	train-error:0.25684	val-error:0.32041
# [53]	train-error:0.25611	val-error:0.32094
# [54]	train-error:0.25424	val-error:0.32139
# [55]	train-error:0.25332	val-error:0.32059
# [56]	train-error:0.25248	val-error:0.32014
# [57]	train-error:0.25135	val-error:0.31916
# [58]	train-error:0.25114	val-error:0.31907
# [59]	train-error:0.25008	val-error:0.31978
# [60]	train-error:0.24906	val-error:0.31889
# [61]	train-error:0.24784	val-error:0.31871
# [62]	train-error:0.24675	val-error:0.31925
# [63]	train-error:0.24577	val-error:0.31916
# [64]	train-error:0.24487	val-error:0.31951
# [65]	train-error:0.24420	val-error:0.31934
# [66]	train-error:0.24346	val-error:0.31880
# [67]	train-error:0.24250	val-error:0.31934
# [68]	train-error:0.24187	val-error:0.31925
# [69]	train-error:0.24122	val-error:0.31925
# [70]	train-error:0.24026	val-error:0.31782
# [71]	train-error:0.23931	val-error:0.31826
# [72]	train-error:0.23805	val-error:0.31871
# [73]	train-error:0.23732	val-error:0.31817
# [74]	train-error:0.23652	val-error:0.31898
# [75]	train-error:0.23568	val-error:0.31826
# [76]	train-error:0.23484	val-error:0.31835
# [77]	train-error:0.23404	val-error:0.31782
# [78]	train-error:0.23373	val-error:0.31728
# [79]	train-error:0.23250	val-error:0.31871
# [80]	train-error:0.23157	val-error:0.31844
# [81]	train-error:0.23112	val-error:0.31925
# [82]	train-error:0.22996	val-error:0.31808
# [83]	train-error:0.22924	val-error:0.31817
# [84]	train-error:0.22870	val-error:0.31835
# [85]	train-error:0.22755	val-error:0.31799
# [86]	train-error:0.22625	val-error:0.31898
# [87]	train-error:0.22599	val-error:0.31880
# [88]	train-error:0.22515	val-error:0.31916
# [89]	train-error:0.22406	val-error:0.31889
# [90]	train-error:0.22332	val-error:0.31898
# [91]	train-error:0.22228	val-error:0.31782
# [92]	train-error:0.22141	val-error:0.31692
# [93]	train-error:0.22074	val-error:0.31683
# [94]	train-error:0.21996	val-error:0.31737
# [95]	train-error:0.21893	val-error:0.31630
# [96]	train-error:0.21848	val-error:0.31621
# [97]	train-error:0.21783	val-error:0.31603
# [98]	train-error:0.21719	val-error:0.31558
# [99]	train-error:0.21644	val-error:0.31576
# [100]	train-error:0.21583	val-error:0.31531
# [101]	train-error:0.21463	val-error:0.31496
# [102]	train-error:0.21422	val-error:0.31585
# [103]	train-error:0.21378	val-error:0.31540
# [104]	train-error:0.21313	val-error:0.31523
# [105]	train-error:0.21238	val-error:0.31576
# [106]	train-error:0.21179	val-error:0.31719
# [107]	train-error:0.21057	val-error:0.31710
# [108]	train-error:0.20976	val-error:0.31764
# [109]	train-error:0.20937	val-error:0.31737
# [110]	train-error:0.20853	val-error:0.31692
# [111]	train-error:0.20774	val-error:0.31746
# [112]	train-error:0.20746	val-error:0.31737
# [113]	train-error:0.20703	val-error:0.31710
# [114]	train-error:0.20609	val-error:0.31737
# [115]	train-error:0.20512	val-error:0.31719
# [116]	train-error:0.20455	val-error:0.31737
# [117]	train-error:0.20338	val-error:0.31657
# [118]	train-error:0.20298	val-error:0.31639
# [119]	train-error:0.20222	val-error:0.31630
# [120]	train-error:0.20129	val-error:0.31630
# [121]	train-error:0.20050	val-error:0.31531
# Accuracy for iteration 4: 0.69
# Iteration 5
# [0]	train-error:0.33660	val-error:0.34789
# [1]	train-error:0.32510	val-error:0.33673
# [2]	train-error:0.32053	val-error:0.33453
# [3]	train-error:0.31853	val-error:0.33234
# [4]	train-error:0.31516	val-error:0.32786
# [5]	train-error:0.31396	val-error:0.32777
# [6]	train-error:0.31213	val-error:0.32830
# [7]	train-error:0.31112	val-error:0.32882
# [8]	train-error:0.30860	val-error:0.32689
# [9]	train-error:0.30670	val-error:0.32663
# [10]	train-error:0.30524	val-error:0.32548
# [11]	train-error:0.30439	val-error:0.32601
# [12]	train-error:0.30337	val-error:0.32460
# [13]	train-error:0.30211	val-error:0.32320
# [14]	train-error:0.30120	val-error:0.32302
# [15]	train-error:0.29996	val-error:0.32144
# [16]	train-error:0.29883	val-error:0.32144
# [17]	train-error:0.29704	val-error:0.31986
# [18]	train-error:0.29661	val-error:0.31837
# [19]	train-error:0.29567	val-error:0.31933
# [20]	train-error:0.29327	val-error:0.32109
# [21]	train-error:0.29185	val-error:0.32118
# [22]	train-error:0.29033	val-error:0.32065
# [23]	train-error:0.28972	val-error:0.31889
# [24]	train-error:0.28734	val-error:0.31863
# [25]	train-error:0.28614	val-error:0.31872
# [26]	train-error:0.28425	val-error:0.31907
# [27]	train-error:0.28331	val-error:0.31977
# [28]	train-error:0.28227	val-error:0.31898
# [29]	train-error:0.28115	val-error:0.31740
# [30]	train-error:0.27979	val-error:0.31599
# [31]	train-error:0.27902	val-error:0.31608
# [32]	train-error:0.27790	val-error:0.31582
# [33]	train-error:0.27617	val-error:0.31529
# [34]	train-error:0.27457	val-error:0.31459
# [35]	train-error:0.27387	val-error:0.31555
# [36]	train-error:0.27284	val-error:0.31705
# [37]	train-error:0.27200	val-error:0.31810
# [38]	train-error:0.27057	val-error:0.31705
# [39]	train-error:0.26907	val-error:0.31626
# [40]	train-error:0.26794	val-error:0.31617
# [41]	train-error:0.26746	val-error:0.31626
# [42]	train-error:0.26649	val-error:0.31529
# [43]	train-error:0.26525	val-error:0.31678
# [44]	train-error:0.26446	val-error:0.31687
# [45]	train-error:0.26265	val-error:0.31529
# [46]	train-error:0.26220	val-error:0.31582
# [47]	train-error:0.26108	val-error:0.31459
# [48]	train-error:0.25961	val-error:0.31547
# [49]	train-error:0.25834	val-error:0.31582
# [50]	train-error:0.25721	val-error:0.31573
# [51]	train-error:0.25669	val-error:0.31591
# [52]	train-error:0.25591	val-error:0.31617
# [53]	train-error:0.25489	val-error:0.31564
# Accuracy for iteration 5: 0.68
# Iteration 6
# [0]	train-error:0.33549	val-error:0.34676
# [1]	train-error:0.32461	val-error:0.34490
# [2]	train-error:0.32120	val-error:0.34120
# [3]	train-error:0.31874	val-error:0.33796
# [4]	train-error:0.31730	val-error:0.33630
# [5]	train-error:0.31546	val-error:0.33555
# [6]	train-error:0.31359	val-error:0.33315
# [7]	train-error:0.31293	val-error:0.33213
# [8]	train-error:0.31094	val-error:0.33269
# [9]	train-error:0.30917	val-error:0.33167
# [10]	train-error:0.30808	val-error:0.32982
# [11]	train-error:0.30641	val-error:0.33167
# [12]	train-error:0.30524	val-error:0.33009
# [13]	train-error:0.30334	val-error:0.32908
# [14]	train-error:0.30162	val-error:0.32889
# [15]	train-error:0.29981	val-error:0.32778
# [16]	train-error:0.29864	val-error:0.32667
# [17]	train-error:0.29735	val-error:0.32639
# [18]	train-error:0.29623	val-error:0.32547
# [19]	train-error:0.29500	val-error:0.32482
# [20]	train-error:0.29376	val-error:0.32417
# [21]	train-error:0.29227	val-error:0.32454
# [22]	train-error:0.29182	val-error:0.32297
# [23]	train-error:0.29006	val-error:0.32130
# [24]	train-error:0.28877	val-error:0.32074
# [25]	train-error:0.28742	val-error:0.32056
# [26]	train-error:0.28619	val-error:0.32093
# [27]	train-error:0.28546	val-error:0.32111
# [28]	train-error:0.28380	val-error:0.32213
# [29]	train-error:0.28290	val-error:0.32093
# [30]	train-error:0.28169	val-error:0.32065
# [31]	train-error:0.28053	val-error:0.32065
# [32]	train-error:0.27946	val-error:0.32102
# [33]	train-error:0.27850	val-error:0.32084
# [34]	train-error:0.27689	val-error:0.31880
# [35]	train-error:0.27583	val-error:0.31926
# [36]	train-error:0.27383	val-error:0.32010
# [37]	train-error:0.27246	val-error:0.31954
# [38]	train-error:0.27167	val-error:0.31954
# [39]	train-error:0.27036	val-error:0.31871
# [40]	train-error:0.26936	val-error:0.31926
# [41]	train-error:0.26823	val-error:0.32028
# [42]	train-error:0.26748	val-error:0.32065
# [43]	train-error:0.26595	val-error:0.31899
# [44]	train-error:0.26508	val-error:0.31954
# [45]	train-error:0.26351	val-error:0.31945
# [46]	train-error:0.26349	val-error:0.31834
# [47]	train-error:0.26229	val-error:0.31787
# [48]	train-error:0.26109	val-error:0.31713
# [49]	train-error:0.26017	val-error:0.31723
# [50]	train-error:0.25931	val-error:0.31723
# [51]	train-error:0.25859	val-error:0.31667
# [52]	train-error:0.25803	val-error:0.31639
# [53]	train-error:0.25689	val-error:0.31510
# [54]	train-error:0.25600	val-error:0.31482
# [55]	train-error:0.25489	val-error:0.31501
# [56]	train-error:0.25448	val-error:0.31371
# [57]	train-error:0.25349	val-error:0.31288
# [58]	train-error:0.25272	val-error:0.31334
# [59]	train-error:0.25174	val-error:0.31325
# [60]	train-error:0.25039	val-error:0.31223
# [61]	train-error:0.24927	val-error:0.31167
# [62]	train-error:0.24836	val-error:0.31056
# [63]	train-error:0.24764	val-error:0.31121
# [64]	train-error:0.24691	val-error:0.31177
# [65]	train-error:0.24631	val-error:0.31121
# [66]	train-error:0.24556	val-error:0.31093
# [67]	train-error:0.24499	val-error:0.31075
# [68]	train-error:0.24445	val-error:0.31177
# [69]	train-error:0.24315	val-error:0.31130
# [70]	train-error:0.24181	val-error:0.31121
# [71]	train-error:0.24098	val-error:0.31001
# [72]	train-error:0.23953	val-error:0.31056
# [73]	train-error:0.23883	val-error:0.31139
# [74]	train-error:0.23808	val-error:0.31028
# [75]	train-error:0.23756	val-error:0.31075
# [76]	train-error:0.23658	val-error:0.31121
# [77]	train-error:0.23529	val-error:0.31149
# [78]	train-error:0.23427	val-error:0.31177
# [79]	train-error:0.23327	val-error:0.31102
# [80]	train-error:0.23298	val-error:0.31056
# [81]	train-error:0.23186	val-error:0.31038
# [82]	train-error:0.23164	val-error:0.31010
# [83]	train-error:0.23085	val-error:0.30936
# [84]	train-error:0.23017	val-error:0.30982
# [85]	train-error:0.22912	val-error:0.31139
# [86]	train-error:0.22846	val-error:0.31102
# [87]	train-error:0.22735	val-error:0.31121
# [88]	train-error:0.22665	val-error:0.31075
# [89]	train-error:0.22624	val-error:0.31075
# [90]	train-error:0.22519	val-error:0.31056
# [91]	train-error:0.22412	val-error:0.30964
# [92]	train-error:0.22330	val-error:0.31028
# [93]	train-error:0.22251	val-error:0.31084
# [94]	train-error:0.22192	val-error:0.31075
# [95]	train-error:0.22123	val-error:0.31010
# [96]	train-error:0.22039	val-error:0.31102
# [97]	train-error:0.21945	val-error:0.31056
# [98]	train-error:0.21865	val-error:0.31130
# [99]	train-error:0.21774	val-error:0.31102
# [100]	train-error:0.21700	val-error:0.31028
# [101]	train-error:0.21617	val-error:0.31056
# [102]	train-error:0.21525	val-error:0.31010
# Accuracy for iteration 6: 0.69
# Iteration 7
# [0]	train-error:0.33407	val-error:0.34586
# [1]	train-error:0.32702	val-error:0.34268
# [2]	train-error:0.32307	val-error:0.34285
# [3]	train-error:0.32180	val-error:0.34130
# [4]	train-error:0.31875	val-error:0.34018
# [5]	train-error:0.31706	val-error:0.33795
# [6]	train-error:0.31623	val-error:0.33563
# [7]	train-error:0.31410	val-error:0.33348
# [8]	train-error:0.31238	val-error:0.33313
# [9]	train-error:0.31048	val-error:0.33356
# [10]	train-error:0.30932	val-error:0.33365
# [11]	train-error:0.30764	val-error:0.33236
# [12]	train-error:0.30603	val-error:0.33236
# [13]	train-error:0.30453	val-error:0.33098
# [14]	train-error:0.30265	val-error:0.33038
# [15]	train-error:0.30156	val-error:0.33141
# [16]	train-error:0.30053	val-error:0.33047
# [17]	train-error:0.29937	val-error:0.33004
# [18]	train-error:0.29810	val-error:0.32969
# [19]	train-error:0.29710	val-error:0.32815
# [20]	train-error:0.29519	val-error:0.32772
# [21]	train-error:0.29372	val-error:0.32651
# [22]	train-error:0.29172	val-error:0.32479
# [23]	train-error:0.29053	val-error:0.32385
# [24]	train-error:0.28927	val-error:0.32282
# [25]	train-error:0.28816	val-error:0.32239
# [26]	train-error:0.28671	val-error:0.32178
# [27]	train-error:0.28495	val-error:0.32161
# [28]	train-error:0.28358	val-error:0.31946
# [29]	train-error:0.28301	val-error:0.31998
# [30]	train-error:0.28192	val-error:0.31878
# [31]	train-error:0.28112	val-error:0.31852
# [32]	train-error:0.27924	val-error:0.31697
# [33]	train-error:0.27783	val-error:0.31688
# [34]	train-error:0.27667	val-error:0.31517
# [35]	train-error:0.27558	val-error:0.31456
# [36]	train-error:0.27439	val-error:0.31465
# [37]	train-error:0.27280	val-error:0.31508
# [38]	train-error:0.27207	val-error:0.31362
# [39]	train-error:0.27085	val-error:0.31508
# [40]	train-error:0.27046	val-error:0.31405
# [41]	train-error:0.26974	val-error:0.31491
# [42]	train-error:0.26878	val-error:0.31456
# [43]	train-error:0.26746	val-error:0.31491
# [44]	train-error:0.26643	val-error:0.31405
# [45]	train-error:0.26578	val-error:0.31310
# [46]	train-error:0.26475	val-error:0.31310
# [47]	train-error:0.26367	val-error:0.31302
# [48]	train-error:0.26186	val-error:0.31327
# [49]	train-error:0.26122	val-error:0.31413
# [50]	train-error:0.25977	val-error:0.31327
# [51]	train-error:0.25863	val-error:0.31370
# [52]	train-error:0.25799	val-error:0.31327
# [53]	train-error:0.25673	val-error:0.31267
# [54]	train-error:0.25588	val-error:0.31164
# [55]	train-error:0.25540	val-error:0.31112
# [56]	train-error:0.25455	val-error:0.31104
# [57]	train-error:0.25385	val-error:0.31052
# [58]	train-error:0.25292	val-error:0.30949
# [59]	train-error:0.25223	val-error:0.30898
# [60]	train-error:0.25108	val-error:0.31018
# [61]	train-error:0.25056	val-error:0.30898
# [62]	train-error:0.24932	val-error:0.30915
# [63]	train-error:0.24892	val-error:0.31044
# [64]	train-error:0.24715	val-error:0.30906
# [65]	train-error:0.24713	val-error:0.30966
# [66]	train-error:0.24583	val-error:0.31026
# [67]	train-error:0.24526	val-error:0.30949
# [68]	train-error:0.24420	val-error:0.31035
# [69]	train-error:0.24317	val-error:0.30975
# [70]	train-error:0.24190	val-error:0.30855
# [71]	train-error:0.24127	val-error:0.30794
# [72]	train-error:0.24052	val-error:0.30769
# [73]	train-error:0.23967	val-error:0.30786
# [74]	train-error:0.23872	val-error:0.30820
# [75]	train-error:0.23750	val-error:0.30803
# [76]	train-error:0.23663	val-error:0.30708
# [77]	train-error:0.23618	val-error:0.30846
# [78]	train-error:0.23531	val-error:0.30777
# [79]	train-error:0.23440	val-error:0.30700
# [80]	train-error:0.23334	val-error:0.30683
# [81]	train-error:0.23252	val-error:0.30691
# [82]	train-error:0.23142	val-error:0.30708
# [83]	train-error:0.23043	val-error:0.30777
# [84]	train-error:0.22948	val-error:0.30855
# [85]	train-error:0.22866	val-error:0.30863
# [86]	train-error:0.22770	val-error:0.30880
# [87]	train-error:0.22693	val-error:0.30812
# [88]	train-error:0.22670	val-error:0.30846
# [89]	train-error:0.22571	val-error:0.30786
# [90]	train-error:0.22486	val-error:0.30760
# [91]	train-error:0.22413	val-error:0.30751
# [92]	train-error:0.22320	val-error:0.30820
# [93]	train-error:0.22200	val-error:0.30691
# [94]	train-error:0.22130	val-error:0.30751
# [95]	train-error:0.22050	val-error:0.30683
# [96]	train-error:0.21976	val-error:0.30734
# [97]	train-error:0.21904	val-error:0.30794
# [98]	train-error:0.21847	val-error:0.30846
# [99]	train-error:0.21746	val-error:0.30837
# Accuracy for iteration 7: 0.70
# Average Accuracy across 7 iterations: 0.69

# %%
import numpy as np
from scipy.stats import sem, t
from scipy import mean

# Assuming accuracies are stored in the 'accuracies' list as per previous example
accuracies = np.array(accuracies)

# Calculate the mean accuracy
mean_accuracy = np.mean(accuracies)

# Calculate the standard error of the mean
std_error = sem(accuracies)

# Determine the size of the accuracies array
n = len(accuracies)

# Use the t-distribution to calculate a 95% confidence interval
confidence = 0.95
h = std_error * t.ppf((1 + confidence) / 2, n - 1)

# Print the mean accuracy and confidence interval
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"95% Confidence interval: {mean_accuracy - h:.5f} - {mean_accuracy + h:.5f}")
# Out:
# Mean Accuracy: 0.69
# 95% Confidence interval: 0.68311 - 0.69137

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.69      0.70      0.70      5816
#         High       0.70      0.68      0.69      5816
#
#     accuracy                           0.69     11632
#    macro avg       0.69      0.69      0.69     11632
# weighted avg       0.69      0.69      0.69     11632

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.69      0.70      0.70      5513
#         High       0.70      0.69      0.69      5512
#
#     accuracy                           0.70     11025
#    macro avg       0.70      0.70      0.70     11025
# weighted avg       0.70      0.70      0.70     11025
