# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep + text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %%
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Followees  Posts  Image_Count   image_0   image_1  ...  text_759  \
# 0         710   1059            1  0.483804  4.411579  ... -0.017703
# 1         710   1059            1  1.257535  4.292836  ...  0.015757
# 2         710   1059            1  1.015909  4.928564  ... -0.097885
# 4         710   1059            1  0.961807  3.994127  ... -0.036261
# 9        7069    261            1  1.316597  1.515859  ... -0.036988
# 10       7069    261            1  1.682237  1.290816  ... -0.165627
# 11       7069    261            1  0.923607  3.838140  ... -0.083701
# 12       7069    261            1  0.044586  1.376372  ... -0.178489
# 13        523    487            1  0.012054  0.549083  ...  0.028141
# 14        523    487            1  0.587146  4.310180  ... -0.001124
#
#     text_760  text_761  text_762  text_763  text_764  text_765  text_766  \
# 0  -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870  0.062999
# 1  -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263 -0.012400
# 2  -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142  0.094179
# 4  -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846  0.141513
# 9  -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471  0.012900
# 10  0.198171  0.093986  0.176528  0.140797  0.070081 -0.168545  0.107152
# 11  0.228142  0.049256  0.080081  0.093756  0.086833 -0.163537  0.100750
# 12  0.159561 -0.046662  0.182022  0.127947  0.299180 -0.091949  0.096147
# 13 -0.179497  0.085646  0.179977  0.134104  0.239402  0.052813  0.030690
# 14 -0.172151  0.021455  0.215737  0.150555  0.408500 -0.234415  0.109303
#
#     text_767  popularity
# 0   0.075272    0.046335
# 1   0.147600    0.011623
# 2   0.080168    0.026034
# 4   0.093924    0.018286
# 9   0.064740    0.021298
# 10  0.057365    0.085827
# 11  0.096130    0.098892
# 12  0.045425    0.106888
# 13 -0.044792    0.062799
# 14 -0.072184    0.074853
#
# [10 rows x 2825 columns]

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Normalize the selected features
    columns_to_normalize = ['Followers', 'Followees', 'Posts']
    scaler = StandardScaler().fit(train_data[columns_to_normalize])
    train_data.loc[:, columns_to_normalize] = scaler.transform(train_data[columns_to_normalize])
    val_data.loc[:, columns_to_normalize] = scaler.transform(val_data[columns_to_normalize])
    test_data.loc[:, columns_to_normalize] = scaler.transform(test_data[columns_to_normalize])

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.33992	val-error:0.35459
# [1]	train-error:0.33286	val-error:0.34850
# [2]	train-error:0.32778	val-error:0.34508
# [3]	train-error:0.32521	val-error:0.34106
# [4]	train-error:0.32236	val-error:0.33935
# [5]	train-error:0.31998	val-error:0.33750
# [6]	train-error:0.31754	val-error:0.33616
# [7]	train-error:0.31674	val-error:0.33638
# [8]	train-error:0.31585	val-error:0.33497
# [9]	train-error:0.31431	val-error:0.33304
# [10]	train-error:0.31208	val-error:0.33207
# [11]	train-error:0.31136	val-error:0.33170
# [12]	train-error:0.30949	val-error:0.33036
# [13]	train-error:0.30845	val-error:0.32939
# [14]	train-error:0.30733	val-error:0.33021
# [15]	train-error:0.30596	val-error:0.32887
# [16]	train-error:0.30463	val-error:0.33036
# [17]	train-error:0.30302	val-error:0.32895
# [18]	train-error:0.30194	val-error:0.32746
# [19]	train-error:0.30069	val-error:0.32739
# [20]	train-error:0.29906	val-error:0.32672
# [21]	train-error:0.29851	val-error:0.32701
# [22]	train-error:0.29762	val-error:0.32538
# [23]	train-error:0.29578	val-error:0.32575
# [24]	train-error:0.29417	val-error:0.32620
# [25]	train-error:0.29297	val-error:0.32597
# [26]	train-error:0.29176	val-error:0.32642
# [27]	train-error:0.29043	val-error:0.32583
# [28]	train-error:0.28900	val-error:0.32560
# [29]	train-error:0.28815	val-error:0.32501
# [30]	train-error:0.28734	val-error:0.32493
# [31]	train-error:0.28658	val-error:0.32315
# [32]	train-error:0.28546	val-error:0.32516
# [33]	train-error:0.28409	val-error:0.32404
# [34]	train-error:0.28250	val-error:0.32508
# [35]	train-error:0.28146	val-error:0.32360
# [36]	train-error:0.28029	val-error:0.32330
# [37]	train-error:0.28030	val-error:0.32404
# [38]	train-error:0.27904	val-error:0.32382
# [39]	train-error:0.27783	val-error:0.32478
# [40]	train-error:0.27649	val-error:0.32449
# [41]	train-error:0.27550	val-error:0.32456
# [42]	train-error:0.27477	val-error:0.32382
# [43]	train-error:0.27421	val-error:0.32412
# [44]	train-error:0.27298	val-error:0.32322
# [45]	train-error:0.27223	val-error:0.32456
# [46]	train-error:0.27138	val-error:0.32493
# [47]	train-error:0.27054	val-error:0.32419
# [48]	train-error:0.26925	val-error:0.32293
# [49]	train-error:0.26857	val-error:0.32352
# [50]	train-error:0.26744	val-error:0.32449
# [51]	train-error:0.26647	val-error:0.32404
# [52]	train-error:0.26594	val-error:0.32382
# [53]	train-error:0.26511	val-error:0.32367
# [54]	train-error:0.26407	val-error:0.32315
# [55]	train-error:0.26328	val-error:0.32367
# [56]	train-error:0.26262	val-error:0.32330
# [57]	train-error:0.26243	val-error:0.32270
# [58]	train-error:0.26156	val-error:0.32367
# [59]	train-error:0.26074	val-error:0.32278
# [60]	train-error:0.25969	val-error:0.32055
# [61]	train-error:0.25885	val-error:0.32107
# [62]	train-error:0.25803	val-error:0.32151
# [63]	train-error:0.25707	val-error:0.32047
# [64]	train-error:0.25669	val-error:0.32181
# [65]	train-error:0.25633	val-error:0.32107
# [66]	train-error:0.25505	val-error:0.32129
# [67]	train-error:0.25419	val-error:0.32055
# [68]	train-error:0.25318	val-error:0.32025
# [69]	train-error:0.25214	val-error:0.32077
# [70]	train-error:0.25186	val-error:0.32151
# [71]	train-error:0.25116	val-error:0.32107
# [72]	train-error:0.25046	val-error:0.32025
# [73]	train-error:0.24955	val-error:0.32062
# [74]	train-error:0.24903	val-error:0.32077
# [75]	train-error:0.24770	val-error:0.32062
# [76]	train-error:0.24683	val-error:0.31995
# [77]	train-error:0.24596	val-error:0.31913
# [78]	train-error:0.24547	val-error:0.32070
# [79]	train-error:0.24479	val-error:0.32062
# [80]	train-error:0.24386	val-error:0.31928
# [81]	train-error:0.24321	val-error:0.31861
# [82]	train-error:0.24250	val-error:0.31943
# [83]	train-error:0.24121	val-error:0.31884
# [84]	train-error:0.24070	val-error:0.31899
# [85]	train-error:0.24025	val-error:0.31951
# [86]	train-error:0.23964	val-error:0.31876
# [87]	train-error:0.23891	val-error:0.31913
# [88]	train-error:0.23791	val-error:0.31906
# [89]	train-error:0.23708	val-error:0.31928
# [90]	train-error:0.23639	val-error:0.31936
# [91]	train-error:0.23606	val-error:0.31913
# [92]	train-error:0.23501	val-error:0.31847
# [93]	train-error:0.23395	val-error:0.31936
# [94]	train-error:0.23300	val-error:0.31809
# [95]	train-error:0.23240	val-error:0.31847
# [96]	train-error:0.23152	val-error:0.31869
# [97]	train-error:0.23082	val-error:0.32032
# [98]	train-error:0.23002	val-error:0.31906
# [99]	train-error:0.22926	val-error:0.31943
# [100]	train-error:0.22869	val-error:0.31869
# [101]	train-error:0.22816	val-error:0.31958
# [102]	train-error:0.22726	val-error:0.31943
# [103]	train-error:0.22665	val-error:0.31936
# [104]	train-error:0.22592	val-error:0.32032
# [105]	train-error:0.22509	val-error:0.32032
# [106]	train-error:0.22404	val-error:0.32062
# [107]	train-error:0.22358	val-error:0.32040
# [108]	train-error:0.22308	val-error:0.32040
# [109]	train-error:0.22273	val-error:0.32099
# [110]	train-error:0.22247	val-error:0.32032
# [111]	train-error:0.22185	val-error:0.31973
# [112]	train-error:0.22053	val-error:0.31899
# [113]	train-error:0.22004	val-error:0.31839
# [114]	train-error:0.21870	val-error:0.31817
# Accuracy for iteration 1: 0.68
# Iteration 2
# [0]	train-error:0.33598	val-error:0.36167
# [1]	train-error:0.32926	val-error:0.35542
# [2]	train-error:0.32574	val-error:0.35046
# [3]	train-error:0.32298	val-error:0.35138
# [4]	train-error:0.32157	val-error:0.34947
# [5]	train-error:0.32045	val-error:0.34612
# [6]	train-error:0.31800	val-error:0.34543
# [7]	train-error:0.31688	val-error:0.34764
# [8]	train-error:0.31564	val-error:0.34680
# [9]	train-error:0.31412	val-error:0.34924
# [10]	train-error:0.31274	val-error:0.34581
# [11]	train-error:0.31124	val-error:0.34764
# [12]	train-error:0.30979	val-error:0.34642
# [13]	train-error:0.30817	val-error:0.34566
# [14]	train-error:0.30642	val-error:0.34307
# [15]	train-error:0.30581	val-error:0.34299
# [16]	train-error:0.30488	val-error:0.34261
# [17]	train-error:0.30295	val-error:0.34406
# [18]	train-error:0.30119	val-error:0.34444
# [19]	train-error:0.30038	val-error:0.34497
# [20]	train-error:0.29866	val-error:0.34444
# [21]	train-error:0.29759	val-error:0.34329
# [22]	train-error:0.29625	val-error:0.34390
# [23]	train-error:0.29500	val-error:0.34337
# [24]	train-error:0.29341	val-error:0.34116
# [25]	train-error:0.29152	val-error:0.33933
# [26]	train-error:0.29017	val-error:0.33895
# [27]	train-error:0.28849	val-error:0.33720
# [28]	train-error:0.28706	val-error:0.33643
# [29]	train-error:0.28602	val-error:0.33567
# [30]	train-error:0.28479	val-error:0.33415
# [31]	train-error:0.28370	val-error:0.33476
# [32]	train-error:0.28177	val-error:0.33323
# [33]	train-error:0.28092	val-error:0.33308
# [34]	train-error:0.27963	val-error:0.33270
# [35]	train-error:0.27784	val-error:0.33148
# [36]	train-error:0.27648	val-error:0.32957
# [37]	train-error:0.27545	val-error:0.32873
# [38]	train-error:0.27422	val-error:0.32706
# [39]	train-error:0.27364	val-error:0.32690
# [40]	train-error:0.27307	val-error:0.32614
# [41]	train-error:0.27220	val-error:0.32652
# [42]	train-error:0.27106	val-error:0.32629
# [43]	train-error:0.27048	val-error:0.32675
# [44]	train-error:0.26944	val-error:0.32629
# [45]	train-error:0.26884	val-error:0.32622
# [46]	train-error:0.26780	val-error:0.32591
# [47]	train-error:0.26715	val-error:0.32637
# [48]	train-error:0.26579	val-error:0.32576
# [49]	train-error:0.26490	val-error:0.32492
# [50]	train-error:0.26405	val-error:0.32469
# [51]	train-error:0.26362	val-error:0.32561
# [52]	train-error:0.26275	val-error:0.32553
# [53]	train-error:0.26216	val-error:0.32485
# [54]	train-error:0.26105	val-error:0.32523
# [55]	train-error:0.26046	val-error:0.32530
# [56]	train-error:0.25942	val-error:0.32477
# [57]	train-error:0.25888	val-error:0.32523
# [58]	train-error:0.25777	val-error:0.32446
# [59]	train-error:0.25692	val-error:0.32454
# [60]	train-error:0.25603	val-error:0.32378
# [61]	train-error:0.25509	val-error:0.32424
# [62]	train-error:0.25449	val-error:0.32416
# [63]	train-error:0.25360	val-error:0.32454
# [64]	train-error:0.25297	val-error:0.32408
# [65]	train-error:0.25194	val-error:0.32393
# [66]	train-error:0.25131	val-error:0.32393
# [67]	train-error:0.25091	val-error:0.32363
# [68]	train-error:0.24998	val-error:0.32309
# [69]	train-error:0.24882	val-error:0.32302
# [70]	train-error:0.24765	val-error:0.32363
# [71]	train-error:0.24703	val-error:0.32294
# [72]	train-error:0.24637	val-error:0.32332
# [73]	train-error:0.24557	val-error:0.32324
# [74]	train-error:0.24445	val-error:0.32263
# [75]	train-error:0.24367	val-error:0.32195
# [76]	train-error:0.24345	val-error:0.32157
# [77]	train-error:0.24222	val-error:0.32363
# [78]	train-error:0.24148	val-error:0.32248
# [79]	train-error:0.24114	val-error:0.32180
# [80]	train-error:0.24038	val-error:0.32294
# [81]	train-error:0.23994	val-error:0.32218
# [82]	train-error:0.23935	val-error:0.32241
# [83]	train-error:0.23845	val-error:0.32195
# [84]	train-error:0.23779	val-error:0.32286
# [85]	train-error:0.23707	val-error:0.32302
# [86]	train-error:0.23636	val-error:0.32248
# [87]	train-error:0.23525	val-error:0.32309
# [88]	train-error:0.23436	val-error:0.32263
# [89]	train-error:0.23365	val-error:0.32363
# [90]	train-error:0.23289	val-error:0.32302
# [91]	train-error:0.23214	val-error:0.32332
# [92]	train-error:0.23151	val-error:0.32233
# [93]	train-error:0.23100	val-error:0.32195
# [94]	train-error:0.23052	val-error:0.32103
# [95]	train-error:0.22958	val-error:0.32141
# [96]	train-error:0.22912	val-error:0.32081
# [97]	train-error:0.22817	val-error:0.32065
# [98]	train-error:0.22701	val-error:0.32126
# [99]	train-error:0.22646	val-error:0.32225
# [100]	train-error:0.22607	val-error:0.32180
# [101]	train-error:0.22494	val-error:0.32126
# [102]	train-error:0.22420	val-error:0.32134
# [103]	train-error:0.22335	val-error:0.32065
# [104]	train-error:0.22275	val-error:0.32157
# [105]	train-error:0.22210	val-error:0.32172
# [106]	train-error:0.22130	val-error:0.32195
# [107]	train-error:0.22060	val-error:0.32187
# [108]	train-error:0.22024	val-error:0.32248
# [109]	train-error:0.21964	val-error:0.32180
# [110]	train-error:0.21888	val-error:0.32172
# [111]	train-error:0.21855	val-error:0.32073
# [112]	train-error:0.21777	val-error:0.32042
# [113]	train-error:0.21681	val-error:0.32027
# [114]	train-error:0.21626	val-error:0.32065
# [115]	train-error:0.21552	val-error:0.32119
# [116]	train-error:0.21472	val-error:0.32202
# [117]	train-error:0.21414	val-error:0.32195
# [118]	train-error:0.21346	val-error:0.32233
# [119]	train-error:0.21257	val-error:0.32355
# [120]	train-error:0.21164	val-error:0.32294
# [121]	train-error:0.21081	val-error:0.32271
# [122]	train-error:0.21002	val-error:0.32157
# [123]	train-error:0.20923	val-error:0.32119
# [124]	train-error:0.20871	val-error:0.32103
# [125]	train-error:0.20838	val-error:0.32103
# [126]	train-error:0.20763	val-error:0.32187
# [127]	train-error:0.20714	val-error:0.32233
# [128]	train-error:0.20634	val-error:0.32202
# [129]	train-error:0.20590	val-error:0.32225
# [130]	train-error:0.20507	val-error:0.32103
# [131]	train-error:0.20487	val-error:0.32111
# [132]	train-error:0.20427	val-error:0.32096
# Accuracy for iteration 2: 0.68
# Iteration 3
# [0]	train-error:0.34158	val-error:0.36104
# [1]	train-error:0.33208	val-error:0.34881
# [2]	train-error:0.32777	val-error:0.34755
# [3]	train-error:0.32575	val-error:0.34505
# [4]	train-error:0.32263	val-error:0.34350
# [5]	train-error:0.32164	val-error:0.34144
# [6]	train-error:0.31859	val-error:0.33901
# [7]	train-error:0.31724	val-error:0.33635
# [8]	train-error:0.31565	val-error:0.33481
# [9]	train-error:0.31466	val-error:0.33333
# [10]	train-error:0.31282	val-error:0.33319
# [11]	train-error:0.31144	val-error:0.33017
# [12]	train-error:0.31021	val-error:0.32943
# [13]	train-error:0.30906	val-error:0.33068
# [14]	train-error:0.30801	val-error:0.32818
# [15]	train-error:0.30653	val-error:0.32913
# [16]	train-error:0.30505	val-error:0.32832
# [17]	train-error:0.30420	val-error:0.32648
# [18]	train-error:0.30301	val-error:0.32641
# [19]	train-error:0.30171	val-error:0.32611
# [20]	train-error:0.30058	val-error:0.32538
# [21]	train-error:0.29849	val-error:0.32486
# [22]	train-error:0.29773	val-error:0.32405
# [23]	train-error:0.29620	val-error:0.32427
# [24]	train-error:0.29512	val-error:0.32361
# [25]	train-error:0.29424	val-error:0.32324
# [26]	train-error:0.29290	val-error:0.32302
# [27]	train-error:0.29174	val-error:0.32339
# [28]	train-error:0.29097	val-error:0.32383
# [29]	train-error:0.28969	val-error:0.32427
# [30]	train-error:0.28836	val-error:0.32375
# [31]	train-error:0.28708	val-error:0.32398
# [32]	train-error:0.28540	val-error:0.32331
# [33]	train-error:0.28476	val-error:0.32383
# [34]	train-error:0.28388	val-error:0.32272
# [35]	train-error:0.28248	val-error:0.32213
# [36]	train-error:0.28147	val-error:0.32103
# [37]	train-error:0.28029	val-error:0.32037
# [38]	train-error:0.27938	val-error:0.31897
# [39]	train-error:0.27752	val-error:0.31919
# [40]	train-error:0.27605	val-error:0.31874
# [41]	train-error:0.27538	val-error:0.31897
# [42]	train-error:0.27454	val-error:0.31793
# [43]	train-error:0.27372	val-error:0.31764
# [44]	train-error:0.27276	val-error:0.31823
# [45]	train-error:0.27186	val-error:0.31793
# [46]	train-error:0.27082	val-error:0.31808
# [47]	train-error:0.27026	val-error:0.31742
# [48]	train-error:0.26896	val-error:0.31764
# [49]	train-error:0.26778	val-error:0.31793
# [50]	train-error:0.26712	val-error:0.31779
# [51]	train-error:0.26641	val-error:0.31838
# [52]	train-error:0.26553	val-error:0.31808
# [53]	train-error:0.26483	val-error:0.31793
# [54]	train-error:0.26412	val-error:0.31683
# [55]	train-error:0.26326	val-error:0.31683
# [56]	train-error:0.26176	val-error:0.31786
# [57]	train-error:0.26072	val-error:0.31734
# [58]	train-error:0.26004	val-error:0.31594
# [59]	train-error:0.25973	val-error:0.31727
# [60]	train-error:0.25895	val-error:0.31528
# [61]	train-error:0.25799	val-error:0.31536
# [62]	train-error:0.25727	val-error:0.31550
# [63]	train-error:0.25654	val-error:0.31528
# [64]	train-error:0.25567	val-error:0.31580
# [65]	train-error:0.25490	val-error:0.31602
# [66]	train-error:0.25366	val-error:0.31594
# [67]	train-error:0.25283	val-error:0.31609
# [68]	train-error:0.25265	val-error:0.31757
# [69]	train-error:0.25178	val-error:0.31734
# [70]	train-error:0.25124	val-error:0.31823
# [71]	train-error:0.25080	val-error:0.31808
# [72]	train-error:0.25005	val-error:0.31771
# [73]	train-error:0.24938	val-error:0.31712
# [74]	train-error:0.24848	val-error:0.31624
# [75]	train-error:0.24748	val-error:0.31698
# [76]	train-error:0.24661	val-error:0.31661
# [77]	train-error:0.24588	val-error:0.31572
# [78]	train-error:0.24486	val-error:0.31550
# [79]	train-error:0.24359	val-error:0.31734
# Accuracy for iteration 3: 0.68
# Iteration 4
# [0]	train-error:0.34078	val-error:0.33920
# [1]	train-error:0.33383	val-error:0.33830
# [2]	train-error:0.32771	val-error:0.33174
# [3]	train-error:0.32599	val-error:0.32809
# [4]	train-error:0.32270	val-error:0.32518
# [5]	train-error:0.32153	val-error:0.32526
# [6]	train-error:0.31938	val-error:0.32287
# [7]	train-error:0.31697	val-error:0.32153
# [8]	train-error:0.31481	val-error:0.32034
# [9]	train-error:0.31374	val-error:0.31952
# [10]	train-error:0.31244	val-error:0.31907
# [11]	train-error:0.31130	val-error:0.31788
# [12]	train-error:0.31000	val-error:0.31683
# [13]	train-error:0.30889	val-error:0.31497
# [14]	train-error:0.30769	val-error:0.31683
# [15]	train-error:0.30651	val-error:0.31765
# [16]	train-error:0.30533	val-error:0.31832
# [17]	train-error:0.30346	val-error:0.31765
# [18]	train-error:0.30212	val-error:0.31825
# [19]	train-error:0.30082	val-error:0.31773
# [20]	train-error:0.29976	val-error:0.31691
# [21]	train-error:0.29835	val-error:0.31646
# [22]	train-error:0.29707	val-error:0.31534
# [23]	train-error:0.29558	val-error:0.31430
# [24]	train-error:0.29462	val-error:0.31452
# [25]	train-error:0.29372	val-error:0.31370
# [26]	train-error:0.29258	val-error:0.31393
# [27]	train-error:0.29107	val-error:0.31400
# [28]	train-error:0.29027	val-error:0.31407
# [29]	train-error:0.28930	val-error:0.31273
# [30]	train-error:0.28784	val-error:0.31191
# [31]	train-error:0.28605	val-error:0.31176
# [32]	train-error:0.28577	val-error:0.31169
# [33]	train-error:0.28381	val-error:0.31191
# [34]	train-error:0.28299	val-error:0.31191
# [35]	train-error:0.28223	val-error:0.31229
# [36]	train-error:0.28125	val-error:0.31251
# [37]	train-error:0.28019	val-error:0.31370
# [38]	train-error:0.27938	val-error:0.31214
# [39]	train-error:0.27852	val-error:0.31206
# [40]	train-error:0.27778	val-error:0.31303
# [41]	train-error:0.27634	val-error:0.31094
# [42]	train-error:0.27507	val-error:0.31109
# [43]	train-error:0.27395	val-error:0.31109
# [44]	train-error:0.27328	val-error:0.31124
# [45]	train-error:0.27167	val-error:0.31184
# [46]	train-error:0.27080	val-error:0.30923
# [47]	train-error:0.27017	val-error:0.30975
# [48]	train-error:0.26936	val-error:0.31050
# [49]	train-error:0.26891	val-error:0.30990
# [50]	train-error:0.26774	val-error:0.30863
# [51]	train-error:0.26709	val-error:0.30930
# [52]	train-error:0.26594	val-error:0.30938
# [53]	train-error:0.26485	val-error:0.31035
# [54]	train-error:0.26391	val-error:0.31072
# [55]	train-error:0.26349	val-error:0.30938
# [56]	train-error:0.26242	val-error:0.30915
# [57]	train-error:0.26147	val-error:0.30930
# [58]	train-error:0.26088	val-error:0.30856
# [59]	train-error:0.26035	val-error:0.30722
# [60]	train-error:0.25919	val-error:0.30819
# [61]	train-error:0.25888	val-error:0.30766
# [62]	train-error:0.25809	val-error:0.30722
# [63]	train-error:0.25709	val-error:0.30826
# [64]	train-error:0.25643	val-error:0.30766
# [65]	train-error:0.25583	val-error:0.30863
# [66]	train-error:0.25505	val-error:0.30915
# [67]	train-error:0.25381	val-error:0.30744
# [68]	train-error:0.25309	val-error:0.30833
# [69]	train-error:0.25235	val-error:0.30819
# [70]	train-error:0.25147	val-error:0.30811
# [71]	train-error:0.25050	val-error:0.30863
# [72]	train-error:0.24967	val-error:0.30968
# [73]	train-error:0.24859	val-error:0.30945
# [74]	train-error:0.24822	val-error:0.31161
# [75]	train-error:0.24761	val-error:0.31050
# [76]	train-error:0.24671	val-error:0.31072
# [77]	train-error:0.24613	val-error:0.30968
# [78]	train-error:0.24591	val-error:0.30990
# Accuracy for iteration 4: 0.67
# Iteration 5
# [0]	train-error:0.33965	val-error:0.35315
# [1]	train-error:0.33183	val-error:0.34343
# [2]	train-error:0.32696	val-error:0.34238
# [3]	train-error:0.32551	val-error:0.34388
# [4]	train-error:0.32375	val-error:0.33921
# [5]	train-error:0.32158	val-error:0.33778
# [6]	train-error:0.31950	val-error:0.33740
# [7]	train-error:0.31774	val-error:0.33469
# [8]	train-error:0.31604	val-error:0.33537
# [9]	train-error:0.31506	val-error:0.33544
# [10]	train-error:0.31332	val-error:0.33401
# [11]	train-error:0.31226	val-error:0.33296
# [12]	train-error:0.31070	val-error:0.33047
# [13]	train-error:0.30954	val-error:0.32904
# [14]	train-error:0.30774	val-error:0.32987
# [15]	train-error:0.30628	val-error:0.32828
# [16]	train-error:0.30565	val-error:0.32859
# [17]	train-error:0.30417	val-error:0.32813
# [18]	train-error:0.30284	val-error:0.32700
# [19]	train-error:0.30142	val-error:0.32610
# [20]	train-error:0.30027	val-error:0.32542
# [21]	train-error:0.29900	val-error:0.32542
# [22]	train-error:0.29781	val-error:0.32482
# [23]	train-error:0.29681	val-error:0.32557
# [24]	train-error:0.29587	val-error:0.32406
# [25]	train-error:0.29447	val-error:0.32452
# [26]	train-error:0.29294	val-error:0.32580
# [27]	train-error:0.29158	val-error:0.32527
# [28]	train-error:0.29042	val-error:0.32572
# [29]	train-error:0.28911	val-error:0.32406
# [30]	train-error:0.28746	val-error:0.32331
# [31]	train-error:0.28602	val-error:0.32158
# [32]	train-error:0.28491	val-error:0.32120
# [33]	train-error:0.28362	val-error:0.32120
# [34]	train-error:0.28273	val-error:0.32082
# [35]	train-error:0.28179	val-error:0.32165
# [36]	train-error:0.28062	val-error:0.32135
# [37]	train-error:0.27925	val-error:0.32158
# [38]	train-error:0.27843	val-error:0.32097
# [39]	train-error:0.27755	val-error:0.32030
# [40]	train-error:0.27641	val-error:0.32135
# [41]	train-error:0.27601	val-error:0.32075
# [42]	train-error:0.27479	val-error:0.32195
# [43]	train-error:0.27332	val-error:0.32135
# [44]	train-error:0.27229	val-error:0.32082
# [45]	train-error:0.27149	val-error:0.32135
# [46]	train-error:0.27061	val-error:0.32120
# [47]	train-error:0.26972	val-error:0.32128
# [48]	train-error:0.26905	val-error:0.32112
# [49]	train-error:0.26791	val-error:0.32075
# [50]	train-error:0.26706	val-error:0.32105
# [51]	train-error:0.26616	val-error:0.32014
# [52]	train-error:0.26506	val-error:0.31999
# [53]	train-error:0.26441	val-error:0.31886
# [54]	train-error:0.26337	val-error:0.31954
# [55]	train-error:0.26265	val-error:0.31962
# [56]	train-error:0.26215	val-error:0.31834
# [57]	train-error:0.26105	val-error:0.31826
# [58]	train-error:0.26014	val-error:0.31849
# [59]	train-error:0.25912	val-error:0.31856
# [60]	train-error:0.25833	val-error:0.31834
# [61]	train-error:0.25751	val-error:0.31796
# [62]	train-error:0.25630	val-error:0.31773
# [63]	train-error:0.25528	val-error:0.31781
# [64]	train-error:0.25481	val-error:0.31743
# [65]	train-error:0.25367	val-error:0.31638
# [66]	train-error:0.25315	val-error:0.31675
# [67]	train-error:0.25202	val-error:0.31675
# [68]	train-error:0.25140	val-error:0.31683
# [69]	train-error:0.25099	val-error:0.31660
# [70]	train-error:0.25034	val-error:0.31675
# [71]	train-error:0.24939	val-error:0.31803
# [72]	train-error:0.24876	val-error:0.31743
# [73]	train-error:0.24794	val-error:0.31653
# [74]	train-error:0.24689	val-error:0.31668
# [75]	train-error:0.24618	val-error:0.31645
# [76]	train-error:0.24573	val-error:0.31690
# [77]	train-error:0.24507	val-error:0.31645
# [78]	train-error:0.24408	val-error:0.31653
# [79]	train-error:0.24335	val-error:0.31675
# [80]	train-error:0.24216	val-error:0.31698
# [81]	train-error:0.24150	val-error:0.31705
# [82]	train-error:0.24096	val-error:0.31721
# [83]	train-error:0.23994	val-error:0.31638
# [84]	train-error:0.23901	val-error:0.31532
# [85]	train-error:0.23822	val-error:0.31502
# [86]	train-error:0.23756	val-error:0.31570
# [87]	train-error:0.23631	val-error:0.31592
# [88]	train-error:0.23546	val-error:0.31690
# [89]	train-error:0.23477	val-error:0.31600
# [90]	train-error:0.23441	val-error:0.31577
# [91]	train-error:0.23374	val-error:0.31668
# [92]	train-error:0.23305	val-error:0.31660
# [93]	train-error:0.23213	val-error:0.31645
# [94]	train-error:0.23157	val-error:0.31623
# [95]	train-error:0.23150	val-error:0.31630
# [96]	train-error:0.23080	val-error:0.31638
# [97]	train-error:0.23011	val-error:0.31585
# [98]	train-error:0.22937	val-error:0.31653
# [99]	train-error:0.22861	val-error:0.31608
# [100]	train-error:0.22794	val-error:0.31532
# [101]	train-error:0.22698	val-error:0.31690
# [102]	train-error:0.22643	val-error:0.31653
# [103]	train-error:0.22584	val-error:0.31547
# [104]	train-error:0.22507	val-error:0.31668
# Accuracy for iteration 5: 0.67
# Iteration 6
# [0]	train-error:0.34120	val-error:0.35766
# [1]	train-error:0.33295	val-error:0.36007
# [2]	train-error:0.33062	val-error:0.35412
# [3]	train-error:0.32486	val-error:0.34743
# [4]	train-error:0.32192	val-error:0.34773
# [5]	train-error:0.31964	val-error:0.34329
# [6]	train-error:0.31740	val-error:0.34321
# [7]	train-error:0.31603	val-error:0.34502
# [8]	train-error:0.31504	val-error:0.34351
# [9]	train-error:0.31368	val-error:0.34201
# [10]	train-error:0.31234	val-error:0.34066
# [11]	train-error:0.31090	val-error:0.34103
# [12]	train-error:0.31018	val-error:0.34073
# [13]	train-error:0.30858	val-error:0.33832
# [14]	train-error:0.30805	val-error:0.33817
# [15]	train-error:0.30675	val-error:0.33780
# [16]	train-error:0.30591	val-error:0.33772
# [17]	train-error:0.30480	val-error:0.33757
# [18]	train-error:0.30319	val-error:0.33516
# [19]	train-error:0.30153	val-error:0.33449
# [20]	train-error:0.30054	val-error:0.33494
# [21]	train-error:0.29936	val-error:0.33381
# [22]	train-error:0.29823	val-error:0.33268
# [23]	train-error:0.29706	val-error:0.33238
# [24]	train-error:0.29617	val-error:0.33208
# [25]	train-error:0.29498	val-error:0.33208
# [26]	train-error:0.29345	val-error:0.33103
# [27]	train-error:0.29223	val-error:0.32990
# [28]	train-error:0.29044	val-error:0.32967
# [29]	train-error:0.28940	val-error:0.32915
# [30]	train-error:0.28756	val-error:0.32847
# [31]	train-error:0.28642	val-error:0.32779
# [32]	train-error:0.28526	val-error:0.32704
# [33]	train-error:0.28392	val-error:0.32734
# [34]	train-error:0.28370	val-error:0.32621
# [35]	train-error:0.28288	val-error:0.32599
# [36]	train-error:0.28183	val-error:0.32621
# [37]	train-error:0.28053	val-error:0.32599
# [38]	train-error:0.27954	val-error:0.32448
# [39]	train-error:0.27830	val-error:0.32471
# [40]	train-error:0.27713	val-error:0.32486
# [41]	train-error:0.27674	val-error:0.32486
# [42]	train-error:0.27579	val-error:0.32328
# [43]	train-error:0.27525	val-error:0.32403
# [44]	train-error:0.27391	val-error:0.32448
# [45]	train-error:0.27341	val-error:0.32380
# [46]	train-error:0.27205	val-error:0.32252
# [47]	train-error:0.27120	val-error:0.32335
# [48]	train-error:0.27002	val-error:0.32290
# [49]	train-error:0.26894	val-error:0.32373
# [50]	train-error:0.26782	val-error:0.32320
# [51]	train-error:0.26699	val-error:0.32320
# [52]	train-error:0.26664	val-error:0.32320
# [53]	train-error:0.26552	val-error:0.32313
# [54]	train-error:0.26455	val-error:0.32237
# [55]	train-error:0.26331	val-error:0.32222
# [56]	train-error:0.26264	val-error:0.32155
# [57]	train-error:0.26194	val-error:0.32140
# [58]	train-error:0.26118	val-error:0.32132
# [59]	train-error:0.26020	val-error:0.32155
# [60]	train-error:0.25937	val-error:0.32072
# [61]	train-error:0.25852	val-error:0.32072
# [62]	train-error:0.25765	val-error:0.32087
# [63]	train-error:0.25679	val-error:0.32162
# [64]	train-error:0.25646	val-error:0.32132
# [65]	train-error:0.25514	val-error:0.32079
# [66]	train-error:0.25457	val-error:0.32019
# [67]	train-error:0.25349	val-error:0.32019
# [68]	train-error:0.25241	val-error:0.32019
# [69]	train-error:0.25177	val-error:0.32057
# [70]	train-error:0.25121	val-error:0.31982
# [71]	train-error:0.24996	val-error:0.32019
# [72]	train-error:0.24939	val-error:0.31959
# [73]	train-error:0.24857	val-error:0.32012
# [74]	train-error:0.24765	val-error:0.31997
# [75]	train-error:0.24712	val-error:0.31997
# [76]	train-error:0.24669	val-error:0.31982
# [77]	train-error:0.24612	val-error:0.31937
# [78]	train-error:0.24523	val-error:0.31937
# [79]	train-error:0.24436	val-error:0.31921
# [80]	train-error:0.24386	val-error:0.31937
# [81]	train-error:0.24300	val-error:0.31974
# [82]	train-error:0.24240	val-error:0.31899
# [83]	train-error:0.24146	val-error:0.31854
# [84]	train-error:0.24085	val-error:0.31861
# [85]	train-error:0.24019	val-error:0.31876
# [86]	train-error:0.23944	val-error:0.31809
# [87]	train-error:0.23841	val-error:0.31726
# [88]	train-error:0.23740	val-error:0.31703
# [89]	train-error:0.23675	val-error:0.31741
# [90]	train-error:0.23609	val-error:0.31831
# [91]	train-error:0.23556	val-error:0.31831
# [92]	train-error:0.23442	val-error:0.31809
# [93]	train-error:0.23367	val-error:0.31854
# [94]	train-error:0.23315	val-error:0.31824
# [95]	train-error:0.23258	val-error:0.31846
# [96]	train-error:0.23224	val-error:0.31839
# [97]	train-error:0.23146	val-error:0.31824
# [98]	train-error:0.23078	val-error:0.31861
# [99]	train-error:0.23055	val-error:0.31771
# [100]	train-error:0.22939	val-error:0.31816
# [101]	train-error:0.22866	val-error:0.31786
# [102]	train-error:0.22816	val-error:0.31748
# [103]	train-error:0.22754	val-error:0.31688
# [104]	train-error:0.22642	val-error:0.31651
# [105]	train-error:0.22583	val-error:0.31688
# [106]	train-error:0.22490	val-error:0.31688
# [107]	train-error:0.22400	val-error:0.31688
# [108]	train-error:0.22350	val-error:0.31711
# [109]	train-error:0.22276	val-error:0.31658
# [110]	train-error:0.22183	val-error:0.31681
# [111]	train-error:0.22106	val-error:0.31756
# [112]	train-error:0.22037	val-error:0.31748
# [113]	train-error:0.21971	val-error:0.31779
# [114]	train-error:0.21907	val-error:0.31718
# [115]	train-error:0.21878	val-error:0.31733
# [116]	train-error:0.21768	val-error:0.31703
# [117]	train-error:0.21746	val-error:0.31733
# [118]	train-error:0.21687	val-error:0.31658
# [119]	train-error:0.21599	val-error:0.31628
# [120]	train-error:0.21469	val-error:0.31688
# [121]	train-error:0.21402	val-error:0.31718
# [122]	train-error:0.21297	val-error:0.31748
# [123]	train-error:0.21287	val-error:0.31786
# [124]	train-error:0.21201	val-error:0.31816
# [125]	train-error:0.21120	val-error:0.31763
# [126]	train-error:0.21068	val-error:0.31846
# [127]	train-error:0.20995	val-error:0.31869
# [128]	train-error:0.20899	val-error:0.31786
# [129]	train-error:0.20848	val-error:0.31794
# [130]	train-error:0.20725	val-error:0.31771
# [131]	train-error:0.20661	val-error:0.31763
# [132]	train-error:0.20591	val-error:0.31786
# [133]	train-error:0.20589	val-error:0.31854
# [134]	train-error:0.20492	val-error:0.31816
# [135]	train-error:0.20445	val-error:0.31854
# [136]	train-error:0.20370	val-error:0.31876
# [137]	train-error:0.20316	val-error:0.31899
# [138]	train-error:0.20255	val-error:0.31891
# [139]	train-error:0.20147	val-error:0.31959
# Accuracy for iteration 6: 0.69
# Iteration 7
# [0]	train-error:0.33947	val-error:0.35343
# [1]	train-error:0.33316	val-error:0.34894
# [2]	train-error:0.33068	val-error:0.34872
# [3]	train-error:0.32714	val-error:0.34739
# [4]	train-error:0.32502	val-error:0.34769
# [5]	train-error:0.32204	val-error:0.34379
# [6]	train-error:0.32077	val-error:0.34379
# [7]	train-error:0.31796	val-error:0.34209
# [8]	train-error:0.31713	val-error:0.34069
# [9]	train-error:0.31542	val-error:0.34025
# [10]	train-error:0.31395	val-error:0.33959
# [11]	train-error:0.31224	val-error:0.33643
# [12]	train-error:0.31082	val-error:0.33723
# [13]	train-error:0.30981	val-error:0.33672
# [14]	train-error:0.30800	val-error:0.33753
# [15]	train-error:0.30664	val-error:0.33834
# [16]	train-error:0.30561	val-error:0.33510
# [17]	train-error:0.30389	val-error:0.33562
# [18]	train-error:0.30354	val-error:0.33407
# [19]	train-error:0.30185	val-error:0.33355
# [20]	train-error:0.30025	val-error:0.33400
# [21]	train-error:0.29937	val-error:0.33274
# [22]	train-error:0.29861	val-error:0.33112
# [23]	train-error:0.29714	val-error:0.33304
# [24]	train-error:0.29551	val-error:0.33201
# [25]	train-error:0.29459	val-error:0.33127
# [26]	train-error:0.29307	val-error:0.33112
# [27]	train-error:0.29228	val-error:0.33076
# [28]	train-error:0.29087	val-error:0.32958
# [29]	train-error:0.28899	val-error:0.32987
# [30]	train-error:0.28794	val-error:0.32943
# [31]	train-error:0.28580	val-error:0.32884
# [32]	train-error:0.28564	val-error:0.32781
# [33]	train-error:0.28479	val-error:0.32774
# [34]	train-error:0.28379	val-error:0.32715
# [35]	train-error:0.28247	val-error:0.32597
# [36]	train-error:0.28186	val-error:0.32605
# [37]	train-error:0.28040	val-error:0.32686
# [38]	train-error:0.27909	val-error:0.32634
# [39]	train-error:0.27812	val-error:0.32752
# [40]	train-error:0.27729	val-error:0.32730
# [41]	train-error:0.27655	val-error:0.32693
# [42]	train-error:0.27541	val-error:0.32686
# [43]	train-error:0.27481	val-error:0.32590
# [44]	train-error:0.27332	val-error:0.32568
# [45]	train-error:0.27228	val-error:0.32501
# [46]	train-error:0.27140	val-error:0.32450
# [47]	train-error:0.27112	val-error:0.32479
# [48]	train-error:0.27063	val-error:0.32413
# [49]	train-error:0.26928	val-error:0.32354
# [50]	train-error:0.26766	val-error:0.32457
# [51]	train-error:0.26674	val-error:0.32509
# [52]	train-error:0.26555	val-error:0.32457
# [53]	train-error:0.26462	val-error:0.32560
# [54]	train-error:0.26381	val-error:0.32450
# [55]	train-error:0.26313	val-error:0.32465
# [56]	train-error:0.26208	val-error:0.32428
# [57]	train-error:0.26147	val-error:0.32420
# [58]	train-error:0.26035	val-error:0.32443
# [59]	train-error:0.25950	val-error:0.32332
# [60]	train-error:0.25857	val-error:0.32340
# [61]	train-error:0.25757	val-error:0.32325
# [62]	train-error:0.25695	val-error:0.32369
# [63]	train-error:0.25634	val-error:0.32317
# [64]	train-error:0.25555	val-error:0.32347
# [65]	train-error:0.25474	val-error:0.32273
# [66]	train-error:0.25364	val-error:0.32266
# [67]	train-error:0.25294	val-error:0.32295
# [68]	train-error:0.25259	val-error:0.32178
# [69]	train-error:0.25162	val-error:0.32236
# [70]	train-error:0.25081	val-error:0.32155
# [71]	train-error:0.24997	val-error:0.32097
# [72]	train-error:0.24898	val-error:0.32119
# [73]	train-error:0.24838	val-error:0.32038
# [74]	train-error:0.24807	val-error:0.32133
# [75]	train-error:0.24717	val-error:0.32126
# [76]	train-error:0.24637	val-error:0.32170
# [77]	train-error:0.24578	val-error:0.32229
# [78]	train-error:0.24494	val-error:0.32163
# [79]	train-error:0.24413	val-error:0.32126
# [80]	train-error:0.24339	val-error:0.32104
# [81]	train-error:0.24221	val-error:0.32089
# [82]	train-error:0.24201	val-error:0.32111
# [83]	train-error:0.24103	val-error:0.32207
# [84]	train-error:0.24062	val-error:0.32178
# [85]	train-error:0.23983	val-error:0.32045
# [86]	train-error:0.23887	val-error:0.32097
# [87]	train-error:0.23804	val-error:0.32074
# [88]	train-error:0.23755	val-error:0.32089
# [89]	train-error:0.23708	val-error:0.32052
# [90]	train-error:0.23641	val-error:0.32023
# [91]	train-error:0.23576	val-error:0.32030
# [92]	train-error:0.23467	val-error:0.31994
# [93]	train-error:0.23416	val-error:0.32052
# [94]	train-error:0.23321	val-error:0.32052
# [95]	train-error:0.23256	val-error:0.32082
# [96]	train-error:0.23207	val-error:0.32082
# [97]	train-error:0.23145	val-error:0.32148
# [98]	train-error:0.23082	val-error:0.32045
# [99]	train-error:0.22992	val-error:0.32030
# [100]	train-error:0.22936	val-error:0.32067
# [101]	train-error:0.22858	val-error:0.32023
# [102]	train-error:0.22776	val-error:0.32104
# [103]	train-error:0.22730	val-error:0.32133
# [104]	train-error:0.22682	val-error:0.32016
# [105]	train-error:0.22589	val-error:0.32030
# [106]	train-error:0.22488	val-error:0.32104
# [107]	train-error:0.22425	val-error:0.31957
# [108]	train-error:0.22351	val-error:0.31949
# [109]	train-error:0.22289	val-error:0.31949
# [110]	train-error:0.22196	val-error:0.31964
# [111]	train-error:0.22134	val-error:0.31920
# [112]	train-error:0.22043	val-error:0.31913
# [113]	train-error:0.22010	val-error:0.31920
# [114]	train-error:0.21931	val-error:0.32030
# [115]	train-error:0.21875	val-error:0.31942
# [116]	train-error:0.21808	val-error:0.31927
# [117]	train-error:0.21732	val-error:0.32045
# [118]	train-error:0.21634	val-error:0.32008
# [119]	train-error:0.21604	val-error:0.31935
# [120]	train-error:0.21544	val-error:0.31868
# [121]	train-error:0.21491	val-error:0.31971
# [122]	train-error:0.21400	val-error:0.32008
# [123]	train-error:0.21339	val-error:0.31994
# [124]	train-error:0.21295	val-error:0.32111
# [125]	train-error:0.21199	val-error:0.32038
# [126]	train-error:0.21141	val-error:0.32030
# [127]	train-error:0.21090	val-error:0.31935
# [128]	train-error:0.21022	val-error:0.32023
# [129]	train-error:0.20974	val-error:0.32023
# [130]	train-error:0.20897	val-error:0.31979
# [131]	train-error:0.20827	val-error:0.32001
# [132]	train-error:0.20800	val-error:0.32016
# [133]	train-error:0.20739	val-error:0.32008
# [134]	train-error:0.20638	val-error:0.32023
# [135]	train-error:0.20606	val-error:0.31957
# [136]	train-error:0.20532	val-error:0.32016
# [137]	train-error:0.20482	val-error:0.32016
# [138]	train-error:0.20434	val-error:0.32082
# [139]	train-error:0.20349	val-error:0.32045
# Accuracy for iteration 7: 0.68
# Average Accuracy across 7 iterations: 0.68

# %%
import numpy as np
from scipy.stats import sem, t
from scipy import mean

# Assuming accuracies are stored in the 'accuracies' list as per previous example
accuracies = np.array(accuracies)

# Calculate the mean accuracy
mean_accuracy = np.mean(accuracies)

# Calculate the standard error of the mean
std_error = sem(accuracies)

# Determine the size of the accuracies array
n = len(accuracies)

# Use the t-distribution to calculate a 95% confidence interval
confidence = 0.95
h = std_error * t.ppf((1 + confidence) / 2, n - 1)

# Print the mean accuracy and confidence interval
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"95% Confidence interval: {mean_accuracy - h:.5f} - {mean_accuracy + h:.5f}")
# Out:
# Mean Accuracy: 0.68
# 95% Confidence interval: 0.67504 - 0.68523

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.67      0.71      0.69      6792
#         High       0.69      0.65      0.67      6792
#
#     accuracy                           0.68     13584
#    macro avg       0.68      0.68      0.68     13584
# weighted avg       0.68      0.68      0.68     13584

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.68      0.71      0.69      6336
#         High       0.69      0.66      0.68      6336
#
#     accuracy                           0.68     12672
#    macro avg       0.69      0.68      0.68     12672
# weighted avg       0.69      0.68      0.68     12672
