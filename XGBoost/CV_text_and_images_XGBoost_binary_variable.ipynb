# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = image_columns + additional_columns_to_keep + text_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Image_Count   image_0   image_1   image_2   image_3  ...  text_758  \
# 0             1  0.483804  4.411579  0.103043  0.694330  ... -0.155746
# 1             1  1.257535  4.292836  0.637026  0.038215  ... -0.247792
# 2             1  1.015909  4.928564  0.049328  1.360145  ... -0.089539
# 4             1  0.961807  3.994127  0.116529  1.330238  ... -0.112963
# 9             1  1.316597  1.515859  0.067210  2.473874  ... -0.147682
# 10            1  1.682237  1.290816  0.079366  0.259502  ... -0.009259
# 11            1  0.923607  3.838140  0.041025  0.159674  ... -0.092988
# 12            1  0.044586  1.376372  0.007699  0.149779  ... -0.161618
# 13            1  0.012054  0.549083  0.087380  0.054316  ... -0.162583
# 14            1  0.587146  4.310180  0.034403  0.048306  ... -0.114496
#
#     text_759  text_760  text_761  text_762  text_763  text_764  text_765  \
# 0  -0.017703 -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870
# 1   0.015757 -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263
# 2  -0.097885 -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142
# 4  -0.036261 -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846
# 9  -0.036988 -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471
# 10 -0.165627  0.198171  0.093986  0.176528  0.140797  0.070081 -0.168545
# 11 -0.083701  0.228142  0.049256  0.080081  0.093756  0.086833 -0.163537
# 12 -0.178489  0.159561 -0.046662  0.182022  0.127947  0.299180 -0.091949
# 13  0.028141 -0.179497  0.085646  0.179977  0.134104  0.239402  0.052813
# 14 -0.001124 -0.172151  0.021455  0.215737  0.150555  0.408500 -0.234415
#
#     text_766  text_767
# 0   0.062999  0.075272
# 1  -0.012400  0.147600
# 2   0.094179  0.080168
# 4   0.141513  0.093924
# 9   0.012900  0.064740
# 10  0.107152  0.057365
# 11  0.100750  0.096130
# 12  0.096147  0.045425
# 13  0.030690 -0.044792
# 14  0.109303 -0.072184
#
# [10 rows x 2822 columns]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %%
data_2.head(10)
# Out:
#          Username              post_id  like_count  comment_count  Followers  \
# 0   00_rocketgirl  1354915397698488656         293              6       6453
# 1   00_rocketgirl  1666974101448132749          73              2       6453
# 2   00_rocketgirl  1768273356099895999         164              4       6453
# 4   00_rocketgirl  1899586748141399903         116              2       6453
# 9          0hkris  1514786978688118458         269              0      12630
# 10         0hkris  1837331879491417999        1065             19      12630
# 11         0hkris  1840089921320547693        1242              7      12630
# 12         0hkris  1847365723795798774        1346              4      12630
# 13        0ldisme  1653111532051112326        1139             28      18583
# 14        0ldisme  1708204647056992205        1352             39      18583
#
#     Image_Count   image_0   image_1   image_2   image_3  ...  text_759  \
# 0             1  0.483804  4.411579  0.103043  0.694330  ... -0.017703
# 1             1  1.257535  4.292836  0.637026  0.038215  ...  0.015757
# 2             1  1.015909  4.928564  0.049328  1.360145  ... -0.097885
# 4             1  0.961807  3.994127  0.116529  1.330238  ... -0.036261
# 9             1  1.316597  1.515859  0.067210  2.473874  ... -0.036988
# 10            1  1.682237  1.290816  0.079366  0.259502  ... -0.165627
# 11            1  0.923607  3.838140  0.041025  0.159674  ... -0.083701
# 12            1  0.044586  1.376372  0.007699  0.149779  ... -0.178489
# 13            1  0.012054  0.549083  0.087380  0.054316  ...  0.028141
# 14            1  0.587146  4.310180  0.034403  0.048306  ... -0.001124
#
#     text_760  text_761  text_762  text_763  text_764  text_765  text_766  \
# 0  -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870  0.062999
# 1  -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263 -0.012400
# 2  -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142  0.094179
# 4  -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846  0.141513
# 9  -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471  0.012900
# 10  0.198171  0.093986  0.176528  0.140797  0.070081 -0.168545  0.107152
# 11  0.228142  0.049256  0.080081  0.093756  0.086833 -0.163537  0.100750
# 12  0.159561 -0.046662  0.182022  0.127947  0.299180 -0.091949  0.096147
# 13 -0.179497  0.085646  0.179977  0.134104  0.239402  0.052813  0.030690
# 14 -0.172151  0.021455  0.215737  0.150555  0.408500 -0.234415  0.109303
#
#     text_767  popularity
# 0   0.075272    0.046335
# 1   0.147600    0.011623
# 2   0.080168    0.026034
# 4   0.093924    0.018286
# 9   0.064740    0.021298
# 10  0.057365    0.085827
# 11  0.096130    0.098892
# 12  0.045425    0.106888
# 13 -0.044792    0.062799
# 14 -0.072184    0.074853
#
# [10 rows x 2823 columns]

# %% [markdown]
# Let's run the algorithm!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_test = test_data['popularity']

    # Convert datasets into DMatrix objects
    dtrain = xgb.DMatrix(X_train, label=y_train)
    dval = xgb.DMatrix(X_val, label=y_val)
    dtest = xgb.DMatrix(X_test, label=y_test)

    # Define XGBoost model parameters
    params = {
        'objective': 'binary:logistic',
        'eval_metric': 'error',
        'alpha': 0.9,
        'learning_rate': 0.1
    }

    # Train the model
    eval_list = [(dtrain, 'train'), (dval, 'val')]
    bst = xgb.train(params, dtrain, num_boost_round=500, evals=eval_list, early_stopping_rounds=20)

    # Evaluate the model on the test set
    y_pred_prob = bst.predict(dtest)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# [0]	train-error:0.41781	val-error:0.44417
# [1]	train-error:0.40457	val-error:0.43265
# [2]	train-error:0.39548	val-error:0.42559
# [3]	train-error:0.38965	val-error:0.42261
# [4]	train-error:0.38699	val-error:0.42150
# [5]	train-error:0.38297	val-error:0.42113
# [6]	train-error:0.38060	val-error:0.41793
# [7]	train-error:0.37756	val-error:0.41659
# [8]	train-error:0.37552	val-error:0.41273
# [9]	train-error:0.37256	val-error:0.41525
# [10]	train-error:0.37105	val-error:0.41094
# [11]	train-error:0.36903	val-error:0.41280
# [12]	train-error:0.36695	val-error:0.41288
# [13]	train-error:0.36513	val-error:0.41169
# [14]	train-error:0.36263	val-error:0.41020
# [15]	train-error:0.36151	val-error:0.41117
# [16]	train-error:0.35974	val-error:0.40960
# [17]	train-error:0.35806	val-error:0.40842
# [18]	train-error:0.35638	val-error:0.40960
# [19]	train-error:0.35442	val-error:0.40938
# [20]	train-error:0.35255	val-error:0.41020
# [21]	train-error:0.35029	val-error:0.40931
# [22]	train-error:0.34845	val-error:0.40782
# [23]	train-error:0.34748	val-error:0.40663
# [24]	train-error:0.34585	val-error:0.40752
# [25]	train-error:0.34364	val-error:0.40678
# [26]	train-error:0.34190	val-error:0.40500
# [27]	train-error:0.34037	val-error:0.40500
# [28]	train-error:0.33875	val-error:0.40507
# [29]	train-error:0.33695	val-error:0.40247
# [30]	train-error:0.33601	val-error:0.40232
# [31]	train-error:0.33407	val-error:0.40225
# [32]	train-error:0.33258	val-error:0.40172
# [33]	train-error:0.33115	val-error:0.40225
# [34]	train-error:0.32947	val-error:0.40150
# [35]	train-error:0.32747	val-error:0.40128
# [36]	train-error:0.32660	val-error:0.39942
# [37]	train-error:0.32525	val-error:0.39838
# [38]	train-error:0.32350	val-error:0.39897
# [39]	train-error:0.32226	val-error:0.40158
# [40]	train-error:0.32070	val-error:0.40150
# [41]	train-error:0.31919	val-error:0.40158
# [42]	train-error:0.31776	val-error:0.40239
# [43]	train-error:0.31592	val-error:0.40143
# [44]	train-error:0.31484	val-error:0.40135
# [45]	train-error:0.31337	val-error:0.40076
# [46]	train-error:0.31187	val-error:0.40001
# [47]	train-error:0.31071	val-error:0.39972
# [48]	train-error:0.30903	val-error:0.39808
# [49]	train-error:0.30741	val-error:0.39816
# [50]	train-error:0.30630	val-error:0.39897
# [51]	train-error:0.30479	val-error:0.40024
# [52]	train-error:0.30348	val-error:0.39942
# [53]	train-error:0.30279	val-error:0.39883
# [54]	train-error:0.30149	val-error:0.39853
# [55]	train-error:0.30036	val-error:0.39734
# [56]	train-error:0.29940	val-error:0.39897
# [57]	train-error:0.29853	val-error:0.39883
# [58]	train-error:0.29797	val-error:0.39875
# [59]	train-error:0.29679	val-error:0.39912
# [60]	train-error:0.29552	val-error:0.39860
# [61]	train-error:0.29429	val-error:0.39912
# [62]	train-error:0.29323	val-error:0.39734
# [63]	train-error:0.29187	val-error:0.39801
# [64]	train-error:0.29054	val-error:0.39689
# [65]	train-error:0.28990	val-error:0.39778
# [66]	train-error:0.28893	val-error:0.39607
# [67]	train-error:0.28739	val-error:0.39481
# [68]	train-error:0.28659	val-error:0.39704
# [69]	train-error:0.28539	val-error:0.39563
# [70]	train-error:0.28451	val-error:0.39474
# [71]	train-error:0.28437	val-error:0.39518
# [72]	train-error:0.28273	val-error:0.39555
# [73]	train-error:0.28207	val-error:0.39459
# [74]	train-error:0.28032	val-error:0.39533
# [75]	train-error:0.27918	val-error:0.39429
# [76]	train-error:0.27837	val-error:0.39392
# [77]	train-error:0.27696	val-error:0.39251
# [78]	train-error:0.27569	val-error:0.39407
# [79]	train-error:0.27438	val-error:0.39496
# [80]	train-error:0.27381	val-error:0.39563
# [81]	train-error:0.27260	val-error:0.39593
# [82]	train-error:0.27147	val-error:0.39637
# [83]	train-error:0.27059	val-error:0.39674
# [84]	train-error:0.26940	val-error:0.39555
# [85]	train-error:0.26868	val-error:0.39496
# [86]	train-error:0.26767	val-error:0.39451
# [87]	train-error:0.26662	val-error:0.39422
# [88]	train-error:0.26596	val-error:0.39451
# [89]	train-error:0.26497	val-error:0.39414
# [90]	train-error:0.26395	val-error:0.39347
# [91]	train-error:0.26297	val-error:0.39362
# [92]	train-error:0.26160	val-error:0.39422
# [93]	train-error:0.26123	val-error:0.39444
# [94]	train-error:0.26048	val-error:0.39474
# [95]	train-error:0.25947	val-error:0.39466
# [96]	train-error:0.25816	val-error:0.39533
# Accuracy for iteration 1: 0.60
# Iteration 2
# [0]	train-error:0.41862	val-error:0.43333
# [1]	train-error:0.40543	val-error:0.42540
# [2]	train-error:0.39569	val-error:0.42304
# [3]	train-error:0.38972	val-error:0.42037
# [4]	train-error:0.38484	val-error:0.41656
# [5]	train-error:0.38039	val-error:0.41709
# [6]	train-error:0.37670	val-error:0.41389
# [7]	train-error:0.37441	val-error:0.41465
# [8]	train-error:0.37212	val-error:0.41153
# [9]	train-error:0.37053	val-error:0.41229
# [10]	train-error:0.36852	val-error:0.41298
# [11]	train-error:0.36721	val-error:0.41214
# [12]	train-error:0.36536	val-error:0.41076
# [13]	train-error:0.36324	val-error:0.41153
# [14]	train-error:0.36190	val-error:0.40893
# [15]	train-error:0.36001	val-error:0.41137
# [16]	train-error:0.35873	val-error:0.40954
# [17]	train-error:0.35652	val-error:0.40863
# [18]	train-error:0.35442	val-error:0.40916
# [19]	train-error:0.35257	val-error:0.40756
# [20]	train-error:0.35060	val-error:0.40741
# [21]	train-error:0.34868	val-error:0.40764
# [22]	train-error:0.34717	val-error:0.40871
# [23]	train-error:0.34556	val-error:0.40817
# [24]	train-error:0.34405	val-error:0.40749
# [25]	train-error:0.34218	val-error:0.40878
# [26]	train-error:0.33996	val-error:0.40703
# [27]	train-error:0.33834	val-error:0.40878
# [28]	train-error:0.33688	val-error:0.40749
# [29]	train-error:0.33577	val-error:0.40680
# [30]	train-error:0.33460	val-error:0.40566
# [31]	train-error:0.33307	val-error:0.40703
# [32]	train-error:0.33219	val-error:0.40718
# [33]	train-error:0.33020	val-error:0.40642
# [34]	train-error:0.32874	val-error:0.40817
# [35]	train-error:0.32819	val-error:0.40718
# [36]	train-error:0.32631	val-error:0.40665
# [37]	train-error:0.32507	val-error:0.40672
# [38]	train-error:0.32337	val-error:0.40817
# [39]	train-error:0.32214	val-error:0.40772
# [40]	train-error:0.32078	val-error:0.40794
# [41]	train-error:0.31943	val-error:0.40756
# [42]	train-error:0.31812	val-error:0.40703
# [43]	train-error:0.31668	val-error:0.40657
# [44]	train-error:0.31552	val-error:0.40779
# [45]	train-error:0.31352	val-error:0.40711
# [46]	train-error:0.31298	val-error:0.40657
# [47]	train-error:0.31161	val-error:0.40589
# [48]	train-error:0.31015	val-error:0.40467
# [49]	train-error:0.30891	val-error:0.40474
# [50]	train-error:0.30774	val-error:0.40733
# [51]	train-error:0.30648	val-error:0.40718
# [52]	train-error:0.30484	val-error:0.40627
# [53]	train-error:0.30377	val-error:0.40558
# [54]	train-error:0.30160	val-error:0.40749
# [55]	train-error:0.30043	val-error:0.40573
# [56]	train-error:0.29946	val-error:0.40543
# [57]	train-error:0.29784	val-error:0.40345
# [58]	train-error:0.29729	val-error:0.40421
# [59]	train-error:0.29602	val-error:0.40367
# [60]	train-error:0.29477	val-error:0.40329
# [61]	train-error:0.29387	val-error:0.40398
# [62]	train-error:0.29257	val-error:0.40467
# [63]	train-error:0.29162	val-error:0.40520
# [64]	train-error:0.29051	val-error:0.40482
# [65]	train-error:0.28922	val-error:0.40482
# [66]	train-error:0.28743	val-error:0.40474
# [67]	train-error:0.28630	val-error:0.40535
# [68]	train-error:0.28502	val-error:0.40413
# [69]	train-error:0.28432	val-error:0.40360
# [70]	train-error:0.28321	val-error:0.40451
# [71]	train-error:0.28217	val-error:0.40436
# [72]	train-error:0.28117	val-error:0.40406
# [73]	train-error:0.28018	val-error:0.40535
# [74]	train-error:0.27930	val-error:0.40596
# [75]	train-error:0.27818	val-error:0.40543
# [76]	train-error:0.27661	val-error:0.40642
# [77]	train-error:0.27584	val-error:0.40665
# [78]	train-error:0.27454	val-error:0.40657
# [79]	train-error:0.27420	val-error:0.40711
# Accuracy for iteration 2: 0.60
# Iteration 3
# [0]	train-error:0.41782	val-error:0.45063
# [1]	train-error:0.40373	val-error:0.44297
# [2]	train-error:0.39510	val-error:0.43767
# [3]	train-error:0.38838	val-error:0.42941
# [4]	train-error:0.38532	val-error:0.43074
# [5]	train-error:0.38078	val-error:0.42706
# [6]	train-error:0.37862	val-error:0.42536
# [7]	train-error:0.37584	val-error:0.42455
# [8]	train-error:0.37184	val-error:0.42293
# [9]	train-error:0.36971	val-error:0.42138
# [10]	train-error:0.36729	val-error:0.42345
# [11]	train-error:0.36580	val-error:0.42234
# [12]	train-error:0.36399	val-error:0.42278
# [13]	train-error:0.36195	val-error:0.42256
# [14]	train-error:0.36069	val-error:0.42087
# [15]	train-error:0.35793	val-error:0.42263
# [16]	train-error:0.35647	val-error:0.41718
# [17]	train-error:0.35472	val-error:0.41696
# [18]	train-error:0.35270	val-error:0.41519
# [19]	train-error:0.35139	val-error:0.41667
# [20]	train-error:0.34977	val-error:0.41519
# [21]	train-error:0.34780	val-error:0.41733
# [22]	train-error:0.34534	val-error:0.41659
# [23]	train-error:0.34374	val-error:0.41711
# [24]	train-error:0.34179	val-error:0.41748
# [25]	train-error:0.34106	val-error:0.41527
# [26]	train-error:0.33981	val-error:0.41416
# [27]	train-error:0.33791	val-error:0.41438
# [28]	train-error:0.33671	val-error:0.41276
# [29]	train-error:0.33506	val-error:0.41158
# [30]	train-error:0.33339	val-error:0.41232
# [31]	train-error:0.33219	val-error:0.41387
# [32]	train-error:0.32996	val-error:0.41490
# [33]	train-error:0.32933	val-error:0.41431
# [34]	train-error:0.32699	val-error:0.41475
# [35]	train-error:0.32546	val-error:0.41401
# [36]	train-error:0.32461	val-error:0.41416
# [37]	train-error:0.32264	val-error:0.41424
# [38]	train-error:0.32160	val-error:0.41320
# [39]	train-error:0.32070	val-error:0.41151
# [40]	train-error:0.31927	val-error:0.41335
# [41]	train-error:0.31791	val-error:0.41497
# [42]	train-error:0.31681	val-error:0.41497
# [43]	train-error:0.31530	val-error:0.41482
# [44]	train-error:0.31410	val-error:0.41298
# [45]	train-error:0.31272	val-error:0.41365
# [46]	train-error:0.31121	val-error:0.41276
# [47]	train-error:0.30931	val-error:0.41387
# [48]	train-error:0.30849	val-error:0.41269
# [49]	train-error:0.30725	val-error:0.41202
# [50]	train-error:0.30579	val-error:0.41254
# [51]	train-error:0.30467	val-error:0.41121
# [52]	train-error:0.30384	val-error:0.41232
# [53]	train-error:0.30226	val-error:0.41269
# [54]	train-error:0.30096	val-error:0.41284
# [55]	train-error:0.30014	val-error:0.41136
# [56]	train-error:0.29890	val-error:0.41320
# [57]	train-error:0.29800	val-error:0.41254
# [58]	train-error:0.29675	val-error:0.41151
# [59]	train-error:0.29586	val-error:0.41298
# [60]	train-error:0.29500	val-error:0.41188
# [61]	train-error:0.29432	val-error:0.41166
# [62]	train-error:0.29298	val-error:0.41158
# [63]	train-error:0.29127	val-error:0.41210
# [64]	train-error:0.28984	val-error:0.41018
# [65]	train-error:0.28852	val-error:0.40967
# [66]	train-error:0.28734	val-error:0.40974
# [67]	train-error:0.28593	val-error:0.40967
# [68]	train-error:0.28481	val-error:0.40937
# [69]	train-error:0.28322	val-error:0.40782
# [70]	train-error:0.28233	val-error:0.40856
# [71]	train-error:0.28146	val-error:0.40841
# [72]	train-error:0.27972	val-error:0.40930
# [73]	train-error:0.27827	val-error:0.40959
# [74]	train-error:0.27810	val-error:0.40996
# [75]	train-error:0.27674	val-error:0.40967
# [76]	train-error:0.27542	val-error:0.41048
# [77]	train-error:0.27446	val-error:0.41004
# [78]	train-error:0.27367	val-error:0.41077
# [79]	train-error:0.27245	val-error:0.41166
# [80]	train-error:0.27152	val-error:0.41225
# [81]	train-error:0.27048	val-error:0.41099
# [82]	train-error:0.26913	val-error:0.41151
# [83]	train-error:0.26785	val-error:0.41195
# [84]	train-error:0.26752	val-error:0.41269
# [85]	train-error:0.26632	val-error:0.41254
# [86]	train-error:0.26606	val-error:0.41188
# [87]	train-error:0.26466	val-error:0.41055
# [88]	train-error:0.26320	val-error:0.41040
# Accuracy for iteration 3: 0.61
# Iteration 4
# [0]	train-error:0.41559	val-error:0.43701
# [1]	train-error:0.40351	val-error:0.43283
# [2]	train-error:0.39502	val-error:0.42612
# [3]	train-error:0.38948	val-error:0.42433
# [4]	train-error:0.38517	val-error:0.42210
# [5]	train-error:0.38274	val-error:0.41800
# [6]	train-error:0.38004	val-error:0.42068
# [7]	train-error:0.37745	val-error:0.42061
# [8]	train-error:0.37380	val-error:0.42016
# [9]	train-error:0.37261	val-error:0.42210
# [10]	train-error:0.37027	val-error:0.41829
# [11]	train-error:0.36879	val-error:0.41546
# [12]	train-error:0.36725	val-error:0.41569
# [13]	train-error:0.36458	val-error:0.41554
# [14]	train-error:0.36273	val-error:0.41703
# [15]	train-error:0.36034	val-error:0.41889
# [16]	train-error:0.35898	val-error:0.41583
# [17]	train-error:0.35739	val-error:0.41569
# [18]	train-error:0.35633	val-error:0.41569
# [19]	train-error:0.35417	val-error:0.41330
# [20]	train-error:0.35359	val-error:0.41293
# [21]	train-error:0.35197	val-error:0.41375
# [22]	train-error:0.35024	val-error:0.41144
# [23]	train-error:0.34795	val-error:0.41166
# [24]	train-error:0.34634	val-error:0.41181
# [25]	train-error:0.34386	val-error:0.40972
# [26]	train-error:0.34314	val-error:0.40808
# [27]	train-error:0.34079	val-error:0.40912
# [28]	train-error:0.33927	val-error:0.41084
# [29]	train-error:0.33719	val-error:0.41151
# [30]	train-error:0.33641	val-error:0.41218
# [31]	train-error:0.33510	val-error:0.41240
# [32]	train-error:0.33286	val-error:0.41270
# [33]	train-error:0.33186	val-error:0.41315
# [34]	train-error:0.33040	val-error:0.41084
# [35]	train-error:0.32840	val-error:0.41121
# [36]	train-error:0.32766	val-error:0.40957
# [37]	train-error:0.32605	val-error:0.41017
# [38]	train-error:0.32403	val-error:0.40942
# [39]	train-error:0.32250	val-error:0.40965
# [40]	train-error:0.32082	val-error:0.40883
# [41]	train-error:0.31942	val-error:0.40830
# [42]	train-error:0.31791	val-error:0.40778
# [43]	train-error:0.31683	val-error:0.40592
# [44]	train-error:0.31571	val-error:0.40540
# [45]	train-error:0.31391	val-error:0.40532
# [46]	train-error:0.31240	val-error:0.40719
# [47]	train-error:0.31118	val-error:0.40756
# [48]	train-error:0.31020	val-error:0.40681
# [49]	train-error:0.30873	val-error:0.40689
# [50]	train-error:0.30748	val-error:0.40532
# [51]	train-error:0.30658	val-error:0.40473
# [52]	train-error:0.30507	val-error:0.40495
# [53]	train-error:0.30357	val-error:0.40540
# [54]	train-error:0.30235	val-error:0.40428
# [55]	train-error:0.30115	val-error:0.40510
# [56]	train-error:0.30000	val-error:0.40301
# [57]	train-error:0.29933	val-error:0.40331
# [58]	train-error:0.29788	val-error:0.40368
# [59]	train-error:0.29652	val-error:0.40316
# [60]	train-error:0.29554	val-error:0.40383
# [61]	train-error:0.29444	val-error:0.40338
# [62]	train-error:0.29306	val-error:0.40264
# [63]	train-error:0.29199	val-error:0.40264
# [64]	train-error:0.29049	val-error:0.40294
# [65]	train-error:0.28963	val-error:0.40249
# [66]	train-error:0.28835	val-error:0.40353
# [67]	train-error:0.28706	val-error:0.40361
# [68]	train-error:0.28582	val-error:0.40279
# [69]	train-error:0.28435	val-error:0.40204
# [70]	train-error:0.28353	val-error:0.40182
# [71]	train-error:0.28273	val-error:0.40182
# [72]	train-error:0.28165	val-error:0.40301
# [73]	train-error:0.28070	val-error:0.40286
# [74]	train-error:0.27949	val-error:0.40189
# [75]	train-error:0.27864	val-error:0.40264
# [76]	train-error:0.27746	val-error:0.40256
# [77]	train-error:0.27627	val-error:0.40256
# [78]	train-error:0.27492	val-error:0.40391
# [79]	train-error:0.27422	val-error:0.40331
# [80]	train-error:0.27366	val-error:0.40219
# [81]	train-error:0.27299	val-error:0.40249
# [82]	train-error:0.27161	val-error:0.40204
# [83]	train-error:0.27028	val-error:0.40182
# [84]	train-error:0.26888	val-error:0.40115
# [85]	train-error:0.26803	val-error:0.40182
# [86]	train-error:0.26761	val-error:0.40160
# [87]	train-error:0.26663	val-error:0.40182
# [88]	train-error:0.26555	val-error:0.40219
# [89]	train-error:0.26451	val-error:0.40174
# [90]	train-error:0.26351	val-error:0.40249
# [91]	train-error:0.26216	val-error:0.40286
# [92]	train-error:0.26124	val-error:0.40309
# [93]	train-error:0.26047	val-error:0.40286
# [94]	train-error:0.25955	val-error:0.40189
# [95]	train-error:0.25833	val-error:0.40197
# [96]	train-error:0.25785	val-error:0.40070
# [97]	train-error:0.25690	val-error:0.40078
# [98]	train-error:0.25592	val-error:0.40085
# [99]	train-error:0.25446	val-error:0.40078
# [100]	train-error:0.25376	val-error:0.40160
# [101]	train-error:0.25268	val-error:0.40018
# [102]	train-error:0.25143	val-error:0.40070
# [103]	train-error:0.25100	val-error:0.40025
# [104]	train-error:0.25026	val-error:0.40092
# [105]	train-error:0.24923	val-error:0.40055
# [106]	train-error:0.24819	val-error:0.40115
# [107]	train-error:0.24749	val-error:0.40078
# [108]	train-error:0.24657	val-error:0.40182
# [109]	train-error:0.24558	val-error:0.40137
# [110]	train-error:0.24455	val-error:0.40107
# [111]	train-error:0.24412	val-error:0.40033
# [112]	train-error:0.24300	val-error:0.40130
# [113]	train-error:0.24187	val-error:0.39973
# [114]	train-error:0.24138	val-error:0.39943
# [115]	train-error:0.24031	val-error:0.40033
# [116]	train-error:0.23921	val-error:0.40018
# [117]	train-error:0.23805	val-error:0.39973
# [118]	train-error:0.23716	val-error:0.39981
# [119]	train-error:0.23646	val-error:0.40010
# [120]	train-error:0.23555	val-error:0.40025
# [121]	train-error:0.23447	val-error:0.40040
# [122]	train-error:0.23359	val-error:0.40018
# [123]	train-error:0.23259	val-error:0.40115
# [124]	train-error:0.23205	val-error:0.40100
# [125]	train-error:0.23100	val-error:0.39973
# [126]	train-error:0.22961	val-error:0.39884
# [127]	train-error:0.22897	val-error:0.39884
# [128]	train-error:0.22820	val-error:0.39809
# [129]	train-error:0.22724	val-error:0.39832
# [130]	train-error:0.22604	val-error:0.39817
# [131]	train-error:0.22528	val-error:0.39884
# [132]	train-error:0.22405	val-error:0.39936
# [133]	train-error:0.22335	val-error:0.39705
# [134]	train-error:0.22239	val-error:0.39563
# [135]	train-error:0.22182	val-error:0.39727
# [136]	train-error:0.22124	val-error:0.39735
# [137]	train-error:0.22044	val-error:0.39772
# [138]	train-error:0.21979	val-error:0.39824
# [139]	train-error:0.21870	val-error:0.39876
# [140]	train-error:0.21790	val-error:0.39973
# [141]	train-error:0.21663	val-error:0.40010
# [142]	train-error:0.21584	val-error:0.39973
# [143]	train-error:0.21536	val-error:0.39951
# [144]	train-error:0.21472	val-error:0.39943
# [145]	train-error:0.21344	val-error:0.39891
# [146]	train-error:0.21246	val-error:0.39943
# [147]	train-error:0.21154	val-error:0.39958
# [148]	train-error:0.21067	val-error:0.40048
# [149]	train-error:0.20955	val-error:0.39966
# [150]	train-error:0.20869	val-error:0.39824
# [151]	train-error:0.20773	val-error:0.39757
# [152]	train-error:0.20698	val-error:0.39727
# [153]	train-error:0.20637	val-error:0.39772
# Accuracy for iteration 4: 0.60
# Iteration 5
# [0]	train-error:0.41935	val-error:0.43869
# [1]	train-error:0.40433	val-error:0.43153
# [2]	train-error:0.39435	val-error:0.42490
# [3]	train-error:0.39060	val-error:0.42189
# [4]	train-error:0.38518	val-error:0.41925
# [5]	train-error:0.38149	val-error:0.41721
# [6]	train-error:0.37786	val-error:0.41397
# [7]	train-error:0.37673	val-error:0.41480
# [8]	train-error:0.37428	val-error:0.41450
# [9]	train-error:0.37237	val-error:0.41427
# [10]	train-error:0.37074	val-error:0.41028
# [11]	train-error:0.36860	val-error:0.41141
# [12]	train-error:0.36621	val-error:0.41013
# [13]	train-error:0.36387	val-error:0.40990
# [14]	train-error:0.36241	val-error:0.40922
# [15]	train-error:0.36087	val-error:0.40877
# [16]	train-error:0.35873	val-error:0.40907
# [17]	train-error:0.35775	val-error:0.40945
# [18]	train-error:0.35620	val-error:0.41156
# [19]	train-error:0.35529	val-error:0.40900
# [20]	train-error:0.35396	val-error:0.41013
# [21]	train-error:0.35067	val-error:0.40794
# [22]	train-error:0.34864	val-error:0.40757
# [23]	train-error:0.34752	val-error:0.40787
# [24]	train-error:0.34570	val-error:0.40877
# [25]	train-error:0.34403	val-error:0.40659
# [26]	train-error:0.34226	val-error:0.40870
# [27]	train-error:0.34056	val-error:0.40817
# [28]	train-error:0.33928	val-error:0.40613
# [29]	train-error:0.33842	val-error:0.40448
# [30]	train-error:0.33656	val-error:0.40463
# [31]	train-error:0.33506	val-error:0.40500
# [32]	train-error:0.33288	val-error:0.40402
# [33]	train-error:0.33174	val-error:0.40576
# [34]	train-error:0.33056	val-error:0.40508
# [35]	train-error:0.32885	val-error:0.40508
# [36]	train-error:0.32733	val-error:0.40410
# [37]	train-error:0.32604	val-error:0.40395
# [38]	train-error:0.32501	val-error:0.40629
# [39]	train-error:0.32339	val-error:0.40387
# [40]	train-error:0.32189	val-error:0.40335
# [41]	train-error:0.32075	val-error:0.40289
# [42]	train-error:0.31941	val-error:0.40402
# [43]	train-error:0.31803	val-error:0.40418
# [44]	train-error:0.31640	val-error:0.40229
# [45]	train-error:0.31542	val-error:0.40274
# [46]	train-error:0.31382	val-error:0.40320
# [47]	train-error:0.31296	val-error:0.40289
# [48]	train-error:0.31130	val-error:0.40289
# [49]	train-error:0.30940	val-error:0.40342
# [50]	train-error:0.30874	val-error:0.40237
# [51]	train-error:0.30733	val-error:0.40470
# [52]	train-error:0.30565	val-error:0.40342
# [53]	train-error:0.30461	val-error:0.40252
# [54]	train-error:0.30277	val-error:0.40101
# [55]	train-error:0.30185	val-error:0.40018
# [56]	train-error:0.30114	val-error:0.40041
# [57]	train-error:0.29957	val-error:0.40063
# [58]	train-error:0.29811	val-error:0.40026
# [59]	train-error:0.29676	val-error:0.40176
# [60]	train-error:0.29607	val-error:0.40139
# [61]	train-error:0.29515	val-error:0.40131
# [62]	train-error:0.29340	val-error:0.40048
# [63]	train-error:0.29262	val-error:0.39935
# [64]	train-error:0.29129	val-error:0.40003
# [65]	train-error:0.29029	val-error:0.39890
# [66]	train-error:0.28865	val-error:0.39837
# [67]	train-error:0.28736	val-error:0.39769
# [68]	train-error:0.28652	val-error:0.39860
# [69]	train-error:0.28501	val-error:0.39822
# [70]	train-error:0.28377	val-error:0.39943
# [71]	train-error:0.28301	val-error:0.39890
# [72]	train-error:0.28215	val-error:0.39732
# [73]	train-error:0.28082	val-error:0.39694
# [74]	train-error:0.27958	val-error:0.39664
# [75]	train-error:0.27845	val-error:0.39604
# [76]	train-error:0.27712	val-error:0.39754
# [77]	train-error:0.27666	val-error:0.39634
# [78]	train-error:0.27620	val-error:0.39581
# [79]	train-error:0.27496	val-error:0.39558
# [80]	train-error:0.27338	val-error:0.39521
# [81]	train-error:0.27238	val-error:0.39460
# [82]	train-error:0.27126	val-error:0.39513
# [83]	train-error:0.27007	val-error:0.39498
# [84]	train-error:0.26942	val-error:0.39445
# [85]	train-error:0.26827	val-error:0.39573
# [86]	train-error:0.26735	val-error:0.39536
# [87]	train-error:0.26684	val-error:0.39649
# [88]	train-error:0.26567	val-error:0.39558
# [89]	train-error:0.26424	val-error:0.39513
# [90]	train-error:0.26306	val-error:0.39415
# [91]	train-error:0.26203	val-error:0.39513
# [92]	train-error:0.26169	val-error:0.39506
# [93]	train-error:0.26040	val-error:0.39664
# [94]	train-error:0.25959	val-error:0.39558
# [95]	train-error:0.25856	val-error:0.39573
# [96]	train-error:0.25703	val-error:0.39506
# [97]	train-error:0.25637	val-error:0.39483
# [98]	train-error:0.25582	val-error:0.39423
# [99]	train-error:0.25440	val-error:0.39355
# [100]	train-error:0.25337	val-error:0.39272
# [101]	train-error:0.25205	val-error:0.39212
# [102]	train-error:0.25108	val-error:0.39182
# [103]	train-error:0.24966	val-error:0.39287
# [104]	train-error:0.24901	val-error:0.39340
# [105]	train-error:0.24853	val-error:0.39264
# [106]	train-error:0.24735	val-error:0.39227
# [107]	train-error:0.24628	val-error:0.39325
# [108]	train-error:0.24551	val-error:0.39385
# [109]	train-error:0.24482	val-error:0.39483
# [110]	train-error:0.24368	val-error:0.39385
# [111]	train-error:0.24300	val-error:0.39445
# [112]	train-error:0.24215	val-error:0.39475
# [113]	train-error:0.24137	val-error:0.39483
# [114]	train-error:0.24040	val-error:0.39506
# [115]	train-error:0.24019	val-error:0.39400
# [116]	train-error:0.23918	val-error:0.39362
# [117]	train-error:0.23811	val-error:0.39347
# [118]	train-error:0.23700	val-error:0.39475
# [119]	train-error:0.23602	val-error:0.39536
# [120]	train-error:0.23551	val-error:0.39460
# [121]	train-error:0.23435	val-error:0.39302
# [122]	train-error:0.23334	val-error:0.39302
# Accuracy for iteration 5: 0.60
# Iteration 6
# [0]	train-error:0.41609	val-error:0.43673
# [1]	train-error:0.40604	val-error:0.42958
# [2]	train-error:0.39832	val-error:0.42567
# [3]	train-error:0.39179	val-error:0.41935
# [4]	train-error:0.38714	val-error:0.41890
# [5]	train-error:0.38343	val-error:0.41589
# [6]	train-error:0.38045	val-error:0.41566
# [7]	train-error:0.37628	val-error:0.41499
# [8]	train-error:0.37449	val-error:0.41830
# [9]	train-error:0.37315	val-error:0.41296
# [10]	train-error:0.37048	val-error:0.41438
# [11]	train-error:0.36863	val-error:0.41288
# [12]	train-error:0.36676	val-error:0.41047
# [13]	train-error:0.36552	val-error:0.40867
# [14]	train-error:0.36281	val-error:0.40927
# [15]	train-error:0.36135	val-error:0.40957
# [16]	train-error:0.36008	val-error:0.40987
# [17]	train-error:0.35753	val-error:0.40980
# [18]	train-error:0.35590	val-error:0.41092
# [19]	train-error:0.35441	val-error:0.40837
# [20]	train-error:0.35314	val-error:0.40852
# [21]	train-error:0.35115	val-error:0.40791
# [22]	train-error:0.34891	val-error:0.40807
# [23]	train-error:0.34699	val-error:0.40633
# [24]	train-error:0.34470	val-error:0.40573
# [25]	train-error:0.34381	val-error:0.40468
# [26]	train-error:0.34179	val-error:0.40325
# [27]	train-error:0.33951	val-error:0.40114
# [28]	train-error:0.33725	val-error:0.40062
# [29]	train-error:0.33540	val-error:0.39964
# [30]	train-error:0.33371	val-error:0.40144
# [31]	train-error:0.33284	val-error:0.40144
# [32]	train-error:0.33132	val-error:0.40092
# [33]	train-error:0.32960	val-error:0.39979
# [34]	train-error:0.32884	val-error:0.39828
# [35]	train-error:0.32687	val-error:0.39655
# [36]	train-error:0.32628	val-error:0.39896
# [37]	train-error:0.32486	val-error:0.39881
# [38]	train-error:0.32337	val-error:0.39941
# [39]	train-error:0.32141	val-error:0.39971
# [40]	train-error:0.32058	val-error:0.40062
# [41]	train-error:0.31978	val-error:0.40167
# [42]	train-error:0.31826	val-error:0.40077
# [43]	train-error:0.31617	val-error:0.40002
# [44]	train-error:0.31517	val-error:0.39889
# [45]	train-error:0.31289	val-error:0.39949
# [46]	train-error:0.31207	val-error:0.40039
# [47]	train-error:0.31066	val-error:0.40017
# [48]	train-error:0.30950	val-error:0.40092
# [49]	train-error:0.30784	val-error:0.40257
# [50]	train-error:0.30655	val-error:0.40250
# [51]	train-error:0.30553	val-error:0.40333
# [52]	train-error:0.30460	val-error:0.40370
# [53]	train-error:0.30355	val-error:0.40122
# [54]	train-error:0.30226	val-error:0.40069
# [55]	train-error:0.30127	val-error:0.40062
# Accuracy for iteration 6: 0.60
# Iteration 7
# [0]	train-error:0.41942	val-error:0.43360
# [1]	train-error:0.40605	val-error:0.43006
# [2]	train-error:0.39934	val-error:0.42521
# [3]	train-error:0.39303	val-error:0.42594
# [4]	train-error:0.38810	val-error:0.42211
# [5]	train-error:0.38378	val-error:0.42057
# [6]	train-error:0.37956	val-error:0.41755
# [7]	train-error:0.37729	val-error:0.41740
# [8]	train-error:0.37464	val-error:0.41733
# [9]	train-error:0.37306	val-error:0.41512
# [10]	train-error:0.37057	val-error:0.41483
# [11]	train-error:0.36760	val-error:0.41306
# [12]	train-error:0.36671	val-error:0.41350
# [13]	train-error:0.36519	val-error:0.41483
# [14]	train-error:0.36352	val-error:0.41416
# [15]	train-error:0.36250	val-error:0.41431
# [16]	train-error:0.36043	val-error:0.41534
# [17]	train-error:0.35826	val-error:0.41254
# [18]	train-error:0.35568	val-error:0.41225
# [19]	train-error:0.35417	val-error:0.41144
# [20]	train-error:0.35230	val-error:0.41115
# [21]	train-error:0.35078	val-error:0.41048
# [22]	train-error:0.34922	val-error:0.41063
# [23]	train-error:0.34701	val-error:0.41041
# [24]	train-error:0.34575	val-error:0.40857
# [25]	train-error:0.34310	val-error:0.40643
# [26]	train-error:0.34163	val-error:0.40746
# [27]	train-error:0.34058	val-error:0.40820
# [28]	train-error:0.33942	val-error:0.40474
# [29]	train-error:0.33841	val-error:0.40533
# [30]	train-error:0.33661	val-error:0.40423
# [31]	train-error:0.33446	val-error:0.40511
# [32]	train-error:0.33281	val-error:0.40496
# [33]	train-error:0.33178	val-error:0.40562
# [34]	train-error:0.33017	val-error:0.40445
# [35]	train-error:0.32856	val-error:0.40349
# [36]	train-error:0.32664	val-error:0.40437
# [37]	train-error:0.32559	val-error:0.40489
# [38]	train-error:0.32410	val-error:0.40467
# [39]	train-error:0.32284	val-error:0.40393
# [40]	train-error:0.32151	val-error:0.40334
# [41]	train-error:0.31999	val-error:0.40408
# [42]	train-error:0.31890	val-error:0.40386
# [43]	train-error:0.31688	val-error:0.40371
# [44]	train-error:0.31572	val-error:0.40356
# [45]	train-error:0.31454	val-error:0.40268
# [46]	train-error:0.31308	val-error:0.40158
# [47]	train-error:0.31201	val-error:0.40275
# [48]	train-error:0.31057	val-error:0.40342
# [49]	train-error:0.30919	val-error:0.40239
# [50]	train-error:0.30756	val-error:0.40342
# [51]	train-error:0.30622	val-error:0.40209
# [52]	train-error:0.30556	val-error:0.40194
# [53]	train-error:0.30389	val-error:0.40378
# [54]	train-error:0.30238	val-error:0.40216
# [55]	train-error:0.30119	val-error:0.40305
# [56]	train-error:0.29966	val-error:0.40261
# [57]	train-error:0.29839	val-error:0.40261
# [58]	train-error:0.29688	val-error:0.40290
# [59]	train-error:0.29656	val-error:0.40349
# [60]	train-error:0.29455	val-error:0.40165
# [61]	train-error:0.29352	val-error:0.40135
# [62]	train-error:0.29238	val-error:0.40187
# [63]	train-error:0.29132	val-error:0.40187
# [64]	train-error:0.29064	val-error:0.40150
# [65]	train-error:0.28921	val-error:0.40143
# [66]	train-error:0.28810	val-error:0.40091
# [67]	train-error:0.28680	val-error:0.40062
# [68]	train-error:0.28609	val-error:0.40187
# [69]	train-error:0.28499	val-error:0.40143
# [70]	train-error:0.28378	val-error:0.40209
# [71]	train-error:0.28305	val-error:0.40180
# [72]	train-error:0.28165	val-error:0.40091
# [73]	train-error:0.28085	val-error:0.40106
# [74]	train-error:0.28021	val-error:0.40172
# [75]	train-error:0.27885	val-error:0.40032
# [76]	train-error:0.27757	val-error:0.40106
# [77]	train-error:0.27658	val-error:0.40158
# [78]	train-error:0.27558	val-error:0.40194
# [79]	train-error:0.27448	val-error:0.40135
# [80]	train-error:0.27341	val-error:0.40135
# [81]	train-error:0.27211	val-error:0.40040
# [82]	train-error:0.27092	val-error:0.39959
# [83]	train-error:0.27047	val-error:0.39988
# [84]	train-error:0.26918	val-error:0.40032
# [85]	train-error:0.26820	val-error:0.40047
# [86]	train-error:0.26728	val-error:0.39929
# [87]	train-error:0.26611	val-error:0.40040
# [88]	train-error:0.26545	val-error:0.39959
# [89]	train-error:0.26428	val-error:0.40010
# [90]	train-error:0.26363	val-error:0.39966
# [91]	train-error:0.26271	val-error:0.40025
# [92]	train-error:0.26154	val-error:0.39944
# [93]	train-error:0.26069	val-error:0.39915
# [94]	train-error:0.25955	val-error:0.40084
# [95]	train-error:0.25857	val-error:0.40099
# [96]	train-error:0.25751	val-error:0.40202
# [97]	train-error:0.25713	val-error:0.40297
# [98]	train-error:0.25609	val-error:0.40150
# [99]	train-error:0.25525	val-error:0.40113
# [100]	train-error:0.25410	val-error:0.40261
# [101]	train-error:0.25274	val-error:0.40224
# [102]	train-error:0.25201	val-error:0.40202
# [103]	train-error:0.25113	val-error:0.40231
# [104]	train-error:0.25033	val-error:0.40216
# [105]	train-error:0.24944	val-error:0.40106
# [106]	train-error:0.24838	val-error:0.40121
# [107]	train-error:0.24774	val-error:0.40084
# [108]	train-error:0.24664	val-error:0.40128
# [109]	train-error:0.24603	val-error:0.40128
# [110]	train-error:0.24476	val-error:0.40158
# [111]	train-error:0.24387	val-error:0.40172
# [112]	train-error:0.24291	val-error:0.40165
# Accuracy for iteration 7: 0.59
# Average Accuracy across 7 iterations: 0.60

# %%
import numpy as np
from scipy.stats import sem, t
from scipy import mean

# Assuming accuracies are stored in the 'accuracies' list as per previous example
accuracies = np.array(accuracies)

# Calculate the mean accuracy
mean_accuracy = np.mean(accuracies)

# Calculate the standard error of the mean
std_error = sem(accuracies)

# Determine the size of the accuracies array
n = len(accuracies)

# Use the t-distribution to calculate a 95% confidence interval
confidence = 0.95
h = std_error * t.ppf((1 + confidence) / 2, n - 1)

# Print the mean accuracy and confidence interval
print(f"Mean Accuracy: {mean_accuracy:.2f}")
print(f"95% Confidence interval: {mean_accuracy - h:.5f} - {mean_accuracy + h:.5f}")
# Out:
# Mean Accuracy: 0.60
# 95% Confidence interval: 0.59446 - 0.60334

# %%
import numpy as np
import pandas as pd
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model(model, X_test, y_test, type_of_model):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title(f'Confusion Matrix for {type_of_model}')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage assuming X_val is a pandas DataFrame and val_data['popularity'] is the true labels
evaluate_model(bst, X_val, val_data['popularity'], 'XGBoost')
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.60      0.59      0.60      6792
#         High       0.60      0.60      0.60      6792
#
#     accuracy                           0.60     13584
#    macro avg       0.60      0.60      0.60     13584
# weighted avg       0.60      0.60      0.60     13584

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Convert X_test to DMatrix for XGBoost prediction
    dtest = xgb.DMatrix(X_test)

    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(dtest)

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage, assuming X_test is a pandas DataFrame and test_data['popularity'] is the true labels
evaluate_model_and_error_rates(bst, X_test, test_data['popularity'])
# Out:
#               precision    recall  f1-score   support
#
#          Low       0.59      0.59      0.59      6336
#         High       0.59      0.59      0.59      6336
#
#     accuracy                           0.59     12672
#    macro avg       0.59      0.59      0.59     12672
# weighted avg       0.59      0.59      0.59     12672
