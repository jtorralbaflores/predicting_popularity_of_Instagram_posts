# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv('/content/drive/MyDrive/MSc Thesis Data Science/influencer_brands/Data/Metadata/all_metadata_2.csv')

# %%
print(data.shape)
# Out:
# (340447, 30)

# %%
from datetime import datetime

# Function to convert UNIX time to readable date-time
def convert_unix_time(unix_time):
    return datetime.utcfromtimestamp(unix_time)

# Convert the UNIX timestamp and create separate columns for month, day, and hour
data['Converted Timestamp'] = data['taken_at_timestamp'].apply(convert_unix_time)
data['Year'] = data['Converted Timestamp'].dt.year
data['Month'] = data['Converted Timestamp'].dt.month
data['Day'] = data['Converted Timestamp'].dt.day
data['Hour'] = data['Converted Timestamp'].dt.hour
data['Day of Week (Number)'] = data['Converted Timestamp'].dt.dayofweek
data['Day of Week (String)'] = data['Converted Timestamp'].dt.day_name()

# %%
print(data.head())
# Out:
#         Username              post_id caption_is_edited  comments_disabled  \
# 0  00_rocketgirl  1354915397698488656        GraphImage              False
# 1  00_rocketgirl  1666974101448132749        GraphImage              False
# 2  00_rocketgirl  1768273356099895999        GraphImage              False
# 3  00_rocketgirl  1770557472379860655      GraphSidecar              False
# 4  00_rocketgirl  1770557472379860655      GraphSidecar              False
#
#    image_height  image_width  like_count  comment_count  is_video  \
# 0          1350         1080         293              6     False
# 1           480          480          73              2     False
# 2          1080         1080         164              4     False
# 3          1350         1080         474             18     False
# 4          1350         1080         474             18     False
#
#                                        media_preview  ...  Email Phone  \
# ...

# %%
print(data.shape)
# Out:
# (340447, 37)

# %%
# Save the updated DataFrame
data.to_csv('/content/drive/MyDrive/MSc Thesis Data Science/influencer_brands/Data/Metadata/all_metadata_3.csv', index=False)
