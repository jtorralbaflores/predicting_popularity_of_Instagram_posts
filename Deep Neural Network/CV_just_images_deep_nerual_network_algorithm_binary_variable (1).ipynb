# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = image_columns + additional_columns_to_keep #+ text_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 4
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 836/836 [==============================] - 7s 7ms/step - loss: 0.6916 - accuracy: 0.5368 - val_loss: 0.6852 - val_accuracy: 0.5542
# Epoch 2/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6855 - accuracy: 0.5503 - val_loss: 0.6802 - val_accuracy: 0.5652
# Epoch 3/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6842 - accuracy: 0.5535 - val_loss: 0.6816 - val_accuracy: 0.5662
# Epoch 4/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6826 - accuracy: 0.5545 - val_loss: 0.6788 - val_accuracy: 0.5792
# Epoch 5/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6815 - accuracy: 0.5597 - val_loss: 0.6800 - val_accuracy: 0.5750
# Epoch 6/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6806 - accuracy: 0.5622 - val_loss: 0.6775 - val_accuracy: 0.5729
# Epoch 7/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6804 - accuracy: 0.5627 - val_loss: 0.6765 - val_accuracy: 0.5745
# Epoch 8/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6796 - accuracy: 0.5641 - val_loss: 0.6783 - val_accuracy: 0.5711
# Epoch 9/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6785 - accuracy: 0.5658 - val_loss: 0.6801 - val_accuracy: 0.5707
# Epoch 10/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6783 - accuracy: 0.5656 - val_loss: 0.6787 - val_accuracy: 0.5667
# Epoch 11/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6784 - accuracy: 0.5655 - val_loss: 0.6785 - val_accuracy: 0.5717
# Epoch 12/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6778 - accuracy: 0.5670 - val_loss: 0.6799 - val_accuracy: 0.5766
# Epoch 13/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6771 - accuracy: 0.5690 - val_loss: 0.6790 - val_accuracy: 0.5769
# Epoch 14/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6765 - accuracy: 0.5693 - val_loss: 0.6796 - val_accuracy: 0.5716
# Epoch 15/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6759 - accuracy: 0.5705 - val_loss: 0.6821 - val_accuracy: 0.5678
# Epoch 16/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6754 - accuracy: 0.5704 - val_loss: 0.6793 - val_accuracy: 0.5727
# Epoch 17/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6747 - accuracy: 0.5713 - val_loss: 0.6790 - val_accuracy: 0.5742
# Epoch 18/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6738 - accuracy: 0.5732 - val_loss: 0.6774 - val_accuracy: 0.5749
# Epoch 19/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6732 - accuracy: 0.5750 - val_loss: 0.6786 - val_accuracy: 0.5741
# Epoch 20/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6727 - accuracy: 0.5735 - val_loss: 0.6795 - val_accuracy: 0.5743
# Epoch 21/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6717 - accuracy: 0.5763 - val_loss: 0.6795 - val_accuracy: 0.5695
# Epoch 22/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6717 - accuracy: 0.5766 - val_loss: 0.6821 - val_accuracy: 0.5739
# Epoch 23/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6712 - accuracy: 0.5776 - val_loss: 0.6792 - val_accuracy: 0.5711
# Epoch 24/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6707 - accuracy: 0.5780 - val_loss: 0.6798 - val_accuracy: 0.5723
# 416/416 [==============================] - 1s 2ms/step - loss: 0.6809 - accuracy: 0.5628
# 416/416 [==============================] - 1s 2ms/step
# Accuracy for iteration 1: 0.56
# Iteration 2
# Epoch 1/500
# 835/835 [==============================] - 7s 6ms/step - loss: 0.6893 - accuracy: 0.5404 - val_loss: 0.6875 - val_accuracy: 0.5490
# Epoch 2/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6858 - accuracy: 0.5531 - val_loss: 0.6811 - val_accuracy: 0.5655
# Epoch 3/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6843 - accuracy: 0.5577 - val_loss: 0.6833 - val_accuracy: 0.5696
# Epoch 4/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6835 - accuracy: 0.5590 - val_loss: 0.6809 - val_accuracy: 0.5661
# Epoch 5/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6831 - accuracy: 0.5597 - val_loss: 0.6838 - val_accuracy: 0.5623
# Epoch 6/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6827 - accuracy: 0.5606 - val_loss: 0.6812 - val_accuracy: 0.5694
# Epoch 7/500
# 835/835 [==============================] - 5s 5ms/step - loss: 0.6816 - accuracy: 0.5642 - val_loss: 0.6804 - val_accuracy: 0.5687
# Epoch 8/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6809 - accuracy: 0.5653 - val_loss: 0.6796 - val_accuracy: 0.5714
# Epoch 9/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6801 - accuracy: 0.5691 - val_loss: 0.6821 - val_accuracy: 0.5720
# Epoch 10/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6800 - accuracy: 0.5688 - val_loss: 0.6835 - val_accuracy: 0.5606
# Epoch 11/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6797 - accuracy: 0.5697 - val_loss: 0.6819 - val_accuracy: 0.5718
# Epoch 12/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6794 - accuracy: 0.5698 - val_loss: 0.6800 - val_accuracy: 0.5695
# Epoch 13/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6791 - accuracy: 0.5701 - val_loss: 0.6847 - val_accuracy: 0.5552
# Epoch 14/500
# 835/835 [==============================] - 5s 5ms/step - loss: 0.6788 - accuracy: 0.5719 - val_loss: 0.6809 - val_accuracy: 0.5706
# Epoch 15/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6783 - accuracy: 0.5723 - val_loss: 0.6816 - val_accuracy: 0.5654
# Epoch 16/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6777 - accuracy: 0.5726 - val_loss: 0.6811 - val_accuracy: 0.5692
# Epoch 17/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6780 - accuracy: 0.5729 - val_loss: 0.6823 - val_accuracy: 0.5672
# Epoch 18/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6767 - accuracy: 0.5760 - val_loss: 0.6806 - val_accuracy: 0.5702
# Epoch 19/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6764 - accuracy: 0.5775 - val_loss: 0.6796 - val_accuracy: 0.5723
# Epoch 20/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6768 - accuracy: 0.5745 - val_loss: 0.6803 - val_accuracy: 0.5716
# Epoch 21/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6764 - accuracy: 0.5754 - val_loss: 0.6822 - val_accuracy: 0.5712
# Epoch 22/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6759 - accuracy: 0.5765 - val_loss: 0.6813 - val_accuracy: 0.5690
# Epoch 23/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6751 - accuracy: 0.5790 - val_loss: 0.6797 - val_accuracy: 0.5662
# Epoch 24/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6747 - accuracy: 0.5797 - val_loss: 0.6814 - val_accuracy: 0.5665
# Epoch 25/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6741 - accuracy: 0.5812 - val_loss: 0.6800 - val_accuracy: 0.5663
# Epoch 26/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6741 - accuracy: 0.5810 - val_loss: 0.6818 - val_accuracy: 0.5692
# Epoch 27/500
# 835/835 [==============================] - 5s 6ms/step - loss: 0.6741 - accuracy: 0.5795 - val_loss: 0.6828 - val_accuracy: 0.5535
# Epoch 28/500
# 835/835 [==============================] - 5s 6ms/step - loss: 0.6728 - accuracy: 0.5834 - val_loss: 0.6836 - val_accuracy: 0.5534
# Epoch 29/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6727 - accuracy: 0.5841 - val_loss: 0.6830 - val_accuracy: 0.5523
# Epoch 30/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6716 - accuracy: 0.5852 - val_loss: 0.6810 - val_accuracy: 0.5650
# Epoch 31/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6718 - accuracy: 0.5845 - val_loss: 0.6847 - val_accuracy: 0.5515
# Epoch 32/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6713 - accuracy: 0.5859 - val_loss: 0.6847 - val_accuracy: 0.5484
# Epoch 33/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6703 - accuracy: 0.5881 - val_loss: 0.6809 - val_accuracy: 0.5682
# Epoch 34/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6707 - accuracy: 0.5858 - val_loss: 0.6834 - val_accuracy: 0.5547
# Epoch 35/500
# 835/835 [==============================] - 5s 5ms/step - loss: 0.6696 - accuracy: 0.5869 - val_loss: 0.6860 - val_accuracy: 0.5488
# Epoch 36/500
# 835/835 [==============================] - 6s 7ms/step - loss: 0.6693 - accuracy: 0.5883 - val_loss: 0.6834 - val_accuracy: 0.5638
# Epoch 37/500
# 835/835 [==============================] - 6s 7ms/step - loss: 0.6690 - accuracy: 0.5870 - val_loss: 0.6823 - val_accuracy: 0.5644
# Epoch 38/500
# 835/835 [==============================] - 6s 8ms/step - loss: 0.6682 - accuracy: 0.5908 - val_loss: 0.6854 - val_accuracy: 0.5465
# Epoch 39/500
# 835/835 [==============================] - 6s 7ms/step - loss: 0.6682 - accuracy: 0.5887 - val_loss: 0.6863 - val_accuracy: 0.5492
# 427/427 [==============================] - 1s 3ms/step - loss: 0.6797 - accuracy: 0.5735
# 427/427 [==============================] - 1s 3ms/step
# Accuracy for iteration 2: 0.57
# Iteration 3
# Epoch 1/500
# 835/835 [==============================] - 8s 8ms/step - loss: 0.6905 - accuracy: 0.5291 - val_loss: 0.6822 - val_accuracy: 0.5612
# Epoch 2/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6858 - accuracy: 0.5420 - val_loss: 0.6865 - val_accuracy: 0.5626
# Epoch 3/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6832 - accuracy: 0.5515 - val_loss: 0.6826 - val_accuracy: 0.5558
# Epoch 4/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6829 - accuracy: 0.5533 - val_loss: 0.6848 - val_accuracy: 0.5606
# Epoch 5/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6813 - accuracy: 0.5585 - val_loss: 0.6826 - val_accuracy: 0.5647
# Epoch 6/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6805 - accuracy: 0.5589 - val_loss: 0.6846 - val_accuracy: 0.5441
# Epoch 7/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6798 - accuracy: 0.5589 - val_loss: 0.6807 - val_accuracy: 0.5633
# Epoch 8/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6793 - accuracy: 0.5615 - val_loss: 0.6810 - val_accuracy: 0.5680
# Epoch 9/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6784 - accuracy: 0.5616 - val_loss: 0.6827 - val_accuracy: 0.5561
# Epoch 10/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6781 - accuracy: 0.5626 - val_loss: 0.6817 - val_accuracy: 0.5585
# Epoch 11/500
# 835/835 [==============================] - 5s 6ms/step - loss: 0.6775 - accuracy: 0.5655 - val_loss: 0.6813 - val_accuracy: 0.5631
# Epoch 12/500
# 835/835 [==============================] - 5s 5ms/step - loss: 0.6768 - accuracy: 0.5668 - val_loss: 0.6818 - val_accuracy: 0.5700
# Epoch 13/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6758 - accuracy: 0.5683 - val_loss: 0.6812 - val_accuracy: 0.5620
# Epoch 14/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6759 - accuracy: 0.5689 - val_loss: 0.6842 - val_accuracy: 0.5557
# Epoch 15/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6754 - accuracy: 0.5695 - val_loss: 0.6822 - val_accuracy: 0.5612
# Epoch 16/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6747 - accuracy: 0.5711 - val_loss: 0.6821 - val_accuracy: 0.5619
# Epoch 17/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6741 - accuracy: 0.5724 - val_loss: 0.6810 - val_accuracy: 0.5640
# Epoch 18/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6740 - accuracy: 0.5724 - val_loss: 0.6815 - val_accuracy: 0.5626
# Epoch 19/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6740 - accuracy: 0.5737 - val_loss: 0.6812 - val_accuracy: 0.5652
# Epoch 20/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6726 - accuracy: 0.5753 - val_loss: 0.6835 - val_accuracy: 0.5628
# Epoch 21/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6722 - accuracy: 0.5753 - val_loss: 0.6805 - val_accuracy: 0.5653
# Epoch 22/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6723 - accuracy: 0.5748 - val_loss: 0.6832 - val_accuracy: 0.5600
# Epoch 23/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6717 - accuracy: 0.5768 - val_loss: 0.6821 - val_accuracy: 0.5637
# Epoch 24/500
# 835/835 [==============================] - 5s 6ms/step - loss: 0.6713 - accuracy: 0.5763 - val_loss: 0.6833 - val_accuracy: 0.5631
# Epoch 25/500
# 835/835 [==============================] - 5s 6ms/step - loss: 0.6702 - accuracy: 0.5780 - val_loss: 0.6822 - val_accuracy: 0.5595
# Epoch 26/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6704 - accuracy: 0.5769 - val_loss: 0.6830 - val_accuracy: 0.5570
# Epoch 27/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6703 - accuracy: 0.5765 - val_loss: 0.6827 - val_accuracy: 0.5613
# Epoch 28/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6688 - accuracy: 0.5802 - val_loss: 0.6826 - val_accuracy: 0.5573
# Epoch 29/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6686 - accuracy: 0.5794 - val_loss: 0.6835 - val_accuracy: 0.5577
# Epoch 30/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6678 - accuracy: 0.5797 - val_loss: 0.6838 - val_accuracy: 0.5573
# Epoch 31/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6677 - accuracy: 0.5813 - val_loss: 0.6853 - val_accuracy: 0.5547
# Epoch 32/500
# 835/835 [==============================] - 4s 5ms/step - loss: 0.6681 - accuracy: 0.5801 - val_loss: 0.6834 - val_accuracy: 0.5605
# 415/415 [==============================] - 1s 2ms/step - loss: 0.6801 - accuracy: 0.5794
# 415/415 [==============================] - 1s 2ms/step
# Accuracy for iteration 3: 0.58
# Iteration 4
# Epoch 1/500
# 836/836 [==============================] - 6s 6ms/step - loss: 0.6901 - accuracy: 0.5366 - val_loss: 0.6820 - val_accuracy: 0.5604
# Epoch 2/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6851 - accuracy: 0.5474 - val_loss: 0.6820 - val_accuracy: 0.5666
# Epoch 3/500
# 836/836 [==============================] - 9s 10ms/step - loss: 0.6842 - accuracy: 0.5499 - val_loss: 0.6804 - val_accuracy: 0.5691
# Epoch 4/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6831 - accuracy: 0.5540 - val_loss: 0.6836 - val_accuracy: 0.5637
# Epoch 5/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6825 - accuracy: 0.5544 - val_loss: 0.6798 - val_accuracy: 0.5705
# Epoch 6/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6814 - accuracy: 0.5567 - val_loss: 0.6796 - val_accuracy: 0.5622
# Epoch 7/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6809 - accuracy: 0.5577 - val_loss: 0.6821 - val_accuracy: 0.5642
# Epoch 8/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6803 - accuracy: 0.5597 - val_loss: 0.6809 - val_accuracy: 0.5648
# Epoch 9/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6799 - accuracy: 0.5601 - val_loss: 0.6782 - val_accuracy: 0.5650
# Epoch 10/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6783 - accuracy: 0.5638 - val_loss: 0.6801 - val_accuracy: 0.5683
# Epoch 11/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6785 - accuracy: 0.5642 - val_loss: 0.6805 - val_accuracy: 0.5640
# Epoch 12/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6774 - accuracy: 0.5658 - val_loss: 0.6805 - val_accuracy: 0.5663
# Epoch 13/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6775 - accuracy: 0.5653 - val_loss: 0.6784 - val_accuracy: 0.5690
# Epoch 14/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6765 - accuracy: 0.5674 - val_loss: 0.6811 - val_accuracy: 0.5672
# Epoch 15/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6762 - accuracy: 0.5697 - val_loss: 0.6788 - val_accuracy: 0.5663
# Epoch 16/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6759 - accuracy: 0.5706 - val_loss: 0.6816 - val_accuracy: 0.5687
# Epoch 17/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6751 - accuracy: 0.5721 - val_loss: 0.6779 - val_accuracy: 0.5723
# Epoch 18/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6740 - accuracy: 0.5741 - val_loss: 0.6804 - val_accuracy: 0.5669
# Epoch 19/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6743 - accuracy: 0.5723 - val_loss: 0.6773 - val_accuracy: 0.5705
# Epoch 20/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6734 - accuracy: 0.5732 - val_loss: 0.6789 - val_accuracy: 0.5667
# Epoch 21/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6733 - accuracy: 0.5764 - val_loss: 0.6790 - val_accuracy: 0.5664
# Epoch 22/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6727 - accuracy: 0.5760 - val_loss: 0.6801 - val_accuracy: 0.5697
# Epoch 23/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6725 - accuracy: 0.5760 - val_loss: 0.6795 - val_accuracy: 0.5661
# Epoch 24/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6722 - accuracy: 0.5764 - val_loss: 0.6793 - val_accuracy: 0.5705
# Epoch 25/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6713 - accuracy: 0.5762 - val_loss: 0.6793 - val_accuracy: 0.5707
# Epoch 26/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6712 - accuracy: 0.5780 - val_loss: 0.6790 - val_accuracy: 0.5704
# Epoch 27/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6707 - accuracy: 0.5785 - val_loss: 0.6819 - val_accuracy: 0.5631
# Epoch 28/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6701 - accuracy: 0.5788 - val_loss: 0.6793 - val_accuracy: 0.5684
# Epoch 29/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6695 - accuracy: 0.5776 - val_loss: 0.6801 - val_accuracy: 0.5647
# Epoch 30/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6688 - accuracy: 0.5794 - val_loss: 0.6795 - val_accuracy: 0.5704
# Epoch 31/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6684 - accuracy: 0.5815 - val_loss: 0.6791 - val_accuracy: 0.5645
# Epoch 32/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6684 - accuracy: 0.5811 - val_loss: 0.6787 - val_accuracy: 0.5695
# Epoch 33/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6678 - accuracy: 0.5811 - val_loss: 0.6809 - val_accuracy: 0.5628
# Epoch 34/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6676 - accuracy: 0.5812 - val_loss: 0.6815 - val_accuracy: 0.5644
# Epoch 35/500
# 836/836 [==============================] - 4s 5ms/step - loss: 0.6668 - accuracy: 0.5827 - val_loss: 0.6809 - val_accuracy: 0.5667
# Epoch 36/500
# 836/836 [==============================] - 5s 5ms/step - loss: 0.6665 - accuracy: 0.5824 - val_loss: 0.6818 - val_accuracy: 0.5657
# Epoch 37/500
# 836/836 [==============================] - 5s 6ms/step - loss: 0.6666 - accuracy: 0.5840 - val_loss: 0.6811 - val_accuracy: 0.5661
# 414/414 [==============================] - 1s 2ms/step - loss: 0.6826 - accuracy: 0.5607
# 414/414 [==============================] - 1s 2ms/step
# Accuracy for iteration 4: 0.56
# Average Accuracy across 4 iterations: 0.57

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.56073 - 0.57944

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 420/420 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.58      0.52      0.55      6707
#         High       0.56      0.63      0.60      6707
#
#     accuracy                           0.57     13414
#    macro avg       0.57      0.57      0.57     13414
# weighted avg       0.57      0.57      0.57     13414

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 414/414 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.57      0.50      0.53      6619
#         High       0.55      0.62      0.59      6619
#
#     accuracy                           0.56     13238
#    macro avg       0.56      0.56      0.56     13238
# weighted avg       0.56      0.56      0.56     13238
