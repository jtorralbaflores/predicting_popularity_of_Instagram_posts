# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = text_columns + additional_columns_to_keep #+ image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))
# Out:
# <ipython-input-6-747e2ff0d805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 7
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 836/836 [==============================] - 4s 4ms/step - loss: 0.6822 - accuracy: 0.5591 - val_loss: 0.6727 - val_accuracy: 0.5856
# Epoch 2/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6733 - accuracy: 0.5831 - val_loss: 0.6715 - val_accuracy: 0.5876
# Epoch 3/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6706 - accuracy: 0.5850 - val_loss: 0.6696 - val_accuracy: 0.5900
# Epoch 4/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6690 - accuracy: 0.5872 - val_loss: 0.6697 - val_accuracy: 0.5844
# Epoch 5/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6677 - accuracy: 0.5904 - val_loss: 0.6703 - val_accuracy: 0.5933
# Epoch 6/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6660 - accuracy: 0.5915 - val_loss: 0.6679 - val_accuracy: 0.5937
# Epoch 7/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6653 - accuracy: 0.5942 - val_loss: 0.6673 - val_accuracy: 0.5940
# Epoch 8/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6641 - accuracy: 0.5945 - val_loss: 0.6701 - val_accuracy: 0.5932
# Epoch 9/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6631 - accuracy: 0.5970 - val_loss: 0.6687 - val_accuracy: 0.5921
# Epoch 10/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6629 - accuracy: 0.5979 - val_loss: 0.6668 - val_accuracy: 0.5967
# Epoch 11/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6621 - accuracy: 0.5983 - val_loss: 0.6689 - val_accuracy: 0.5968
# Epoch 12/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6610 - accuracy: 0.6003 - val_loss: 0.6690 - val_accuracy: 0.5995
# Epoch 13/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6608 - accuracy: 0.5990 - val_loss: 0.6692 - val_accuracy: 0.5933
# Epoch 14/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6598 - accuracy: 0.6011 - val_loss: 0.6692 - val_accuracy: 0.5979
# Epoch 15/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6595 - accuracy: 0.6017 - val_loss: 0.6677 - val_accuracy: 0.5977
# Epoch 16/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6588 - accuracy: 0.6021 - val_loss: 0.6679 - val_accuracy: 0.5987
# Epoch 17/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6586 - accuracy: 0.6030 - val_loss: 0.6681 - val_accuracy: 0.5963
# Epoch 18/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6581 - accuracy: 0.6038 - val_loss: 0.6670 - val_accuracy: 0.5973
# Epoch 19/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6577 - accuracy: 0.6033 - val_loss: 0.6681 - val_accuracy: 0.5994
# Epoch 20/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6566 - accuracy: 0.6052 - val_loss: 0.6692 - val_accuracy: 0.5991
# Epoch 21/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6566 - accuracy: 0.6035 - val_loss: 0.6689 - val_accuracy: 0.5969
# Epoch 22/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6558 - accuracy: 0.6055 - val_loss: 0.6709 - val_accuracy: 0.5953
# Epoch 23/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6559 - accuracy: 0.6060 - val_loss: 0.6707 - val_accuracy: 0.5953
# Epoch 24/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6553 - accuracy: 0.6060 - val_loss: 0.6687 - val_accuracy: 0.5979
# Epoch 25/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6542 - accuracy: 0.6083 - val_loss: 0.6705 - val_accuracy: 0.5974
# Epoch 26/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6545 - accuracy: 0.6064 - val_loss: 0.6684 - val_accuracy: 0.5971
# Epoch 27/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6543 - accuracy: 0.6071 - val_loss: 0.6686 - val_accuracy: 0.6002
# Epoch 28/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6539 - accuracy: 0.6082 - val_loss: 0.6699 - val_accuracy: 0.5951
# Epoch 29/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6534 - accuracy: 0.6081 - val_loss: 0.6705 - val_accuracy: 0.5974
# Epoch 30/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6534 - accuracy: 0.6081 - val_loss: 0.6690 - val_accuracy: 0.6000
# Epoch 31/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6529 - accuracy: 0.6088 - val_loss: 0.6711 - val_accuracy: 0.5980
# Epoch 32/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6524 - accuracy: 0.6093 - val_loss: 0.6698 - val_accuracy: 0.5975
# Epoch 33/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6522 - accuracy: 0.6095 - val_loss: 0.6689 - val_accuracy: 0.5989
# Epoch 34/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6515 - accuracy: 0.6109 - val_loss: 0.6701 - val_accuracy: 0.5956
# Epoch 35/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6512 - accuracy: 0.6118 - val_loss: 0.6713 - val_accuracy: 0.5991
# Epoch 36/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6510 - accuracy: 0.6117 - val_loss: 0.6701 - val_accuracy: 0.6006
# Epoch 37/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6507 - accuracy: 0.6112 - val_loss: 0.6715 - val_accuracy: 0.5952
# Epoch 38/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6506 - accuracy: 0.6113 - val_loss: 0.6706 - val_accuracy: 0.5990
# Epoch 39/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6501 - accuracy: 0.6126 - val_loss: 0.6693 - val_accuracy: 0.5980
# Epoch 40/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6503 - accuracy: 0.6116 - val_loss: 0.6717 - val_accuracy: 0.5940
# Epoch 41/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6491 - accuracy: 0.6136 - val_loss: 0.6718 - val_accuracy: 0.5952
# Epoch 42/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6497 - accuracy: 0.6116 - val_loss: 0.6725 - val_accuracy: 0.5961
# Epoch 43/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6488 - accuracy: 0.6138 - val_loss: 0.6725 - val_accuracy: 0.5957
# Epoch 44/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6481 - accuracy: 0.6133 - val_loss: 0.6716 - val_accuracy: 0.5946
# Epoch 45/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6489 - accuracy: 0.6135 - val_loss: 0.6714 - val_accuracy: 0.6007
# Epoch 46/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6479 - accuracy: 0.6150 - val_loss: 0.6714 - val_accuracy: 0.6000
# Epoch 47/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6480 - accuracy: 0.6134 - val_loss: 0.6721 - val_accuracy: 0.5955
# Epoch 48/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6473 - accuracy: 0.6154 - val_loss: 0.6706 - val_accuracy: 0.5977
# Epoch 49/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6468 - accuracy: 0.6133 - val_loss: 0.6698 - val_accuracy: 0.5999
# Epoch 50/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6476 - accuracy: 0.6147 - val_loss: 0.6730 - val_accuracy: 0.5975
# Epoch 51/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6471 - accuracy: 0.6134 - val_loss: 0.6719 - val_accuracy: 0.5952
# Epoch 52/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6465 - accuracy: 0.6147 - val_loss: 0.6720 - val_accuracy: 0.5934
# Epoch 53/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6461 - accuracy: 0.6152 - val_loss: 0.6727 - val_accuracy: 0.5942
# Epoch 54/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6458 - accuracy: 0.6153 - val_loss: 0.6721 - val_accuracy: 0.5994
# Epoch 55/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6455 - accuracy: 0.6163 - val_loss: 0.6724 - val_accuracy: 0.5978
# Epoch 56/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6458 - accuracy: 0.6174 - val_loss: 0.6759 - val_accuracy: 0.5960
# Epoch 57/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6447 - accuracy: 0.6157 - val_loss: 0.6739 - val_accuracy: 0.5955
# Epoch 58/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6452 - accuracy: 0.6171 - val_loss: 0.6745 - val_accuracy: 0.5933
# Epoch 59/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6447 - accuracy: 0.6162 - val_loss: 0.6713 - val_accuracy: 0.5917
# Epoch 60/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6453 - accuracy: 0.6161 - val_loss: 0.6721 - val_accuracy: 0.6003
# Epoch 61/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6441 - accuracy: 0.6180 - val_loss: 0.6730 - val_accuracy: 0.5943
# Epoch 62/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6444 - accuracy: 0.6174 - val_loss: 0.6725 - val_accuracy: 0.6007
# Epoch 63/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6441 - accuracy: 0.6157 - val_loss: 0.6753 - val_accuracy: 0.5913
# Epoch 64/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6425 - accuracy: 0.6175 - val_loss: 0.6774 - val_accuracy: 0.5922
# Epoch 65/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6428 - accuracy: 0.6188 - val_loss: 0.6729 - val_accuracy: 0.5974
# 416/416 [==============================] - 1s 2ms/step - loss: 0.6669 - accuracy: 0.5981
# 416/416 [==============================] - 1s 1ms/step
# Accuracy for iteration 1: 0.60
# Iteration 2
# Epoch 1/500
# 835/835 [==============================] - 4s 4ms/step - loss: 0.6820 - accuracy: 0.5621 - val_loss: 0.6749 - val_accuracy: 0.5829
# Epoch 2/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6734 - accuracy: 0.5817 - val_loss: 0.6725 - val_accuracy: 0.5833
# Epoch 3/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6708 - accuracy: 0.5855 - val_loss: 0.6702 - val_accuracy: 0.5853
# Epoch 4/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6693 - accuracy: 0.5879 - val_loss: 0.6706 - val_accuracy: 0.5863
# Epoch 5/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6676 - accuracy: 0.5898 - val_loss: 0.6698 - val_accuracy: 0.5858
# Epoch 6/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6666 - accuracy: 0.5906 - val_loss: 0.6709 - val_accuracy: 0.5838
# Epoch 7/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6656 - accuracy: 0.5944 - val_loss: 0.6704 - val_accuracy: 0.5850
# Epoch 8/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6645 - accuracy: 0.5935 - val_loss: 0.6680 - val_accuracy: 0.5909
# Epoch 9/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6635 - accuracy: 0.5959 - val_loss: 0.6700 - val_accuracy: 0.5869
# Epoch 10/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6633 - accuracy: 0.5970 - val_loss: 0.6694 - val_accuracy: 0.5902
# Epoch 11/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6628 - accuracy: 0.5963 - val_loss: 0.6696 - val_accuracy: 0.5903
# Epoch 12/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6618 - accuracy: 0.5973 - val_loss: 0.6690 - val_accuracy: 0.5898
# Epoch 13/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6616 - accuracy: 0.5975 - val_loss: 0.6694 - val_accuracy: 0.5889
# Epoch 14/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6610 - accuracy: 0.5999 - val_loss: 0.6681 - val_accuracy: 0.5908
# Epoch 15/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6606 - accuracy: 0.6003 - val_loss: 0.6686 - val_accuracy: 0.5921
# Epoch 16/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6599 - accuracy: 0.6003 - val_loss: 0.6684 - val_accuracy: 0.5937
# Epoch 17/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6595 - accuracy: 0.6010 - val_loss: 0.6682 - val_accuracy: 0.5892
# Epoch 18/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6592 - accuracy: 0.6003 - val_loss: 0.6686 - val_accuracy: 0.5905
# Epoch 19/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6595 - accuracy: 0.6015 - val_loss: 0.6691 - val_accuracy: 0.5919
# Epoch 20/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6588 - accuracy: 0.6013 - val_loss: 0.6708 - val_accuracy: 0.5866
# Epoch 21/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6586 - accuracy: 0.6011 - val_loss: 0.6695 - val_accuracy: 0.5892
# Epoch 22/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6573 - accuracy: 0.6035 - val_loss: 0.6680 - val_accuracy: 0.5914
# Epoch 23/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6571 - accuracy: 0.6048 - val_loss: 0.6698 - val_accuracy: 0.5883
# Epoch 24/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6568 - accuracy: 0.6037 - val_loss: 0.6684 - val_accuracy: 0.5927
# Epoch 25/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6566 - accuracy: 0.6044 - val_loss: 0.6684 - val_accuracy: 0.5914
# Epoch 26/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6568 - accuracy: 0.6029 - val_loss: 0.6697 - val_accuracy: 0.5834
# Epoch 27/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6558 - accuracy: 0.6053 - val_loss: 0.6680 - val_accuracy: 0.5920
# Epoch 28/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6559 - accuracy: 0.6025 - val_loss: 0.6685 - val_accuracy: 0.5918
# Epoch 29/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6556 - accuracy: 0.6035 - val_loss: 0.6694 - val_accuracy: 0.5875
# Epoch 30/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6558 - accuracy: 0.6044 - val_loss: 0.6700 - val_accuracy: 0.5895
# Epoch 31/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6551 - accuracy: 0.6057 - val_loss: 0.6695 - val_accuracy: 0.5861
# Epoch 32/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6543 - accuracy: 0.6069 - val_loss: 0.6701 - val_accuracy: 0.5869
# Epoch 33/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6544 - accuracy: 0.6074 - val_loss: 0.6680 - val_accuracy: 0.5922
# Epoch 34/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6545 - accuracy: 0.6062 - val_loss: 0.6693 - val_accuracy: 0.5866
# Epoch 35/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6549 - accuracy: 0.6037 - val_loss: 0.6693 - val_accuracy: 0.5888
# Epoch 36/500
# 835/835 [==============================] - 4s 4ms/step - loss: 0.6541 - accuracy: 0.6071 - val_loss: 0.6709 - val_accuracy: 0.5852
# 427/427 [==============================] - 1s 2ms/step - loss: 0.6667 - accuracy: 0.5947
# 427/427 [==============================] - 1s 2ms/step
# Accuracy for iteration 2: 0.59
# Iteration 3
# Epoch 1/500
# 835/835 [==============================] - 4s 4ms/step - loss: 0.6818 - accuracy: 0.5613 - val_loss: 0.6824 - val_accuracy: 0.5561
# Epoch 2/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6734 - accuracy: 0.5809 - val_loss: 0.6757 - val_accuracy: 0.5747
# Epoch 3/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6707 - accuracy: 0.5855 - val_loss: 0.6730 - val_accuracy: 0.5785
# Epoch 4/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6691 - accuracy: 0.5875 - val_loss: 0.6728 - val_accuracy: 0.5836
# Epoch 5/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6681 - accuracy: 0.5902 - val_loss: 0.6744 - val_accuracy: 0.5751
# Epoch 6/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6664 - accuracy: 0.5923 - val_loss: 0.6730 - val_accuracy: 0.5803
# Epoch 7/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6650 - accuracy: 0.5946 - val_loss: 0.6718 - val_accuracy: 0.5789
# Epoch 8/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6645 - accuracy: 0.5960 - val_loss: 0.6715 - val_accuracy: 0.5841
# Epoch 9/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6635 - accuracy: 0.5958 - val_loss: 0.6705 - val_accuracy: 0.5863
# Epoch 10/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6631 - accuracy: 0.5951 - val_loss: 0.6706 - val_accuracy: 0.5864
# Epoch 11/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6623 - accuracy: 0.5971 - val_loss: 0.6708 - val_accuracy: 0.5822
# Epoch 12/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6616 - accuracy: 0.5974 - val_loss: 0.6709 - val_accuracy: 0.5827
# Epoch 13/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6612 - accuracy: 0.5996 - val_loss: 0.6714 - val_accuracy: 0.5861
# Epoch 14/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6613 - accuracy: 0.5978 - val_loss: 0.6708 - val_accuracy: 0.5859
# Epoch 15/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6595 - accuracy: 0.6010 - val_loss: 0.6707 - val_accuracy: 0.5866
# Epoch 16/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6595 - accuracy: 0.6009 - val_loss: 0.6726 - val_accuracy: 0.5810
# Epoch 17/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6591 - accuracy: 0.6013 - val_loss: 0.6713 - val_accuracy: 0.5860
# Epoch 18/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6586 - accuracy: 0.6016 - val_loss: 0.6711 - val_accuracy: 0.5827
# Epoch 19/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6581 - accuracy: 0.6027 - val_loss: 0.6711 - val_accuracy: 0.5883
# Epoch 20/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6573 - accuracy: 0.6041 - val_loss: 0.6719 - val_accuracy: 0.5829
# Epoch 21/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6572 - accuracy: 0.6038 - val_loss: 0.6696 - val_accuracy: 0.5877
# Epoch 22/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6567 - accuracy: 0.6034 - val_loss: 0.6711 - val_accuracy: 0.5836
# Epoch 23/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6567 - accuracy: 0.6044 - val_loss: 0.6706 - val_accuracy: 0.5863
# Epoch 24/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6562 - accuracy: 0.6052 - val_loss: 0.6711 - val_accuracy: 0.5875
# Epoch 25/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6553 - accuracy: 0.6054 - val_loss: 0.6713 - val_accuracy: 0.5847
# Epoch 26/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6563 - accuracy: 0.6039 - val_loss: 0.6720 - val_accuracy: 0.5820
# Epoch 27/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6545 - accuracy: 0.6070 - val_loss: 0.6698 - val_accuracy: 0.5891
# Epoch 28/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6543 - accuracy: 0.6070 - val_loss: 0.6710 - val_accuracy: 0.5857
# Epoch 29/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6545 - accuracy: 0.6072 - val_loss: 0.6693 - val_accuracy: 0.5886
# Epoch 30/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6533 - accuracy: 0.6073 - val_loss: 0.6697 - val_accuracy: 0.5882
# Epoch 31/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6544 - accuracy: 0.6053 - val_loss: 0.6708 - val_accuracy: 0.5806
# Epoch 32/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6531 - accuracy: 0.6090 - val_loss: 0.6691 - val_accuracy: 0.5879
# Epoch 33/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6526 - accuracy: 0.6082 - val_loss: 0.6697 - val_accuracy: 0.5891
# Epoch 34/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6526 - accuracy: 0.6080 - val_loss: 0.6716 - val_accuracy: 0.5833
# Epoch 35/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6524 - accuracy: 0.6087 - val_loss: 0.6706 - val_accuracy: 0.5838
# Epoch 36/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6520 - accuracy: 0.6079 - val_loss: 0.6714 - val_accuracy: 0.5834
# Epoch 37/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6523 - accuracy: 0.6088 - val_loss: 0.6700 - val_accuracy: 0.5869
# Epoch 38/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6523 - accuracy: 0.6067 - val_loss: 0.6692 - val_accuracy: 0.5848
# Epoch 39/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6516 - accuracy: 0.6095 - val_loss: 0.6711 - val_accuracy: 0.5851
# Epoch 40/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6508 - accuracy: 0.6104 - val_loss: 0.6705 - val_accuracy: 0.5880
# Epoch 41/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6509 - accuracy: 0.6104 - val_loss: 0.6710 - val_accuracy: 0.5862
# Epoch 42/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6500 - accuracy: 0.6118 - val_loss: 0.6723 - val_accuracy: 0.5797
# Epoch 43/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6505 - accuracy: 0.6092 - val_loss: 0.6710 - val_accuracy: 0.5816
# Epoch 44/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6498 - accuracy: 0.6127 - val_loss: 0.6695 - val_accuracy: 0.5882
# Epoch 45/500
# 835/835 [==============================] - 3s 4ms/step - loss: 0.6494 - accuracy: 0.6126 - val_loss: 0.6708 - val_accuracy: 0.5848
# Epoch 46/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6493 - accuracy: 0.6120 - val_loss: 0.6716 - val_accuracy: 0.5852
# Epoch 47/500
# 835/835 [==============================] - 3s 3ms/step - loss: 0.6490 - accuracy: 0.6118 - val_loss: 0.6700 - val_accuracy: 0.5886
# 415/415 [==============================] - 1s 2ms/step - loss: 0.6657 - accuracy: 0.5970
# 415/415 [==============================] - 1s 1ms/step
# Accuracy for iteration 3: 0.60
# Iteration 4
# Epoch 1/500
# 836/836 [==============================] - 4s 4ms/step - loss: 0.6817 - accuracy: 0.5621 - val_loss: 0.6734 - val_accuracy: 0.5821
# Epoch 2/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6733 - accuracy: 0.5832 - val_loss: 0.6702 - val_accuracy: 0.5883
# Epoch 3/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6706 - accuracy: 0.5860 - val_loss: 0.6684 - val_accuracy: 0.5848
# Epoch 4/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6688 - accuracy: 0.5869 - val_loss: 0.6677 - val_accuracy: 0.5915
# Epoch 5/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6675 - accuracy: 0.5908 - val_loss: 0.6664 - val_accuracy: 0.5904
# Epoch 6/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6665 - accuracy: 0.5927 - val_loss: 0.6674 - val_accuracy: 0.5948
# Epoch 7/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6656 - accuracy: 0.5943 - val_loss: 0.6674 - val_accuracy: 0.5914
# Epoch 8/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6650 - accuracy: 0.5938 - val_loss: 0.6663 - val_accuracy: 0.5953
# Epoch 9/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6640 - accuracy: 0.5966 - val_loss: 0.6666 - val_accuracy: 0.5915
# Epoch 10/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6637 - accuracy: 0.5960 - val_loss: 0.6676 - val_accuracy: 0.5950
# Epoch 11/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6629 - accuracy: 0.5955 - val_loss: 0.6666 - val_accuracy: 0.5965
# Epoch 12/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6625 - accuracy: 0.5985 - val_loss: 0.6663 - val_accuracy: 0.5951
# Epoch 13/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6613 - accuracy: 0.5993 - val_loss: 0.6651 - val_accuracy: 0.5948
# Epoch 14/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6614 - accuracy: 0.5991 - val_loss: 0.6656 - val_accuracy: 0.5970
# Epoch 15/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6599 - accuracy: 0.6008 - val_loss: 0.6659 - val_accuracy: 0.5970
# Epoch 16/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6602 - accuracy: 0.6006 - val_loss: 0.6662 - val_accuracy: 0.5921
# Epoch 17/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6594 - accuracy: 0.6013 - val_loss: 0.6649 - val_accuracy: 0.5977
# Epoch 18/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6588 - accuracy: 0.6025 - val_loss: 0.6652 - val_accuracy: 0.5966
# Epoch 19/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6586 - accuracy: 0.6022 - val_loss: 0.6652 - val_accuracy: 0.5923
# Epoch 20/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6576 - accuracy: 0.6035 - val_loss: 0.6664 - val_accuracy: 0.5950
# Epoch 21/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6580 - accuracy: 0.6021 - val_loss: 0.6638 - val_accuracy: 0.5942
# Epoch 22/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6572 - accuracy: 0.6046 - val_loss: 0.6659 - val_accuracy: 0.5943
# Epoch 23/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6562 - accuracy: 0.6048 - val_loss: 0.6684 - val_accuracy: 0.5898
# Epoch 24/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6565 - accuracy: 0.6052 - val_loss: 0.6651 - val_accuracy: 0.5943
# Epoch 25/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6562 - accuracy: 0.6057 - val_loss: 0.6673 - val_accuracy: 0.5922
# Epoch 26/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6548 - accuracy: 0.6070 - val_loss: 0.6661 - val_accuracy: 0.5918
# Epoch 27/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6547 - accuracy: 0.6077 - val_loss: 0.6670 - val_accuracy: 0.5912
# Epoch 28/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6555 - accuracy: 0.6043 - val_loss: 0.6666 - val_accuracy: 0.5933
# Epoch 29/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6547 - accuracy: 0.6064 - val_loss: 0.6666 - val_accuracy: 0.5909
# Epoch 30/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6542 - accuracy: 0.6074 - val_loss: 0.6670 - val_accuracy: 0.5959
# Epoch 31/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6542 - accuracy: 0.6073 - val_loss: 0.6689 - val_accuracy: 0.5941
# Epoch 32/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6536 - accuracy: 0.6083 - val_loss: 0.6676 - val_accuracy: 0.5905
# Epoch 33/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6535 - accuracy: 0.6072 - val_loss: 0.6656 - val_accuracy: 0.5963
# Epoch 34/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6537 - accuracy: 0.6087 - val_loss: 0.6671 - val_accuracy: 0.5965
# Epoch 35/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6529 - accuracy: 0.6097 - val_loss: 0.6672 - val_accuracy: 0.5947
# Epoch 36/500
# 836/836 [==============================] - 3s 4ms/step - loss: 0.6523 - accuracy: 0.6087 - val_loss: 0.6675 - val_accuracy: 0.5955
# Epoch 37/500
# 836/836 [==============================] - 3s 3ms/step - loss: 0.6525 - accuracy: 0.6073 - val_loss: 0.6683 - val_accuracy: 0.5971
# 414/414 [==============================] - 1s 2ms/step - loss: 0.6660 - accuracy: 0.5942
# 414/414 [==============================] - 1s 1ms/step
# Accuracy for iteration 4: 0.59
# Iteration 5
# Epoch 1/500
# 833/833 [==============================] - 4s 4ms/step - loss: 0.6832 - accuracy: 0.5578 - val_loss: 0.6705 - val_accuracy: 0.5863
# Epoch 2/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6739 - accuracy: 0.5818 - val_loss: 0.6701 - val_accuracy: 0.5881
# Epoch 3/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6713 - accuracy: 0.5868 - val_loss: 0.6693 - val_accuracy: 0.5863
# Epoch 4/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6693 - accuracy: 0.5896 - val_loss: 0.6671 - val_accuracy: 0.5915
# Epoch 5/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6680 - accuracy: 0.5908 - val_loss: 0.6681 - val_accuracy: 0.5902
# Epoch 6/500
# 833/833 [==============================] - 7s 8ms/step - loss: 0.6666 - accuracy: 0.5932 - val_loss: 0.6670 - val_accuracy: 0.5909
# Epoch 7/500
# 833/833 [==============================] - 5s 6ms/step - loss: 0.6655 - accuracy: 0.5936 - val_loss: 0.6671 - val_accuracy: 0.5930
# Epoch 8/500
# 833/833 [==============================] - 4s 5ms/step - loss: 0.6643 - accuracy: 0.5966 - val_loss: 0.6666 - val_accuracy: 0.5949
# Epoch 9/500
# 833/833 [==============================] - 4s 5ms/step - loss: 0.6636 - accuracy: 0.5955 - val_loss: 0.6648 - val_accuracy: 0.5951
# Epoch 10/500
# 833/833 [==============================] - 4s 5ms/step - loss: 0.6632 - accuracy: 0.5958 - val_loss: 0.6673 - val_accuracy: 0.5917
# Epoch 11/500
# 833/833 [==============================] - 4s 5ms/step - loss: 0.6619 - accuracy: 0.5976 - val_loss: 0.6672 - val_accuracy: 0.5943
# Epoch 12/500
# 833/833 [==============================] - 6s 8ms/step - loss: 0.6619 - accuracy: 0.5991 - val_loss: 0.6680 - val_accuracy: 0.5939
# Epoch 13/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6605 - accuracy: 0.5995 - val_loss: 0.6653 - val_accuracy: 0.5948
# Epoch 14/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6600 - accuracy: 0.6009 - val_loss: 0.6634 - val_accuracy: 0.5985
# Epoch 15/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6595 - accuracy: 0.6015 - val_loss: 0.6654 - val_accuracy: 0.5988
# Epoch 16/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6591 - accuracy: 0.6025 - val_loss: 0.6640 - val_accuracy: 0.5945
# Epoch 17/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6579 - accuracy: 0.6046 - val_loss: 0.6654 - val_accuracy: 0.5942
# Epoch 18/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6577 - accuracy: 0.6044 - val_loss: 0.6651 - val_accuracy: 0.5956
# Epoch 19/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6570 - accuracy: 0.6054 - val_loss: 0.6665 - val_accuracy: 0.5943
# Epoch 20/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6566 - accuracy: 0.6044 - val_loss: 0.6660 - val_accuracy: 0.5918
# Epoch 21/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6560 - accuracy: 0.6065 - val_loss: 0.6670 - val_accuracy: 0.5940
# Epoch 22/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6558 - accuracy: 0.6064 - val_loss: 0.6674 - val_accuracy: 0.5909
# Epoch 23/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6544 - accuracy: 0.6092 - val_loss: 0.6673 - val_accuracy: 0.5948
# Epoch 24/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6552 - accuracy: 0.6081 - val_loss: 0.6654 - val_accuracy: 0.5955
# Epoch 25/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6539 - accuracy: 0.6080 - val_loss: 0.6668 - val_accuracy: 0.5921
# Epoch 26/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6535 - accuracy: 0.6082 - val_loss: 0.6651 - val_accuracy: 0.5950
# Epoch 27/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6533 - accuracy: 0.6094 - val_loss: 0.6666 - val_accuracy: 0.5917
# Epoch 28/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6525 - accuracy: 0.6097 - val_loss: 0.6671 - val_accuracy: 0.5895
# Epoch 29/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6525 - accuracy: 0.6093 - val_loss: 0.6658 - val_accuracy: 0.5965
# Epoch 30/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6520 - accuracy: 0.6089 - val_loss: 0.6649 - val_accuracy: 0.5957
# Epoch 31/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6516 - accuracy: 0.6111 - val_loss: 0.6654 - val_accuracy: 0.5946
# Epoch 32/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6511 - accuracy: 0.6128 - val_loss: 0.6648 - val_accuracy: 0.5976
# Epoch 33/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6505 - accuracy: 0.6122 - val_loss: 0.6666 - val_accuracy: 0.5929
# Epoch 34/500
# 833/833 [==============================] - 3s 4ms/step - loss: 0.6512 - accuracy: 0.6105 - val_loss: 0.6679 - val_accuracy: 0.5885
# Epoch 35/500
# 833/833 [==============================] - 3s 3ms/step - loss: 0.6500 - accuracy: 0.6111 - val_loss: 0.6657 - val_accuracy: 0.5938
# 432/432 [==============================] - 1s 2ms/step - loss: 0.6669 - accuracy: 0.5985
# 432/432 [==============================] - 1s 1ms/step
# Accuracy for iteration 5: 0.60
# Iteration 6
# Epoch 1/500
# 837/837 [==============================] - 4s 3ms/step - loss: 0.6814 - accuracy: 0.5616 - val_loss: 0.6742 - val_accuracy: 0.5822
# Epoch 2/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6730 - accuracy: 0.5802 - val_loss: 0.6740 - val_accuracy: 0.5828
# Epoch 3/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6704 - accuracy: 0.5861 - val_loss: 0.6748 - val_accuracy: 0.5794
# Epoch 4/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6684 - accuracy: 0.5883 - val_loss: 0.6716 - val_accuracy: 0.5846
# Epoch 5/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6670 - accuracy: 0.5896 - val_loss: 0.6744 - val_accuracy: 0.5858
# Epoch 6/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6663 - accuracy: 0.5894 - val_loss: 0.6731 - val_accuracy: 0.5874
# Epoch 7/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6648 - accuracy: 0.5940 - val_loss: 0.6715 - val_accuracy: 0.5890
# Epoch 8/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6641 - accuracy: 0.5934 - val_loss: 0.6725 - val_accuracy: 0.5872
# Epoch 9/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6640 - accuracy: 0.5944 - val_loss: 0.6728 - val_accuracy: 0.5849
# Epoch 10/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6626 - accuracy: 0.5973 - val_loss: 0.6741 - val_accuracy: 0.5850
# Epoch 11/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6616 - accuracy: 0.5982 - val_loss: 0.6719 - val_accuracy: 0.5864
# Epoch 12/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6611 - accuracy: 0.5997 - val_loss: 0.6728 - val_accuracy: 0.5861
# Epoch 13/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6607 - accuracy: 0.6001 - val_loss: 0.6729 - val_accuracy: 0.5869
# Epoch 14/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6605 - accuracy: 0.5996 - val_loss: 0.6719 - val_accuracy: 0.5867
# Epoch 15/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6599 - accuracy: 0.6014 - val_loss: 0.6716 - val_accuracy: 0.5864
# Epoch 16/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6599 - accuracy: 0.5996 - val_loss: 0.6720 - val_accuracy: 0.5881
# Epoch 17/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6592 - accuracy: 0.6006 - val_loss: 0.6729 - val_accuracy: 0.5862
# Epoch 18/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6582 - accuracy: 0.6009 - val_loss: 0.6724 - val_accuracy: 0.5898
# Epoch 19/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6578 - accuracy: 0.6023 - val_loss: 0.6740 - val_accuracy: 0.5831
# Epoch 20/500
# 837/837 [==============================] - 3s 4ms/step - loss: 0.6576 - accuracy: 0.6042 - val_loss: 0.6709 - val_accuracy: 0.5896
# Epoch 21/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6571 - accuracy: 0.6038 - val_loss: 0.6722 - val_accuracy: 0.5874
# Epoch 22/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6570 - accuracy: 0.6023 - val_loss: 0.6718 - val_accuracy: 0.5895
# Epoch 23/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6561 - accuracy: 0.6048 - val_loss: 0.6731 - val_accuracy: 0.5873
# Epoch 24/500
# 837/837 [==============================] - 3s 4ms/step - loss: 0.6561 - accuracy: 0.6041 - val_loss: 0.6730 - val_accuracy: 0.5896
# Epoch 25/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6552 - accuracy: 0.6055 - val_loss: 0.6739 - val_accuracy: 0.5825
# Epoch 26/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6555 - accuracy: 0.6048 - val_loss: 0.6727 - val_accuracy: 0.5871
# Epoch 27/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6552 - accuracy: 0.6051 - val_loss: 0.6724 - val_accuracy: 0.5867
# Epoch 28/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6551 - accuracy: 0.6050 - val_loss: 0.6724 - val_accuracy: 0.5886
# Epoch 29/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6552 - accuracy: 0.6041 - val_loss: 0.6730 - val_accuracy: 0.5867
# Epoch 30/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6539 - accuracy: 0.6065 - val_loss: 0.6725 - val_accuracy: 0.5897
# Epoch 31/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6544 - accuracy: 0.6051 - val_loss: 0.6739 - val_accuracy: 0.5865
# Epoch 32/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6535 - accuracy: 0.6053 - val_loss: 0.6735 - val_accuracy: 0.5904
# Epoch 33/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6533 - accuracy: 0.6074 - val_loss: 0.6746 - val_accuracy: 0.5850
# Epoch 34/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6534 - accuracy: 0.6061 - val_loss: 0.6746 - val_accuracy: 0.5829
# Epoch 35/500
# 837/837 [==============================] - 3s 4ms/step - loss: 0.6524 - accuracy: 0.6075 - val_loss: 0.6725 - val_accuracy: 0.5870
# Epoch 36/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6521 - accuracy: 0.6075 - val_loss: 0.6729 - val_accuracy: 0.5891
# Epoch 37/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6523 - accuracy: 0.6076 - val_loss: 0.6732 - val_accuracy: 0.5845
# Epoch 38/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6521 - accuracy: 0.6085 - val_loss: 0.6743 - val_accuracy: 0.5882
# Epoch 39/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6521 - accuracy: 0.6079 - val_loss: 0.6741 - val_accuracy: 0.5852
# Epoch 40/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6510 - accuracy: 0.6095 - val_loss: 0.6752 - val_accuracy: 0.5864
# Epoch 41/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6519 - accuracy: 0.6092 - val_loss: 0.6754 - val_accuracy: 0.5816
# Epoch 42/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6511 - accuracy: 0.6069 - val_loss: 0.6737 - val_accuracy: 0.5870
# Epoch 43/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6510 - accuracy: 0.6098 - val_loss: 0.6740 - val_accuracy: 0.5844
# Epoch 44/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6511 - accuracy: 0.6087 - val_loss: 0.6751 - val_accuracy: 0.5846
# Epoch 45/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6506 - accuracy: 0.6094 - val_loss: 0.6749 - val_accuracy: 0.5819
# Epoch 46/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6500 - accuracy: 0.6106 - val_loss: 0.6757 - val_accuracy: 0.5801
# Epoch 47/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6500 - accuracy: 0.6102 - val_loss: 0.6753 - val_accuracy: 0.5854
# Epoch 48/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6506 - accuracy: 0.6105 - val_loss: 0.6748 - val_accuracy: 0.5811
# Epoch 49/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6494 - accuracy: 0.6109 - val_loss: 0.6741 - val_accuracy: 0.5892
# Epoch 50/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6489 - accuracy: 0.6110 - val_loss: 0.6735 - val_accuracy: 0.5897
# Epoch 51/500
# 837/837 [==============================] - 3s 4ms/step - loss: 0.6497 - accuracy: 0.6098 - val_loss: 0.6746 - val_accuracy: 0.5831
# Epoch 52/500
# 837/837 [==============================] - 3s 3ms/step - loss: 0.6488 - accuracy: 0.6123 - val_loss: 0.6753 - val_accuracy: 0.5832
# 417/417 [==============================] - 1s 2ms/step - loss: 0.6716 - accuracy: 0.5896
# 417/417 [==============================] - 1s 1ms/step
# Accuracy for iteration 6: 0.59
# Iteration 7
# Epoch 1/500
# 839/839 [==============================] - 4s 4ms/step - loss: 0.6821 - accuracy: 0.5610 - val_loss: 0.6741 - val_accuracy: 0.5814
# Epoch 2/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6733 - accuracy: 0.5817 - val_loss: 0.6716 - val_accuracy: 0.5813
# Epoch 3/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6706 - accuracy: 0.5859 - val_loss: 0.6711 - val_accuracy: 0.5864
# Epoch 4/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6687 - accuracy: 0.5886 - val_loss: 0.6706 - val_accuracy: 0.5916
# Epoch 5/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6672 - accuracy: 0.5909 - val_loss: 0.6713 - val_accuracy: 0.5891
# Epoch 6/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6663 - accuracy: 0.5931 - val_loss: 0.6718 - val_accuracy: 0.5880
# Epoch 7/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6646 - accuracy: 0.5947 - val_loss: 0.6705 - val_accuracy: 0.5919
# Epoch 8/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6634 - accuracy: 0.5974 - val_loss: 0.6685 - val_accuracy: 0.5925
# Epoch 9/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6628 - accuracy: 0.5974 - val_loss: 0.6711 - val_accuracy: 0.5880
# Epoch 10/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6624 - accuracy: 0.5974 - val_loss: 0.6696 - val_accuracy: 0.5931
# Epoch 11/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6620 - accuracy: 0.5979 - val_loss: 0.6689 - val_accuracy: 0.5918
# Epoch 12/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6615 - accuracy: 0.5978 - val_loss: 0.6695 - val_accuracy: 0.5900
# Epoch 13/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6607 - accuracy: 0.6008 - val_loss: 0.6688 - val_accuracy: 0.5931
# Epoch 14/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6607 - accuracy: 0.5994 - val_loss: 0.6695 - val_accuracy: 0.5944
# Epoch 15/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6597 - accuracy: 0.6006 - val_loss: 0.6705 - val_accuracy: 0.5933
# Epoch 16/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6596 - accuracy: 0.6018 - val_loss: 0.6679 - val_accuracy: 0.5956
# Epoch 17/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6585 - accuracy: 0.6028 - val_loss: 0.6686 - val_accuracy: 0.5933
# Epoch 18/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6578 - accuracy: 0.6040 - val_loss: 0.6677 - val_accuracy: 0.5944
# Epoch 19/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6572 - accuracy: 0.6045 - val_loss: 0.6668 - val_accuracy: 0.5956
# Epoch 20/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6574 - accuracy: 0.6042 - val_loss: 0.6687 - val_accuracy: 0.5888
# Epoch 21/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6569 - accuracy: 0.6047 - val_loss: 0.6687 - val_accuracy: 0.5917
# Epoch 22/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6565 - accuracy: 0.6053 - val_loss: 0.6696 - val_accuracy: 0.5920
# Epoch 23/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6559 - accuracy: 0.6066 - val_loss: 0.6675 - val_accuracy: 0.5937
# Epoch 24/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6558 - accuracy: 0.6060 - val_loss: 0.6676 - val_accuracy: 0.5957
# Epoch 25/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6552 - accuracy: 0.6074 - val_loss: 0.6704 - val_accuracy: 0.5903
# Epoch 26/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6547 - accuracy: 0.6067 - val_loss: 0.6671 - val_accuracy: 0.5928
# Epoch 27/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6546 - accuracy: 0.6066 - val_loss: 0.6697 - val_accuracy: 0.5911
# Epoch 28/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6538 - accuracy: 0.6083 - val_loss: 0.6685 - val_accuracy: 0.5883
# Epoch 29/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6537 - accuracy: 0.6074 - val_loss: 0.6682 - val_accuracy: 0.5900
# Epoch 30/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6533 - accuracy: 0.6091 - val_loss: 0.6688 - val_accuracy: 0.5903
# Epoch 31/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6525 - accuracy: 0.6098 - val_loss: 0.6681 - val_accuracy: 0.5948
# Epoch 32/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6529 - accuracy: 0.6090 - val_loss: 0.6683 - val_accuracy: 0.5914
# Epoch 33/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6525 - accuracy: 0.6107 - val_loss: 0.6676 - val_accuracy: 0.5927
# Epoch 34/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6531 - accuracy: 0.6070 - val_loss: 0.6661 - val_accuracy: 0.5929
# Epoch 35/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6519 - accuracy: 0.6094 - val_loss: 0.6706 - val_accuracy: 0.5916
# Epoch 36/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6521 - accuracy: 0.6101 - val_loss: 0.6680 - val_accuracy: 0.5937
# Epoch 37/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6513 - accuracy: 0.6113 - val_loss: 0.6678 - val_accuracy: 0.5928
# Epoch 38/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6515 - accuracy: 0.6108 - val_loss: 0.6688 - val_accuracy: 0.5942
# Epoch 39/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6514 - accuracy: 0.6117 - val_loss: 0.6675 - val_accuracy: 0.5933
# Epoch 40/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6508 - accuracy: 0.6106 - val_loss: 0.6689 - val_accuracy: 0.5936
# Epoch 41/500
# 839/839 [==============================] - 3s 3ms/step - loss: 0.6493 - accuracy: 0.6131 - val_loss: 0.6686 - val_accuracy: 0.5930
# Epoch 42/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6503 - accuracy: 0.6106 - val_loss: 0.6682 - val_accuracy: 0.5911
# Epoch 43/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6497 - accuracy: 0.6131 - val_loss: 0.6697 - val_accuracy: 0.5922
# Epoch 44/500
# 839/839 [==============================] - 3s 4ms/step - loss: 0.6487 - accuracy: 0.6130 - val_loss: 0.6696 - val_accuracy: 0.5917
# 396/396 [==============================] - 1s 2ms/step - loss: 0.6697 - accuracy: 0.5908
# 396/396 [==============================] - 1s 2ms/step
# Accuracy for iteration 7: 0.59
# Average Accuracy across 7 iterations: 0.59

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.58965 - 0.59848

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 425/425 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#          Low       0.60      0.57      0.59      6792
#         High       0.59      0.62      0.60      6792
#
#     accuracy                           0.60     13584
#    macro avg       0.60      0.60      0.60     13584
# weighted avg       0.60      0.60      0.60     13584

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 396/396 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#          Low       0.59      0.58      0.58      6336
#         High       0.59      0.61      0.60      6336
#
#     accuracy                           0.59     12672
#    macro avg       0.59      0.59      0.59     12672
# weighted avg       0.59      0.59      0.59     12672
