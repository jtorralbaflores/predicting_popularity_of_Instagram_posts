# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = image_columns + additional_columns_to_keep + text_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))
# Out:
# <ipython-input-6-747e2ff0d805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 4
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 706/706 [==============================] - 7s 5ms/step - loss: 0.6901 - accuracy: 0.5333 - val_loss: 0.6830 - val_accuracy: 0.5674
# Epoch 2/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6821 - accuracy: 0.5511 - val_loss: 0.6770 - val_accuracy: 0.5706
# Epoch 3/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6788 - accuracy: 0.5585 - val_loss: 0.6772 - val_accuracy: 0.5717
# Epoch 4/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6770 - accuracy: 0.5623 - val_loss: 0.6744 - val_accuracy: 0.5722
# Epoch 5/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6748 - accuracy: 0.5685 - val_loss: 0.6779 - val_accuracy: 0.5810
# Epoch 6/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6731 - accuracy: 0.5706 - val_loss: 0.6762 - val_accuracy: 0.5767
# Epoch 7/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6713 - accuracy: 0.5736 - val_loss: 0.6727 - val_accuracy: 0.5791
# Epoch 8/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6703 - accuracy: 0.5767 - val_loss: 0.6691 - val_accuracy: 0.5854
# Epoch 9/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6687 - accuracy: 0.5809 - val_loss: 0.6762 - val_accuracy: 0.5823
# Epoch 10/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6698 - accuracy: 0.5806 - val_loss: 0.6750 - val_accuracy: 0.5818
# Epoch 11/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6670 - accuracy: 0.5845 - val_loss: 0.6727 - val_accuracy: 0.5844
# Epoch 12/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6662 - accuracy: 0.5843 - val_loss: 0.6706 - val_accuracy: 0.5823
# Epoch 13/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6652 - accuracy: 0.5866 - val_loss: 0.6746 - val_accuracy: 0.5775
# Epoch 14/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6637 - accuracy: 0.5891 - val_loss: 0.6701 - val_accuracy: 0.5910
# Epoch 15/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6622 - accuracy: 0.5902 - val_loss: 0.6688 - val_accuracy: 0.5882
# Epoch 16/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6620 - accuracy: 0.5900 - val_loss: 0.6687 - val_accuracy: 0.5882
# Epoch 17/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6614 - accuracy: 0.5906 - val_loss: 0.6710 - val_accuracy: 0.5838
# Epoch 18/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6618 - accuracy: 0.5931 - val_loss: 0.6718 - val_accuracy: 0.5841
# Epoch 19/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6598 - accuracy: 0.5914 - val_loss: 0.6692 - val_accuracy: 0.5861
# Epoch 20/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6589 - accuracy: 0.5959 - val_loss: 0.6703 - val_accuracy: 0.5851
# Epoch 21/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6567 - accuracy: 0.5968 - val_loss: 0.6766 - val_accuracy: 0.5834
# Epoch 22/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6563 - accuracy: 0.5976 - val_loss: 0.6681 - val_accuracy: 0.5890
# Epoch 23/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6575 - accuracy: 0.5942 - val_loss: 0.6733 - val_accuracy: 0.5840
# Epoch 24/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6558 - accuracy: 0.5986 - val_loss: 0.6724 - val_accuracy: 0.5867
# Epoch 25/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6541 - accuracy: 0.5999 - val_loss: 0.6697 - val_accuracy: 0.5921
# Epoch 26/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6543 - accuracy: 0.5998 - val_loss: 0.6735 - val_accuracy: 0.5841
# Epoch 27/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6534 - accuracy: 0.6021 - val_loss: 0.6679 - val_accuracy: 0.5873
# Epoch 28/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6529 - accuracy: 0.6000 - val_loss: 0.6721 - val_accuracy: 0.5853
# Epoch 29/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.6017 - val_loss: 0.6698 - val_accuracy: 0.5902
# Epoch 30/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6519 - accuracy: 0.6024 - val_loss: 0.6699 - val_accuracy: 0.5891
# Epoch 31/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6513 - accuracy: 0.6024 - val_loss: 0.6741 - val_accuracy: 0.5841
# Epoch 32/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.6051 - val_loss: 0.6748 - val_accuracy: 0.5811
# Epoch 33/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6504 - accuracy: 0.6017 - val_loss: 0.6677 - val_accuracy: 0.5907
# Epoch 34/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6497 - accuracy: 0.6041 - val_loss: 0.6717 - val_accuracy: 0.5866
# Epoch 35/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6491 - accuracy: 0.6057 - val_loss: 0.6745 - val_accuracy: 0.5855
# Epoch 36/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6486 - accuracy: 0.6049 - val_loss: 0.6703 - val_accuracy: 0.5883
# Epoch 37/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6472 - accuracy: 0.6093 - val_loss: 0.6702 - val_accuracy: 0.5875
# Epoch 38/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6477 - accuracy: 0.6069 - val_loss: 0.6729 - val_accuracy: 0.5856
# Epoch 39/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6475 - accuracy: 0.6059 - val_loss: 0.6683 - val_accuracy: 0.5897
# Epoch 40/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6476 - accuracy: 0.6067 - val_loss: 0.6752 - val_accuracy: 0.5871
# Epoch 41/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6459 - accuracy: 0.6079 - val_loss: 0.6733 - val_accuracy: 0.5855
# Epoch 42/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6446 - accuracy: 0.6088 - val_loss: 0.6772 - val_accuracy: 0.5880
# Epoch 43/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6447 - accuracy: 0.6080 - val_loss: 0.6740 - val_accuracy: 0.5884
# Epoch 44/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6442 - accuracy: 0.6090 - val_loss: 0.6710 - val_accuracy: 0.5866
# Epoch 45/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6435 - accuracy: 0.6101 - val_loss: 0.6732 - val_accuracy: 0.5844
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6728 - accuracy: 0.5903
# 363/363 [==============================] - 1s 2ms/step
# Accuracy for iteration 1: 0.59
# Iteration 2
# Epoch 1/500
# 710/710 [==============================] - 5s 5ms/step - loss: 0.6869 - accuracy: 0.5474 - val_loss: 0.6791 - val_accuracy: 0.5779
# Epoch 2/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6793 - accuracy: 0.5636 - val_loss: 0.6751 - val_accuracy: 0.5898
# Epoch 3/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6754 - accuracy: 0.5712 - val_loss: 0.6710 - val_accuracy: 0.5925
# Epoch 4/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6729 - accuracy: 0.5764 - val_loss: 0.6748 - val_accuracy: 0.5898
# Epoch 5/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6709 - accuracy: 0.5784 - val_loss: 0.6682 - val_accuracy: 0.5954
# Epoch 6/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6697 - accuracy: 0.5793 - val_loss: 0.6670 - val_accuracy: 0.5961
# Epoch 7/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6664 - accuracy: 0.5854 - val_loss: 0.6656 - val_accuracy: 0.6033
# Epoch 8/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6656 - accuracy: 0.5848 - val_loss: 0.6705 - val_accuracy: 0.6020
# Epoch 9/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6628 - accuracy: 0.5890 - val_loss: 0.6689 - val_accuracy: 0.5978
# Epoch 10/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6615 - accuracy: 0.5886 - val_loss: 0.6650 - val_accuracy: 0.6055
# Epoch 11/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6602 - accuracy: 0.5923 - val_loss: 0.6677 - val_accuracy: 0.6010
# Epoch 12/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6586 - accuracy: 0.5940 - val_loss: 0.6650 - val_accuracy: 0.6020
# Epoch 13/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6573 - accuracy: 0.5938 - val_loss: 0.6669 - val_accuracy: 0.6018
# Epoch 14/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6568 - accuracy: 0.5960 - val_loss: 0.6652 - val_accuracy: 0.6034
# Epoch 15/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6555 - accuracy: 0.5957 - val_loss: 0.6671 - val_accuracy: 0.6000
# Epoch 16/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6542 - accuracy: 0.5985 - val_loss: 0.6646 - val_accuracy: 0.6027
# Epoch 17/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6534 - accuracy: 0.6008 - val_loss: 0.6669 - val_accuracy: 0.6026
# Epoch 18/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6515 - accuracy: 0.6000 - val_loss: 0.6677 - val_accuracy: 0.6033
# Epoch 19/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6513 - accuracy: 0.6001 - val_loss: 0.6651 - val_accuracy: 0.6059
# Epoch 20/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6505 - accuracy: 0.6017 - val_loss: 0.6658 - val_accuracy: 0.6034
# Epoch 21/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6484 - accuracy: 0.6039 - val_loss: 0.6642 - val_accuracy: 0.6033
# Epoch 22/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6477 - accuracy: 0.6066 - val_loss: 0.6652 - val_accuracy: 0.6027
# Epoch 23/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6467 - accuracy: 0.6062 - val_loss: 0.6646 - val_accuracy: 0.6045
# Epoch 24/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6469 - accuracy: 0.6038 - val_loss: 0.6668 - val_accuracy: 0.5990
# Epoch 25/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6453 - accuracy: 0.6064 - val_loss: 0.6669 - val_accuracy: 0.6027
# Epoch 26/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6447 - accuracy: 0.6053 - val_loss: 0.6673 - val_accuracy: 0.5989
# Epoch 27/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6426 - accuracy: 0.6076 - val_loss: 0.6697 - val_accuracy: 0.6025
# Epoch 28/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6419 - accuracy: 0.6082 - val_loss: 0.6662 - val_accuracy: 0.6004
# Epoch 29/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6409 - accuracy: 0.6089 - val_loss: 0.6677 - val_accuracy: 0.6004
# Epoch 30/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6409 - accuracy: 0.6089 - val_loss: 0.6653 - val_accuracy: 0.6028
# Epoch 31/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6410 - accuracy: 0.6070 - val_loss: 0.6705 - val_accuracy: 0.5996
# Epoch 32/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6398 - accuracy: 0.6090 - val_loss: 0.6674 - val_accuracy: 0.6010
# Epoch 33/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6380 - accuracy: 0.6131 - val_loss: 0.6721 - val_accuracy: 0.5960
# Epoch 34/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6367 - accuracy: 0.6126 - val_loss: 0.6705 - val_accuracy: 0.5979
# Epoch 35/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6372 - accuracy: 0.6100 - val_loss: 0.6687 - val_accuracy: 0.6003
# Epoch 36/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6372 - accuracy: 0.6104 - val_loss: 0.6725 - val_accuracy: 0.5973
# Epoch 37/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6347 - accuracy: 0.6132 - val_loss: 0.6727 - val_accuracy: 0.5964
# Epoch 38/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6341 - accuracy: 0.6108 - val_loss: 0.6709 - val_accuracy: 0.5992
# Epoch 39/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6337 - accuracy: 0.6119 - val_loss: 0.6697 - val_accuracy: 0.6006
# 345/345 [==============================] - 1s 2ms/step - loss: 0.6705 - accuracy: 0.5869
# 345/345 [==============================] - 1s 2ms/step
# Accuracy for iteration 2: 0.59
# Iteration 3
# Epoch 1/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6903 - accuracy: 0.5336 - val_loss: 0.6768 - val_accuracy: 0.5823
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6833 - accuracy: 0.5507 - val_loss: 0.6698 - val_accuracy: 0.5906
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6803 - accuracy: 0.5571 - val_loss: 0.6733 - val_accuracy: 0.5859
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6780 - accuracy: 0.5605 - val_loss: 0.6715 - val_accuracy: 0.5927
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6748 - accuracy: 0.5658 - val_loss: 0.6676 - val_accuracy: 0.5955
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6730 - accuracy: 0.5672 - val_loss: 0.6693 - val_accuracy: 0.5974
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6725 - accuracy: 0.5687 - val_loss: 0.6683 - val_accuracy: 0.5962
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6707 - accuracy: 0.5714 - val_loss: 0.6650 - val_accuracy: 0.6003
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6692 - accuracy: 0.5730 - val_loss: 0.6654 - val_accuracy: 0.5982
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6688 - accuracy: 0.5753 - val_loss: 0.6705 - val_accuracy: 0.5945
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6668 - accuracy: 0.5769 - val_loss: 0.6651 - val_accuracy: 0.6014
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6662 - accuracy: 0.5761 - val_loss: 0.6631 - val_accuracy: 0.6028
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6662 - accuracy: 0.5775 - val_loss: 0.6683 - val_accuracy: 0.5893
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6644 - accuracy: 0.5814 - val_loss: 0.6654 - val_accuracy: 0.5957
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6634 - accuracy: 0.5802 - val_loss: 0.6634 - val_accuracy: 0.6034
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6626 - accuracy: 0.5782 - val_loss: 0.6660 - val_accuracy: 0.5970
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6623 - accuracy: 0.5800 - val_loss: 0.6643 - val_accuracy: 0.6016
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6614 - accuracy: 0.5815 - val_loss: 0.6636 - val_accuracy: 0.6049
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6599 - accuracy: 0.5818 - val_loss: 0.6648 - val_accuracy: 0.5997
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6602 - accuracy: 0.5809 - val_loss: 0.6608 - val_accuracy: 0.6009
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6599 - accuracy: 0.5819 - val_loss: 0.6647 - val_accuracy: 0.5979
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6585 - accuracy: 0.5819 - val_loss: 0.6697 - val_accuracy: 0.5985
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6579 - accuracy: 0.5828 - val_loss: 0.6604 - val_accuracy: 0.6045
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6571 - accuracy: 0.5859 - val_loss: 0.6609 - val_accuracy: 0.6040
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6560 - accuracy: 0.5880 - val_loss: 0.6656 - val_accuracy: 0.6044
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6555 - accuracy: 0.5848 - val_loss: 0.6643 - val_accuracy: 0.5965
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6552 - accuracy: 0.5869 - val_loss: 0.6618 - val_accuracy: 0.6046
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6559 - accuracy: 0.5859 - val_loss: 0.6660 - val_accuracy: 0.6000
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6543 - accuracy: 0.5864 - val_loss: 0.6653 - val_accuracy: 0.6027
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6536 - accuracy: 0.5874 - val_loss: 0.6638 - val_accuracy: 0.6014
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6533 - accuracy: 0.5889 - val_loss: 0.6608 - val_accuracy: 0.6045
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6530 - accuracy: 0.5899 - val_loss: 0.6624 - val_accuracy: 0.6023
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6535 - accuracy: 0.5890 - val_loss: 0.6614 - val_accuracy: 0.6017
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.5894 - val_loss: 0.6610 - val_accuracy: 0.6054
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6512 - accuracy: 0.5917 - val_loss: 0.6642 - val_accuracy: 0.5993
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6514 - accuracy: 0.5907 - val_loss: 0.6606 - val_accuracy: 0.6027
# Epoch 37/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6516 - accuracy: 0.5911 - val_loss: 0.6620 - val_accuracy: 0.6032
# Epoch 38/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6514 - accuracy: 0.5889 - val_loss: 0.6631 - val_accuracy: 0.6006
# Epoch 39/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6509 - accuracy: 0.5873 - val_loss: 0.6679 - val_accuracy: 0.5955
# Epoch 40/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6514 - accuracy: 0.5901 - val_loss: 0.6619 - val_accuracy: 0.6011
# Epoch 41/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6503 - accuracy: 0.5889 - val_loss: 0.6624 - val_accuracy: 0.6024
# Epoch 42/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6501 - accuracy: 0.5904 - val_loss: 0.6623 - val_accuracy: 0.5974
# Epoch 43/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6491 - accuracy: 0.5919 - val_loss: 0.6640 - val_accuracy: 0.5977
# Epoch 44/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6484 - accuracy: 0.5914 - val_loss: 0.6627 - val_accuracy: 0.5967
# Epoch 45/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6480 - accuracy: 0.5924 - val_loss: 0.6636 - val_accuracy: 0.6000
# Epoch 46/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6490 - accuracy: 0.5916 - val_loss: 0.6630 - val_accuracy: 0.6005
# Epoch 47/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6474 - accuracy: 0.5935 - val_loss: 0.6625 - val_accuracy: 0.6036
# Epoch 48/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6486 - accuracy: 0.5926 - val_loss: 0.6630 - val_accuracy: 0.6010
# Epoch 49/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6468 - accuracy: 0.5925 - val_loss: 0.6664 - val_accuracy: 0.5936
# Epoch 50/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6474 - accuracy: 0.5948 - val_loss: 0.6649 - val_accuracy: 0.5973
# Epoch 51/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6474 - accuracy: 0.5936 - val_loss: 0.6633 - val_accuracy: 0.5999
# Epoch 52/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6474 - accuracy: 0.5924 - val_loss: 0.6633 - val_accuracy: 0.6001
# Epoch 53/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6459 - accuracy: 0.5945 - val_loss: 0.6649 - val_accuracy: 0.5975
# Epoch 54/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6460 - accuracy: 0.5935 - val_loss: 0.6623 - val_accuracy: 0.6024
# 343/343 [==============================] - 1s 2ms/step - loss: 0.6679 - accuracy: 0.5899
# 343/343 [==============================] - 1s 2ms/step
# Accuracy for iteration 3: 0.59
# Iteration 4
# Epoch 1/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6878 - accuracy: 0.5498 - val_loss: 0.6828 - val_accuracy: 0.5616
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6807 - accuracy: 0.5642 - val_loss: 0.6828 - val_accuracy: 0.5582
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6780 - accuracy: 0.5703 - val_loss: 0.6781 - val_accuracy: 0.5765
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6747 - accuracy: 0.5746 - val_loss: 0.6754 - val_accuracy: 0.5762
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6727 - accuracy: 0.5773 - val_loss: 0.6763 - val_accuracy: 0.5750
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6708 - accuracy: 0.5822 - val_loss: 0.6755 - val_accuracy: 0.5791
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6696 - accuracy: 0.5830 - val_loss: 0.6743 - val_accuracy: 0.5829
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6671 - accuracy: 0.5876 - val_loss: 0.6711 - val_accuracy: 0.5850
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6652 - accuracy: 0.5892 - val_loss: 0.6718 - val_accuracy: 0.5873
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6644 - accuracy: 0.5907 - val_loss: 0.6746 - val_accuracy: 0.5846
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6637 - accuracy: 0.5904 - val_loss: 0.6749 - val_accuracy: 0.5818
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6613 - accuracy: 0.5956 - val_loss: 0.6734 - val_accuracy: 0.5858
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6603 - accuracy: 0.5973 - val_loss: 0.6730 - val_accuracy: 0.5811
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6600 - accuracy: 0.5984 - val_loss: 0.6707 - val_accuracy: 0.5889
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6585 - accuracy: 0.5983 - val_loss: 0.6710 - val_accuracy: 0.5884
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6574 - accuracy: 0.6001 - val_loss: 0.6687 - val_accuracy: 0.5919
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6562 - accuracy: 0.6034 - val_loss: 0.6714 - val_accuracy: 0.5847
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6560 - accuracy: 0.6015 - val_loss: 0.6735 - val_accuracy: 0.5813
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6548 - accuracy: 0.6040 - val_loss: 0.6699 - val_accuracy: 0.5861
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6543 - accuracy: 0.6043 - val_loss: 0.6713 - val_accuracy: 0.5852
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6531 - accuracy: 0.6055 - val_loss: 0.6687 - val_accuracy: 0.5913
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6523 - accuracy: 0.6077 - val_loss: 0.6699 - val_accuracy: 0.5924
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6521 - accuracy: 0.6061 - val_loss: 0.6723 - val_accuracy: 0.5863
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.6056 - val_loss: 0.6696 - val_accuracy: 0.5877
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6491 - accuracy: 0.6103 - val_loss: 0.6726 - val_accuracy: 0.5805
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6490 - accuracy: 0.6077 - val_loss: 0.6716 - val_accuracy: 0.5857
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6479 - accuracy: 0.6099 - val_loss: 0.6707 - val_accuracy: 0.5843
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6475 - accuracy: 0.6128 - val_loss: 0.6706 - val_accuracy: 0.5886
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6461 - accuracy: 0.6117 - val_loss: 0.6701 - val_accuracy: 0.5861
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6475 - accuracy: 0.6107 - val_loss: 0.6687 - val_accuracy: 0.5856
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6459 - accuracy: 0.6123 - val_loss: 0.6693 - val_accuracy: 0.5903
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6455 - accuracy: 0.6127 - val_loss: 0.6691 - val_accuracy: 0.5869
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6444 - accuracy: 0.6134 - val_loss: 0.6688 - val_accuracy: 0.5852
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6428 - accuracy: 0.6139 - val_loss: 0.6695 - val_accuracy: 0.5877
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6422 - accuracy: 0.6156 - val_loss: 0.6721 - val_accuracy: 0.5798
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6419 - accuracy: 0.6162 - val_loss: 0.6701 - val_accuracy: 0.5841
# Epoch 37/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6417 - accuracy: 0.6141 - val_loss: 0.6701 - val_accuracy: 0.5842
# Epoch 38/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6405 - accuracy: 0.6168 - val_loss: 0.6705 - val_accuracy: 0.5864
# Epoch 39/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6402 - accuracy: 0.6145 - val_loss: 0.6715 - val_accuracy: 0.5841
# Epoch 40/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6380 - accuracy: 0.6177 - val_loss: 0.6711 - val_accuracy: 0.5833
# Epoch 41/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6384 - accuracy: 0.6167 - val_loss: 0.6705 - val_accuracy: 0.5843
# Epoch 42/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6381 - accuracy: 0.6169 - val_loss: 0.6749 - val_accuracy: 0.5751
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6688 - accuracy: 0.5933
# 354/354 [==============================] - 1s 2ms/step
# Accuracy for iteration 4: 0.59
# Average Accuracy across 4 iterations: 0.59

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.58690 - 0.59330

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 350/350 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.60      0.56      0.58      5596
#         High       0.59      0.63      0.61      5596
#
#     accuracy                           0.59     11192
#    macro avg       0.59      0.59      0.59     11192
# weighted avg       0.59      0.59      0.59     11192

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 354/354 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.60      0.55      0.58      5659
#         High       0.59      0.63      0.61      5659
#
#     accuracy                           0.59     11318
#    macro avg       0.59      0.59      0.59     11318
# weighted avg       0.59      0.59      0.59     11318
