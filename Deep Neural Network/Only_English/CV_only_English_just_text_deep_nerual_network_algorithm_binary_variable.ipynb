# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = text_columns + additional_columns_to_keep #+ image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 4
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 706/706 [==============================] - 4s 4ms/step - loss: 0.6832 - accuracy: 0.5579 - val_loss: 0.6780 - val_accuracy: 0.5643
# Epoch 2/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6747 - accuracy: 0.5768 - val_loss: 0.6685 - val_accuracy: 0.5914
# Epoch 3/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6720 - accuracy: 0.5825 - val_loss: 0.6672 - val_accuracy: 0.5919
# Epoch 4/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6700 - accuracy: 0.5859 - val_loss: 0.6666 - val_accuracy: 0.5975
# Epoch 5/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6689 - accuracy: 0.5867 - val_loss: 0.6699 - val_accuracy: 0.5953
# Epoch 6/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6675 - accuracy: 0.5899 - val_loss: 0.6669 - val_accuracy: 0.5918
# Epoch 7/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6664 - accuracy: 0.5930 - val_loss: 0.6660 - val_accuracy: 0.5969
# Epoch 8/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6650 - accuracy: 0.5941 - val_loss: 0.6670 - val_accuracy: 0.5949
# Epoch 9/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6645 - accuracy: 0.5945 - val_loss: 0.6663 - val_accuracy: 0.5949
# Epoch 10/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6642 - accuracy: 0.5931 - val_loss: 0.6673 - val_accuracy: 0.5927
# Epoch 11/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6628 - accuracy: 0.5967 - val_loss: 0.6656 - val_accuracy: 0.5929
# Epoch 12/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6621 - accuracy: 0.5970 - val_loss: 0.6672 - val_accuracy: 0.5963
# Epoch 13/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6616 - accuracy: 0.5988 - val_loss: 0.6653 - val_accuracy: 0.5931
# Epoch 14/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6612 - accuracy: 0.5963 - val_loss: 0.6648 - val_accuracy: 0.5958
# Epoch 15/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6598 - accuracy: 0.6000 - val_loss: 0.6672 - val_accuracy: 0.5873
# Epoch 16/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6597 - accuracy: 0.5990 - val_loss: 0.6642 - val_accuracy: 0.5988
# Epoch 17/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6600 - accuracy: 0.5996 - val_loss: 0.6625 - val_accuracy: 0.6002
# Epoch 18/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6584 - accuracy: 0.5990 - val_loss: 0.6653 - val_accuracy: 0.5900
# Epoch 19/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6584 - accuracy: 0.6006 - val_loss: 0.6644 - val_accuracy: 0.5986
# Epoch 20/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6575 - accuracy: 0.6043 - val_loss: 0.6661 - val_accuracy: 0.5950
# Epoch 21/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6564 - accuracy: 0.6051 - val_loss: 0.6651 - val_accuracy: 0.5986
# Epoch 22/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6574 - accuracy: 0.5997 - val_loss: 0.6641 - val_accuracy: 0.5990
# Epoch 23/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6560 - accuracy: 0.6054 - val_loss: 0.6643 - val_accuracy: 0.6009
# Epoch 24/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6548 - accuracy: 0.6072 - val_loss: 0.6664 - val_accuracy: 0.5962
# Epoch 25/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6557 - accuracy: 0.6055 - val_loss: 0.6645 - val_accuracy: 0.6023
# Epoch 26/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6555 - accuracy: 0.6049 - val_loss: 0.6654 - val_accuracy: 0.5953
# Epoch 27/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6547 - accuracy: 0.6079 - val_loss: 0.6661 - val_accuracy: 0.5942
# Epoch 28/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6540 - accuracy: 0.6068 - val_loss: 0.6647 - val_accuracy: 0.5974
# Epoch 29/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6531 - accuracy: 0.6087 - val_loss: 0.6655 - val_accuracy: 0.5970
# Epoch 30/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6530 - accuracy: 0.6057 - val_loss: 0.6654 - val_accuracy: 0.5954
# Epoch 31/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6537 - accuracy: 0.6061 - val_loss: 0.6657 - val_accuracy: 0.5943
# Epoch 32/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6521 - accuracy: 0.6092 - val_loss: 0.6663 - val_accuracy: 0.5961
# Epoch 33/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6513 - accuracy: 0.6103 - val_loss: 0.6658 - val_accuracy: 0.5951
# Epoch 34/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6513 - accuracy: 0.6092 - val_loss: 0.6664 - val_accuracy: 0.5957
# Epoch 35/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6515 - accuracy: 0.6091 - val_loss: 0.6668 - val_accuracy: 0.5966
# Epoch 36/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6512 - accuracy: 0.6094 - val_loss: 0.6645 - val_accuracy: 0.5990
# Epoch 37/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6503 - accuracy: 0.6117 - val_loss: 0.6656 - val_accuracy: 0.5981
# Epoch 38/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6499 - accuracy: 0.6104 - val_loss: 0.6654 - val_accuracy: 0.5980
# Epoch 39/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6502 - accuracy: 0.6088 - val_loss: 0.6665 - val_accuracy: 0.5937
# Epoch 40/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6496 - accuracy: 0.6109 - val_loss: 0.6640 - val_accuracy: 0.5990
# Epoch 41/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6481 - accuracy: 0.6146 - val_loss: 0.6654 - val_accuracy: 0.5971
# Epoch 42/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6484 - accuracy: 0.6121 - val_loss: 0.6663 - val_accuracy: 0.5949
# Epoch 43/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6484 - accuracy: 0.6119 - val_loss: 0.6672 - val_accuracy: 0.5942
# Epoch 44/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6476 - accuracy: 0.6113 - val_loss: 0.6656 - val_accuracy: 0.5955
# Epoch 45/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6475 - accuracy: 0.6113 - val_loss: 0.6641 - val_accuracy: 0.5974
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6650 - accuracy: 0.6016
# 363/363 [==============================] - 1s 2ms/step
# Accuracy for iteration 1: 0.60
# Iteration 2
# Epoch 1/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6849 - accuracy: 0.5498 - val_loss: 0.6698 - val_accuracy: 0.5911
# Epoch 2/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6758 - accuracy: 0.5757 - val_loss: 0.6692 - val_accuracy: 0.5938
# Epoch 3/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6723 - accuracy: 0.5833 - val_loss: 0.6690 - val_accuracy: 0.5879
# Epoch 4/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6703 - accuracy: 0.5861 - val_loss: 0.6687 - val_accuracy: 0.5894
# Epoch 5/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6685 - accuracy: 0.5879 - val_loss: 0.6664 - val_accuracy: 0.5935
# Epoch 6/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6670 - accuracy: 0.5909 - val_loss: 0.6644 - val_accuracy: 0.6004
# Epoch 7/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6664 - accuracy: 0.5907 - val_loss: 0.6629 - val_accuracy: 0.6010
# Epoch 8/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6652 - accuracy: 0.5935 - val_loss: 0.6653 - val_accuracy: 0.5974
# Epoch 9/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6651 - accuracy: 0.5938 - val_loss: 0.6633 - val_accuracy: 0.5962
# Epoch 10/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6639 - accuracy: 0.5963 - val_loss: 0.6637 - val_accuracy: 0.6005
# Epoch 11/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6632 - accuracy: 0.5954 - val_loss: 0.6662 - val_accuracy: 0.5923
# Epoch 12/500
# 710/710 [==============================] - 2s 4ms/step - loss: 0.6635 - accuracy: 0.5969 - val_loss: 0.6651 - val_accuracy: 0.6015
# Epoch 13/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6618 - accuracy: 0.5975 - val_loss: 0.6660 - val_accuracy: 0.5979
# Epoch 14/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6616 - accuracy: 0.5977 - val_loss: 0.6637 - val_accuracy: 0.5931
# Epoch 15/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6613 - accuracy: 0.5994 - val_loss: 0.6670 - val_accuracy: 0.5905
# Epoch 16/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6604 - accuracy: 0.6018 - val_loss: 0.6647 - val_accuracy: 0.6024
# Epoch 17/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6602 - accuracy: 0.5991 - val_loss: 0.6631 - val_accuracy: 0.5990
# Epoch 18/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6597 - accuracy: 0.6019 - val_loss: 0.6645 - val_accuracy: 0.6007
# Epoch 19/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6593 - accuracy: 0.5996 - val_loss: 0.6644 - val_accuracy: 0.5987
# Epoch 20/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6584 - accuracy: 0.6011 - val_loss: 0.6625 - val_accuracy: 0.6030
# Epoch 21/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6580 - accuracy: 0.6023 - val_loss: 0.6611 - val_accuracy: 0.6025
# Epoch 22/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6583 - accuracy: 0.6015 - val_loss: 0.6634 - val_accuracy: 0.5984
# Epoch 23/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6577 - accuracy: 0.6015 - val_loss: 0.6631 - val_accuracy: 0.6013
# Epoch 24/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6563 - accuracy: 0.6038 - val_loss: 0.6643 - val_accuracy: 0.6014
# Epoch 25/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6558 - accuracy: 0.6038 - val_loss: 0.6645 - val_accuracy: 0.5961
# Epoch 26/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6573 - accuracy: 0.6020 - val_loss: 0.6635 - val_accuracy: 0.6023
# Epoch 27/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6564 - accuracy: 0.6032 - val_loss: 0.6649 - val_accuracy: 0.6023
# Epoch 28/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6551 - accuracy: 0.6057 - val_loss: 0.6650 - val_accuracy: 0.5962
# Epoch 29/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6553 - accuracy: 0.6065 - val_loss: 0.6618 - val_accuracy: 0.6007
# Epoch 30/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6545 - accuracy: 0.6073 - val_loss: 0.6647 - val_accuracy: 0.5969
# Epoch 31/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6539 - accuracy: 0.6097 - val_loss: 0.6632 - val_accuracy: 0.6007
# Epoch 32/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6547 - accuracy: 0.6063 - val_loss: 0.6620 - val_accuracy: 0.6037
# Epoch 33/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6534 - accuracy: 0.6081 - val_loss: 0.6644 - val_accuracy: 0.6012
# Epoch 34/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6533 - accuracy: 0.6072 - val_loss: 0.6663 - val_accuracy: 0.5975
# Epoch 35/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6526 - accuracy: 0.6089 - val_loss: 0.6636 - val_accuracy: 0.5999
# Epoch 36/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6532 - accuracy: 0.6065 - val_loss: 0.6636 - val_accuracy: 0.5950
# Epoch 37/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6530 - accuracy: 0.6089 - val_loss: 0.6644 - val_accuracy: 0.5975
# Epoch 38/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.6088 - val_loss: 0.6639 - val_accuracy: 0.6010
# Epoch 39/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.6097 - val_loss: 0.6663 - val_accuracy: 0.5963
# Epoch 40/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6515 - accuracy: 0.6105 - val_loss: 0.6646 - val_accuracy: 0.5959
# Epoch 41/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6512 - accuracy: 0.6096 - val_loss: 0.6640 - val_accuracy: 0.6013
# Epoch 42/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6507 - accuracy: 0.6095 - val_loss: 0.6632 - val_accuracy: 0.6030
# Epoch 43/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6509 - accuracy: 0.6110 - val_loss: 0.6651 - val_accuracy: 0.5967
# Epoch 44/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6505 - accuracy: 0.6107 - val_loss: 0.6657 - val_accuracy: 0.6001
# Epoch 45/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6503 - accuracy: 0.6115 - val_loss: 0.6665 - val_accuracy: 0.5976
# Epoch 46/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6499 - accuracy: 0.6108 - val_loss: 0.6639 - val_accuracy: 0.6028
# Epoch 47/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6498 - accuracy: 0.6091 - val_loss: 0.6656 - val_accuracy: 0.5939
# Epoch 48/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6491 - accuracy: 0.6136 - val_loss: 0.6630 - val_accuracy: 0.5948
# Epoch 49/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6489 - accuracy: 0.6120 - val_loss: 0.6643 - val_accuracy: 0.6020
# Epoch 50/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6485 - accuracy: 0.6123 - val_loss: 0.6658 - val_accuracy: 0.5979
# Epoch 51/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6479 - accuracy: 0.6136 - val_loss: 0.6656 - val_accuracy: 0.5965
# Epoch 52/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6475 - accuracy: 0.6123 - val_loss: 0.6637 - val_accuracy: 0.6009
# 345/345 [==============================] - 1s 2ms/step - loss: 0.6706 - accuracy: 0.5814
# 345/345 [==============================] - 1s 2ms/step
# Accuracy for iteration 2: 0.58
# Iteration 3
# Epoch 1/500
# 709/709 [==============================] - 4s 4ms/step - loss: 0.6841 - accuracy: 0.5543 - val_loss: 0.6692 - val_accuracy: 0.5932
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6755 - accuracy: 0.5766 - val_loss: 0.6648 - val_accuracy: 0.5931
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6724 - accuracy: 0.5811 - val_loss: 0.6640 - val_accuracy: 0.5966
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6705 - accuracy: 0.5851 - val_loss: 0.6660 - val_accuracy: 0.5924
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6690 - accuracy: 0.5871 - val_loss: 0.6675 - val_accuracy: 0.5987
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6674 - accuracy: 0.5875 - val_loss: 0.6619 - val_accuracy: 0.6014
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6661 - accuracy: 0.5901 - val_loss: 0.6625 - val_accuracy: 0.5987
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6653 - accuracy: 0.5917 - val_loss: 0.6629 - val_accuracy: 0.6040
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6646 - accuracy: 0.5913 - val_loss: 0.6651 - val_accuracy: 0.5954
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6646 - accuracy: 0.5918 - val_loss: 0.6640 - val_accuracy: 0.5980
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6631 - accuracy: 0.5960 - val_loss: 0.6618 - val_accuracy: 0.6053
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6634 - accuracy: 0.5949 - val_loss: 0.6646 - val_accuracy: 0.6058
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6618 - accuracy: 0.5970 - val_loss: 0.6625 - val_accuracy: 0.6034
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6615 - accuracy: 0.5959 - val_loss: 0.6652 - val_accuracy: 0.6009
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6612 - accuracy: 0.5964 - val_loss: 0.6638 - val_accuracy: 0.6063
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6606 - accuracy: 0.5971 - val_loss: 0.6642 - val_accuracy: 0.5950
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6598 - accuracy: 0.5986 - val_loss: 0.6623 - val_accuracy: 0.6029
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6595 - accuracy: 0.6000 - val_loss: 0.6612 - val_accuracy: 0.6032
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6596 - accuracy: 0.5998 - val_loss: 0.6642 - val_accuracy: 0.6049
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6587 - accuracy: 0.6002 - val_loss: 0.6616 - val_accuracy: 0.6102
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6580 - accuracy: 0.5997 - val_loss: 0.6615 - val_accuracy: 0.6053
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6582 - accuracy: 0.5994 - val_loss: 0.6637 - val_accuracy: 0.6005
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6576 - accuracy: 0.5997 - val_loss: 0.6639 - val_accuracy: 0.6017
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6571 - accuracy: 0.6014 - val_loss: 0.6630 - val_accuracy: 0.6079
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6569 - accuracy: 0.6008 - val_loss: 0.6616 - val_accuracy: 0.6031
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6564 - accuracy: 0.6032 - val_loss: 0.6643 - val_accuracy: 0.6037
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6554 - accuracy: 0.6021 - val_loss: 0.6628 - val_accuracy: 0.6024
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6555 - accuracy: 0.6038 - val_loss: 0.6617 - val_accuracy: 0.6052
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6553 - accuracy: 0.6053 - val_loss: 0.6624 - val_accuracy: 0.6021
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6548 - accuracy: 0.6045 - val_loss: 0.6650 - val_accuracy: 0.6026
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6547 - accuracy: 0.6050 - val_loss: 0.6631 - val_accuracy: 0.6077
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6535 - accuracy: 0.6071 - val_loss: 0.6626 - val_accuracy: 0.6078
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6536 - accuracy: 0.6059 - val_loss: 0.6625 - val_accuracy: 0.6087
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6539 - accuracy: 0.6061 - val_loss: 0.6644 - val_accuracy: 0.6040
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6523 - accuracy: 0.6065 - val_loss: 0.6644 - val_accuracy: 0.6033
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6533 - accuracy: 0.6058 - val_loss: 0.6639 - val_accuracy: 0.6068
# Epoch 37/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6524 - accuracy: 0.6062 - val_loss: 0.6642 - val_accuracy: 0.6012
# Epoch 38/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.6061 - val_loss: 0.6667 - val_accuracy: 0.6006
# Epoch 39/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6515 - accuracy: 0.6060 - val_loss: 0.6669 - val_accuracy: 0.5979
# Epoch 40/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6518 - accuracy: 0.6067 - val_loss: 0.6632 - val_accuracy: 0.6070
# 343/343 [==============================] - 1s 2ms/step - loss: 0.6663 - accuracy: 0.5989
# 343/343 [==============================] - 1s 2ms/step
# Accuracy for iteration 3: 0.60
# Iteration 4
# Epoch 1/500
# 709/709 [==============================] - 4s 4ms/step - loss: 0.6820 - accuracy: 0.5609 - val_loss: 0.6764 - val_accuracy: 0.5756
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6748 - accuracy: 0.5790 - val_loss: 0.6720 - val_accuracy: 0.5809
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6716 - accuracy: 0.5848 - val_loss: 0.6711 - val_accuracy: 0.5810
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6699 - accuracy: 0.5860 - val_loss: 0.6714 - val_accuracy: 0.5815
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6683 - accuracy: 0.5880 - val_loss: 0.6709 - val_accuracy: 0.5884
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6671 - accuracy: 0.5907 - val_loss: 0.6703 - val_accuracy: 0.5892
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6659 - accuracy: 0.5912 - val_loss: 0.6697 - val_accuracy: 0.5882
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6651 - accuracy: 0.5929 - val_loss: 0.6691 - val_accuracy: 0.5907
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6642 - accuracy: 0.5955 - val_loss: 0.6698 - val_accuracy: 0.5889
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6637 - accuracy: 0.5944 - val_loss: 0.6690 - val_accuracy: 0.5922
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6625 - accuracy: 0.5960 - val_loss: 0.6705 - val_accuracy: 0.5859
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6616 - accuracy: 0.5987 - val_loss: 0.6695 - val_accuracy: 0.5914
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6610 - accuracy: 0.5986 - val_loss: 0.6692 - val_accuracy: 0.5864
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6603 - accuracy: 0.6007 - val_loss: 0.6673 - val_accuracy: 0.5923
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6597 - accuracy: 0.6010 - val_loss: 0.6686 - val_accuracy: 0.5944
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6587 - accuracy: 0.6025 - val_loss: 0.6670 - val_accuracy: 0.5946
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6587 - accuracy: 0.6020 - val_loss: 0.6682 - val_accuracy: 0.5898
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6582 - accuracy: 0.6036 - val_loss: 0.6683 - val_accuracy: 0.5883
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6576 - accuracy: 0.6042 - val_loss: 0.6680 - val_accuracy: 0.5961
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6566 - accuracy: 0.6033 - val_loss: 0.6688 - val_accuracy: 0.5927
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6567 - accuracy: 0.6032 - val_loss: 0.6685 - val_accuracy: 0.5956
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6559 - accuracy: 0.6045 - val_loss: 0.6686 - val_accuracy: 0.5964
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6555 - accuracy: 0.6076 - val_loss: 0.6683 - val_accuracy: 0.5971
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6547 - accuracy: 0.6060 - val_loss: 0.6681 - val_accuracy: 0.5945
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6547 - accuracy: 0.6071 - val_loss: 0.6691 - val_accuracy: 0.5966
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6541 - accuracy: 0.6090 - val_loss: 0.6700 - val_accuracy: 0.5898
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6535 - accuracy: 0.6083 - val_loss: 0.6672 - val_accuracy: 0.5923
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6534 - accuracy: 0.6087 - val_loss: 0.6699 - val_accuracy: 0.5918
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6532 - accuracy: 0.6097 - val_loss: 0.6673 - val_accuracy: 0.5952
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6529 - accuracy: 0.6090 - val_loss: 0.6671 - val_accuracy: 0.5999
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6525 - accuracy: 0.6102 - val_loss: 0.6689 - val_accuracy: 0.5962
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6520 - accuracy: 0.6092 - val_loss: 0.6692 - val_accuracy: 0.5941
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6514 - accuracy: 0.6105 - val_loss: 0.6691 - val_accuracy: 0.5940
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6511 - accuracy: 0.6107 - val_loss: 0.6675 - val_accuracy: 0.5970
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6508 - accuracy: 0.6110 - val_loss: 0.6675 - val_accuracy: 0.5950
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6508 - accuracy: 0.6120 - val_loss: 0.6683 - val_accuracy: 0.5957
# Epoch 37/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6495 - accuracy: 0.6142 - val_loss: 0.6698 - val_accuracy: 0.5927
# Epoch 38/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6495 - accuracy: 0.6138 - val_loss: 0.6700 - val_accuracy: 0.5949
# Epoch 39/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6491 - accuracy: 0.6131 - val_loss: 0.6706 - val_accuracy: 0.5913
# Epoch 40/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6488 - accuracy: 0.6125 - val_loss: 0.6695 - val_accuracy: 0.5931
# Epoch 41/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6482 - accuracy: 0.6136 - val_loss: 0.6690 - val_accuracy: 0.5964
# Epoch 42/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6492 - accuracy: 0.6131 - val_loss: 0.6681 - val_accuracy: 0.5968
# Epoch 43/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6473 - accuracy: 0.6148 - val_loss: 0.6678 - val_accuracy: 0.5969
# Epoch 44/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6480 - accuracy: 0.6143 - val_loss: 0.6688 - val_accuracy: 0.5948
# Epoch 45/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6475 - accuracy: 0.6149 - val_loss: 0.6688 - val_accuracy: 0.5979
# Epoch 46/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6474 - accuracy: 0.6153 - val_loss: 0.6689 - val_accuracy: 0.5963
# Epoch 47/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6464 - accuracy: 0.6157 - val_loss: 0.6683 - val_accuracy: 0.5994
# Epoch 48/500
# 709/709 [==============================] - 3s 5ms/step - loss: 0.6460 - accuracy: 0.6172 - val_loss: 0.6695 - val_accuracy: 0.5951
# Epoch 49/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6464 - accuracy: 0.6154 - val_loss: 0.6693 - val_accuracy: 0.5973
# Epoch 50/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6450 - accuracy: 0.6185 - val_loss: 0.6687 - val_accuracy: 0.5984
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6658 - accuracy: 0.6024
# 354/354 [==============================] - 1s 2ms/step
# Accuracy for iteration 4: 0.60
# Average Accuracy across 4 iterations: 0.60

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.58137 - 0.60240

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 350/350 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.60      0.61      0.60      5596
#         High       0.60      0.59      0.60      5596
#
#     accuracy                           0.60     11192
#    macro avg       0.60      0.60      0.60     11192
# weighted avg       0.60      0.60      0.60     11192

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 354/354 [==============================] - 1s 1ms/step
#               precision    recall  f1-score   support
#
#          Low       0.60      0.60      0.60      5659
#         High       0.60      0.60      0.60      5659
#
#     accuracy                           0.60     11318
#    macro avg       0.60      0.60      0.60     11318
# weighted avg       0.60      0.60      0.60     11318
