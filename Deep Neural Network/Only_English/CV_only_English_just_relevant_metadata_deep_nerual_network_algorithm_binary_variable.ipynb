# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts', 'Image_Count', 'Is_English']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep #text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 4
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Normalize the selected features
    columns_to_normalize = ['Followers', 'Followees', 'Posts']
    scaler = StandardScaler().fit(train_data[columns_to_normalize])
    train_data.loc[:, columns_to_normalize] = scaler.transform(train_data[columns_to_normalize])
    val_data.loc[:, columns_to_normalize] = scaler.transform(val_data[columns_to_normalize])
    test_data.loc[:, columns_to_normalize] = scaler.transform(test_data[columns_to_normalize])

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 706/706 [==============================] - 3s 3ms/step - loss: 0.6557 - accuracy: 0.6166 - val_loss: 0.6526 - val_accuracy: 0.6197
# Epoch 2/500
# 706/706 [==============================] - 2s 2ms/step - loss: 0.6501 - accuracy: 0.6218 - val_loss: 0.6533 - val_accuracy: 0.6119
# Epoch 3/500
# 706/706 [==============================] - 2s 2ms/step - loss: 0.6491 - accuracy: 0.6229 - val_loss: 0.6519 - val_accuracy: 0.6184
# Epoch 4/500
# 706/706 [==============================] - 2s 3ms/step - loss: 0.
500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6495 - accuracy: 0.6236 - val_loss: 0.6407 - val_accuracy: 0.6223
# Epoch 4/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6485 - accuracy: 0.6231 - val_loss: 0.6407 - val_accuracy: 0.6238
# Epoch 5/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6484 - accuracy: 0.6238 - val_loss: 0.6410 - val_accuracy: 0.6239
# Epoch 6/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6481 - accuracy: 0.6237 - val_loss: 0.6416 - val_accuracy: 0.6244
# Epoch 7/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6482 - accuracy: 0.6231 - val_loss: 0.6420 - val_accuracy: 0.6227
# Epoch 8/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6481 - accuracy: 0.6233 - val_loss: 0.6438 - val_accuracy: 0.6268
# Epoch 9/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6478 - accuracy: 0.6243 - val_loss: 0.6435 - val_accuracy: 0.6228
# Epoch 10/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6477 - accuracy: 0.6241 - val_loss: 0.6419 - val_accuracy: 0.6244
# Epoch 11/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6474 - accuracy: 0.6241 - val_loss: 0.6426 - val_accuracy: 0.6281
# Epoch 12/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6475 - accuracy: 0.6244 - val_loss: 0.6431 - val_accuracy: 0.6243
# Epoch 13/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6477 - accuracy: 0.6229 - val_loss: 0.6433 - val_accuracy: 0.6257
# Epoch 14/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6475 - accuracy: 0.6243 - val_loss: 0.6425 - val_accuracy: 0.6247
# Epoch 15/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6474 - accuracy: 0.6242 - val_loss: 0.6424 - val_accuracy: 0.6230
# Epoch 16/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6471 - accuracy: 0.6248 - val_loss: 0.6423 - val_accuracy: 0.6243
# Epoch 17/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6473 - accuracy: 0.6237 - val_loss: 0.6423 - val_accuracy: 0.6253
# Epoch 18/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6473 - accuracy: 0.6248 - val_loss: 0.6436 - val_accuracy: 0.6216
# Epoch 19/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6471 - accuracy: 0.6245 - val_loss: 0.6442 - val_accuracy: 0.6258
# Epoch 20/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6470 - accuracy: 0.6261 - val_loss: 0.6430 - val_accuracy: 0.6270
# Epoch 21/500
# 710/710 [==============================] - 2s 3ms/step - loss: 0.6472 - accuracy: 0.6246 - val_loss: 0.6434 - val_accuracy: 0.6226
# Epoch 22/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6470 - accuracy: 0.6259 - val_loss: 0.6429 - val_accuracy: 0.6260
# Epoch 23/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6468 - accuracy: 0.6259 - val_loss: 0.6442 - val_accuracy: 0.6265
# Epoch 24/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6470 - accuracy: 0.6267 - val_loss: 0.6426 - val_accuracy: 0.6268
# Epoch 25/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6471 - accuracy: 0.6247 - val_loss: 0.6435 - val_accuracy: 0.6283
# Epoch 26/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6469 - accuracy: 0.6258 - val_loss: 0.6432 - val_accuracy: 0.6273
# Epoch 27/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6469 - accuracy: 0.6255 - val_loss: 0.6442 - val_accuracy: 0.6284
# Epoch 28/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6472 - accuracy: 0.6252 - val_loss: 0.6430 - val_accuracy: 0.6281
# Epoch 29/500
# 710/710 [==============================] - 1s 2ms/step - loss: 0.6466 - accuracy: 0.6260 - val_loss: 0.6431 - val_accuracy: 0.6254
# Epoch 30/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.6467 - accuracy: 0.6258 - val_loss: 0.6435 - val_accuracy: 0.6283
# Epoch 31/500
# 710/710 [==============================] - 2s 2ms/step - loss: 0.
500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6471 - accuracy: 0.6232 - val_loss: 0.6504 - val_accuracy: 0.6254
# Epoch 10/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6469 - accuracy: 0.6231 - val_loss: 0.6503 - val_accuracy: 0.6245
# Epoch 11/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6468 - accuracy: 0.6238 - val_loss: 0.6505 - val_accuracy: 0.6240
# Epoch 12/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6469 - accuracy: 0.6241 - val_loss: 0.6507 - val_accuracy: 0.6210
# Epoch 13/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6470 - accuracy: 0.6239 - val_loss: 0.6506 - val_accuracy: 0.6188
# Epoch 14/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6466 - accuracy: 0.6244 - val_loss: 0.6500 - val_accuracy: 0.6201
# Epoch 15/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6467 - accuracy: 0.6240 - val_loss: 0.6514 - val_accuracy: 0.6290
# Epoch 16/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6466 - accuracy: 0.6242 - val_loss: 0.6495 - val_accuracy: 0.6220
# Epoch 17/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6243 - val_loss: 0.6497 - val_accuracy: 0.6256
# Epoch 18/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6467 - accuracy: 0.6251 - val_loss: 0.6510 - val_accuracy: 0.6220
# Epoch 19/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6463 - accuracy: 0.6237 - val_loss: 0.6495 - val_accuracy: 0.6242
# Epoch 20/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6463 - accuracy: 0.6256 - val_loss: 0.6510 - val_accuracy: 0.6296
# Epoch 21/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6463 - accuracy: 0.6243 - val_loss: 0.6494 - val_accuracy: 0.6312
# Epoch 22/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6464 - accuracy: 0.6246 - val_loss: 0.6507 - val_accuracy: 0.6235
# Epoch 23/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6463 - accuracy: 0.6250 - val_loss: 0.6500 - val_accuracy: 0.6224
# Epoch 24/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6462 - accuracy: 0.6247 - val_loss: 0.6506 - val_accuracy: 0.6249
# Epoch 25/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6463 - accuracy: 0.6245 - val_loss: 0.6498 - val_accuracy: 0.6254
# Epoch 26/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6462 - accuracy: 0.6250 - val_loss: 0.6501 - val_accuracy: 0.6279
# Epoch 27/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6463 - accuracy: 0.6239 - val_loss: 0.6506 - val_accuracy: 0.6293
# Epoch 28/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6460 - accuracy: 0.6255 - val_loss: 0.6505 - val_accuracy: 0.6276
# Epoch 29/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6460 - accuracy: 0.6249 - val_loss: 0.6508 - val_accuracy: 0.6256
# Epoch 30/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6462 - accuracy: 0.6250 - val_loss: 0.6509 - val_accuracy: 0.6260
# Epoch 31/500
# 709/709 [==============================] - 1s 2ms/step - loss: 0.6460 - accuracy: 0.6245 - val_loss: 0.6505 - val_accuracy: 0.6294
# Epoch 32/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6462 - accuracy: 0.6255 - val_loss: 0.6499 - val_accuracy: 0.6247
# Epoch 33/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6461 - accuracy: 0.6243 - val_loss: 0.6511 - val_accuracy: 0.6255
# Epoch 34/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6462 - accuracy: 0.6239 - val_loss: 0.6504 - val_accuracy: 0.6285
# Epoch 35/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6457 - accuracy: 0.6249 - val_loss: 0.6523 - val_accuracy: 0.6260
# Epoch 36/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6250 - val_loss: 0.6507 - val_accuracy: 0.6234
# Epoch 37/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6246 - val_loss: 0.6499 - val_accuracy: 0.6273
# Epoch 38/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6255 - val_loss: 0.6512 - val_accuracy: 0.6265
# Epoch 39/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6461 - accuracy: 0.6247 - val_loss: 0.6498 - val_accuracy: 0.6332
# Epoch 40/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6456 - accuracy: 0.6251 - val_loss: 0.6513 - val_accuracy: 0.6254
# Epoch 41/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6255 - val_loss: 0.6513 - val_accuracy: 0.6223
# Epoch 42/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6460 - accuracy: 0.6253 - val_loss: 0.6507 - val_accuracy: 0.6270
# Epoch 43/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6252 - val_loss: 0.6509 - val_accuracy: 0.6255
# Epoch 44/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6457 - accuracy: 0.6251 - val_loss: 0.6498 - val_accuracy: 0.6296
# Epoch 45/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6256 - val_loss: 0.6528 - val_accuracy: 0.6232
# Epoch 46/500
# 709/709 [==============================] - 1s 2ms/step - loss: 0.6458 - accuracy: 0.6250 - val_loss: 0.6514 - val_accuracy: 0.6242
# Epoch 47/500
# 709/709 [==============================] - 1s 2ms/step - loss: 0.6461 - accuracy: 0.6258 - val_loss: 0.6512 - val_accuracy: 0.6273
# Epoch 48/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6247 - val_loss: 0.6513 - val_accuracy: 0.6240
# Epoch 49/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6458 - accuracy: 0.6243 - val_loss: 0.6513 - val_accuracy: 0.6219
# Epoch 50/500
# 709/709 [==============================] - 1s 2ms/step - loss: 0.6456 - accuracy: 0.6251 - val_loss: 0.6518 - val_accuracy: 0.6237
# Epoch 51/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6457 - accuracy: 0.6252 - val_loss: 0.6524 - val_accuracy: 0.6229
# Epoch 52/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6456 - accuracy: 0.6255 - val_loss: 0.6512 - val_accuracy: 0.6207
# Epoch 53/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6457 - accuracy: 0.6247 - val_loss: 0.6505 - val_accuracy: 0.6292
# Epoch 54/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6457 - accuracy: 0.6247 - val_loss: 0.6510 - val_accuracy: 0.6288
# Epoch 55/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6456 - accuracy: 0.6244 - val_loss: 0.6501 - val_accuracy: 0.6261
# Epoch 56/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6458 - accuracy: 0.6251 - val_loss: 0.6522 - val_accuracy: 0.6273
# Epoch 57/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6250 - val_loss: 0.6511 - val_accuracy: 0.6279
# Epoch 58/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6457 - accuracy: 0.6257 - val_loss: 0.6507 - val_accuracy: 0.6287
# Epoch 59/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6459 - accuracy: 0.6255 - val_loss: 0.6507 - val_accuracy: 0.6262
# 343/343 [==============================] - 1s 1ms/step - loss: 0.6453 - accuracy: 0.6348
# 343/343 [==============================] - 1s 1ms/step
# Accuracy for iteration 3: 0.63
# Iteration 4
# Epoch 1/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6517 - accuracy: 0.6195 - val_loss: 0.6562 - val_accuracy: 0.6093
# Epoch 2/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6491 - accuracy: 0.6236 - val_loss: 0.6558 - val_accuracy: 0.6137
# Epoch 3/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6485 - accuracy: 0.6232 - val_loss: 0.6557 - val_accuracy: 0.6098
# Epoch 4/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6483 - accuracy: 0.6238 - val_loss: 0.6554 - val_accuracy: 0.6112
# Epoch 5/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6480 - accuracy: 0.6234 - val_loss: 0.6556 - val_accuracy: 0.6096
# Epoch 6/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6479 - accuracy: 0.6234 - val_loss: 0.6558 - val_accuracy: 0.6129
# Epoch 7/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6477 - accuracy: 0.6240 - val_loss: 0.6555 - val_accuracy: 0.6086
# Epoch 8/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6474 - accuracy: 0.6238 - val_loss: 0.6556 - val_accuracy: 0.6129
# Epoch 9/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6471 - accuracy: 0.6250 - val_loss: 0.6554 - val_accuracy: 0.6144
# Epoch 10/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6475 - accuracy: 0.6243 - val_loss: 0.6552 - val_accuracy: 0.6087
# Epoch 11/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6470 - accuracy: 0.6237 - val_loss: 0.6555 - val_accuracy: 0.6166
# Epoch 12/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6469 - accuracy: 0.6241 - val_loss: 0.6560 - val_accuracy: 0.6108
# Epoch 13/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6472 - accuracy: 0.6239 - val_loss: 0.6550 - val_accuracy: 0.6162
# Epoch 14/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6468 - accuracy: 0.6236 - val_loss: 0.6550 - val_accuracy: 0.6105
# Epoch 15/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6468 - accuracy: 0.6251 - val_loss: 0.6546 - val_accuracy: 0.6103
# Epoch 16/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6469 - accuracy: 0.6236 - val_loss: 0.6552 - val_accuracy: 0.6142
# Epoch 17/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6471 - accuracy: 0.6241 - val_loss: 0.6558 - val_accuracy: 0.6066
# Epoch 18/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6240 - val_loss: 0.6562 - val_accuracy: 0.6094
# Epoch 19/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6466 - accuracy: 0.6240 - val_loss: 0.6551 - val_accuracy: 0.6088
# Epoch 20/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6467 - accuracy: 0.6246 - val_loss: 0.6553 - val_accuracy: 0.6122
# Epoch 21/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6466 - accuracy: 0.6243 - val_loss: 0.6549 - val_accuracy: 0.6115
# Epoch 22/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6468 - accuracy: 0.6235 - val_loss: 0.6548 - val_accuracy: 0.6086
# Epoch 23/500
# 709/709 [==============================] - 2s 2ms/step - loss: 0.6465 - accuracy: 0.6244 - val_loss: 0.6564 - val_accuracy: 0.6148
# Epoch 24/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6470 - accuracy: 0.6244 - val_loss: 0.6557 - val_accuracy: 0.6086
# Epoch 25/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6249 - val_loss: 0.6556 - val_accuracy: 0.6133
# Epoch 26/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6469 - accuracy: 0.6236 - val_loss: 0.6553 - val_accuracy: 0.6119
# Epoch 27/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6465 - accuracy: 0.6235 - val_loss: 0.6558 - val_accuracy: 0.6092
# Epoch 28/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6464 - accuracy: 0.6246 - val_loss: 0.6555 - val_accuracy: 0.6073
# Epoch 29/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6465 - accuracy: 0.6244 - val_loss: 0.6556 - val_accuracy: 0.6122
# Epoch 30/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6239 - val_loss: 0.6559 - val_accuracy: 0.6049
# Epoch 31/500
# 709/709 [==============================] - 2s 3ms/step - loss: 0.6466 - accuracy: 0.6244 - val_loss: 0.6553 - val_accuracy: 0.6115
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6363 - accuracy: 0.6445
# 354/354 [==============================] - 1s 2ms/step
# Accuracy for iteration 4: 0.64
# Average Accuracy across 4 iterations: 0.63

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.62698 - 0.64455

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep #text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 350/350 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#          Low       0.63      0.56      0.59      5596
#         High       0.60      0.67      0.64      5596
#
#     accuracy                           0.62     11192
#    macro avg       0.62      0.62      0.62     11192
# weighted avg       0.62      0.62      0.62     11192

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 354/354 [==============================] - 0s 1ms/step
#               precision    recall  f1-score   support
#
#          Low       0.66      0.61      0.63      5659
#         High       0.63      0.68      0.66      5659
#
#     accuracy                           0.64     11318
#    macro avg       0.65      0.64      0.64     11318
# weighted avg       0.65      0.64      0.64     11318
