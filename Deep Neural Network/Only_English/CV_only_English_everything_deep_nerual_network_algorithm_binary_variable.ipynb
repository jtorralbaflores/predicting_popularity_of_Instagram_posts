# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts',
                              'Year', 'Month', 'Day of Week (String)', 'Hour', 'Language', 'Is_English', 'Image_Count', 'Sponsorship label', 'is_video']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep + text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)
# Out:
#         Username              post_id  like_count  comment_count  is_video  \
# 0  00_rocketgirl  1354915397698488656         293              6     False
# 1  00_rocketgirl  1666974101448132749          73              2     False
# 2  00_rocketgirl  1768273356099895999         164              4     False
# 3  00_rocketgirl  1770557472379860655         474             18     False
# 4  00_rocketgirl  1899586748141399903         116              2     False
# 5         0720_b  1828882589862019412        1835             13     False
# 6         0720_b  1996580229074923796        1170              2     False
# 7         0720_b  2021587997624266181         820              2     False
# 8         0720_b  2021587997624266181         820              2     False
# 9         0hkris  1514786978688118458         269              0     False
#
#    Sponsorship label  Followers  Followees  Posts  Year  ...  text_758  \
# 0                  0       6453        710   1059  2016  ... -0.155746
# 1                  0       6453        710   1059  2017  ... -0.247792
# 2                  0       6453        710   1059  2018  ... -0.089539
# 3                  0       6453        710   1059  2018  ... -0.215643
# 4                  0       6453        710   1059  2018  ... -0.112963
# 5                  0      31521       2202    601  2018  ...  0.013015
# 6                  0      31521       2202    601  2019  ...  0.027090
# 7                  0      31521       2202    601  2019  ...  0.043861
# 8                  0      31521       2202    601  2019  ...  0.043861
# 9                  0      12630       7069    261  2017  ... -0.147682
#
#    text_759  text_760  text_761  text_762  text_763  text_764  text_765  \
# 0 -0.017703 -0.091135  0.058261  0.159358  0.032952 -0.012526 -0.204870
# 1  0.015757 -0.037442 -0.018389  0.203054  0.074983  0.049237 -0.213263
# 2 -0.097885 -0.226008  0.053440  0.047846  0.004013 -0.182280 -0.174142
# 3 -0.101936 -0.123704  0.029802  0.113963  0.098773 -0.108283 -0.082098
# 4 -0.036261 -0.078814  0.114615  0.149342  0.011751 -0.150317 -0.156846
# 5 -0.100801 -0.067726  0.076079  0.248161  0.093687 -0.052417 -0.504811
# 6 -0.154764 -0.085396  0.070190  0.285331  0.098012 -0.022090 -0.441710
# 7 -0.152151 -0.037170  0.045965  0.204610  0.092008 -0.048374 -0.509754
# 8 -0.152151 -0.037170  0.045965  0.204610  0.092008 -0.048374 -0.509754
# 9 -0.036988 -0.208915  0.104713  0.120187  0.093342  0.097392 -0.009471
#
#    text_766  text_767
# 0  0.062999  0.075272
# 1 -0.012400  0.147600
# 2  0.094179  0.080168
# 3  0.045219  0.057346
# 4  0.141513  0.093924
# 5  0.080545 -0.086281
# 6  0.055267 -0.116288
# 7  0.074065 -0.092127
# 8  0.074065 -0.092127
# 9  0.012900  0.064740
#
# [10 rows x 2831 columns]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %%
# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# Columns to one-hot encode
columns_to_encode = ['Year', 'Month', 'Hour', 'Day of Week (String)']

# Apply one-hot encoding
data_2 = pd.get_dummies(data_2, columns=columns_to_encode)

# Find the new one-hot encoded columns
encoded_columns = data_2.columns[data_2.columns.str.startswith(tuple(columns_to_encode))]

# Convert only the new one-hot encoded columns and boolean columns to int
data_2[encoded_columns] = data_2[encoded_columns].astype(int)

# Convert English column to integer
data_2['Is_English'] = data_2['Is_English'].astype(int)
data_2['is_video'] = data_2['is_video'].astype(int)
data_2['Sponsorship label'] = data_2['Sponsorship label'].astype(int)

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 4
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Normalize the selected features
    columns_to_normalize = ['Followers', 'Followees', 'Posts']
    scaler = StandardScaler().fit(train_data[columns_to_normalize])
    train_data.loc[:, columns_to_normalize] = scaler.transform(train_data[columns_to_normalize])
    val_data.loc[:, columns_to_normalize] = scaler.transform(val_data[columns_to_normalize])
    test_data.loc[:, columns_to_normalize] = scaler.transform(test_data[columns_to_normalize])

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 706/706 [==============================] - 8s 6ms/step - loss: 0.6869 - accuracy: 0.5469 - val_loss: 0.6781 - val_accuracy: 0.5696
# Epoch 2/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6718 - accuracy: 0.5782 - val_loss: 0.6716 - val_accuracy: 0.5759
# Epoch 3/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6598 - accuracy: 0.5939 - val_loss: 0.6488 - val_accuracy: 0.6304
# Epoch 4/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6514 - accuracy: 0.6065 - val_loss: 0.6536 - val_accuracy: 0.6172
# Epoch 5/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6445 - accuracy: 0.6154 - val_loss: 0.6394 - val_accuracy: 0.6376
# Epoch 6/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6455 - accuracy: 0.6200 - val_loss: 0.6471 - val_accuracy: 0.6311
# Epoch 7/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6418 - accuracy: 0.6252 - val_loss: 0.6337 - val_accuracy: 0.6464
# Epoch 8/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6413 - accuracy: 0.6249 - val_loss: 0.6379 - val_accuracy: 0.6477
# Epoch 9/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6388 - accuracy: 0.6306 - val_loss: 0.6401 - val_accuracy: 0.6424
# Epoch 10/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6354 - accuracy: 0.6352 - val_loss: 0.6427 - val_accuracy: 0.6433
# Epoch 11/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6327 - accuracy: 0.6378 - val_loss: 0.6389 - val_accuracy: 0.6427
# Epoch 12/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6303 - accuracy: 0.6408 - val_loss: 0.6376 - val_accuracy: 0.6397
# Epoch 13/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6328 - accuracy: 0.6423 - val_loss: 0.6348 - val_accuracy: 0.6483
# Epoch 14/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6270 - accuracy: 0.6469 - val_loss: 0.6380 - val_accuracy: 0.6453
# Epoch 15/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6260 - accuracy: 0.6476 - val_loss: 0.6405 - val_accuracy: 0.6406
# Epoch 16/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6243 - accuracy: 0.6514 - val_loss: 0.6359 - val_accuracy: 0.6457
# Epoch 17/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6242 - accuracy: 0.6517 - val_loss: 0.6378 - val_accuracy: 0.6470
# Epoch 18/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6254 - accuracy: 0.6515 - val_loss: 0.6294 - val_accuracy: 0.6483
# Epoch 19/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6197 - accuracy: 0.6552 - val_loss: 0.6374 - val_accuracy: 0.6487
# Epoch 20/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6197 - accuracy: 0.6558 - val_loss: 0.6335 - val_accuracy: 0.6476
# Epoch 21/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6181 - accuracy: 0.6573 - val_loss: 0.6364 - val_accuracy: 0.6442
# Epoch 22/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6183 - accuracy: 0.6571 - val_loss: 0.6388 - val_accuracy: 0.6418
# Epoch 23/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6171 - accuracy: 0.6584 - val_loss: 0.6312 - val_accuracy: 0.6518
# Epoch 24/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6162 - accuracy: 0.6602 - val_loss: 0.6426 - val_accuracy: 0.6384
# Epoch 25/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6168 - accuracy: 0.6597 - val_loss: 0.6435 - val_accuracy: 0.6346
# Epoch 26/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6225 - accuracy: 0.6580 - val_loss: 0.6357 - val_accuracy: 0.6495
# Epoch 27/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6156 - accuracy: 0.6617 - val_loss: 0.6361 - val_accuracy: 0.6470
# Epoch 28/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6138 - accuracy: 0.6635 - val_loss: 0.6378 - val_accuracy: 0.6482
# Epoch 29/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6129 - accuracy: 0.6629 - val_loss: 0.6351 - val_accuracy: 0.6493
# Epoch 30/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6123 - accuracy: 0.6653 - val_loss: 0.6309 - val_accuracy: 0.6490
# Epoch 31/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6111 - accuracy: 0.6665 - val_loss: 0.6289 - val_accuracy: 0.6507
# Epoch 32/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6115 - accuracy: 0.6676 - val_loss: 0.6319 - val_accuracy: 0.6485
# Epoch 33/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6189 - accuracy: 0.6636 - val_loss: 0.6376 - val_accuracy: 0.6473
# Epoch 34/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6116 - accuracy: 0.6679 - val_loss: 0.6349 - val_accuracy: 0.6445
# Epoch 35/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6101 - accuracy: 0.6676 - val_loss: 0.6322 - val_accuracy: 0.6496
# Epoch 36/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6098 - accuracy: 0.6687 - val_loss: 0.6296 - val_accuracy: 0.6503
# Epoch 37/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6087 - accuracy: 0.6687 - val_loss: 0.6275 - val_accuracy: 0.6514
# Epoch 38/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6083 - accuracy: 0.6700 - val_loss: 0.6325 - val_accuracy: 0.6506
# Epoch 39/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6073 - accuracy: 0.6715 - val_loss: 0.6351 - val_accuracy: 0.6493
# Epoch 40/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6081 - accuracy: 0.6692 - val_loss: 0.6378 - val_accuracy: 0.6434
# Epoch 41/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6070 - accuracy: 0.6711 - val_loss: 0.6326 - val_accuracy: 0.6507
# Epoch 42/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6069 - accuracy: 0.6699 - val_loss: 0.6312 - val_accuracy: 0.6465
# Epoch 43/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6159 - accuracy: 0.6670 - val_loss: 0.6323 - val_accuracy: 0.6492
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6314 - accuracy: 0.6487
# 363/363 [==============================] - 1s 2ms/step
# Accuracy for iteration 1: 0.65
# Iteration 2
# Epoch 1/500
# 710/710 [==============================] - 5s 6ms/step - loss: 0.6861 - accuracy: 0.5516 - val_loss: 0.6739 - val_accuracy: 0.5887
# Epoch 2/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6732 - accuracy: 0.5790 - val_loss: 0.6648 - val_accuracy: 0.6055
# Epoch 3/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6612 - accuracy: 0.5985 - val_loss: 0.6585 - val_accuracy: 0.6029
# Epoch 4/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6516 - accuracy: 0.6119 - val_loss: 0.6431 - val_accuracy: 0.6430
# Epoch 5/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6444 - accuracy: 0.6220 - val_loss: 0.6354 - val_accuracy: 0.6575
# Epoch 6/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6399 - accuracy: 0.6298 - val_loss: 0.6219 - val_accuracy: 0.6635
# Epoch 7/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6367 - accuracy: 0.6330 - val_loss: 0.6274 - val_accuracy: 0.6672
# Epoch 8/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6341 - accuracy: 0.6351 - val_loss: 0.6251 - val_accuracy: 0.6639
# Epoch 9/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6314 - accuracy: 0.6405 - val_loss: 0.6353 - val_accuracy: 0.6580
# Epoch 10/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6303 - accuracy: 0.6417 - val_loss: 0.6374 - val_accuracy: 0.6580
# Epoch 11/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6313 - accuracy: 0.6426 - val_loss: 0.6336 - val_accuracy: 0.6638
# Epoch 12/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6287 - accuracy: 0.6465 - val_loss: 0.6213 - val_accuracy: 0.6662
# Epoch 13/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6255 - accuracy: 0.6504 - val_loss: 0.6355 - val_accuracy: 0.6561
# Epoch 14/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6237 - accuracy: 0.6506 - val_loss: 0.6335 - val_accuracy: 0.6593
# Epoch 15/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6227 - accuracy: 0.6526 - val_loss: 0.6300 - val_accuracy: 0.6653
# Epoch 16/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6223 - accuracy: 0.6512 - val_loss: 0.6208 - val_accuracy: 0.6632
# Epoch 17/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6216 - accuracy: 0.6534 - val_loss: 0.6198 - val_accuracy: 0.6638
# Epoch 18/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6221 - accuracy: 0.6512 - val_loss: 0.6292 - val_accuracy: 0.6634
# Epoch 19/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6204 - accuracy: 0.6547 - val_loss: 0.6261 - val_accuracy: 0.6648
# Epoch 20/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6185 - accuracy: 0.6567 - val_loss: 0.6241 - val_accuracy: 0.6660
# Epoch 21/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6198 - accuracy: 0.6566 - val_loss: 0.6306 - val_accuracy: 0.6628
# Epoch 22/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6176 - accuracy: 0.6584 - val_loss: 0.6291 - val_accuracy: 0.6640
# Epoch 23/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6171 - accuracy: 0.6589 - val_loss: 0.6299 - val_accuracy: 0.6686
# Epoch 24/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6176 - accuracy: 0.6589 - val_loss: 0.6323 - val_accuracy: 0.6655
# Epoch 25/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6163 - accuracy: 0.6591 - val_loss: 0.6263 - val_accuracy: 0.6637
# Epoch 26/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6160 - accuracy: 0.6602 - val_loss: 0.6280 - val_accuracy: 0.6668
# Epoch 27/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6164 - accuracy: 0.6588 - val_loss: 0.6295 - val_accuracy: 0.6643
# Epoch 28/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6150 - accuracy: 0.6621 - val_loss: 0.6338 - val_accuracy: 0.6523
# Epoch 29/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6141 - accuracy: 0.6620 - val_loss: 0.6323 - val_accuracy: 0.6648
# Epoch 30/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6142 - accuracy: 0.6625 - val_loss: 0.6318 - val_accuracy: 0.6665
# Epoch 31/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6141 - accuracy: 0.6624 - val_loss: 0.6335 - val_accuracy: 0.6660
# Epoch 32/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6125 - accuracy: 0.6644 - val_loss: 0.6351 - val_accuracy: 0.6614
# Epoch 33/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6139 - accuracy: 0.6628 - val_loss: 0.6418 - val_accuracy: 0.6612
# Epoch 34/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6118 - accuracy: 0.6645 - val_loss: 0.6306 - val_accuracy: 0.6641
# Epoch 35/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6119 - accuracy: 0.6640 - val_loss: 0.6354 - val_accuracy: 0.6616
# Epoch 36/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6126 - accuracy: 0.6638 - val_loss: 0.6362 - val_accuracy: 0.6639
# Epoch 37/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6107 - accuracy: 0.6654 - val_loss: 0.6312 - val_accuracy: 0.6653
# Epoch 38/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6101 - accuracy: 0.6663 - val_loss: 0.6375 - val_accuracy: 0.6597
# Epoch 39/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6101 - accuracy: 0.6657 - val_loss: 0.6411 - val_accuracy: 0.6564
# Epoch 40/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6085 - accuracy: 0.6676 - val_loss: 0.6275 - val_accuracy: 0.6692
# Epoch 41/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6082 - accuracy: 0.6677 - val_loss: 0.6452 - val_accuracy: 0.6652
# Epoch 42/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6084 - accuracy: 0.6670 - val_loss: 0.6535 - val_accuracy: 0.6507
# Epoch 43/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6084 - accuracy: 0.6665 - val_loss: 0.6432 - val_accuracy: 0.6613
# Epoch 44/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6079 - accuracy: 0.6685 - val_loss: 0.6492 - val_accuracy: 0.6617
# Epoch 45/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6073 - accuracy: 0.6685 - val_loss: 0.6528 - val_accuracy: 0.6488
# Epoch 46/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6064 - accuracy: 0.6691 - val_loss: 0.6455 - val_accuracy: 0.6453
# Epoch 47/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6066 - accuracy: 0.6695 - val_loss: 0.6532 - val_accuracy: 0.6304
# Epoch 48/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6039 - accuracy: 0.6705 - val_loss: 0.6561 - val_accuracy: 0.6526
# Epoch 49/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6056 - accuracy: 0.6697 - val_loss: 0.6469 - val_accuracy: 0.6584
# Epoch 50/500
# 710/710 [==============================] - 3s 5ms/step - loss: 0.6075 - accuracy: 0.6682 - val_loss: 0.6505 - val_accuracy: 0.6558
# Epoch 51/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6054 - accuracy: 0.6703 - val_loss: 0.6408 - val_accuracy: 0.6572
# Epoch 52/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6036 - accuracy: 0.6719 - val_loss: 0.6476 - val_accuracy: 0.6635
# Epoch 53/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6041 - accuracy: 0.6709 - val_loss: 0.6525 - val_accuracy: 0.6570
# Epoch 54/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6031 - accuracy: 0.6736 - val_loss: 0.6433 - val_accuracy: 0.6569
# Epoch 55/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6040 - accuracy: 0.6716 - val_loss: 0.6538 - val_accuracy: 0.6556
# Epoch 56/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6021 - accuracy: 0.6741 - val_loss: 0.6470 - val_accuracy: 0.6632
# Epoch 57/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6026 - accuracy: 0.6731 - val_loss: 0.6546 - val_accuracy: 0.6583
# Epoch 58/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6022 - accuracy: 0.6732 - val_loss: 0.6533 - val_accuracy: 0.6295
# Epoch 59/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6023 - accuracy: 0.6725 - val_loss: 0.6541 - val_accuracy: 0.6543
# Epoch 60/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6032 - accuracy: 0.6727 - val_loss: 0.6496 - val_accuracy: 0.6451
# 345/345 [==============================] - 1s 2ms/step - loss: 0.6391 - accuracy: 0.6401
# 345/345 [==============================] - 1s 2ms/step
# Accuracy for iteration 2: 0.64
# Iteration 3
# Epoch 1/500
# 709/709 [==============================] - 5s 6ms/step - loss: 0.6853 - accuracy: 0.5499 - val_loss: 0.6691 - val_accuracy: 0.6024
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6690 - accuracy: 0.5821 - val_loss: 0.6511 - val_accuracy: 0.6290
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6554 - accuracy: 0.6030 - val_loss: 0.6432 - val_accuracy: 0.6372
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6454 - accuracy: 0.6142 - val_loss: 0.6454 - val_accuracy: 0.6454
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6423 - accuracy: 0.6157 - val_loss: 0.6395 - val_accuracy: 0.6415
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6359 - accuracy: 0.6254 - val_loss: 0.6401 - val_accuracy: 0.6537
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6345 - accuracy: 0.6278 - val_loss: 0.6290 - val_accuracy: 0.6551
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6292 - accuracy: 0.6356 - val_loss: 0.6327 - val_accuracy: 0.6597
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6269 - accuracy: 0.6363 - val_loss: 0.6338 - val_accuracy: 0.6565
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6258 - accuracy: 0.6393 - val_loss: 0.6352 - val_accuracy: 0.6549
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6233 - accuracy: 0.6400 - val_loss: 0.6345 - val_accuracy: 0.6570
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6212 - accuracy: 0.6421 - val_loss: 0.6331 - val_accuracy: 0.6644
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6198 - accuracy: 0.6413 - val_loss: 0.6329 - val_accuracy: 0.6578
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6201 - accuracy: 0.6397 - val_loss: 0.6290 - val_accuracy: 0.6641
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6182 - accuracy: 0.6437 - val_loss: 0.6358 - val_accuracy: 0.6605
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6170 - accuracy: 0.6447 - val_loss: 0.6321 - val_accuracy: 0.6611
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6160 - accuracy: 0.6433 - val_loss: 0.6287 - val_accuracy: 0.6627
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6157 - accuracy: 0.6455 - val_loss: 0.6279 - val_accuracy: 0.6641
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6144 - accuracy: 0.6464 - val_loss: 0.6325 - val_accuracy: 0.6625
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6144 - accuracy: 0.6457 - val_loss: 0.6289 - val_accuracy: 0.6592
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6130 - accuracy: 0.6482 - val_loss: 0.6409 - val_accuracy: 0.6448
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6122 - accuracy: 0.6487 - val_loss: 0.6287 - val_accuracy: 0.6670
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6132 - accuracy: 0.6460 - val_loss: 0.6297 - val_accuracy: 0.6610
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6105 - accuracy: 0.6490 - val_loss: 0.6336 - val_accuracy: 0.6553
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6090 - accuracy: 0.6481 - val_loss: 0.6330 - val_accuracy: 0.6578
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6083 - accuracy: 0.6502 - val_loss: 0.6342 - val_accuracy: 0.6553
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6088 - accuracy: 0.6482 - val_loss: 0.6278 - val_accuracy: 0.6614
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6086 - accuracy: 0.6495 - val_loss: 0.6238 - val_accuracy: 0.6635
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6075 - accuracy: 0.6505 - val_loss: 0.6324 - val_accuracy: 0.6616
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6074 - accuracy: 0.6493 - val_loss: 0.6418 - val_accuracy: 0.6342
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6077 - accuracy: 0.6492 - val_loss: 0.6378 - val_accuracy: 0.6543
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6064 - accuracy: 0.6505 - val_loss: 0.6391 - val_accuracy: 0.6464
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6058 - accuracy: 0.6491 - val_loss: 0.6338 - val_accuracy: 0.6504
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6038 - accuracy: 0.6496 - val_loss: 0.6278 - val_accuracy: 0.6633
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6045 - accuracy: 0.6523 - val_loss: 0.6351 - val_accuracy: 0.6614
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6039 - accuracy: 0.6515 - val_loss: 0.6380 - val_accuracy: 0.6504
# Epoch 37/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6031 - accuracy: 0.6529 - val_loss: 0.6283 - val_accuracy: 0.6566
# Epoch 38/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6031 - accuracy: 0.6510 - val_loss: 0.6292 - val_accuracy: 0.6607
# Epoch 39/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6024 - accuracy: 0.6521 - val_loss: 0.6290 - val_accuracy: 0.6585
# Epoch 40/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6023 - accuracy: 0.6522 - val_loss: 0.6381 - val_accuracy: 0.6434
# Epoch 41/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6011 - accuracy: 0.6511 - val_loss: 0.6323 - val_accuracy: 0.6499
# Epoch 42/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6009 - accuracy: 0.6514 - val_loss: 0.6322 - val_accuracy: 0.6541
# 343/343 [==============================] - 1s 2ms/step - loss: 0.6297 - accuracy: 0.6536
# 343/343 [==============================] - 1s 2ms/step
# Accuracy for iteration 3: 0.65
# Iteration 4
# Epoch 1/500
# 709/709 [==============================] - 5s 6ms/step - loss: 0.6874 - accuracy: 0.5436 - val_loss: 0.6799 - val_accuracy: 0.5730
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6708 - accuracy: 0.5785 - val_loss: 0.6658 - val_accuracy: 0.6082
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6587 - accuracy: 0.5985 - val_loss: 0.6650 - val_accuracy: 0.6105
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6512 - accuracy: 0.6100 - val_loss: 0.6635 - val_accuracy: 0.5918
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6452 - accuracy: 0.6167 - val_loss: 0.6423 - val_accuracy: 0.6310
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6421 - accuracy: 0.6232 - val_loss: 0.6460 - val_accuracy: 0.6362
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6393 - accuracy: 0.6291 - val_loss: 0.6564 - val_accuracy: 0.6279
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6345 - accuracy: 0.6350 - val_loss: 0.6512 - val_accuracy: 0.6288
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6331 - accuracy: 0.6350 - val_loss: 0.6460 - val_accuracy: 0.6357
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6308 - accuracy: 0.6401 - val_loss: 0.6476 - val_accuracy: 0.6306
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6297 - accuracy: 0.6397 - val_loss: 0.6481 - val_accuracy: 0.6171
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6280 - accuracy: 0.6428 - val_loss: 0.6473 - val_accuracy: 0.6277
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6265 - accuracy: 0.6457 - val_loss: 0.6446 - val_accuracy: 0.6339
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6264 - accuracy: 0.6455 - val_loss: 0.6515 - val_accuracy: 0.6174
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6255 - accuracy: 0.6476 - val_loss: 0.6458 - val_accuracy: 0.6249
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6243 - accuracy: 0.6496 - val_loss: 0.6432 - val_accuracy: 0.6357
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6226 - accuracy: 0.6491 - val_loss: 0.6422 - val_accuracy: 0.6350
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6215 - accuracy: 0.6509 - val_loss: 0.6451 - val_accuracy: 0.6221
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6209 - accuracy: 0.6530 - val_loss: 0.6427 - val_accuracy: 0.6390
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6190 - accuracy: 0.6551 - val_loss: 0.6428 - val_accuracy: 0.6349
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6200 - accuracy: 0.6534 - val_loss: 0.6383 - val_accuracy: 0.6319
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6175 - accuracy: 0.6561 - val_loss: 0.6448 - val_accuracy: 0.6326
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6166 - accuracy: 0.6576 - val_loss: 0.6434 - val_accuracy: 0.6293
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6176 - accuracy: 0.6564 - val_loss: 0.6411 - val_accuracy: 0.6330
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6167 - accuracy: 0.6577 - val_loss: 0.6446 - val_accuracy: 0.6312
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6160 - accuracy: 0.6581 - val_loss: 0.6561 - val_accuracy: 0.6179
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6152 - accuracy: 0.6600 - val_loss: 0.6447 - val_accuracy: 0.6322
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6141 - accuracy: 0.6608 - val_loss: 0.6436 - val_accuracy: 0.6326
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6149 - accuracy: 0.6586 - val_loss: 0.6428 - val_accuracy: 0.6372
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6142 - accuracy: 0.6600 - val_loss: 0.6431 - val_accuracy: 0.6359
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6127 - accuracy: 0.6627 - val_loss: 0.6432 - val_accuracy: 0.6311
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6110 - accuracy: 0.6624 - val_loss: 0.6431 - val_accuracy: 0.6339
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6121 - accuracy: 0.6625 - val_loss: 0.6450 - val_accuracy: 0.6272
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6113 - accuracy: 0.6622 - val_loss: 0.6584 - val_accuracy: 0.6042
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6109 - accuracy: 0.6625 - val_loss: 0.6461 - val_accuracy: 0.6196
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6088 - accuracy: 0.6652 - val_loss: 0.6525 - val_accuracy: 0.6151
# Epoch 37/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6099 - accuracy: 0.6655 - val_loss: 0.6512 - val_accuracy: 0.6179
# Epoch 38/500
# 709/709 [==============================] - 3s 5ms/step - loss: 0.6078 - accuracy: 0.6656 - val_loss: 0.6469 - val_accuracy: 0.6305
# Epoch 39/500
# 709/709 [==============================] - 3s 5ms/step - loss: 0.6078 - accuracy: 0.6651 - val_loss: 0.6442 - val_accuracy: 0.6286
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6327 - accuracy: 0.6542
# 354/354 [==============================] - 1s 2ms/step
# Accuracy for iteration 4: 0.65
# Average Accuracy across 4 iterations: 0.65

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.64015 - 0.65418

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 350/350 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.64      0.64      0.64      5596
#         High       0.64      0.63      0.64      5596
#
#     accuracy                           0.64     11192
#    macro avg       0.64      0.64      0.64     11192
# weighted avg       0.64      0.64      0.64     11192

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 354/354 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.65      0.67      0.66      5659
#         High       0.66      0.64      0.65      5659
#
#     accuracy                           0.65     11318
#    macro avg       0.65      0.65      0.65     11318
# weighted avg       0.65      0.65      0.65     11318
