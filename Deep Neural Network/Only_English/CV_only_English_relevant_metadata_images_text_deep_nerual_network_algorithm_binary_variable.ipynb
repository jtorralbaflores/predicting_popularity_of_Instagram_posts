# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Followees', 'Posts', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = additional_columns_to_keep + text_columns + image_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))
# Out:
# <ipython-input-7-747e2ff0d805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 4
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Normalize the selected features
    columns_to_normalize = ['Followers', 'Followees', 'Posts']
    scaler = StandardScaler().fit(train_data[columns_to_normalize])
    train_data.loc[:, columns_to_normalize] = scaler.transform(train_data[columns_to_normalize])
    val_data.loc[:, columns_to_normalize] = scaler.transform(val_data[columns_to_normalize])
    test_data.loc[:, columns_to_normalize] = scaler.transform(test_data[columns_to_normalize])

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 706/706 [==============================] - 8s 6ms/step - loss: 0.6844 - accuracy: 0.5519 - val_loss: 0.6756 - val_accuracy: 0.5819
# Epoch 2/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.
500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6012 - accuracy: 0.6711 - val_loss: 0.6458 - val_accuracy: 0.6447
# Epoch 63/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6004 - accuracy: 0.6732 - val_loss: 0.6498 - val_accuracy: 0.6434
# Epoch 64/500
# 706/706 [==============================] - 3s 4ms/step - loss: 0.6020 - accuracy: 0.6703 - val_loss: 0.6445 - val_accuracy: 0.6435
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6352 - accuracy: 0.6472
# 363/363 [==============================] - 1s 2ms/step
# Accuracy for iteration 1: 0.65
# Iteration 2
# Epoch 1/500
# 710/710 [==============================] - 5s 5ms/step - loss: 0.6873 - accuracy: 0.5410 - val_loss: 0.6748 - val_accuracy: 0.5903
# Epoch 2/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6752 - accuracy: 0.5642 - val_loss: 0.6590 - val_accuracy: 0.6266
# Epoch 3/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6653 - accuracy: 0.5799 - val_loss: 0.6532 - val_accuracy: 0.6378
# Epoch 4/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6578 - accuracy: 0.5896 - val_loss: 0.6459 - val_accuracy: 0.6517
# Epoch 5/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6538 - accuracy: 0.5983 - val_loss: 0.6412 - val_accuracy: 0.6444
# Epoch 6/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6476 - accuracy: 0.6071 - val_loss: 0.6422 - val_accuracy: 0.6419
# Epoch 7/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6433 - accuracy: 0.6140 - val_loss: 0.6325 - val_accuracy: 0.6468
# Epoch 8/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6408 - accuracy: 0.6156 - val_loss: 0.6284 - val_accuracy: 0.6562
# Epoch 9/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6378 - accuracy: 0.6228 - val_loss: 0.6370 - val_accuracy: 0.6508
# Epoch 10/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6355 - accuracy: 0.6243 - val_loss: 0.6314 - val_accuracy: 0.6524
# Epoch 11/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6346 - accuracy: 0.6272 - val_loss: 0.6387 - val_accuracy: 0.6563
# Epoch 12/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6326 - accuracy: 0.6312 - val_loss: 0.6301 - val_accuracy: 0.6543
# Epoch 13/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6303 - accuracy: 0.6322 - val_loss: 0.6396 - val_accuracy: 0.6475
# Epoch 14/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6288 - accuracy: 0.6334 - val_loss: 0.6290 - val_accuracy: 0.6566
# Epoch 15/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6273 - accuracy: 0.6359 - val_loss: 0.6268 - val_accuracy: 0.6591
# Epoch 16/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6273 - accuracy: 0.6382 - val_loss: 0.6313 - val_accuracy: 0.6537
# Epoch 17/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6265 - accuracy: 0.6360 - val_loss: 0.6277 - val_accuracy: 0.6614
# Epoch 18/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6248 - accuracy: 0.6390 - val_loss: 0.6277 - val_accuracy: 0.6590
# Epoch 19/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6244 - accuracy: 0.6397 - val_loss: 0.6362 - val_accuracy: 0.6583
# Epoch 20/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6222 - accuracy: 0.6420 - val_loss: 0.6236 - val_accuracy: 0.6563
# Epoch 21/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6285 - accuracy: 0.6390 - val_loss: 0.6297 - val_accuracy: 0.6534
# Epoch 22/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6290 - accuracy: 0.6395 - val_loss: 0.6282 - val_accuracy: 0.6535
# Epoch 23/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6280 - accuracy: 0.6426 - val_loss: 0.6249 - val_accuracy: 0.6560
# Epoch 24/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6286 - accuracy: 0.6404 - val_loss: 0.6328 - val_accuracy: 0.6533
# Epoch 25/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6267 - accuracy: 0.6438 - val_loss: 0.6279 - val_accuracy: 0.6576
# Epoch 26/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6267 - accuracy: 0.6438 - val_loss: 0.6321 - val_accuracy: 0.6581
# Epoch 27/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6251 - accuracy: 0.6471 - val_loss: 0.6264 - val_accuracy: 0.6551
# Epoch 28/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6231 - accuracy: 0.6497 - val_loss: 0.6274 - val_accuracy: 0.6558
# Epoch 29/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6240 - accuracy: 0.6477 - val_loss: 0.6288 - val_accuracy: 0.6563
# Epoch 30/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6235 - accuracy: 0.6488 - val_loss: 0.6286 - val_accuracy: 0.6553
# Epoch 31/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6230 - accuracy: 0.6485 - val_loss: 0.6307 - val_accuracy: 0.6514
# Epoch 32/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6237 - accuracy: 0.6473 - val_loss: 0.6313 - val_accuracy: 0.6478
# Epoch 33/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6220 - accuracy: 0.6490 - val_loss: 0.6304 - val_accuracy: 0.6518
# Epoch 34/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6215 - accuracy: 0.6509 - val_loss: 0.6264 - val_accuracy: 0.6531
# Epoch 35/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6219 - accuracy: 0.6514 - val_loss: 0.6335 - val_accuracy: 0.6437
# Epoch 36/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6196 - accuracy: 0.6527 - val_loss: 0.6312 - val_accuracy: 0.6512
# Epoch 37/500
# 710/710 [==============================] - 3s 4ms/step - loss: 0.6199 - accuracy: 0.6514 - val_loss: 0.6317 - val_accuracy: 0.6489
# 345/345 [==============================] - 1s 2ms/step - loss: 0.6410 - accuracy: 0.6448
# 345/345 [==============================] - 1s 2ms/step
# Accuracy for iteration 2: 0.64
# Iteration 3
# Epoch 1/500
# 709/709 [==============================] - 5s 5ms/step - loss: 0.6893 - accuracy: 0.5428 - val_loss: 0.6808 - val_accuracy: 0.5752
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6736 - accuracy: 0.5763 - val_loss: 0.6581 - val_accuracy: 0.6275
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6626 - accuracy: 0.5951 - val_loss: 0.6441 - val_accuracy: 0.6316
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6529 - accuracy: 0.6087 - val_loss: 0.6465 - val_accuracy: 0.6361
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6486 - accuracy: 0.6186 - val_loss: 0.6480 - val_accuracy: 0.6420
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6429 - accuracy: 0.6255 - val_loss: 0.6570 - val_accuracy: 0.6056
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6390 - accuracy: 0.6316 - val_loss: 0.6456 - val_accuracy: 0.6423
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6378 - accuracy: 0.6326 - val_loss: 0.6366 - val_accuracy: 0.6488
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6340 - accuracy: 0.6362 - val_loss: 0.6501 - val_accuracy: 0.6385
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6330 - accuracy: 0.6399 - val_loss: 0.6364 - val_accuracy: 0.6531
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6320 - accuracy: 0.6392 - val_loss: 0.6371 - val_accuracy: 0.6533
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6314 - accuracy: 0.6405 - val_loss: 0.6348 - val_accuracy: 0.6465
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6297 - accuracy: 0.6434 - val_loss: 0.6363 - val_accuracy: 0.6422
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6288 - accuracy: 0.6450 - val_loss: 0.6348 - val_accuracy: 0.6494
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6290 - accuracy: 0.6442 - val_loss: 0.6407 - val_accuracy: 0.6524
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6263 - accuracy: 0.6472 - val_loss: 0.6316 - val_accuracy: 0.6563
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6259 - accuracy: 0.6480 - val_loss: 0.6376 - val_accuracy: 0.6452
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6239 - accuracy: 0.6490 - val_loss: 0.6371 - val_accuracy: 0.6415
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6248 - accuracy: 0.6483 - val_loss: 0.6440 - val_accuracy: 0.6361
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6233 - accuracy: 0.6504 - val_loss: 0.6406 - val_accuracy: 0.6413
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6242 - accuracy: 0.6492 - val_loss: 0.6382 - val_accuracy: 0.6423
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6217 - accuracy: 0.6526 - val_loss: 0.6402 - val_accuracy: 0.6402
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6228 - accuracy: 0.6505 - val_loss: 0.6385 - val_accuracy: 0.6475
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6212 - accuracy: 0.6517 - val_loss: 0.6374 - val_accuracy: 0.6484
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6201 - accuracy: 0.6537 - val_loss: 0.6363 - val_accuracy: 0.6514
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6207 - accuracy: 0.6525 - val_loss: 0.6355 - val_accuracy: 0.6462
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6211 - accuracy: 0.6537 - val_loss: 0.6471 - val_accuracy: 0.6354
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6197 - accuracy: 0.6539 - val_loss: 0.6319 - val_accuracy: 0.6519
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6187 - accuracy: 0.6566 - val_loss: 0.6324 - val_accuracy: 0.6536
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6177 - accuracy: 0.6564 - val_loss: 0.6363 - val_accuracy: 0.6523
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6168 - accuracy: 0.6581 - val_loss: 0.6363 - val_accuracy: 0.6483
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6165 - accuracy: 0.6586 - val_loss: 0.6395 - val_accuracy: 0.6421
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6169 - accuracy: 0.6579 - val_loss: 0.6316 - val_accuracy: 0.6549
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6154 - accuracy: 0.6588 - val_loss: 0.6389 - val_accuracy: 0.6503
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6165 - accuracy: 0.6586 - val_loss: 0.6432 - val_accuracy: 0.6493
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6169 - accuracy: 0.6578 - val_loss: 0.6365 - val_accuracy: 0.6486
# 343/343 [==============================] - 1s 2ms/step - loss: 0.6325 - accuracy: 0.6453
# 343/343 [==============================] - 1s 2ms/step
# Accuracy for iteration 3: 0.65
# Iteration 4
# Epoch 1/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6857 - accuracy: 0.5473 - val_loss: 0.6764 - val_accuracy: 0.5765
# Epoch 2/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6725 - accuracy: 0.5757 - val_loss: 0.6670 - val_accuracy: 0.5927
# Epoch 3/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6612 - accuracy: 0.5962 - val_loss: 0.6588 - val_accuracy: 0.6119
# Epoch 4/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6532 - accuracy: 0.6065 - val_loss: 0.6496 - val_accuracy: 0.6224
# Epoch 5/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6468 - accuracy: 0.6180 - val_loss: 0.6504 - val_accuracy: 0.6213
# Epoch 6/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6437 - accuracy: 0.6227 - val_loss: 0.6500 - val_accuracy: 0.6240
# Epoch 7/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6391 - accuracy: 0.6285 - val_loss: 0.6494 - val_accuracy: 0.6263
# Epoch 8/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6373 - accuracy: 0.6311 - val_loss: 0.6513 - val_accuracy: 0.6288
# Epoch 9/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6358 - accuracy: 0.6342 - val_loss: 0.6457 - val_accuracy: 0.6310
# Epoch 10/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6330 - accuracy: 0.6376 - val_loss: 0.6490 - val_accuracy: 0.6279
# Epoch 11/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6343 - accuracy: 0.6367 - val_loss: 0.6478 - val_accuracy: 0.6293
# Epoch 12/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6324 - accuracy: 0.6379 - val_loss: 0.6473 - val_accuracy: 0.6326
# Epoch 13/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6301 - accuracy: 0.6416 - val_loss: 0.6467 - val_accuracy: 0.6267
# Epoch 14/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6299 - accuracy: 0.6422 - val_loss: 0.6449 - val_accuracy: 0.6325
# Epoch 15/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6291 - accuracy: 0.6429 - val_loss: 0.6432 - val_accuracy: 0.6308
# Epoch 16/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6282 - accuracy: 0.6459 - val_loss: 0.6459 - val_accuracy: 0.6290
# Epoch 17/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6277 - accuracy: 0.6435 - val_loss: 0.6487 - val_accuracy: 0.6241
# Epoch 18/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6256 - accuracy: 0.6462 - val_loss: 0.6500 - val_accuracy: 0.6284
# Epoch 19/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6259 - accuracy: 0.6475 - val_loss: 0.6473 - val_accuracy: 0.6298
# Epoch 20/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6253 - accuracy: 0.6491 - val_loss: 0.6404 - val_accuracy: 0.6311
# Epoch 21/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6244 - accuracy: 0.6479 - val_loss: 0.6451 - val_accuracy: 0.6302
# Epoch 22/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6238 - accuracy: 0.6485 - val_loss: 0.6464 - val_accuracy: 0.6341
# Epoch 23/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6221 - accuracy: 0.6526 - val_loss: 0.6485 - val_accuracy: 0.6251
# Epoch 24/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6228 - accuracy: 0.6509 - val_loss: 0.6473 - val_accuracy: 0.6274
# Epoch 25/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6211 - accuracy: 0.6519 - val_loss: 0.6473 - val_accuracy: 0.6303
# Epoch 26/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6211 - accuracy: 0.6522 - val_loss: 0.6472 - val_accuracy: 0.6307
# Epoch 27/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6212 - accuracy: 0.6516 - val_loss: 0.6470 - val_accuracy: 0.6322
# Epoch 28/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6209 - accuracy: 0.6542 - val_loss: 0.6514 - val_accuracy: 0.6219
# Epoch 29/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6198 - accuracy: 0.6547 - val_loss: 0.6462 - val_accuracy: 0.6268
# Epoch 30/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6178 - accuracy: 0.6573 - val_loss: 0.6463 - val_accuracy: 0.6278
# Epoch 31/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6179 - accuracy: 0.6569 - val_loss: 0.6449 - val_accuracy: 0.6321
# Epoch 32/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6188 - accuracy: 0.6555 - val_loss: 0.6441 - val_accuracy: 0.6330
# Epoch 33/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6169 - accuracy: 0.6572 - val_loss: 0.6505 - val_accuracy: 0.6219
# Epoch 34/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6176 - accuracy: 0.6578 - val_loss: 0.6432 - val_accuracy: 0.6248
# Epoch 35/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6172 - accuracy: 0.6561 - val_loss: 0.6501 - val_accuracy: 0.6241
# Epoch 36/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6147 - accuracy: 0.6607 - val_loss: 0.6447 - val_accuracy: 0.6257
# Epoch 37/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6151 - accuracy: 0.6593 - val_loss: 0.6467 - val_accuracy: 0.6251
# Epoch 38/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6139 - accuracy: 0.6612 - val_loss: 0.6448 - val_accuracy: 0.6268
# Epoch 39/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6141 - accuracy: 0.6614 - val_loss: 0.6493 - val_accuracy: 0.6236
# Epoch 40/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6134 - accuracy: 0.6619 - val_loss: 0.6460 - val_accuracy: 0.6296
# Epoch 41/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6123 - accuracy: 0.6621 - val_loss: 0.6478 - val_accuracy: 0.6260
# Epoch 42/500
# 709/709 [==============================] - 3s 4ms/step - loss: 0.6133 - accuracy: 0.6620 - val_loss: 0.6463 - val_accuracy: 0.6254
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6384 - accuracy: 0.6511
# 354/354 [==============================] - 1s 2ms/step
# Accuracy for iteration 4: 0.65
# Average Accuracy across 4 iterations: 0.65

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.64478 - 0.65109

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 350/350 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.66      0.56      0.61      5596
#         High       0.62      0.70      0.66      5596
#
#     accuracy                           0.63     11192
#    macro avg       0.64      0.63      0.63     11192
# weighted avg       0.64      0.63      0.63     11192

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 354/354 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.67      0.59      0.63      5659
#         High       0.63      0.71      0.67      5659
#
#     accuracy                           0.65     11318
#    macro avg       0.65      0.65      0.65     11318
# weighted avg       0.65      0.65      0.65     11318
