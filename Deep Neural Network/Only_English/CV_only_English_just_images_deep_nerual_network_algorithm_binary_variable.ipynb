# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.preprocessing import StandardScaler
import xgboost as xgb
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.optimizers import Adam

# %% [markdown]
# Step 0: load our data

# %%
# Load data
data = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/MSc thesis/processed_data/metadata/fully_concatenated_data.csv", lineterminator='\n')

# %%
data.iloc[1:10, 28:45]
# Out:
#    Hour  Day of Week (Number) Day of Week (String)  Is_English  \
# 1    20                     6               Sunday        True
# 2    15                     6               Sunday        True
# 3    18                     2            Wednesday        True
# 4    19                     5             Saturday        True
# 5     6                     6               Sunday       False
# 6    15                     6               Sunday       False
# 7     3                     6               Sunday       False
# 8     3                     6               Sunday       False
# 9    21                     6               Sunday        True
#
#   Detected_Language  Image_Count   image_0   image_1   image_2   image_3  \
# 1                en            1  1.257535  4.292836  0.637026  0.038215
# 2                en            1  1.015909  4.928564  0.049328  1.360145
# 3                en            7  0.612580  2.573719  0.000000  0.000000
# 4                en            1  0.961807  3.994127  0.116529  1.330238
# 5                ko            3  0.024685  0.956713  0.100529  0.715106
# 6                ko            2  0.000000  1.686701  0.022357  0.000000
# 7                ko           10  0.272321  1.318672  0.063117  0.000000
# 8                ko           10  1.009356  0.572479  0.049320  0.017962
# 9                en            1  1.316597  1.515859  0.067210  2.473874
#
#     image_4   image_5   image_6   image_7   image_8   image_9  image_10
# 1  0.341019  0.103195  0.023346  0.352497  0.099513  0.015858  0.282103
# 2  0.188817  0.242184  1.370974  0.206735  0.089321  0.008390  0.464875
# 3  1.416055  0.397631  1.642256  0.049719  0.000707  0.285212  0.627529
# 4  0.034433  2.436250  0.633051  0.620503  3.313558  0.000000  0.139836
# 5  0.565287  0.084047  0.267570  0.000000  0.030411  0.600792  0.018151
# 6  0.007881  0.025374  0.328463  0.324222  0.000000  0.042074  0.056771
# 7  0.127826  0.154153  0.012882  0.257812  0.000000  0.082779  0.027158
# 8  0.707233  0.036858  0.366499  0.633115  0.058597  0.069269  0.271958
# 9  0.316460  0.163660  0.673739  0.901117  0.219723  1.258277  0.542950

# %%
# List of image and text feature columns to keep
image_columns = [f'image_{i}' for i in range(0, 2049)]
text_columns = [f'text_{i}' for i in range(0, 768)]

# Additional columns you want to keep
additional_columns_to_keep = ['like_count', 'comment_count', 'post_id', 'Followers', 'Username', 'Is_English', 'Image_Count']

# Combine both lists of columns to keep
columns_to_keep = image_columns + additional_columns_to_keep #+ text_columns

# Drop all columns except those specified in columns_to_keep
columns_to_drop = [col for col in data.columns if col not in columns_to_keep]

# Drop the unwanted columns from the dataframe
data_2 = data.drop(columns=columns_to_drop)


# Maybe don't delete category and detected languages
# Same with comments disabled and video
# potential columns to add or not:
#'comments_disabled',
#'is_video'
# Category
data_2.head(10)

# Filter image count to 10 or less, which is what is realistic in the industry
data_2 = data_2[data_2['Image_Count'] <= 1]

# %%
# Filter the DataFrame to keep only observations where 'Is_English' is True
data_2 = data_2[data_2['Is_English'] == True]

# %% [markdown]
# Step 1: group and split the data by post_id

# %% [markdown]
# Define a popularity variable

# %%
# Set the engagement rate variable
data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))
# Out:
# <ipython-input-7-747e2ff0d805>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_2['popularity'] = (((data_2['like_count'] + data_2['comment_count'])/data_2['Followers']))

# %% [markdown]
# Let's split the data!

# %%
# Define the number of iterations and an array to store accuracies
n_iterations = 4
accuracies = []

for seed in range(n_iterations):
    print(f"Iteration {seed+1}")

    # Split users into training and temporary sets with a new seed each time
    train_users, temp_users = train_test_split(data_2['Username'].unique(), test_size=0.2, random_state=seed)
    val_users, test_users = train_test_split(temp_users, test_size=0.5, random_state=seed)

    # Assign posts to training, validation, and test sets
    train_data = data_2[data_2['Username'].isin(train_users)]
    val_data = data_2[data_2['Username'].isin(val_users)]
    test_data = data_2[data_2['Username'].isin(test_users)]

    # Calculate the median popularity rate for each dataset
    median_popularity_rate_train = train_data['popularity'].quantile(0.5)
    train_data.loc[:, 'popularity'] = (train_data['popularity'] > median_popularity_rate_train).astype(int)
    median_popularity_rate_val = val_data['popularity'].quantile(0.5)
    val_data.loc[:, 'popularity'] = (val_data['popularity'] > median_popularity_rate_val).astype(int)
    median_popularity_rate_test = test_data['popularity'].quantile(0.5)
    test_data.loc[:, 'popularity'] = (test_data['popularity'] > median_popularity_rate_test).astype(int)

    # Prepare data for XGBoost
    X_train = train_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_train = train_data['popularity']
    X_val = val_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_val = val_data['popularity']
    X_test = test_data.drop(['popularity', 'post_id', 'like_count', 'comment_count', 'Username', 'Image_Count', 'Followers', 'Is_English'], axis=1)
    y_test = test_data['popularity']

    # Create the model
    model_b = Sequential()

    # Assume X_train is your training data loaded previously with correct dimensions
    # Add new layers
    model_b.add(Dense(64, input_shape=(X_train.shape[1],), activation='relu'))
    model_b.add(Dropout(0.5))
    model_b.add(Dense(32, activation='relu'))
    model_b.add(Dense(1, activation='sigmoid'))

    # Initialize the Adam optimizer with a specific learning rate
    optimizer = Adam(learning_rate=0.001)

    #Compiling the model
    model_b.compile(optimizer= optimizer,
              loss='binary_crossentropy',
              metrics=['accuracy'])

    # Set up early stopping
    early_stopping = EarlyStopping(monitor = 'val_accuracy',
                               patience = 20,
                               restore_best_weights = True)
    # Fit the model
    history = model_b.fit(X_train,
                      y_train,
                      epochs=500,
                      batch_size=128,
                      validation_data = (X_val, y_val),
                      callbacks=[early_stopping])

    test_loss, test_acc = model_b.evaluate(X_test, y_test)

    # Evaluate the model on the test set
    y_pred_prob = model_b.predict(X_test)
    y_pred_binary = (y_pred_prob > 0.5).astype(int)
    accuracy = accuracy_score(y_test, y_pred_binary)
    accuracies.append(accuracy)

    print(f"Accuracy for iteration {seed+1}: {accuracy:.2f}")

# Calculate the average accuracy across all iterations
average_accuracy = np.mean(accuracies)
print(f"Average Accuracy across {n_iterations} iterations: {average_accuracy:.2f}")
# Out:
# Iteration 1
# Epoch 1/500
# 706/706 [==============================] - 6s 7ms/step - loss: 0.6906 - accuracy: 0.5444 - val_loss: 0.6846 - val_accuracy: 0.5558
# Epoch 2/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6840 - accuracy: 0.5573 - val_loss: 0.6874 - val_accuracy: 0.5460
# Epoch 3/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6828 - accuracy: 0.5581 - val_loss: 0.6838 - val_accuracy: 0.5534
# Epoch 4/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6813 - accuracy: 0.5631 - val_loss: 0.6824 - val_accuracy: 0.5622
# Epoch 5/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6829 - accuracy: 0.5625 - val_loss: 0.6836 - val_accuracy: 0.5615
# Epoch 6/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6816 - accuracy: 0.5645 - val_loss: 0.6846 - val_accuracy: 0.5563
# Epoch 7/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6813 - accuracy: 0.5645 - val_loss: 0.6830 - val_accuracy: 0.5568
# Epoch 8/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6807 - accuracy: 0.5682 - val_loss: 0.6822 - val_accuracy: 0.5664
# Epoch 9/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6791 - accuracy: 0.5713 - val_loss: 0.6821 - val_accuracy: 0.5651
# Epoch 10/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6791 - accuracy: 0.5708 - val_loss: 0.6845 - val_accuracy: 0.5629
# Epoch 11/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6783 - accuracy: 0.5732 - val_loss: 0.6815 - val_accuracy: 0.5663
# Epoch 12/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6779 - accuracy: 0.5732 - val_loss: 0.6829 - val_accuracy: 0.5651
# Epoch 13/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6769 - accuracy: 0.5761 - val_loss: 0.6858 - val_accuracy: 0.5537
# Epoch 14/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6770 - accuracy: 0.5756 - val_loss: 0.6822 - val_accuracy: 0.5594
# Epoch 15/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6767 - accuracy: 0.5772 - val_loss: 0.6835 - val_accuracy: 0.5623
# Epoch 16/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6759 - accuracy: 0.5770 - val_loss: 0.6824 - val_accuracy: 0.5654
# Epoch 17/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6764 - accuracy: 0.5772 - val_loss: 0.6836 - val_accuracy: 0.5616
# Epoch 18/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6754 - accuracy: 0.5783 - val_loss: 0.6826 - val_accuracy: 0.5620
# Epoch 19/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6753 - accuracy: 0.5789 - val_loss: 0.6823 - val_accuracy: 0.5668
# Epoch 20/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6747 - accuracy: 0.5785 - val_loss: 0.6818 - val_accuracy: 0.5655
# Epoch 21/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6738 - accuracy: 0.5816 - val_loss: 0.6812 - val_accuracy: 0.5644
# Epoch 22/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6727 - accuracy: 0.5837 - val_loss: 0.6812 - val_accuracy: 0.5631
# Epoch 23/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6737 - accuracy: 0.5808 - val_loss: 0.6834 - val_accuracy: 0.5552
# Epoch 24/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6727 - accuracy: 0.5811 - val_loss: 0.6811 - val_accuracy: 0.5661
# Epoch 25/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6728 - accuracy: 0.5827 - val_loss: 0.6822 - val_accuracy: 0.5616
# Epoch 26/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6717 - accuracy: 0.5841 - val_loss: 0.6829 - val_accuracy: 0.5572
# Epoch 27/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6714 - accuracy: 0.5837 - val_loss: 0.6826 - val_accuracy: 0.5593
# Epoch 28/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6703 - accuracy: 0.5845 - val_loss: 0.6812 - val_accuracy: 0.5628
# Epoch 29/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6706 - accuracy: 0.5858 - val_loss: 0.6854 - val_accuracy: 0.5413
# Epoch 30/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6694 - accuracy: 0.5866 - val_loss: 0.6851 - val_accuracy: 0.5424
# Epoch 31/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6685 - accuracy: 0.5875 - val_loss: 0.6858 - val_accuracy: 0.5436
# Epoch 32/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6682 - accuracy: 0.5893 - val_loss: 0.6855 - val_accuracy: 0.5461
# Epoch 33/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6677 - accuracy: 0.5900 - val_loss: 0.6869 - val_accuracy: 0.5488
# Epoch 34/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6667 - accuracy: 0.5906 - val_loss: 0.6820 - val_accuracy: 0.5582
# Epoch 35/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6663 - accuracy: 0.5910 - val_loss: 0.6846 - val_accuracy: 0.5486
# Epoch 36/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6656 - accuracy: 0.5904 - val_loss: 0.6850 - val_accuracy: 0.5537
# Epoch 37/500
# 706/706 [==============================] - 4s 6ms/step - loss: 0.6652 - accuracy: 0.5911 - val_loss: 0.6840 - val_accuracy: 0.5596
# Epoch 38/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6644 - accuracy: 0.5922 - val_loss: 0.6886 - val_accuracy: 0.5465
# Epoch 39/500
# 706/706 [==============================] - 4s 5ms/step - loss: 0.6638 - accuracy: 0.5918 - val_loss: 0.6871 - val_accuracy: 0.5465
# 363/363 [==============================] - 1s 2ms/step - loss: 0.6840 - accuracy: 0.5633
# 363/363 [==============================] - 1s 2ms/step
# Accuracy for iteration 1: 0.56
# Iteration 2
# Epoch 1/500
# 710/710 [==============================] - 5s 6ms/step - loss: 0.6921 - accuracy: 0.5372 - val_loss: 0.6842 - val_accuracy: 0.5686
# Epoch 2/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6843 - accuracy: 0.5532 - val_loss: 0.6777 - val_accuracy: 0.5711
# Epoch 3/500
# 710/710 [==============================] - 4s 6ms/step - loss: 0.6834 - accuracy: 0.5552 - val_loss: 0.6785 - val_accuracy: 0.5764
# Epoch 4/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6824 - accuracy: 0.5580 - val_loss: 0.6758 - val_accuracy: 0.5770
# Epoch 5/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6806 - accuracy: 0.5621 - val_loss: 0.6784 - val_accuracy: 0.5756
# Epoch 6/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6798 - accuracy: 0.5657 - val_loss: 0.6807 - val_accuracy: 0.5762
# Epoch 7/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6795 - accuracy: 0.5649 - val_loss: 0.6778 - val_accuracy: 0.5778
# Epoch 8/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6785 - accuracy: 0.5661 - val_loss: 0.6765 - val_accuracy: 0.5805
# Epoch 9/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6784 - accuracy: 0.5676 - val_loss: 0.6773 - val_accuracy: 0.5772
# Epoch 10/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6772 - accuracy: 0.5689 - val_loss: 0.6765 - val_accuracy: 0.5814
# Epoch 11/500
# 710/710 [==============================] - 4s 6ms/step - loss: 0.6770 - accuracy: 0.5705 - val_loss: 0.6809 - val_accuracy: 0.5702
# Epoch 12/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6756 - accuracy: 0.5725 - val_loss: 0.6789 - val_accuracy: 0.5806
# Epoch 13/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6750 - accuracy: 0.5717 - val_loss: 0.6770 - val_accuracy: 0.5778
# Epoch 14/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6744 - accuracy: 0.5743 - val_loss: 0.6775 - val_accuracy: 0.5798
# Epoch 15/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6746 - accuracy: 0.5733 - val_loss: 0.6786 - val_accuracy: 0.5793
# Epoch 16/500
# 710/710 [==============================] - 4s 6ms/step - loss: 0.6731 - accuracy: 0.5761 - val_loss: 0.6777 - val_accuracy: 0.5797
# Epoch 17/500
# 710/710 [==============================] - 4s 6ms/step - loss: 0.6729 - accuracy: 0.5764 - val_loss: 0.6771 - val_accuracy: 0.5762
# Epoch 18/500
# 710/710 [==============================] - 4s 6ms/step - loss: 0.6721 - accuracy: 0.5776 - val_loss: 0.6782 - val_accuracy: 0.5792
# Epoch 19/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6718 - accuracy: 0.5775 - val_loss: 0.6777 - val_accuracy: 0.5821
# Epoch 20/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6713 - accuracy: 0.5778 - val_loss: 0.6800 - val_accuracy: 0.5766
# Epoch 21/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6700 - accuracy: 0.5793 - val_loss: 0.6779 - val_accuracy: 0.5773
# Epoch 22/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6694 - accuracy: 0.5806 - val_loss: 0.6777 - val_accuracy: 0.5817
# Epoch 23/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6689 - accuracy: 0.5807 - val_loss: 0.6796 - val_accuracy: 0.5738
# Epoch 24/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6683 - accuracy: 0.5827 - val_loss: 0.6777 - val_accuracy: 0.5789
# Epoch 25/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6678 - accuracy: 0.5816 - val_loss: 0.6796 - val_accuracy: 0.5779
# Epoch 26/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6670 - accuracy: 0.5825 - val_loss: 0.6785 - val_accuracy: 0.5744
# Epoch 27/500
# 710/710 [==============================] - 4s 6ms/step - loss: 0.6664 - accuracy: 0.5853 - val_loss: 0.6775 - val_accuracy: 0.5798
# Epoch 28/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6656 - accuracy: 0.5854 - val_loss: 0.6788 - val_accuracy: 0.5797
# Epoch 29/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6653 - accuracy: 0.5845 - val_loss: 0.6793 - val_accuracy: 0.5735
# Epoch 30/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6652 - accuracy: 0.5850 - val_loss: 0.6786 - val_accuracy: 0.5746
# Epoch 31/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6651 - accuracy: 0.5850 - val_loss: 0.6799 - val_accuracy: 0.5755
# Epoch 32/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6646 - accuracy: 0.5850 - val_loss: 0.6792 - val_accuracy: 0.5775
# Epoch 33/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6644 - accuracy: 0.5859 - val_loss: 0.6801 - val_accuracy: 0.5738
# Epoch 34/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6644 - accuracy: 0.5841 - val_loss: 0.6810 - val_accuracy: 0.5755
# Epoch 35/500
# 710/710 [==============================] - 4s 6ms/step - loss: 0.6627 - accuracy: 0.5888 - val_loss: 0.6796 - val_accuracy: 0.5765
# Epoch 36/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6625 - accuracy: 0.5881 - val_loss: 0.6786 - val_accuracy: 0.5784
# Epoch 37/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6625 - accuracy: 0.5858 - val_loss: 0.6842 - val_accuracy: 0.5654
# Epoch 38/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6620 - accuracy: 0.5877 - val_loss: 0.6815 - val_accuracy: 0.5705
# Epoch 39/500
# 710/710 [==============================] - 4s 5ms/step - loss: 0.6612 - accuracy: 0.5880 - val_loss: 0.6831 - val_accuracy: 0.5706
# 345/345 [==============================] - 1s 2ms/step - loss: 0.6812 - accuracy: 0.5653
# 345/345 [==============================] - 1s 2ms/step
# Accuracy for iteration 2: 0.57
# Iteration 3
# Epoch 1/500
# 709/709 [==============================] - 6s 6ms/step - loss: 0.6897 - accuracy: 0.5426 - val_loss: 0.6784 - val_accuracy: 0.5739
# Epoch 2/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6849 - accuracy: 0.5547 - val_loss: 0.6820 - val_accuracy: 0.5717
# Epoch 3/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6841 - accuracy: 0.5566 - val_loss: 0.6824 - val_accuracy: 0.5774
# Epoch 4/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6829 - accuracy: 0.5588 - val_loss: 0.6784 - val_accuracy: 0.5818
# Epoch 5/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6827 - accuracy: 0.5619 - val_loss: 0.6812 - val_accuracy: 0.5677
# Epoch 6/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6818 - accuracy: 0.5627 - val_loss: 0.6803 - val_accuracy: 0.5753
# Epoch 7/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6813 - accuracy: 0.5646 - val_loss: 0.6811 - val_accuracy: 0.5827
# Epoch 8/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6810 - accuracy: 0.5652 - val_loss: 0.6804 - val_accuracy: 0.5754
# Epoch 9/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6809 - accuracy: 0.5651 - val_loss: 0.6815 - val_accuracy: 0.5699
# Epoch 10/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6803 - accuracy: 0.5661 - val_loss: 0.6800 - val_accuracy: 0.5782
# Epoch 11/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6797 - accuracy: 0.5688 - val_loss: 0.6807 - val_accuracy: 0.5683
# Epoch 12/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6796 - accuracy: 0.5688 - val_loss: 0.6799 - val_accuracy: 0.5846
# Epoch 13/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6790 - accuracy: 0.5705 - val_loss: 0.6827 - val_accuracy: 0.5731
# Epoch 14/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6783 - accuracy: 0.5721 - val_loss: 0.6833 - val_accuracy: 0.5715
# Epoch 15/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6783 - accuracy: 0.5712 - val_loss: 0.6776 - val_accuracy: 0.5769
# Epoch 16/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6775 - accuracy: 0.5733 - val_loss: 0.6775 - val_accuracy: 0.5773
# Epoch 17/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6766 - accuracy: 0.5759 - val_loss: 0.6790 - val_accuracy: 0.5738
# Epoch 18/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6767 - accuracy: 0.5752 - val_loss: 0.6809 - val_accuracy: 0.5752
# Epoch 19/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6762 - accuracy: 0.5769 - val_loss: 0.6798 - val_accuracy: 0.5800
# Epoch 20/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6757 - accuracy: 0.5780 - val_loss: 0.6824 - val_accuracy: 0.5788
# Epoch 21/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6759 - accuracy: 0.5779 - val_loss: 0.6769 - val_accuracy: 0.5784
# Epoch 22/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6755 - accuracy: 0.5776 - val_loss: 0.6806 - val_accuracy: 0.5759
# Epoch 23/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6763 - accuracy: 0.5749 - val_loss: 0.6793 - val_accuracy: 0.5819
# Epoch 24/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6746 - accuracy: 0.5803 - val_loss: 0.6829 - val_accuracy: 0.5583
# Epoch 25/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6751 - accuracy: 0.5785 - val_loss: 0.6773 - val_accuracy: 0.5800
# Epoch 26/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6741 - accuracy: 0.5805 - val_loss: 0.6771 - val_accuracy: 0.5819
# Epoch 27/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6735 - accuracy: 0.5813 - val_loss: 0.6786 - val_accuracy: 0.5760
# Epoch 28/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6733 - accuracy: 0.5818 - val_loss: 0.6815 - val_accuracy: 0.5652
# Epoch 29/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6739 - accuracy: 0.5797 - val_loss: 0.6793 - val_accuracy: 0.5706
# Epoch 30/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6733 - accuracy: 0.5815 - val_loss: 0.6811 - val_accuracy: 0.5643
# Epoch 31/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6730 - accuracy: 0.5817 - val_loss: 0.6826 - val_accuracy: 0.5652
# Epoch 32/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6730 - accuracy: 0.5829 - val_loss: 0.6835 - val_accuracy: 0.5570
# 343/343 [==============================] - 1s 2ms/step - loss: 0.6838 - accuracy: 0.5603
# 343/343 [==============================] - 1s 2ms/step
# Accuracy for iteration 3: 0.56
# Iteration 4
# Epoch 1/500
# 709/709 [==============================] - 5s 6ms/step - loss: 0.6900 - accuracy: 0.5394 - val_loss: 0.6842 - val_accuracy: 0.5548
# Epoch 2/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6840 - accuracy: 0.5517 - val_loss: 0.6814 - val_accuracy: 0.5651
# Epoch 3/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6821 - accuracy: 0.5560 - val_loss: 0.6825 - val_accuracy: 0.5616
# Epoch 4/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6812 - accuracy: 0.5570 - val_loss: 0.6811 - val_accuracy: 0.5612
# Epoch 5/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6806 - accuracy: 0.5575 - val_loss: 0.6811 - val_accuracy: 0.5601
# Epoch 6/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6795 - accuracy: 0.5568 - val_loss: 0.6819 - val_accuracy: 0.5564
# Epoch 7/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6788 - accuracy: 0.5595 - val_loss: 0.6817 - val_accuracy: 0.5605
# Epoch 8/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6776 - accuracy: 0.5603 - val_loss: 0.6814 - val_accuracy: 0.5658
# Epoch 9/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6772 - accuracy: 0.5635 - val_loss: 0.6817 - val_accuracy: 0.5593
# Epoch 10/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6763 - accuracy: 0.5668 - val_loss: 0.6815 - val_accuracy: 0.5657
# Epoch 11/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6765 - accuracy: 0.5658 - val_loss: 0.6822 - val_accuracy: 0.5585
# Epoch 12/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6752 - accuracy: 0.5666 - val_loss: 0.6823 - val_accuracy: 0.5628
# Epoch 13/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6741 - accuracy: 0.5682 - val_loss: 0.6816 - val_accuracy: 0.5591
# Epoch 14/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6737 - accuracy: 0.5701 - val_loss: 0.6820 - val_accuracy: 0.5552
# Epoch 15/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6730 - accuracy: 0.5710 - val_loss: 0.6824 - val_accuracy: 0.5660
# Epoch 16/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6725 - accuracy: 0.5702 - val_loss: 0.6820 - val_accuracy: 0.5640
# Epoch 17/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6719 - accuracy: 0.5712 - val_loss: 0.6815 - val_accuracy: 0.5618
# Epoch 18/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6715 - accuracy: 0.5716 - val_loss: 0.6808 - val_accuracy: 0.5647
# Epoch 19/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6705 - accuracy: 0.5743 - val_loss: 0.6805 - val_accuracy: 0.5624
# Epoch 20/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6704 - accuracy: 0.5726 - val_loss: 0.6808 - val_accuracy: 0.5667
# Epoch 21/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6699 - accuracy: 0.5753 - val_loss: 0.6803 - val_accuracy: 0.5644
# Epoch 22/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6683 - accuracy: 0.5749 - val_loss: 0.6809 - val_accuracy: 0.5634
# Epoch 23/500
# 709/709 [==============================] - 5s 7ms/step - loss: 0.6687 - accuracy: 0.5746 - val_loss: 0.6807 - val_accuracy: 0.5649
# Epoch 24/500
# 709/709 [==============================] - 6s 8ms/step - loss: 0.6676 - accuracy: 0.5747 - val_loss: 0.6819 - val_accuracy: 0.5623
# Epoch 25/500
# 709/709 [==============================] - 9s 13ms/step - loss: 0.6674 - accuracy: 0.5764 - val_loss: 0.6821 - val_accuracy: 0.5636
# Epoch 26/500
# 709/709 [==============================] - 6s 8ms/step - loss: 0.6667 - accuracy: 0.5753 - val_loss: 0.6819 - val_accuracy: 0.5625
# Epoch 27/500
# 709/709 [==============================] - 5s 7ms/step - loss: 0.6665 - accuracy: 0.5768 - val_loss: 0.6814 - val_accuracy: 0.5632
# Epoch 28/500
# 709/709 [==============================] - 5s 6ms/step - loss: 0.6661 - accuracy: 0.5763 - val_loss: 0.6828 - val_accuracy: 0.5649
# Epoch 29/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6652 - accuracy: 0.5787 - val_loss: 0.6820 - val_accuracy: 0.5690
# Epoch 30/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6632 - accuracy: 0.5810 - val_loss: 0.6830 - val_accuracy: 0.5580
# Epoch 31/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6639 - accuracy: 0.5783 - val_loss: 0.6811 - val_accuracy: 0.5633
# Epoch 32/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6634 - accuracy: 0.5798 - val_loss: 0.6830 - val_accuracy: 0.5653
# Epoch 33/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6627 - accuracy: 0.5799 - val_loss: 0.6830 - val_accuracy: 0.5618
# Epoch 34/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6614 - accuracy: 0.5822 - val_loss: 0.6826 - val_accuracy: 0.5644
# Epoch 35/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6606 - accuracy: 0.5835 - val_loss: 0.6834 - val_accuracy: 0.5612
# Epoch 36/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6612 - accuracy: 0.5823 - val_loss: 0.6829 - val_accuracy: 0.5665
# Epoch 37/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6592 - accuracy: 0.5839 - val_loss: 0.6837 - val_accuracy: 0.5614
# Epoch 38/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6593 - accuracy: 0.5813 - val_loss: 0.6846 - val_accuracy: 0.5566
# Epoch 39/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6590 - accuracy: 0.5837 - val_loss: 0.6837 - val_accuracy: 0.5614
# Epoch 40/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6585 - accuracy: 0.5835 - val_loss: 0.6851 - val_accuracy: 0.5633
# Epoch 41/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6580 - accuracy: 0.5836 - val_loss: 0.6856 - val_accuracy: 0.5613
# Epoch 42/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6590 - accuracy: 0.5831 - val_loss: 0.6855 - val_accuracy: 0.5610
# Epoch 43/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6570 - accuracy: 0.5819 - val_loss: 0.6889 - val_accuracy: 0.5617
# Epoch 44/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6567 - accuracy: 0.5833 - val_loss: 0.6876 - val_accuracy: 0.5608
# Epoch 45/500
# 709/709 [==============================] - 4s 6ms/step - loss: 0.6557 - accuracy: 0.5854 - val_loss: 0.6878 - val_accuracy: 0.5639
# Epoch 46/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6553 - accuracy: 0.5858 - val_loss: 0.6878 - val_accuracy: 0.5635
# Epoch 47/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6537 - accuracy: 0.5868 - val_loss: 0.6887 - val_accuracy: 0.5657
# Epoch 48/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6543 - accuracy: 0.5885 - val_loss: 0.6899 - val_accuracy: 0.5546
# Epoch 49/500
# 709/709 [==============================] - 4s 5ms/step - loss: 0.6528 - accuracy: 0.5889 - val_loss: 0.6898 - val_accuracy: 0.5622
# 354/354 [==============================] - 1s 2ms/step - loss: 0.6803 - accuracy: 0.5623
# 354/354 [==============================] - 1s 2ms/step
# Accuracy for iteration 4: 0.56
# Average Accuracy across 4 iterations: 0.56

# %%
# Alternatively, using numpy to generate bootstrap samples and calculate the percentiles
# Determine the size of the accuracies array
n = len(accuracies)
bootstrap_samples = np.random.choice(accuracies, (10000, n), replace=True)
ci_lower = np.percentile(bootstrap_samples, 2.5)
ci_upper = np.percentile(bootstrap_samples, 97.5)

print(f"Bootstrap 95% Confidence Interval: {ci_lower:.5f} - {ci_upper:.5f}")
# Out:
# Bootstrap 95% Confidence Interval: 0.56035 - 0.56531

# %%
from sklearn.metrics import confusion_matrix, classification_report
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

def evaluate_model(model, X_test, y_test, type_of_model):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test)
    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

    # Show plot
    plt.show()

    # Print the classification report
    print(clr)

# Example usage
evaluate_model(model_b, X_val, val_data['popularity'], 'LightGBM')
# Out:
# 350/350 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.58      0.52      0.55      5596
#         High       0.56      0.62      0.59      5596
#
#     accuracy                           0.57     11192
#    macro avg       0.57      0.57      0.57     11192
# weighted avg       0.57      0.57      0.57     11192

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report

def evaluate_model_and_error_rates(model, X_test, y_test):
    # Predicting the probabilities for the test set
    y_pred_prob = model.predict(X_test).flatten()

    # Convert probabilities to binary labels
    y_pred = (y_pred_prob > 0.5).astype(int)

    # y_test should already be binary labels
    y_true = y_test.astype(int)

    # Generating the confusion matrix
    cm = confusion_matrix(y_true, y_pred)

    # Generating the classification report
    clr = classification_report(y_true, y_pred, target_names=['Low', 'High'])

    # Plotting the confusion matrix
    plt.figure(figsize=(7, 5))
    sns.heatmap(cm, annot=True, fmt='d', cmap='viridis', xticklabels=['Low', 'High'], yticklabels=['Low', 'High'])
    plt.title('Confusion Matrix')
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

    # Print the classification report
    print(clr)

    # Calculate error rates by probability bins
    results = pd.DataFrame({
        'y_true': y_true,
        'y_pred_prob': y_pred_prob
    })

    results['prob_bin'] = pd.cut(results['y_pred_prob'], bins=np.arange(0, 1.1, 0.1), labels=np.arange(0.05, 1.05, 0.1))

    # Calculate error rates
    error_rates = results.groupby('prob_bin').apply(
        lambda x: np.mean(x['y_true'] != (x['y_pred_prob'] > 0.5))
    )

    # Plotting error rates by predicted probability bins
    plt.figure(figsize=(10, 6))
    error_rates.plot(kind='bar', color='skyblue')
    plt.title('Error Rates by Predicted Probability Bins')
    plt.xlabel('Predicted Probability Bins')
    plt.ylabel('Error Rate')
    plt.xticks(rotation=45)
    plt.grid(True)
    plt.show()

# Example usage
evaluate_model_and_error_rates(model_b, X_test, test_data['popularity'])
# Out:
# 354/354 [==============================] - 1s 2ms/step
#               precision    recall  f1-score   support
#
#          Low       0.57      0.50      0.53      5659
#         High       0.56      0.62      0.59      5659
#
#     accuracy                           0.56     11318
#    macro avg       0.56      0.56      0.56     11318
# weighted avg       0.56      0.56      0.56     11318
